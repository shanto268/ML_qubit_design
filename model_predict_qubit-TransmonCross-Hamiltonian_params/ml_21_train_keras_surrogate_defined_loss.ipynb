# %% [markdown]
# # Model Training (qubit-TransmonCross-Hamiltonian_params)
# ## Hamiltonian Parameters --> Qiskit Metal
#
# Inverse model with surrogate-defined loss for the Transmon Cross dataset.

# %% [markdown]
# Instead of training the inverse model to directly predict Qiskit Metal parameters and comparing
# against ground truth SQuADDS data (which penalizes valid alternative solutions), we chain the
# inverse model with a frozen surrogate and compute loss in Hamiltonian space.
#
# **Pipeline:** Hamiltonian_input -> Inverse MLP -> Qiskit_params -> ScalerConversion -> Surrogate(frozen) -> Hamiltonian_reconstructed
#
# **Loss:** MSE(Hamiltonian_input, Hamiltonian_reconstructed) + penalty for out-of-range predictions
#
# The Transmon Cross dataset has all continuous parameters,
# but the inverse model (ml_00/ml_01) and surrogate (ml_10/ml_11) use different scalers.
# A ScalerConversionLayer handles the transform between scalers.

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters_surrogate_defined_loss import *

if KERAS_TUNER == True:
    print("keras tuner is ON with {} trials".format(KERAS_TUNER_TRIALS))
else:
    print("keras tuner is OFF")
# Out:
# keras tuner is OFF

# %% [markdown]
# ## Library

# %%
import os, gc, joblib, json, time, sys, math, csv

# Disable some console warnings so you can be free of them printing. 
# Comment the next line if you want to see them
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import pandas as pd
from pandas import json_normalize
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Dropout, Input, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.python.client import device_lib

# %%
seed = 0

# Input seed value. If this value is the same, the random number generator 
# will generate the same set of random numbers. 
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Check GPU

# %%
# Look at what you are working with. If you dont have a nice GPU I highly reccomend finding one
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13165258431562682151
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 19046727680
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7408401522481850087
# physical_device_desc: "device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:00:11.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774889756.065465    4112 gpu_device.cc:2020] Created device /device:GPU:0 with 18164 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:00:11.0, compute capability: 8.0

# %%
# make sure something prints in the list. if it doesnt, run:
# import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install tensorflow[and-cuda]
gpus = tf.config.list_physical_devices('GPU')
print(f'GPUs available: {len(gpus)}')
for gpu in gpus:
    print(f'  {gpu}')
# Out:
# GPUs available: 1
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# check cuda
import sys
# !{sys.executable} -m pip list | egrep "tensorflow|nvidia-(cuda|cudnn|cublas|nccl)"
# Out:
# nvidia-cublas-cu12           12.9.1.4
# nvidia-cuda-cupti-cu12       12.9.79
# nvidia-cuda-nvcc-cu12        12.9.86
# nvidia-cuda-nvrtc-cu12       12.9.86
# nvidia-cuda-runtime-cu12     12.9.79
# nvidia-cudnn-cu12            9.19.0.56
# nvidia-nccl-cu12             2.29.3
# tensorflow                   2.20.0
# tensorflow-datasets          4.8.3+nightly
# tensorflow-estimator         2.11.0
# tensorflow-io-gcs-filesystem 0.37.1
# tensorflow-metadata          1.13.1

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
# Load the data saved from ml_00 notebook (inverse model format)
# For the transmon cross, ml_00 uses 'one_hot' encoding label but all params are continuous

# inputs are the Hamiltonian values (what we want to invert)
X_train = np.load(f'{DATA_DIR}/npy/x_train_one_hot_encoding_augmented.npy', allow_pickle=True)
X_val   = np.load(f'{DATA_DIR}/npy/x_val_one_hot_encoding_augmented.npy', allow_pickle=True)
X_test  = np.load(f'{DATA_DIR}/npy/x_test_one_hot_encoding_augmented.npy', allow_pickle=True)

# Qiskit Metal params (all continuous for transmon cross)
y_train = np.load(f'{DATA_DIR}/npy/y_train_one_hot_encoding_augmented.npy', allow_pickle=True)
y_val   = np.load(f'{DATA_DIR}/npy/y_val_one_hot_encoding_augmented.npy', allow_pickle=True)
y_test  = np.load(f'{DATA_DIR}/npy/y_test_one_hot_encoding_augmented.npy', allow_pickle=True)

# column names
with open('X_names', 'r') as f:
    Hamiltonian_column_names = f.read().splitlines()

qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()

print(f'Inputs (Hamiltonian):     {X_train.shape[1]} columns')
print(f'Outputs (Qiskit params):  {y_train.shape[1]} columns')
print(f'Training samples: {len(X_train)}')
print(f'\nHamiltonian columns: {Hamiltonian_column_names}')
print(f'Qiskit param columns: {qiskit_param_names}')
# Out:
# Inputs (Hamiltonian):     2 columns
# Outputs (Qiskit params):  3 columns
# Training samples: 1353
#
# Hamiltonian columns: ['qubit_frequency_GHz', 'anharmonicity_MHz']
# Qiskit param columns: ['design_options.connection_pads.readout.claw_length', 'design_options.connection_pads.readout.ground_spacing', 'design_options.cross_length']

# %%
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')
X_val   = X_val.astype('float32')
y_val   = y_val.astype('float32')
X_test  = X_test.astype('float32')
y_test  = y_test.astype('float32')

# %% [markdown]
# ### Visualize

# %%
print('X_train.shape: ', X_train.shape)
print('X_val.shape:   ', X_val.shape)
print('y_train.shape: ', y_train.shape)
print('y_val.shape:   ', y_val.shape)
print('y_train[0]: ', y_train[0])
# Out:
# X_train.shape:  (1353, 2)
# X_val.shape:    (290, 2)
# y_train.shape:  (1353, 3)
# y_val.shape:    (290, 3)
# y_train[0]:  [0.18181819 0.         0.8484849 ]

# %%
display(X_train)
display(y_train)
# Out:
# array([[0.07120386, 0.96058077],
#        [0.02208401, 0.98819655],
#        [0.19025461, 0.885589  ],
#        ...,
#        [0.03279327, 0.98233676],
#        [0.6696863 , 0.4527291 ],
#        [0.01136153, 0.99397445]], dtype=float32)
# array([[0.18181819, 0.        , 0.8484849 ],
#        [0.06060606, 1.        , 0.93939394],
#        [0.03030303, 0.84745765, 0.57575756],
#        ...,
#        [0.6363636 , 0.        , 0.90909094],
#        [0.12121212, 0.84745765, 0.12121212],
#        [0.21212122, 0.        , 0.969697  ]], dtype=float32)

# %%
# Look at how it was split and decide if we like the split (we do for now)
total = len(X_train) + len(X_test) + len(X_val)
print(f'train: {len(X_train)} ({len(X_train)/total*100:.1f}%)')
print(f'val:   {len(X_val)} ({len(X_val)/total*100:.1f}%)')
print(f'test:  {len(X_test)} ({len(X_test)/total*100:.1f}%)')
print(f'total: {total}')
# Out:
# train: 1353 (70.0%)
# val:   290 (15.0%)
# test:  291 (15.0%)
# total: 1934

# %%
# Bin the input data (Hamiltonian parameter values) and look at distribution

num_cols = X_train.shape[1]
num_rows = math.ceil(num_cols / 3)

fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
axes = axes.ravel()
for i in range(num_cols):
    axes[i].hist(X_train[:, i], bins=30, edgecolor='black', alpha=0.7)
    axes[i].set_title(Hamiltonian_column_names[i] if i < len(Hamiltonian_column_names) else f'col_{i}')
for j in range(num_cols, len(axes)):
    fig.delaxes(axes[j])
plt.suptitle('Input distribution (Hamiltonian, scaled)')
plt.tight_layout()
plt.show()

# %%
steps_per_epoch = int(np.ceil(len(X_train) / TRAIN_BATCH_SIZE))
LR_DECAY_STEPS = steps_per_epoch * 20   # decay every ~20 epochs
print(f'Steps per epoch: {steps_per_epoch}, LR decay steps: {LR_DECAY_STEPS}')
# Out:
# Steps per epoch: 11, LR decay steps: 220

# %% [markdown]
# ## MLP

# %% [markdown]
# ### Create model

# %% [markdown]
# Reccomended to download a third party app like "Sleep control Center" or "Amphetamine" to prevent computer from sleeping during training

# %% [markdown]
# ### Make scaler conversion layer
#
# The inverse model (ml_00/ml_01) and surrogate model (ml_10/ml_11) may use different MinMaxScalers
# because they were fit on different data splits or processing pipelines.
# This layer does the affine transform: `linear_scaled = oh_scaled * scale_a + scale_b`
# to convert between the two scaler spaces. All operations are differentiable.

# %%
# Determine column mapping between inverse model output and surrogate input
# The inverse model outputs Qiskit params in ml_00 scaler space
# The surrogate expects them in ml_10 scaler space

n_qiskit_params = y_train.shape[1]
print(f'Number of Qiskit Metal params: {n_qiskit_params}')
print(f'Param names: {qiskit_param_names}')
# Out:
# Number of Qiskit Metal params: 3
# Param names: ['design_options.connection_pads.readout.claw_length', 'design_options.connection_pads.readout.ground_spacing', 'design_options.cross_length']

# %%
# Compute affine conversion constants between ml_00 and ml_10 scaler spaces
# For each param: linear_scaled = oh_scaled * scale_a + scale_b
# where scale_a = oh_range / lin_range, scale_b = (oh_min - lin_min) / lin_range

scale_a = np.ones(n_qiskit_params, dtype=np.float32)
scale_b = np.zeros(n_qiskit_params, dtype=np.float32)

for i, col in enumerate(qiskit_param_names):
    # Try loading both scalers
    oh_path = f'scalers/scaler_y_{col}_one_hot_encoding.save'
    lin_path = f'scalers/scaler_y_linear_{col}.save'
    
    if os.path.exists(oh_path) and os.path.exists(lin_path):
        oh_sc  = joblib.load(oh_path)
        lin_sc = joblib.load(lin_path)
        oh_min, oh_range   = float(oh_sc.data_min_[0]), float(oh_sc.data_range_[0])
        lin_min, lin_range = float(lin_sc.data_min_[0]), float(lin_sc.data_range_[0])
        scale_a[i] = oh_range / lin_range
        scale_b[i] = (oh_min - lin_min) / lin_range
        print(f'  {col}: a={scale_a[i]:.6f}, b={scale_b[i]:.6f}')
    else:
        print(f'  {col}: using identity (missing scaler file)')

if np.allclose(scale_a, 1.0) and np.allclose(scale_b, 0.0):
    print('\nScalers are identical — conversion is identity (no transform needed)')
else:
    print('\nScalers differ — affine conversion will be applied')
# Out:
#   design_options.connection_pads.readout.claw_length: a=1.000000, b=0.000000
#   design_options.connection_pads.readout.ground_spacing: a=1.000000, b=0.000000
#   design_options.cross_length: a=1.000000, b=0.000000
#
# Scalers are identical — conversion is identity (no transform needed)

# %%
# Load and freeze the surrogate model so its not updated during training
SURROGATE_PATH = 'model/best_keras_model_model2_surrogate.keras'
surrogate = load_model(SURROGATE_PATH, compile=False)

#freeze it
surrogate.trainable = False
for layer in surrogate.layers:
    layer.trainable = False

surr_input_dim = surrogate.input_shape[-1]
print(f'\nSurrogate loaded from {SURROGATE_PATH}')
print(f'Surrogate expects {surr_input_dim} inputs, inverse model outputs {n_qiskit_params}')
assert surr_input_dim == n_qiskit_params, f'Dimension mismatch!'
surrogate.summary()
# Out:
# I0000 00:00:1774889782.802494    4112 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18164 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:00:11.0, compute capability: 8.0
# Surrogate loaded from model/best_keras_model_model2_surrogate.keras
# Surrogate expects 3 inputs, inverse model outputs 3
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 736)            │         2,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 736)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 736)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │         1,474 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,418 (17.26 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 4,418 (17.26 KB)

# %%
# Build the scaler conversion layer
# Converts inverse model output (ml_00 scaler space) to surrogate input (ml_10 scaler space)
# All operations are differentiable so gradients flow through

class ScalerConversionLayer(tf.keras.layers.Layer):
    def __init__(self, scale_a, scale_b, **kwargs):
        kwargs.setdefault('trainable', False)
        super().__init__(**kwargs)
        self._scale_a = tf.constant(scale_a, dtype=tf.float32)
        self._scale_b = tf.constant(scale_b, dtype=tf.float32)
        self._cfg = dict(
            scale_a=list(scale_a) if hasattr(scale_a, '__iter__') else scale_a,
            scale_b=list(scale_b) if hasattr(scale_b, '__iter__') else scale_b)

    def call(self, inputs):
        a = tf.cast(self._scale_a, inputs.dtype)
        b = tf.cast(self._scale_b, inputs.dtype)
        return inputs * a + b

    def get_config(self):
        config = super().get_config()
        config.update(self._cfg)
        return config

scaler_converter = ScalerConversionLayer(
    scale_a=scale_a, scale_b=scale_b, name='scaler_conversion')

# Quick sanity test
test_input = tf.constant(y_train[:3])
test_output = scaler_converter(test_input)
print(f'Conversion test: input shape {test_input.shape} → output shape {test_output.shape}')
# Out:
# Conversion test: input shape (3, 3) → output shape (3, 3)

# %%
# Penalizes the inverse model for predicting Qiskit Metal values outside
# the training data range [0, 1] (since data is MinMaxScaled).
# This prevents the model from finding "adversarial" inputs to the surrogate
# that look good in Hamiltonian parameter space but don't correspond to real designs.

PENALTY_WEIGHT = 0.1  # tune this: increase if params are still wild, decrease if reconstruction suffers

def qiskit_range_penalty(y_true_dummy, y_pred):
    """Penalize predictions outside [0, 1] range.
    y_true_dummy is ignored (we pass zeros as dummy targets).
    y_pred is the inverse model's raw output in scaled space."""
    below = tf.nn.relu(-y_pred)
    above = tf.nn.relu(y_pred - 1.0)
    return tf.reduce_mean(below ** 2 + above ** 2)

# Pre-build dummy targets for training
dummy_y_train = np.zeros_like(y_train)
dummy_y_val   = np.zeros_like(y_val)
dummy_y_test  = np.zeros_like(y_test)

print(f'Penalty weight: {PENALTY_WEIGHT}')
print(f'Dummy targets shape: {dummy_y_train.shape}')
# Out:
# Penalty weight: 0.1
# Dummy targets shape: (1353, 3)

# %% [markdown]
# ### Create Model by Hand

# %%
# just checkin to make sure everything looks good still, we want float32
print(X_train.dtype, X_train.shape)
print(y_train.dtype, y_train.shape)
# Out:
# float32 (1353, 2)
# float32 (1353, 3)

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    # Model shape string for file naming
    model_shape = f'surrogate_loss_{X_train.shape[1]}in_{y_train.shape[1]}out'
    print(model_shape)
# Out:
# surrogate_loss_2in_3out

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    # Build inverse model that takes Hamiltonian --> Qiskit Metal params
    inverse_model = Sequential(name='inverse_model')
    inverse_model.add(Input(shape=(X_train.shape[1],), name='Hamiltonian_input'))
    
    for i, n in enumerate(NEURONS_PER_LAYER):
        inverse_model.add(Dense(n, name='fc{}'.format(i),
                        kernel_initializer='lecun_uniform',
                        kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
        inverse_model.add(LeakyReLU(negative_slope=0.01, name='leaky_relu{}'.format(i)))
        inverse_model.add(Dropout(rate=TRAIN_DROPOUT_RATE, name='dropout{}'.format(i)))
    
    # output layer predicts Qiskit Metal params
    inverse_model.add(Dense(y_train.shape[1], activation='linear', name='qiskit_output',
                    kernel_initializer='lecun_uniform'))
    
    # Two-output combined model:
    # Output 1: reconstructed Hamiltonian (through frozen surrogate) — main loss
    # Output 2: raw Qiskit params — range penalty loss
    combined_input = Input(shape=(X_train.shape[1],), name='combined_input')
    predicted_qiskit = inverse_model(combined_input)
    predicted_qiskit_converted = scaler_converter(predicted_qiskit)  # affine conversion
    reconstructed_Hamiltonian = surrogate(predicted_qiskit_converted)
    model = Model(
        inputs=combined_input,
        outputs=[reconstructed_Hamiltonian, predicted_qiskit],
        name='combined_model'
    )
    
    print('Inverse model (outputs Qiskit Metal params):')
    inverse_model.summary()
    print('\nCombined model (two outputs: Hamiltonian reconstruction + Qiskit params for penalty):')
    model.summary()
# Out:
# Inverse model (outputs Qiskit Metal params):
# Model: "inverse_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 64)             │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu1 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu2 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu3 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout3 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc4 (Dense)                     │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu4 (LeakyReLU)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout4 (Dropout)              │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ qiskit_output (Dense)           │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,027 (66.51 KB)
#  Trainable params: 17,027 (66.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Combined model (two outputs: Hamiltonian reconstruction + Qiskit params for penalty):
# Model: "combined_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ combined_input (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inverse_model (Sequential)      │ (None, 3)              │        17,027 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaler_conversion               │ (None, 3)              │             0 │
# │ (ScalerConversionLayer)         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 2)              │         4,418 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,445 (83.77 KB)
#  Trainable params: 17,027 (66.51 KB)
#  Non-trainable params: 4,418 (17.26 KB)

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=LR_INITIAL,  
        decay_steps=LR_DECAY_STEPS,        
        decay_rate=LR_DECAY_RATE,          
        staircase=LR_STAIRCASE             
    )
    
    # Two losses: reconstruction + range penalty on Qiskit params
    model.compile(
        optimizer=tf.optimizers.Adam(learning_rate=lr_schedule),  
        loss=[TRAIN_LOSS, qiskit_range_penalty],
        loss_weights=[1.0, PENALTY_WEIGHT],
        metrics={model.output_names[0]: [TRAIN_LOSS]}
    )

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    # !mkdir -p model
    best_model_file = 'model/{}_best_model.keras'.format(model_shape)
    last_model_file = 'model/{}_last_model.keras'.format(model_shape)
    print('Best model will be saved to:', best_model_file)
# Out:
# Best model will be saved to: model/surrogate_loss_2in_3out_best_model.keras

# %% [markdown]
# Enable training (`train_and_save`) to overwrite the model file.

# %%
train_and_save = True

# %% [markdown]
# We use Adam optimizer, minimize the loss specified in parameters, and early stop.

# %% [markdown]
# #### Training

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    class TrainingPlot(tf.keras.callbacks.Callback):
        def on_train_begin(self, logs=None):
            self.losses = []
            self.val_losses = []
        def on_epoch_end(self, epoch, logs=None):
            self.losses.append(logs.get('loss'))
            self.val_losses.append(logs.get('val_loss'))

    class LearningRateMonitor(tf.keras.callbacks.Callback):
        def on_train_begin(self, logs=None):
            self.learning_rates = []
        def on_epoch_end(self, epoch, logs=None):
            lr = self.model.optimizer.learning_rate
            if callable(lr):
                lr = lr(self.model.optimizer.iterations)
            self.learning_rates.append(float(tf.keras.backend.get_value(lr)))

# %%
# %%time

# Train the model — two targets:
# 1. Hamiltonian reconstruction (input Hamiltonian is the target)
# 2. Dummy zeros for the penalty loss (penalty only uses predictions, ignores target)
history = None  
if not KERAS_TUNER and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    if train_and_save: 
        early_stopping = EarlyStopping(
            monitor='val_loss',
            mode='min',
            patience=TRAIN_EARLY_STOPPING_PATIENCE,
            verbose=1
        )
    
        plot_callback = TrainingPlot()
        lr_monitor = LearningRateMonitor()
        
        model_checkpoint = ModelCheckpoint(
            filepath=best_model_file,          
            monitor='val_loss',
            mode='min',
            save_best_only=True,
            verbose=0
        )

        history = model.fit(
            np.asarray(X_train),
            [np.asarray(X_train), dummy_y_train],
            epochs=400,                   
            batch_size=TRAIN_BATCH_SIZE,  
            validation_data=(np.asarray(X_val), [np.asarray(X_val), dummy_y_val]),  
            callbacks=[early_stopping, model_checkpoint, plot_callback, lr_monitor],  
            verbose=1
        )
        
        model.save(last_model_file)
# Out:
# Epoch 1/400
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - inverse_model_loss: 7.2283e-04 - loss: 0.9687 - sequential_loss: 0.9365 - sequential_mae: 0.9365
# I0000 00:00:1774889801.521039    4727 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 631ms/step - inverse_model_loss: 7.8592e-05 - loss: 0.4694 - sequential_loss: 0.4255 - sequential_mae: 0.4376 - val_inverse_model_loss: 3.5034e-06 - val_loss: 0.1342 - val_sequential_loss: 0.1096 - val_sequential_mae: 0.1029
# Epoch 2/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 5.3958e-07 - loss: 0.1280 - sequential_loss: 0.0973 - sequential_mae: 0.0970 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.1133 - val_sequential_loss: 0.0864 - val_sequential_mae: 0.0828
# Epoch 3/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0932 - sequential_loss: 0.0616 - sequential_mae: 0.0631 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0552 - val_sequential_loss: 0.0245 - val_sequential_mae: 0.0255
# Epoch 4/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0575 - sequential_loss: 0.0278 - sequential_mae: 0.0282 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0442 - val_sequential_loss: 0.0155 - val_sequential_mae: 0.0154
# Epoch 5/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 2.8553e-08 - loss: 0.0420 - sequential_loss: 0.0134 - sequential_mae: 0.0135 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0358 - val_sequential_loss: 0.0080 - val_sequential_mae: 0.0077
# Epoch 6/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 9.8376e-09 - loss: 0.0334 - sequential_loss: 0.0056 - sequential_mae: 0.0056 - val_inverse_model_loss: 9.4977e-08 - val_loss: 0.0321 - val_sequential_loss: 0.0051 - val_sequential_mae: 0.0047
# Epoch 7/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.0038e-07 - loss: 0.0314 - sequential_loss: 0.0043 - sequential_mae: 0.0043 - val_inverse_model_loss: 2.3790e-08 - val_loss: 0.0334 - val_sequential_loss: 0.0069 - val_sequential_mae: 0.0067
# Epoch 8/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.3165e-09 - loss: 0.0327 - sequential_loss: 0.0061 - sequential_mae: 0.0063 - val_inverse_model_loss: 4.6820e-08 - val_loss: 0.0381 - val_sequential_loss: 0.0117 - val_sequential_mae: 0.0120
# Epoch 9/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 8.7580e-08 - loss: 0.0333 - sequential_loss: 0.0074 - sequential_mae: 0.0075 - val_inverse_model_loss: 3.8205e-08 - val_loss: 0.0278 - val_sequential_loss: 0.0024 - val_sequential_mae: 0.0023
# Epoch 10/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 2.1102e-08 - loss: 0.0295 - sequential_loss: 0.0043 - sequential_mae: 0.0042 - val_inverse_model_loss: 7.4899e-08 - val_loss: 0.0269 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0019
# Epoch 11/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.5514e-08 - loss: 0.0286 - sequential_loss: 0.0039 - sequential_mae: 0.0038 - val_inverse_model_loss: 4.8515e-08 - val_loss: 0.0277 - val_sequential_loss: 0.0032 - val_sequential_mae: 0.0032
# Epoch 12/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.5856e-08 - loss: 0.0303 - sequential_loss: 0.0060 - sequential_mae: 0.0060 - val_inverse_model_loss: 1.1527e-08 - val_loss: 0.0345 - val_sequential_loss: 0.0107 - val_sequential_mae: 0.0105
# Epoch 13/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.2713e-08 - loss: 0.0321 - sequential_loss: 0.0080 - sequential_mae: 0.0082 - val_inverse_model_loss: 5.7548e-08 - val_loss: 0.0279 - val_sequential_loss: 0.0043 - val_sequential_mae: 0.0043
# Epoch 14/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 2.3909e-08 - loss: 0.0261 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 9.0403e-08 - val_loss: 0.0256 - val_sequential_loss: 0.0025 - val_sequential_mae: 0.0024
# Epoch 15/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.0651e-08 - loss: 0.0259 - sequential_loss: 0.0028 - sequential_mae: 0.0029 - val_inverse_model_loss: 3.7144e-09 - val_loss: 0.0258 - val_sequential_loss: 0.0031 - val_sequential_mae: 0.0030
# Epoch 16/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.2895e-08 - loss: 0.0258 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 4.2952e-08 - val_loss: 0.0260 - val_sequential_loss: 0.0038 - val_sequential_mae: 0.0036
# Epoch 17/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 2.2649e-08 - loss: 0.0255 - sequential_loss: 0.0032 - sequential_mae: 0.0033 - val_inverse_model_loss: 4.8244e-08 - val_loss: 0.0242 - val_sequential_loss: 0.0021 - val_sequential_mae: 0.0021
# Epoch 18/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.2189e-07 - loss: 0.0254 - sequential_loss: 0.0034 - sequential_mae: 0.0034 - val_inverse_model_loss: 1.0652e-07 - val_loss: 0.0272 - val_sequential_loss: 0.0055 - val_sequential_mae: 0.0055
# Epoch 19/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.0619e-08 - loss: 0.0266 - sequential_loss: 0.0049 - sequential_mae: 0.0050 - val_inverse_model_loss: 2.3168e-08 - val_loss: 0.0281 - val_sequential_loss: 0.0068 - val_sequential_mae: 0.0067
# Epoch 20/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.0645e-07 - loss: 0.0269 - sequential_loss: 0.0055 - sequential_mae: 0.0056 - val_inverse_model_loss: 6.6504e-08 - val_loss: 0.0271 - val_sequential_loss: 0.0061 - val_sequential_mae: 0.0060
# Epoch 21/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 8.2981e-08 - loss: 0.0254 - sequential_loss: 0.0045 - sequential_mae: 0.0044 - val_inverse_model_loss: 1.1341e-07 - val_loss: 0.0247 - val_sequential_loss: 0.0037 - val_sequential_mae: 0.0038
# Epoch 22/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 1.0425e-07 - loss: 0.0242 - sequential_loss: 0.0034 - sequential_mae: 0.0035 - val_inverse_model_loss: 7.4299e-09 - val_loss: 0.0228 - val_sequential_loss: 0.0022 - val_sequential_mae: 0.0022
# Epoch 23/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 4.2925e-08 - loss: 0.0234 - sequential_loss: 0.0031 - sequential_mae: 0.0029 - val_inverse_model_loss: 2.0556e-08 - val_loss: 0.0281 - val_sequential_loss: 0.0077 - val_sequential_mae: 0.0078
# Epoch 24/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.8697e-08 - loss: 0.0247 - sequential_loss: 0.0046 - sequential_mae: 0.0045 - val_inverse_model_loss: 1.2236e-08 - val_loss: 0.0258 - val_sequential_loss: 0.0058 - val_sequential_mae: 0.0057
# Epoch 25/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.2402e-08 - loss: 0.0244 - sequential_loss: 0.0044 - sequential_mae: 0.0044 - val_inverse_model_loss: 4.1454e-09 - val_loss: 0.0234 - val_sequential_loss: 0.0038 - val_sequential_mae: 0.0036
# Epoch 26/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.4266e-09 - loss: 0.0258 - sequential_loss: 0.0062 - sequential_mae: 0.0061 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0320 - val_sequential_loss: 0.0124 - val_sequential_mae: 0.0123
# Epoch 27/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0268 - sequential_loss: 0.0072 - sequential_mae: 0.0072 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0268 - val_sequential_loss: 0.0073 - val_sequential_mae: 0.0073
# Epoch 28/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0267 - sequential_loss: 0.0074 - sequential_mae: 0.0074 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0294 - val_sequential_loss: 0.0103 - val_sequential_mae: 0.0102
# Epoch 29/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.1192e-09 - loss: 0.0278 - sequential_loss: 0.0088 - sequential_mae: 0.0086 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0272 - val_sequential_loss: 0.0085 - val_sequential_mae: 0.0082
# Epoch 30/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.8592e-11 - loss: 0.0250 - sequential_loss: 0.0062 - sequential_mae: 0.0061 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0288 - val_sequential_loss: 0.0102 - val_sequential_mae: 0.0100
# Epoch 31/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0255 - sequential_loss: 0.0065 - sequential_mae: 0.0067 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0245 - val_sequential_loss: 0.0059 - val_sequential_mae: 0.0059
# Epoch 32/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0219 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0199 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0015
# Epoch 33/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0221 - sequential_loss: 0.0038 - sequential_mae: 0.0037 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0204 - val_sequential_loss: 0.0022 - val_sequential_mae: 0.0021
# Epoch 34/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0215 - sequential_loss: 0.0032 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0217 - val_sequential_loss: 0.0036 - val_sequential_mae: 0.0036
# Epoch 35/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0213 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0222 - val_sequential_loss: 0.0042 - val_sequential_mae: 0.0042
# Epoch 36/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0216 - sequential_loss: 0.0037 - sequential_mae: 0.0037 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0211 - val_sequential_loss: 0.0032 - val_sequential_mae: 0.0033
# Epoch 37/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0213 - sequential_loss: 0.0036 - sequential_mae: 0.0036 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0205 - val_sequential_loss: 0.0029 - val_sequential_mae: 0.0028
# Epoch 38/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0208 - sequential_loss: 0.0033 - sequential_mae: 0.0032 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0228 - val_sequential_loss: 0.0052 - val_sequential_mae: 0.0052
# Epoch 39/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0207 - sequential_loss: 0.0034 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0191 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0017
# Epoch 40/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0207 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0190 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0018
# Epoch 41/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0193 - sequential_loss: 0.0020 - sequential_mae: 0.0021 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0186 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0015
# Epoch 42/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0188 - sequential_loss: 0.0018 - sequential_mae: 0.0018 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0179 - val_sequential_loss: 9.2292e-04 - val_sequential_mae: 9.4849e-04
# Epoch 43/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0187 - sequential_loss: 0.0018 - sequential_mae: 0.0018 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0181 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0013
# Epoch 44/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0185 - sequential_loss: 0.0017 - sequential_mae: 0.0017 - val_inverse_model_loss: 1.5063e-10 - val_loss: 0.0191 - val_sequential_loss: 0.0023 - val_sequential_mae: 0.0023
# Epoch 45/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 1.2916e-10 - loss: 0.0195 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0201 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0034
# Epoch 46/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0198 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 8.8651e-11 - val_loss: 0.0196 - val_sequential_loss: 0.0031 - val_sequential_mae: 0.0031
# Epoch 47/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.6738e-13 - loss: 0.0198 - sequential_loss: 0.0034 - sequential_mae: 0.0034 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0216 - val_sequential_loss: 0.0052 - val_sequential_mae: 0.0052
# Epoch 48/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0200 - sequential_loss: 0.0036 - sequential_mae: 0.0036 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0211 - val_sequential_loss: 0.0047 - val_sequential_mae: 0.0048
# Epoch 49/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0187 - sequential_loss: 0.0026 - sequential_mae: 0.0025 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0212 - val_sequential_loss: 0.0050 - val_sequential_mae: 0.0050
# Epoch 50/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0221 - sequential_loss: 0.0058 - sequential_mae: 0.0060 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0233 - val_sequential_loss: 0.0071 - val_sequential_mae: 0.0072
# Epoch 51/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0190 - sequential_loss: 0.0029 - sequential_mae: 0.0030 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0174 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0014
# Epoch 52/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0175 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0179 - val_sequential_loss: 0.0020 - val_sequential_mae: 0.0020
# Epoch 53/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.0488e-09 - loss: 0.0185 - sequential_loss: 0.0027 - sequential_mae: 0.0026 - val_inverse_model_loss: 2.3311e-09 - val_loss: 0.0199 - val_sequential_loss: 0.0040 - val_sequential_mae: 0.0041
# Epoch 54/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 8.0236e-11 - loss: 0.0194 - sequential_loss: 0.0036 - sequential_mae: 0.0036 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0192 - val_sequential_loss: 0.0035 - val_sequential_mae: 0.0035
# Epoch 55/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0176 - sequential_loss: 0.0020 - sequential_mae: 0.0020 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0176 - val_sequential_loss: 0.0021 - val_sequential_mae: 0.0020
# Epoch 56/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0180 - sequential_loss: 0.0025 - sequential_mae: 0.0025 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0179 - val_sequential_loss: 0.0024 - val_sequential_mae: 0.0024
# Epoch 57/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0190 - sequential_loss: 0.0036 - sequential_mae: 0.0035 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0169 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0015
# Epoch 58/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0198 - sequential_loss: 0.0044 - sequential_mae: 0.0044 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0207 - val_sequential_loss: 0.0056 - val_sequential_mae: 0.0054
# Epoch 59/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0202 - sequential_loss: 0.0048 - sequential_mae: 0.0049 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0221 - val_sequential_loss: 0.0069 - val_sequential_mae: 0.0068
# Epoch 60/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0215 - sequential_loss: 0.0062 - sequential_mae: 0.0063 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0165 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0013
# Epoch 61/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0184 - sequential_loss: 0.0032 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0193 - val_sequential_loss: 0.0043 - val_sequential_mae: 0.0042
# Epoch 62/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0183 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0170 - val_sequential_loss: 0.0020 - val_sequential_mae: 0.0020
# Epoch 63/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.9667e-12 - loss: 0.0179 - sequential_loss: 0.0029 - sequential_mae: 0.0030 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0192 - val_sequential_loss: 0.0043 - val_sequential_mae: 0.0043
# Epoch 64/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0178 - sequential_loss: 0.0029 - sequential_mae: 0.0029 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0162 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0014
# Epoch 65/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0176 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0183 - val_sequential_loss: 0.0035 - val_sequential_mae: 0.0035
# Epoch 66/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 8.8206e-09 - loss: 0.0176 - sequential_loss: 0.0029 - sequential_mae: 0.0029 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0176 - val_sequential_loss: 0.0028 - val_sequential_mae: 0.0028
# Epoch 67/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 7.6302e-10 - loss: 0.0178 - sequential_loss: 0.0031 - sequential_mae: 0.0031 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0179 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0033
# Epoch 68/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 0.0000e+00 - loss: 0.0179 - sequential_loss: 0.0032 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0196 - val_sequential_loss: 0.0050 - val_sequential_mae: 0.0050
# Epoch 69/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.1814e-09 - loss: 0.0183 - sequential_loss: 0.0038 - sequential_mae: 0.0038 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0180 - val_sequential_loss: 0.0035 - val_sequential_mae: 0.0035
# Epoch 70/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 3.1699e-09 - loss: 0.0174 - sequential_loss: 0.0030 - sequential_mae: 0.0030 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0178 - val_sequential_loss: 0.0035 - val_sequential_mae: 0.0034
# Epoch 71/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 1.1518e-09 - loss: 0.0177 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0161 - val_sequential_loss: 0.0018 - val_sequential_mae: 0.0018
# Epoch 72/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.2704e-09 - loss: 0.0175 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0162 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0019
# Epoch 73/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 2.5044e-09 - loss: 0.0169 - sequential_loss: 0.0026 - sequential_mae: 0.0026 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0153 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 74/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 9.8099e-09 - loss: 0.0181 - sequential_loss: 0.0042 - sequential_mae: 0.0039 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0220 - val_sequential_loss: 0.0078 - val_sequential_mae: 0.0078
# Epoch 75/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.7587e-09 - loss: 0.0200 - sequential_loss: 0.0058 - sequential_mae: 0.0058 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0196 - val_sequential_loss: 0.0053 - val_sequential_mae: 0.0055
# Epoch 76/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.3613e-09 - loss: 0.0189 - sequential_loss: 0.0047 - sequential_mae: 0.0048 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0182 - val_sequential_loss: 0.0041 - val_sequential_mae: 0.0041
# Epoch 77/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.2495e-08 - loss: 0.0175 - sequential_loss: 0.0034 - sequential_mae: 0.0034 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0168 - val_sequential_loss: 0.0029 - val_sequential_mae: 0.0028
# Epoch 78/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.3703e-08 - loss: 0.0168 - sequential_loss: 0.0028 - sequential_mae: 0.0029 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0157 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0018
# Epoch 79/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 1.3405e-08 - loss: 0.0152 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0150 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 80/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 3.4792e-08 - loss: 0.0153 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0148 - val_sequential_loss: 9.4139e-04 - val_sequential_mae: 9.6734e-04
# Epoch 81/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.6838e-08 - loss: 0.0154 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 1.2218e-08 - val_loss: 0.0157 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0019
# Epoch 82/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.9950e-08 - loss: 0.0154 - sequential_loss: 0.0017 - sequential_mae: 0.0016 - val_inverse_model_loss: 1.5448e-07 - val_loss: 0.0153 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0016
# Epoch 83/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 8.8983e-08 - loss: 0.0152 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 6.9169e-09 - val_loss: 0.0150 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0013
# Epoch 84/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 9.4040e-08 - loss: 0.0149 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 5.6933e-08 - val_loss: 0.0146 - val_sequential_loss: 9.3990e-04 - val_sequential_mae: 9.6439e-04
# Epoch 85/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.2701e-07 - loss: 0.0150 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 1.1655e-07 - val_loss: 0.0147 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 86/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.5132e-07 - loss: 0.0146 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 1.1861e-07 - val_loss: 0.0153 - val_sequential_loss: 0.0018 - val_sequential_mae: 0.0018
# Epoch 87/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.7230e-07 - loss: 0.0152 - sequential_loss: 0.0017 - sequential_mae: 0.0017 - val_inverse_model_loss: 1.4060e-07 - val_loss: 0.0151 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0016
# Epoch 88/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.6717e-07 - loss: 0.0163 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 1.9898e-07 - val_loss: 0.0195 - val_sequential_loss: 0.0061 - val_sequential_mae: 0.0061
# Epoch 89/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 9.7472e-08 - loss: 0.0193 - sequential_loss: 0.0060 - sequential_mae: 0.0059 - val_inverse_model_loss: 1.7296e-07 - val_loss: 0.0201 - val_sequential_loss: 0.0068 - val_sequential_mae: 0.0067
# Epoch 90/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.5336e-07 - loss: 0.0203 - sequential_loss: 0.0070 - sequential_mae: 0.0070 - val_inverse_model_loss: 4.0247e-07 - val_loss: 0.0167 - val_sequential_loss: 0.0035 - val_sequential_mae: 0.0034
# Epoch 91/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.3420e-07 - loss: 0.0175 - sequential_loss: 0.0042 - sequential_mae: 0.0042 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0160 - val_sequential_loss: 0.0030 - val_sequential_mae: 0.0028
# Epoch 92/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.1223e-08 - loss: 0.0178 - sequential_loss: 0.0046 - sequential_mae: 0.0046 - val_inverse_model_loss: 2.4766e-08 - val_loss: 0.0151 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0019
# Epoch 93/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 9.5000e-08 - loss: 0.0179 - sequential_loss: 0.0047 - sequential_mae: 0.0047 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0156 - val_sequential_loss: 0.0025 - val_sequential_mae: 0.0024
# Epoch 94/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.6897e-08 - loss: 0.0185 - sequential_loss: 0.0054 - sequential_mae: 0.0053 - val_inverse_model_loss: 1.5693e-07 - val_loss: 0.0191 - val_sequential_loss: 0.0060 - val_sequential_mae: 0.0060
# Epoch 95/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 8.3796e-08 - loss: 0.0162 - sequential_loss: 0.0030 - sequential_mae: 0.0031 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0143 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 96/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 5.9785e-08 - loss: 0.0163 - sequential_loss: 0.0033 - sequential_mae: 0.0032 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0177 - val_sequential_loss: 0.0046 - val_sequential_mae: 0.0047
# Epoch 97/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 7.1471e-08 - loss: 0.0161 - sequential_loss: 0.0030 - sequential_mae: 0.0030 - val_inverse_model_loss: 2.1218e-10 - val_loss: 0.0155 - val_sequential_loss: 0.0026 - val_sequential_mae: 0.0025
# Epoch 98/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 1.8367e-08 - loss: 0.0158 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0156 - val_sequential_loss: 0.0027 - val_sequential_mae: 0.0026
# Epoch 99/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 1.0214e-07 - loss: 0.0148 - sequential_loss: 0.0019 - sequential_mae: 0.0019 - val_inverse_model_loss: 0.0000e+00 - val_loss: 0.0145 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0015
# Epoch 100/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 7.8207e-08 - loss: 0.0150 - sequential_loss: 0.0021 - sequential_mae: 0.0020 - val_inverse_model_loss: 1.0307e-07 - val_loss: 0.0148 - val_sequential_loss: 0.0020 - val_sequential_mae: 0.0019
# Epoch 101/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.0599e-07 - loss: 0.0155 - sequential_loss: 0.0026 - sequential_mae: 0.0026 - val_inverse_model_loss: 5.8367e-08 - val_loss: 0.0151 - val_sequential_loss: 0.0022 - val_sequential_mae: 0.0022
# Epoch 102/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.2343e-07 - loss: 0.0143 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 1.2447e-07 - val_loss: 0.0143 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0015
# Epoch 103/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 1.4050e-07 - loss: 0.0148 - sequential_loss: 0.0021 - sequential_mae: 0.0020 - val_inverse_model_loss: 4.8977e-08 - val_loss: 0.0141 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0014
# Epoch 104/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.8914e-07 - loss: 0.0156 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 1.1538e-07 - val_loss: 0.0172 - val_sequential_loss: 0.0044 - val_sequential_mae: 0.0044
# Epoch 105/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.1297e-07 - loss: 0.0160 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 2.7702e-07 - val_loss: 0.0160 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0033
# Epoch 106/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.1623e-07 - loss: 0.0154 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 2.8694e-08 - val_loss: 0.0156 - val_sequential_loss: 0.0028 - val_sequential_mae: 0.0029
# Epoch 107/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.9493e-07 - loss: 0.0157 - sequential_loss: 0.0031 - sequential_mae: 0.0031 - val_inverse_model_loss: 1.2582e-07 - val_loss: 0.0154 - val_sequential_loss: 0.0028 - val_sequential_mae: 0.0028
# Epoch 108/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.3097e-07 - loss: 0.0154 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 9.8207e-08 - val_loss: 0.0169 - val_sequential_loss: 0.0043 - val_sequential_mae: 0.0043
# Epoch 109/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 1.6391e-07 - loss: 0.0150 - sequential_loss: 0.0024 - sequential_mae: 0.0025 - val_inverse_model_loss: 2.0505e-08 - val_loss: 0.0135 - val_sequential_loss: 0.0010 - val_sequential_mae: 9.8771e-04
# Epoch 110/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.5922e-07 - loss: 0.0141 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 7.9079e-08 - val_loss: 0.0158 - val_sequential_loss: 0.0032 - val_sequential_mae: 0.0033
# Epoch 111/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.0179e-07 - loss: 0.0152 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 1.4576e-07 - val_loss: 0.0139 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0014
# Epoch 112/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.1356e-07 - loss: 0.0159 - sequential_loss: 0.0034 - sequential_mae: 0.0035 - val_inverse_model_loss: 4.2525e-07 - val_loss: 0.0181 - val_sequential_loss: 0.0058 - val_sequential_mae: 0.0057
# Epoch 113/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.5255e-07 - loss: 0.0162 - sequential_loss: 0.0038 - sequential_mae: 0.0037 - val_inverse_model_loss: 2.8381e-07 - val_loss: 0.0156 - val_sequential_loss: 0.0033 - val_sequential_mae: 0.0032
# Epoch 114/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.6074e-07 - loss: 0.0157 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 8.4706e-08 - val_loss: 0.0143 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0019
# Epoch 115/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 1.6708e-07 - loss: 0.0137 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 8.7756e-08 - val_loss: 0.0134 - val_sequential_loss: 0.0010 - val_sequential_mae: 0.0010
# Epoch 116/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 1.4312e-07 - loss: 0.0134 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 1.6501e-07 - val_loss: 0.0132 - val_sequential_loss: 8.6988e-04 - val_sequential_mae: 8.9750e-04
# Epoch 117/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 1.6089e-07 - loss: 0.0138 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 3.7244e-07 - val_loss: 0.0143 - val_sequential_loss: 0.0021 - val_sequential_mae: 0.0020
# Epoch 118/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 1.9804e-07 - loss: 0.0141 - sequential_loss: 0.0018 - sequential_mae: 0.0019 - val_inverse_model_loss: 2.6017e-07 - val_loss: 0.0157 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0034
# Epoch 119/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.3015e-07 - loss: 0.0144 - sequential_loss: 0.0022 - sequential_mae: 0.0022 - val_inverse_model_loss: 5.2316e-08 - val_loss: 0.0136 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 120/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 1.6930e-07 - loss: 0.0136 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 2.4250e-07 - val_loss: 0.0132 - val_sequential_loss: 9.5999e-04 - val_sequential_mae: 9.7719e-04
# Epoch 121/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 1.7335e-07 - loss: 0.0146 - sequential_loss: 0.0025 - sequential_mae: 0.0025 - val_inverse_model_loss: 3.2008e-07 - val_loss: 0.0132 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 122/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.4378e-07 - loss: 0.0138 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 5.0404e-07 - val_loss: 0.0132 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 123/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.0539e-07 - loss: 0.0137 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 3.9236e-07 - val_loss: 0.0134 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0013
# Epoch 124/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.4210e-07 - loss: 0.0135 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 6.4841e-07 - val_loss: 0.0132 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 125/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.9132e-07 - loss: 0.0135 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 6.7613e-07 - val_loss: 0.0135 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0015
# Epoch 126/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.3053e-07 - loss: 0.0134 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 5.3708e-07 - val_loss: 0.0134 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 127/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.3108e-07 - loss: 0.0139 - sequential_loss: 0.0019 - sequential_mae: 0.0019 - val_inverse_model_loss: 6.6382e-07 - val_loss: 0.0170 - val_sequential_loss: 0.0050 - val_sequential_mae: 0.0051
# Epoch 128/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.1167e-07 - loss: 0.0174 - sequential_loss: 0.0056 - sequential_mae: 0.0054 - val_inverse_model_loss: 2.5080e-07 - val_loss: 0.0183 - val_sequential_loss: 0.0065 - val_sequential_mae: 0.0064
# Epoch 129/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 3.3022e-07 - loss: 0.0169 - sequential_loss: 0.0051 - sequential_mae: 0.0050 - val_inverse_model_loss: 5.9518e-07 - val_loss: 0.0215 - val_sequential_loss: 0.0096 - val_sequential_mae: 0.0096
# Epoch 130/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.5932e-07 - loss: 0.0168 - sequential_loss: 0.0047 - sequential_mae: 0.0049 - val_inverse_model_loss: 1.7590e-07 - val_loss: 0.0168 - val_sequential_loss: 0.0050 - val_sequential_mae: 0.0049
# Epoch 131/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.4900e-07 - loss: 0.0151 - sequential_loss: 0.0032 - sequential_mae: 0.0033 - val_inverse_model_loss: 5.7221e-07 - val_loss: 0.0138 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0020
# Epoch 132/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 3.0177e-07 - loss: 0.0147 - sequential_loss: 0.0029 - sequential_mae: 0.0029 - val_inverse_model_loss: 6.6296e-07 - val_loss: 0.0146 - val_sequential_loss: 0.0028 - val_sequential_mae: 0.0028
# Epoch 133/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.6173e-07 - loss: 0.0145 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 5.8174e-07 - val_loss: 0.0135 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0017
# Epoch 134/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.1761e-07 - loss: 0.0150 - sequential_loss: 0.0032 - sequential_mae: 0.0032 - val_inverse_model_loss: 5.5265e-07 - val_loss: 0.0150 - val_sequential_loss: 0.0032 - val_sequential_mae: 0.0032
# Epoch 135/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.4650e-07 - loss: 0.0146 - sequential_loss: 0.0029 - sequential_mae: 0.0028 - val_inverse_model_loss: 5.5508e-07 - val_loss: 0.0134 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0017
# Epoch 136/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 2.7160e-07 - loss: 0.0144 - sequential_loss: 0.0027 - sequential_mae: 0.0026 - val_inverse_model_loss: 7.4737e-07 - val_loss: 0.0157 - val_sequential_loss: 0.0040 - val_sequential_mae: 0.0040
# Epoch 137/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.4562e-07 - loss: 0.0147 - sequential_loss: 0.0029 - sequential_mae: 0.0030 - val_inverse_model_loss: 5.0896e-07 - val_loss: 0.0151 - val_sequential_loss: 0.0033 - val_sequential_mae: 0.0034
# Epoch 138/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 2.9111e-07 - loss: 0.0142 - sequential_loss: 0.0024 - sequential_mae: 0.0025 - val_inverse_model_loss: 2.9023e-07 - val_loss: 0.0128 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 139/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.3284e-07 - loss: 0.0131 - sequential_loss: 0.0015 - sequential_mae: 0.0014 - val_inverse_model_loss: 6.4435e-07 - val_loss: 0.0129 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0013
# Epoch 140/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.4170e-07 - loss: 0.0145 - sequential_loss: 0.0030 - sequential_mae: 0.0029 - val_inverse_model_loss: 9.3815e-07 - val_loss: 0.0187 - val_sequential_loss: 0.0070 - val_sequential_mae: 0.0070
# Epoch 141/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 4.1878e-07 - loss: 0.0169 - sequential_loss: 0.0051 - sequential_mae: 0.0053 - val_inverse_model_loss: 7.4370e-07 - val_loss: 0.0158 - val_sequential_loss: 0.0041 - val_sequential_mae: 0.0042
# Epoch 142/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.5017e-07 - loss: 0.0143 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 9.5232e-07 - val_loss: 0.0130 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 143/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 3.3562e-07 - loss: 0.0131 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 8.0790e-07 - val_loss: 0.0127 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0011
# Epoch 144/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 3.4801e-07 - loss: 0.0128 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 6.4375e-07 - val_loss: 0.0125 - val_sequential_loss: 9.7639e-04 - val_sequential_mae: 0.0010
# Epoch 145/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.3950e-07 - loss: 0.0126 - sequential_loss: 0.0012 - sequential_mae: 0.0011 - val_inverse_model_loss: 1.2474e-06 - val_loss: 0.0125 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 146/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.3137e-07 - loss: 0.0127 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 1.2265e-06 - val_loss: 0.0135 - val_sequential_loss: 0.0020 - val_sequential_mae: 0.0020
# Epoch 147/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 6.2602e-07 - loss: 0.0137 - sequential_loss: 0.0023 - sequential_mae: 0.0022 - val_inverse_model_loss: 1.4962e-06 - val_loss: 0.0143 - val_sequential_loss: 0.0029 - val_sequential_mae: 0.0028
# Epoch 148/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.7655e-07 - loss: 0.0144 - sequential_loss: 0.0030 - sequential_mae: 0.0030 - val_inverse_model_loss: 1.2296e-06 - val_loss: 0.0131 - val_sequential_loss: 0.0018 - val_sequential_mae: 0.0017
# Epoch 149/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.5763e-07 - loss: 0.0154 - sequential_loss: 0.0041 - sequential_mae: 0.0040 - val_inverse_model_loss: 1.1849e-06 - val_loss: 0.0139 - val_sequential_loss: 0.0026 - val_sequential_mae: 0.0026
# Epoch 150/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.3915e-07 - loss: 0.0155 - sequential_loss: 0.0040 - sequential_mae: 0.0041 - val_inverse_model_loss: 8.1199e-07 - val_loss: 0.0137 - val_sequential_loss: 0.0024 - val_sequential_mae: 0.0024
# Epoch 151/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.9403e-07 - loss: 0.0131 - sequential_loss: 0.0018 - sequential_mae: 0.0018 - val_inverse_model_loss: 7.9214e-07 - val_loss: 0.0130 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0016
# Epoch 152/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 5.1624e-07 - loss: 0.0129 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 7.3242e-07 - val_loss: 0.0124 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0011
# Epoch 153/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 5.1367e-07 - loss: 0.0142 - sequential_loss: 0.0031 - sequential_mae: 0.0029 - val_inverse_model_loss: 1.0516e-06 - val_loss: 0.0182 - val_sequential_loss: 0.0068 - val_sequential_mae: 0.0069
# Epoch 154/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.7897e-07 - loss: 0.0166 - sequential_loss: 0.0052 - sequential_mae: 0.0053 - val_inverse_model_loss: 1.2364e-06 - val_loss: 0.0151 - val_sequential_loss: 0.0037 - val_sequential_mae: 0.0038
# Epoch 155/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.0627e-07 - loss: 0.0140 - sequential_loss: 0.0028 - sequential_mae: 0.0028 - val_inverse_model_loss: 1.4314e-06 - val_loss: 0.0157 - val_sequential_loss: 0.0044 - val_sequential_mae: 0.0045
# Epoch 156/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.4345e-07 - loss: 0.0142 - sequential_loss: 0.0030 - sequential_mae: 0.0030 - val_inverse_model_loss: 1.0738e-06 - val_loss: 0.0133 - val_sequential_loss: 0.0020 - val_sequential_mae: 0.0021
# Epoch 157/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.1072e-07 - loss: 0.0137 - sequential_loss: 0.0025 - sequential_mae: 0.0025 - val_inverse_model_loss: 1.2111e-06 - val_loss: 0.0137 - val_sequential_loss: 0.0024 - val_sequential_mae: 0.0025
# Epoch 158/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.0665e-07 - loss: 0.0138 - sequential_loss: 0.0026 - sequential_mae: 0.0026 - val_inverse_model_loss: 1.3798e-06 - val_loss: 0.0151 - val_sequential_loss: 0.0039 - val_sequential_mae: 0.0040
# Epoch 159/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.6364e-07 - loss: 0.0132 - sequential_loss: 0.0020 - sequential_mae: 0.0021 - val_inverse_model_loss: 1.1438e-06 - val_loss: 0.0128 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0016
# Epoch 160/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.1428e-07 - loss: 0.0131 - sequential_loss: 0.0020 - sequential_mae: 0.0019 - val_inverse_model_loss: 8.8054e-07 - val_loss: 0.0134 - val_sequential_loss: 0.0023 - val_sequential_mae: 0.0023
# Epoch 161/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 4.1776e-07 - loss: 0.0146 - sequential_loss: 0.0034 - sequential_mae: 0.0034 - val_inverse_model_loss: 9.1296e-07 - val_loss: 0.0146 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0035
# Epoch 162/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.5397e-07 - loss: 0.0138 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 1.2806e-06 - val_loss: 0.0149 - val_sequential_loss: 0.0038 - val_sequential_mae: 0.0038
# Epoch 163/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - inverse_model_loss: 4.0610e-07 - loss: 0.0135 - sequential_loss: 0.0024 - sequential_mae: 0.0024 - val_inverse_model_loss: 8.3177e-07 - val_loss: 0.0123 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0012
# Epoch 164/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.7862e-07 - loss: 0.0128 - sequential_loss: 0.0017 - sequential_mae: 0.0017 - val_inverse_model_loss: 1.0095e-06 - val_loss: 0.0125 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 165/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.5242e-07 - loss: 0.0128 - sequential_loss: 0.0018 - sequential_mae: 0.0017 - val_inverse_model_loss: 1.1105e-06 - val_loss: 0.0140 - val_sequential_loss: 0.0030 - val_sequential_mae: 0.0030
# Epoch 166/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 5.9736e-07 - loss: 0.0150 - sequential_loss: 0.0041 - sequential_mae: 0.0040 - val_inverse_model_loss: 1.1557e-06 - val_loss: 0.0133 - val_sequential_loss: 0.0024 - val_sequential_mae: 0.0023
# Epoch 167/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.0925e-07 - loss: 0.0159 - sequential_loss: 0.0049 - sequential_mae: 0.0049 - val_inverse_model_loss: 7.5604e-07 - val_loss: 0.0146 - val_sequential_loss: 0.0036 - val_sequential_mae: 0.0036
# Epoch 168/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - inverse_model_loss: 4.7624e-07 - loss: 0.0129 - sequential_loss: 0.0019 - sequential_mae: 0.0020 - val_inverse_model_loss: 1.0102e-06 - val_loss: 0.0122 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 169/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 5.5885e-07 - loss: 0.0121 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 9.7855e-07 - val_loss: 0.0120 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 170/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 8.1310e-07 - loss: 0.0122 - sequential_loss: 0.0013 - sequential_mae: 0.0012 - val_inverse_model_loss: 1.5970e-06 - val_loss: 0.0120 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 171/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 8.1287e-07 - loss: 0.0135 - sequential_loss: 0.0025 - sequential_mae: 0.0026 - val_inverse_model_loss: 1.6520e-06 - val_loss: 0.0154 - val_sequential_loss: 0.0045 - val_sequential_mae: 0.0045
# Epoch 172/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 7.7942e-07 - loss: 0.0145 - sequential_loss: 0.0035 - sequential_mae: 0.0036 - val_inverse_model_loss: 1.1096e-06 - val_loss: 0.0140 - val_sequential_loss: 0.0031 - val_sequential_mae: 0.0031
# Epoch 173/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 6.5336e-07 - loss: 0.0135 - sequential_loss: 0.0027 - sequential_mae: 0.0026 - val_inverse_model_loss: 1.7486e-06 - val_loss: 0.0128 - val_sequential_loss: 0.0021 - val_sequential_mae: 0.0020
# Epoch 174/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - inverse_model_loss: 6.5493e-07 - loss: 0.0127 - sequential_loss: 0.0018 - sequential_mae: 0.0019 - val_inverse_model_loss: 1.1157e-06 - val_loss: 0.0154 - val_sequential_loss: 0.0046 - val_sequential_mae: 0.0046
# Epoch 175/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 7.0766e-07 - loss: 0.0139 - sequential_loss: 0.0030 - sequential_mae: 0.0030 - val_inverse_model_loss: 1.1104e-06 - val_loss: 0.0137 - val_sequential_loss: 0.0029 - val_sequential_mae: 0.0029
# Epoch 176/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 7.1263e-07 - loss: 0.0131 - sequential_loss: 0.0023 - sequential_mae: 0.0023 - val_inverse_model_loss: 1.5369e-06 - val_loss: 0.0126 - val_sequential_loss: 0.0019 - val_sequential_mae: 0.0018
# Epoch 177/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 6.7953e-07 - loss: 0.0127 - sequential_loss: 0.0020 - sequential_mae: 0.0020 - val_inverse_model_loss: 1.8865e-06 - val_loss: 0.0156 - val_sequential_loss: 0.0048 - val_sequential_mae: 0.0048
# Epoch 178/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 7.1843e-07 - loss: 0.0147 - sequential_loss: 0.0039 - sequential_mae: 0.0040 - val_inverse_model_loss: 1.6144e-06 - val_loss: 0.0149 - val_sequential_loss: 0.0041 - val_sequential_mae: 0.0042
# Epoch 179/400
# ...
# Epoch 343/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.6350e-06 - loss: 0.0106 - sequential_loss: 0.0023 - sequential_mae: 0.0022 - val_inverse_model_loss: 7.0159e-06 - val_loss: 0.0094 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 344/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.2613e-06 - loss: 0.0108 - sequential_loss: 0.0025 - sequential_mae: 0.0025 - val_inverse_model_loss: 5.5205e-06 - val_loss: 0.0096 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0013
# Epoch 345/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - inverse_model_loss: 2.9644e-06 - loss: 0.0109 - sequential_loss: 0.0026 - sequential_mae: 0.0026 - val_inverse_model_loss: 6.6011e-06 - val_loss: 0.0112 - val_sequential_loss: 0.0029 - val_sequential_mae: 0.0029
# Epoch 346/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.9198e-06 - loss: 0.0108 - sequential_loss: 0.0024 - sequential_mae: 0.0025 - val_inverse_model_loss: 5.3856e-06 - val_loss: 0.0099 - val_sequential_loss: 0.0016 - val_sequential_mae: 0.0016
# Epoch 347/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.0835e-06 - loss: 0.0106 - sequential_loss: 0.0022 - sequential_mae: 0.0023 - val_inverse_model_loss: 6.6990e-06 - val_loss: 0.0111 - val_sequential_loss: 0.0027 - val_sequential_mae: 0.0028
# Epoch 348/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.3071e-06 - loss: 0.0105 - sequential_loss: 0.0022 - sequential_mae: 0.0022 - val_inverse_model_loss: 7.3240e-06 - val_loss: 0.0097 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 349/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 3.0834e-06 - loss: 0.0095 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 6.1533e-06 - val_loss: 0.0092 - val_sequential_loss: 9.2488e-04 - val_sequential_mae: 9.4290e-04
# Epoch 350/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.2292e-06 - loss: 0.0097 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 6.7165e-06 - val_loss: 0.0124 - val_sequential_loss: 0.0042 - val_sequential_mae: 0.0042
# Epoch 351/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.4070e-06 - loss: 0.0122 - sequential_loss: 0.0040 - sequential_mae: 0.0040 - val_inverse_model_loss: 4.5962e-06 - val_loss: 0.0132 - val_sequential_loss: 0.0051 - val_sequential_mae: 0.0049
# Epoch 352/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.8361e-06 - loss: 0.0126 - sequential_loss: 0.0044 - sequential_mae: 0.0044 - val_inverse_model_loss: 6.4487e-06 - val_loss: 0.0101 - val_sequential_loss: 0.0018 - val_sequential_mae: 0.0019
# Epoch 353/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.0670e-06 - loss: 0.0106 - sequential_loss: 0.0023 - sequential_mae: 0.0024 - val_inverse_model_loss: 6.6211e-06 - val_loss: 0.0098 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0015
# Epoch 354/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.1802e-06 - loss: 0.0096 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 5.9178e-06 - val_loss: 0.0100 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0018
# Epoch 355/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.1065e-06 - loss: 0.0095 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 7.7922e-06 - val_loss: 0.0098 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0016
# Epoch 356/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.5070e-06 - loss: 0.0097 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 6.9688e-06 - val_loss: 0.0096 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0014
# Epoch 357/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.4766e-06 - loss: 0.0093 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 8.2628e-06 - val_loss: 0.0092 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0010
# Epoch 358/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 3.8292e-06 - loss: 0.0095 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 8.1017e-06 - val_loss: 0.0092 - val_sequential_loss: 9.8441e-04 - val_sequential_mae: 9.9002e-04
# Epoch 359/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 4.0378e-06 - loss: 0.0097 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 8.0324e-06 - val_loss: 0.0107 - val_sequential_loss: 0.0026 - val_sequential_mae: 0.0026
# Epoch 360/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 3.7393e-06 - loss: 0.0106 - sequential_loss: 0.0024 - sequential_mae: 0.0024 - val_inverse_model_loss: 7.2277e-06 - val_loss: 0.0104 - val_sequential_loss: 0.0022 - val_sequential_mae: 0.0022
# Epoch 361/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.1015e-06 - loss: 0.0096 - sequential_loss: 0.0014 - sequential_mae: 0.0014 - val_inverse_model_loss: 7.3603e-06 - val_loss: 0.0093 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 362/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 3.8593e-06 - loss: 0.0094 - sequential_loss: 0.0013 - sequential_mae: 0.0013 - val_inverse_model_loss: 8.2032e-06 - val_loss: 0.0090 - val_sequential_loss: 8.0092e-04 - val_sequential_mae: 8.3642e-04
# Epoch 363/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.3215e-06 - loss: 0.0091 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 9.5721e-06 - val_loss: 0.0093 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0011
# Epoch 364/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.0542e-06 - loss: 0.0092 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 1.0703e-05 - val_loss: 0.0090 - val_sequential_loss: 8.6348e-04 - val_sequential_mae: 8.8495e-04
# Epoch 365/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - inverse_model_loss: 5.8959e-06 - loss: 0.0091 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 1.1994e-05 - val_loss: 0.0089 - val_sequential_loss: 7.8342e-04 - val_sequential_mae: 8.0896e-04
# Epoch 366/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 7.0428e-06 - loss: 0.0091 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 1.3698e-05 - val_loss: 0.0090 - val_sequential_loss: 9.1395e-04 - val_sequential_mae: 9.2316e-04
# Epoch 367/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 8.9184e-06 - loss: 0.0096 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 1.7054e-05 - val_loss: 0.0121 - val_sequential_loss: 0.0040 - val_sequential_mae: 0.0041
# Epoch 368/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - inverse_model_loss: 8.6250e-06 - loss: 0.0102 - sequential_loss: 0.0021 - sequential_mae: 0.0021 - val_inverse_model_loss: 1.5013e-05 - val_loss: 0.0095 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 369/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 7.0065e-06 - loss: 0.0102 - sequential_loss: 0.0021 - sequential_mae: 0.0021 - val_inverse_model_loss: 1.2793e-05 - val_loss: 0.0096 - val_sequential_loss: 0.0017 - val_sequential_mae: 0.0016
# Epoch 370/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.7065e-06 - loss: 0.0104 - sequential_loss: 0.0024 - sequential_mae: 0.0024 - val_inverse_model_loss: 9.1472e-06 - val_loss: 0.0090 - val_sequential_loss: 9.0253e-04 - val_sequential_mae: 9.2426e-04
# Epoch 371/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.6481e-06 - loss: 0.0098 - sequential_loss: 0.0017 - sequential_mae: 0.0017 - val_inverse_model_loss: 8.7623e-06 - val_loss: 0.0094 - val_sequential_loss: 0.0015 - val_sequential_mae: 0.0014
# Epoch 372/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.8407e-06 - loss: 0.0100 - sequential_loss: 0.0020 - sequential_mae: 0.0019 - val_inverse_model_loss: 6.9112e-06 - val_loss: 0.0114 - val_sequential_loss: 0.0034 - val_sequential_mae: 0.0034
# Epoch 373/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.5344e-06 - loss: 0.0106 - sequential_loss: 0.0027 - sequential_mae: 0.0026 - val_inverse_model_loss: 4.9541e-06 - val_loss: 0.0091 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0011
# Epoch 374/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.6207e-06 - loss: 0.0095 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 4.3837e-06 - val_loss: 0.0090 - val_sequential_loss: 0.0011 - val_sequential_mae: 0.0010
# Epoch 375/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.7793e-06 - loss: 0.0092 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 6.0573e-06 - val_loss: 0.0089 - val_sequential_loss: 9.0005e-04 - val_sequential_mae: 9.1847e-04
# Epoch 376/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 3.2835e-06 - loss: 0.0092 - sequential_loss: 0.0012 - sequential_mae: 0.0012 - val_inverse_model_loss: 6.7227e-06 - val_loss: 0.0089 - val_sequential_loss: 8.5602e-04 - val_sequential_mae: 8.6747e-04
# Epoch 377/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.9240e-06 - loss: 0.0090 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 8.1595e-06 - val_loss: 0.0089 - val_sequential_loss: 8.7914e-04 - val_sequential_mae: 8.8090e-04
# Epoch 378/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.0257e-06 - loss: 0.0090 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 1.1001e-05 - val_loss: 0.0089 - val_sequential_loss: 9.0670e-04 - val_sequential_mae: 9.2267e-04
# Epoch 379/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.9001e-06 - loss: 0.0094 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 1.0779e-05 - val_loss: 0.0089 - val_sequential_loss: 9.2196e-04 - val_sequential_mae: 9.1838e-04
# Epoch 380/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.3078e-06 - loss: 0.0094 - sequential_loss: 0.0015 - sequential_mae: 0.0014 - val_inverse_model_loss: 1.0182e-05 - val_loss: 0.0104 - val_sequential_loss: 0.0025 - val_sequential_mae: 0.0024
# Epoch 381/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.4869e-06 - loss: 0.0119 - sequential_loss: 0.0041 - sequential_mae: 0.0040 - val_inverse_model_loss: 9.9932e-06 - val_loss: 0.0128 - val_sequential_loss: 0.0048 - val_sequential_mae: 0.0049
# Epoch 382/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.1264e-06 - loss: 0.0125 - sequential_loss: 0.0045 - sequential_mae: 0.0046 - val_inverse_model_loss: 8.3077e-06 - val_loss: 0.0132 - val_sequential_loss: 0.0054 - val_sequential_mae: 0.0053
# Epoch 383/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.3938e-06 - loss: 0.0126 - sequential_loss: 0.0047 - sequential_mae: 0.0047 - val_inverse_model_loss: 7.0382e-06 - val_loss: 0.0108 - val_sequential_loss: 0.0028 - val_sequential_mae: 0.0029
# Epoch 384/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.0968e-06 - loss: 0.0105 - sequential_loss: 0.0025 - sequential_mae: 0.0026 - val_inverse_model_loss: 5.4965e-06 - val_loss: 0.0091 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 385/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 2.7454e-06 - loss: 0.0090 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 4.7829e-06 - val_loss: 0.0091 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 386/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 2.9037e-06 - loss: 0.0089 - sequential_loss: 0.0011 - sequential_mae: 0.0011 - val_inverse_model_loss: 7.2289e-06 - val_loss: 0.0088 - val_sequential_loss: 9.6207e-04 - val_sequential_mae: 9.6006e-04
# Epoch 387/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - inverse_model_loss: 3.8078e-06 - loss: 0.0089 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 8.4696e-06 - val_loss: 0.0087 - val_sequential_loss: 8.6179e-04 - val_sequential_mae: 8.6529e-04
# Epoch 388/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.7596e-06 - loss: 0.0088 - sequential_loss: 9.3158e-04 - sequential_mae: 9.3354e-04 - val_inverse_model_loss: 1.0008e-05 - val_loss: 0.0088 - val_sequential_loss: 9.5843e-04 - val_sequential_mae: 9.3276e-04
# Epoch 389/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.6230e-06 - loss: 0.0095 - sequential_loss: 0.0017 - sequential_mae: 0.0017 - val_inverse_model_loss: 1.1697e-05 - val_loss: 0.0124 - val_sequential_loss: 0.0046 - val_sequential_mae: 0.0046
# Epoch 390/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 6.0764e-06 - loss: 0.0114 - sequential_loss: 0.0034 - sequential_mae: 0.0035 - val_inverse_model_loss: 1.1496e-05 - val_loss: 0.0121 - val_sequential_loss: 0.0042 - val_sequential_mae: 0.0042
# Epoch 391/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.4460e-06 - loss: 0.0100 - sequential_loss: 0.0022 - sequential_mae: 0.0022 - val_inverse_model_loss: 9.0301e-06 - val_loss: 0.0092 - val_sequential_loss: 0.0014 - val_sequential_mae: 0.0014
# Epoch 392/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - inverse_model_loss: 4.7560e-06 - loss: 0.0088 - sequential_loss: 0.0010 - sequential_mae: 0.0010 - val_inverse_model_loss: 9.3580e-06 - val_loss: 0.0086 - val_sequential_loss: 7.9716e-04 - val_sequential_mae: 8.1384e-04
# Epoch 393/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.2661e-06 - loss: 0.0094 - sequential_loss: 0.0016 - sequential_mae: 0.0016 - val_inverse_model_loss: 1.0348e-05 - val_loss: 0.0090 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 394/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 5.8244e-06 - loss: 0.0093 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 1.1059e-05 - val_loss: 0.0090 - val_sequential_loss: 0.0013 - val_sequential_mae: 0.0012
# Epoch 395/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 4.5487e-06 - loss: 0.0093 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 7.4129e-06 - val_loss: 0.0087 - val_sequential_loss: 9.1542e-04 - val_sequential_mae: 9.2901e-04
# Epoch 396/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.8190e-06 - loss: 0.0093 - sequential_loss: 0.0015 - sequential_mae: 0.0015 - val_inverse_model_loss: 7.7966e-06 - val_loss: 0.0095 - val_sequential_loss: 0.0018 - val_sequential_mae: 0.0017
# Epoch 397/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 3.6572e-06 - loss: 0.0097 - sequential_loss: 0.0020 - sequential_mae: 0.0019 - val_inverse_model_loss: 6.9204e-06 - val_loss: 0.0110 - val_sequential_loss: 0.0032 - val_sequential_mae: 0.0032
# Epoch 398/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 3.7028e-06 - loss: 0.0104 - sequential_loss: 0.0027 - sequential_mae: 0.0027 - val_inverse_model_loss: 5.5074e-06 - val_loss: 0.0099 - val_sequential_loss: 0.0022 - val_sequential_mae: 0.0021
# Epoch 399/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - inverse_model_loss: 2.8360e-06 - loss: 0.0101 - sequential_loss: 0.0022 - sequential_mae: 0.0023 - val_inverse_model_loss: 4.8589e-06 - val_loss: 0.0090 - val_sequential_loss: 0.0012 - val_sequential_mae: 0.0012
# Epoch 400/400
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - inverse_model_loss: 2.6314e-06 - loss: 0.0111 - sequential_loss: 0.0033 - sequential_mae: 0.0033 - val_inverse_model_loss: 4.9052e-06 - val_loss: 0.0125 - val_sequential_loss: 0.0047 - val_sequential_mae: 0.0048
# CPU times: user 2min 2s, sys: 2min 6s, total: 4min 9s
# Wall time: 1min 21s

# %% [markdown]
# Load the saved best model and use it from now on.

# %%
if not KERAS_TUNER and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    model = load_model(best_model_file, custom_objects={
        'ScalerConversionLayer': ScalerConversionLayer,
        'qiskit_range_penalty': qiskit_range_penalty})

# %% [markdown]
# ### Sweep total number of parameters to find the right range

# %%
if SWEEP_PARAM_NUM:
    qiskit_dim = y_train.shape[1]
    Hamiltonian_dim = X_train.shape[1]
    
    def build_combined_mlp(neurons_per_layer):
        inv = Sequential(name='inverse_model')
        inv.add(Input(shape=(Hamiltonian_dim,), name='Hamiltonian_input'))
        for i, n in enumerate(neurons_per_layer):
            inv.add(Dense(n, name=f'fc{i}', kernel_initializer='lecun_uniform',
                            kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
            inv.add(LeakyReLU(negative_slope=0.01, name=f'leaky_relu{i}'))
            inv.add(Dropout(rate=TRAIN_DROPOUT_RATE, name=f'dropout{i}'))
        inv.add(Dense(qiskit_dim, activation='linear', name='qiskit_output',
                        kernel_initializer='lecun_uniform'))
        combined_input = Input(shape=(Hamiltonian_dim,))
        qiskit_out = inv(combined_input)
        qiskit_conv = scaler_converter(qiskit_out)
        Hamiltonian_recon = surrogate(qiskit_conv)
        return Model(combined_input, [Hamiltonian_recon, qiskit_out])
    
    def make_optimizer():
        lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=LR_INITIAL,
            decay_steps=LR_DECAY_STEPS,
            decay_rate=LR_DECAY_RATE,
            staircase=LR_STAIRCASE)
        return tf.optimizers.Adam(learning_rate=lr_schedule)
    
    def train_one_config(neurons_per_layer, seed=0):
        tf.keras.backend.clear_session()
        tf.random.set_seed(seed)
        np.random.seed(seed)
        global surrogate, scaler_converter
        surrogate = load_model(SURROGATE_PATH, compile=False)
        surrogate.trainable = False
        for layer in surrogate.layers:
            layer.trainable = False
        scaler_converter = ScalerConversionLayer(
            scale_a=scale_a, scale_b=scale_b, name='scaler_conversion')
        combined = build_combined_mlp(neurons_per_layer)
        combined.compile(optimizer=make_optimizer(),
                        loss=[TRAIN_LOSS, qiskit_range_penalty],
                        loss_weights=[1.0, PENALTY_WEIGHT])
        early_stopping = EarlyStopping(
            monitor='val_loss', mode='min',
            patience=TRAIN_EARLY_STOPPING_PATIENCE, verbose=0,
            restore_best_weights=True)
        history = combined.fit(
            np.asarray(X_train), [np.asarray(X_train), dummy_y_train],
            validation_data=(np.asarray(X_val), [np.asarray(X_val), dummy_y_val]),
            epochs=400, batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping], verbose=0)
        best_val = min(history.history['val_loss'])
        return combined, history, best_val

# %% [markdown]
# ### Sweep amount of data used in training

# %%
if SWEEP_DATA_AMOUNT:
    FIXED_DEPTH = 1
    FIXED_WIDTH = 1024
    FIXED_NEURONS = [FIXED_WIDTH] * FIXED_DEPTH
    print(f'Sweep data amount with fixed architecture: {FIXED_NEURONS}')

# %% [markdown]
# ### Keras Tuner to Find Best Hyperparameters

# %% [markdown]
# Run this if you want to use keras tuner to make the model rather than doing it by hand

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    from tensorflow.keras import Sequential
    from tensorflow.keras.layers import Dense, Dropout, LeakyReLU, Input
    from keras_tuner import BayesianOptimization
    import keras_tuner as kt

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    Hamiltonian_dim = X_train.shape[1]
    qiskit_dim = y_train.shape[1]
    
    def build_hypermodel(hp):
        tf.keras.backend.clear_session()
        gc.collect()
        
        # reload surrogate + rebuild conversion layer after clear_session
        surr = load_model(SURROGATE_PATH, compile=False)
        surr.trainable = False
        for layer in surr.layers:
            layer.trainable = False
        converter = ScalerConversionLayer(
            scale_a=scale_a, scale_b=scale_b, name='scaler_conversion')
        
        n_layers = hp.Int('n_layers', min_value=1, max_value=4, default=2)
        neurons_per_layer = [hp.Int(f'neurons_{i}', min_value=64, max_value=1024, step=64) for i in range(n_layers)]
        dropout_rate = hp.Float('dropout_rate', 0.0, 0.3, step=0.05)
        l2_reg = hp.Float('l2_reg', 1e-6, 1e-2, sampling='LOG', default=1e-4)
        lr_initial = hp.Float('learning_rate', 1e-3, 1e-1, sampling='LOG', default=1e-2)
        use_batchnorm = hp.Boolean('use_batchnorm', default=True)
        penalty_wt = hp.Float('penalty_weight', 0.01, 1.0, sampling='LOG', default=0.1)
        
        # build the inverse model
        inv = Sequential(name='inverse_model')
        inv.add(Input(shape=(Hamiltonian_dim,), name='Hamiltonian_input'))
        for i, n_units in enumerate(neurons_per_layer):
            inv.add(Dense(n_units, name=f'fc{i}', kernel_initializer='he_normal',
                            kernel_regularizer=tf.keras.regularizers.l2(l2_reg)))
            if use_batchnorm:
                inv.add(tf.keras.layers.BatchNormalization(name=f'bn{i}'))
            inv.add(LeakyReLU(negative_slope=0.01, name=f'leaky_relu{i}'))
            inv.add(Dropout(rate=dropout_rate, name=f'dropout{i}'))
        inv.add(Dense(qiskit_dim, name='qiskit_output', kernel_initializer='he_normal'))
        
        # Two-output model
        combined_input = Input(shape=(Hamiltonian_dim,), name='combined_input')
        qiskit_out = inv(combined_input)
        qiskit_conv = converter(qiskit_out)
        Hamiltonian_recon = surr(qiskit_conv)
        combined = Model(combined_input, [Hamiltonian_recon, qiskit_out], name='combined_model')
        combined.compile(
            optimizer=tf.optimizers.Adam(learning_rate=lr_initial),
            loss=[TRAIN_LOSS, qiskit_range_penalty],
            loss_weights=[1.0, penalty_wt],
        )
        return combined

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    tuner = BayesianOptimization(
        build_hypermodel,
        objective='val_loss',
        max_trials=KERAS_TUNER_TRIALS,
        seed=seed,
        directory='kt_dir2',
        project_name='transmon_cross_surrogate_loss2'
    )

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    early_stopping = EarlyStopping(
        monitor='val_loss', mode='min',
        patience=TRAIN_EARLY_STOPPING_PATIENCE, verbose=1)
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    tuner.search(
        np.asarray(X_train), [np.asarray(X_train), dummy_y_train],
        epochs=400, batch_size=TRAIN_BATCH_SIZE,
        validation_data=(np.asarray(X_val), [np.asarray(X_val), dummy_y_val]),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

# %%
encoding = 'surrogate_defined_loss'
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    os.makedirs('model', exist_ok=True)
    best_model_file = f'model/best_keras_model_{encoding}.keras'
    best_combined = tuner.get_best_models(1)[0]
    best_combined.save(best_model_file)
    
    inverse_only = best_combined.get_layer('inverse_model')
    inverse_only.save(f'model/best_inverse_model_{encoding}.keras')
    print(f'Saved combined model: {best_model_file}')
    print(f'Saved inverse-only model: model/best_inverse_model_{encoding}.keras')
    
    tf.keras.backend.clear_session()
    gc.collect()
    with tf.device('/CPU:0'):
        loaded_model = load_model(best_model_file, compile=False,
                                  custom_objects={'ScalerConversionLayer': ScalerConversionLayer})

# %% [markdown]
# ### View the model

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM:
    print('Combined model (inverse + conversion + frozen surrogate):')
    best_combined.summary()

if not KERAS_TUNER and not SWEEP_PARAM_NUM:
    print('Combined model:')
    model.summary()
# Out:
# Combined model:
# Model: "combined_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ combined_input (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inverse_model (Sequential)      │ (None, 3)              │        17,027 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaler_conversion               │ (None, 3)              │             0 │
# │ (ScalerConversionLayer)         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 2)              │         4,418 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,500 (216.80 KB)
#  Trainable params: 17,027 (66.51 KB)
#  Non-trainable params: 4,418 (17.26 KB)
#  Optimizer params: 34,055 (133.03 KB)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Plot training history.

# %% [markdown]
# ### Visualize gradients for best model

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
    class GradientNormLogger(tf.keras.callbacks.Callback):
        def __init__(self, x_probe, y_probe, layer_name_prefixes=('fc0',), log_every=1, verbose=0):
            super().__init__()
            self.x_probe = x_probe
            self.y_probe = y_probe
            self.prefixes = layer_name_prefixes
            self.log_every = log_every
            self.verbose = verbose
            self.records = []
        def on_epoch_end(self, epoch, logs=None):
            if epoch % self.log_every != 0: return
            with tf.GradientTape() as tape:
                preds = self.model(self.x_probe, training=True)
                loss = self.model.compute_loss(self.x_probe, self.y_probe, preds)
            grads = tape.gradient(loss, self.model.trainable_variables)
            rec = {'epoch': epoch, 'loss': float(loss)}
            for var, g in zip(self.model.trainable_variables, grads):
                if g is None: continue
                for pfx in self.prefixes:
                    if pfx in var.name:
                        rec[f'grad_norm_{var.name}'] = float(tf.norm(g))
            self.records.append(rec)
        def to_csv(self, path):
            pd.DataFrame(self.records).to_csv(path, index=False)

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
    probe_n = min(256, len(X_train))
    x_probe = np.asarray(X_train[:probe_n])
    y_probe = [np.asarray(X_train[:probe_n]), np.zeros((probe_n, y_train.shape[1]), dtype='float32')]
    grad_logger = GradientNormLogger(x_probe=x_probe, y_probe=y_probe,
        layer_name_prefixes=('fc0', 'qiskit_output'), log_every=1, verbose=1)
    best_hp = tuner.get_best_hyperparameters(1)[0]
    model = tuner.hypermodel.build(best_hp)
    lr_monitor = LearningRateMonitor()
    history = model.fit(
        np.asarray(X_train), [np.asarray(X_train), dummy_y_train],
        epochs=400, batch_size=TRAIN_BATCH_SIZE,
        validation_data=(np.asarray(X_val), [np.asarray(X_val), dummy_y_val]),
        callbacks=[early_stopping, lr_monitor, grad_logger], verbose=1)
    grad_logger.to_csv(f'plots/{encoding}_gradients.csv')
    del model; tf.keras.backend.clear_session(); gc.collect()

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
    dfg = pd.DataFrame(grad_logger.records)
    plt.figure(figsize=(12, 4))
    for col in dfg.columns:
        if col.startswith('grad_norm_'):
            plt.plot(dfg['epoch'], dfg[col], label=col.replace('grad_norm_', ''))
    plt.xlabel('Epoch'); plt.ylabel('Gradient Norm'); plt.legend(fontsize=6)
    plt.title('Gradient norms during training'); plt.tight_layout()
    plt.savefig(f'plots/{encoding}_gradient_norms.pdf'); plt.show()

# %% [markdown]
# ### Look at best model

# %%
if KERAS_TUNER and not SWEEP_PARAM_NUM and not VISUALIZE_GRADIENTS:
    class LearningRateMonitor(tf.keras.callbacks.Callback):
        def on_train_begin(self, logs=None):
            self.learning_rates = []
        def on_epoch_end(self, epoch, logs=None):
            lr = self.model.optimizer.learning_rate
            if callable(lr):
                lr = lr(self.model.optimizer.iterations)
            self.learning_rates.append(float(tf.keras.backend.get_value(lr)))

    best_hp = tuner.get_best_hyperparameters(1)[0]
    model = tuner.hypermodel.build(best_hp)
    lr_monitor = LearningRateMonitor()
    history = model.fit(
        np.asarray(X_train), [np.asarray(X_train), dummy_y_train],
        epochs=400, batch_size=TRAIN_BATCH_SIZE,
        validation_data=(np.asarray(X_val), [np.asarray(X_val), dummy_y_val]),
        callbacks=[early_stopping, lr_monitor], verbose=1)
    del model; tf.keras.backend.clear_session(); gc.collect()

import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Surrogate-defined loss (total: reconstruction + range penalty)')
plt.ylabel('Loss'); plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best')
#plt.ylim(-.1,4)
plt.tight_layout(); plt.savefig(f'plots/surrogate_loss_history.pdf'); plt.show()

plt.plot(lr_monitor.learning_rates)
plt.title('Learning Rate over Epochs')
plt.xlabel('Epoch'); plt.ylabel('Learning Rate')
plt.tight_layout(); plt.savefig(f'plots/surrogate_loss_learning_rate.pdf'); plt.show()

# %% [markdown]
# ### Test set evaluation

# %%
# Evaluate on test set
tf.keras.backend.clear_session()
gc.collect()

def get_loss(eval_out):
    if isinstance(eval_out, dict):
        return float(eval_out.get('loss', list(eval_out.values())[0]))
    if isinstance(eval_out, (list, tuple, np.ndarray)):
        return float(eval_out[0])
    return float(eval_out)

combined_model = load_model(best_model_file, compile=False,
    custom_objects={'ScalerConversionLayer': ScalerConversionLayer})
combined_model.compile(optimizer='adam',
    loss=[TRAIN_LOSS, qiskit_range_penalty],
    loss_weights=[1.0, PENALTY_WEIGHT])
eval_result = combined_model.evaluate(
    np.asarray(X_test), [np.asarray(X_test), dummy_y_test])
total_loss = float(eval_result[0])
Hamiltonian_recon_loss = float(eval_result[1])
penalty_loss = float(eval_result[2])

print(f'Total test loss: {total_loss}')
print(f'  Reconstruction loss ({TRAIN_LOSS}): {Hamiltonian_recon_loss}')
print(f'  Range penalty loss: {penalty_loss} (weighted: {penalty_loss * PENALTY_WEIGHT})')

# Check out-of-range
inverse_model = combined_model.get_layer('inverse_model')
qiskit_pred = inverse_model.predict(np.asarray(X_test), verbose=0)
out_of_range = np.sum((qiskit_pred < 0) | (qiskit_pred > 1))
total_values = qiskit_pred.size
print(f'Out-of-range values: {out_of_range}/{total_values} ({100*out_of_range/total_values:.1f}%)')

test_loss_result = Hamiltonian_recon_loss
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - inverse_model_loss: 7.9028e-06 - loss: 0.0089 - sequential_loss: 0.0010
# Total test loss: 0.008915177546441555
#   Reconstruction loss (mae): 0.001035809749737382
#   Range penalty loss: 7.902755896793678e-06 (weighted: 7.902755896793679e-07)
# Out-of-range values: 11/873 (1.3%)

# %% [markdown]
# ## Compare predictions vs. test set

# %%
csv_data = [[
    DATA_AUGMENTATION,
    'surrogate_loss_model',
    'InverseModel_SurrogateLoss',
    test_loss_result,
    TRAIN_LOSS,
    TRAIN_BATCH_SIZE,
]]
with open('test_results.csv', 'a', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(csv_data)
    print(f'Appended to test_results.csv: {csv_data}')
# Out:
# Appended to test_results.csv: [[True, 'surrogate_loss_model', 'InverseModel_SurrogateLoss', 0.001035809749737382, 'mae', 128]]

# %%
# predictaroo on test set
tf.keras.backend.clear_session()
gc.collect()

with tf.device('/CPU:0'):
    combined_model = load_model(best_model_file, compile=False,
        custom_objects={'ScalerConversionLayer': ScalerConversionLayer})
    predictions = combined_model.predict(np.asarray(X_test), verbose=0)
    if isinstance(predictions, list):
        Hamiltonian_reconstructed = predictions[0]
        qiskit_predicted = predictions[1]
    else:
        Hamiltonian_reconstructed = predictions
        inverse_model = combined_model.get_layer('inverse_model')
        qiskit_predicted = inverse_model.predict(np.asarray(X_test), verbose=0)

# %%
# look at how well the reconstructed Hamiltonian matches the input Hamiltonian

X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)  # ground truth Qiskit params (for reference)
Hamiltonian_recon  = np.asarray(Hamiltonian_reconstructed)
qiskit_pred = np.asarray(qiskit_predicted)

n_samples, n_Hamiltonian_cols = X_test_cur.shape
n_qiskit_cols = qiskit_pred.shape[1]
n_samples_to_show = 3

# reconstruction errors (Hamiltonian space — this is what we trained on)
Hamiltonian_abs_errors = np.abs(X_test_cur - Hamiltonian_recon)

print('########## Hamiltonian Reconstruction (what the loss is based on) #############')
for i in range(n_samples_to_show):
    rows = []
    for j in range(n_Hamiltonian_cols):
        label = Hamiltonian_column_names[j] if j < len(Hamiltonian_column_names) else f'Hamiltonian_col_{j}'
        rows.append({'param': label, 'ref': X_test_cur[i,j],
                     'pred': Hamiltonian_recon[i,j], 'abs_error': Hamiltonian_abs_errors[i,j]})
    print(f'— Sample {i} — Hamiltonian reconstruction (scaled)')
    print(pd.DataFrame(rows).to_string(index=False))
    
    # predicted Qiskit params
    print(f'\n  Predicted Qiskit Metal params (scaled):')
    for j, col_name in enumerate(qiskit_param_names):
        short = col_name.replace('design_options.', '')
        print(f'    {short:40s}  pred={qiskit_pred[i,j]:.6f}  ref={y_test_cur[i,j]:.6f}  err={abs(qiskit_pred[i,j]-y_test_cur[i,j]):.6f}')
    print()
# Out:
# ########## Hamiltonian Reconstruction (what the loss is based on) #############
# — Sample 0 — Hamiltonian reconstruction (scaled)
#               param      ref     pred  abs_error
# qubit_frequency_GHz 0.229409 0.228653   0.000757
#   anharmonicity_MHz 0.858338 0.856715   0.001623
#
#   Predicted Qiskit Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.048381  ref=0.333333  err=0.284952
#     connection_pads.readout.ground_spacing    pred=0.145037  ref=0.152542  err=0.007506
#     cross_length                              pred=0.526674  ref=0.515152  err=0.011522
#
# — Sample 1 — Hamiltonian reconstruction (scaled)
#               param      ref     pred  abs_error
# qubit_frequency_GHz 0.189596 0.188595   0.001002
#   anharmonicity_MHz 0.886036 0.886011   0.000025
#
#   Predicted Qiskit Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.042676  ref=0.090909  err=0.048233
#     connection_pads.readout.ground_spacing    pred=0.164918  ref=1.000000  err=0.835082
#     cross_length                              pred=0.578971  ref=0.606061  err=0.027090
#
# — Sample 2 — Hamiltonian reconstruction (scaled)
#               param      ref     pred  abs_error
# qubit_frequency_GHz 0.467938 0.467024   0.000913
#   anharmonicity_MHz 0.662521 0.661571   0.000950
#
#   Predicted Qiskit Metal params (scaled):
#     connection_pads.readout.claw_length       pred=0.032084  ref=0.121212  err=0.089128
#     connection_pads.readout.ground_spacing    pred=0.067855  ref=0.000000  err=0.067855
#     cross_length                              pred=0.274820  ref=0.272727  err=0.002093

# %% [markdown]
# ### Unscaled test vs predictions

# %%
# Unscale everything and look at errors in real units that we can actually make sense of
with open('X_names', 'r') as f:
    Hamiltonian_names = f.read().splitlines()
qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()

# Unscale input Hamiltonian
x_scaler_prefix = 'scaler_X'
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        Hamiltonian_name = Hamiltonian_names[j] if j < len(Hamiltonian_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/{x_scaler_prefix}_{Hamiltonian_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale reconstructed Hamiltonian
Hamiltonian_recon_unscaled = np.asarray(Hamiltonian_recon.copy())
for i in range(Hamiltonian_recon_unscaled.shape[0]):
    for j in range(Hamiltonian_recon_unscaled.shape[1]):
        Hamiltonian_name = Hamiltonian_names[j] if j < len(Hamiltonian_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/{x_scaler_prefix}_{Hamiltonian_name}.save')
        Hamiltonian_recon_unscaled[i, j] = scaler.inverse_transform([[Hamiltonian_recon_unscaled[i, j]]])[0][0]

# Unscale Qiskit param predictions (using ml_00 one_hot scalers)
qiskit_pred_unscaled = np.asarray(qiskit_pred.copy())
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(qiskit_pred_unscaled.shape[0]):
    for j in range(qiskit_pred_unscaled.shape[1]):
        col_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_{col_name}_one_hot_encoding.save')
        qiskit_pred_unscaled[i, j] = scaler.inverse_transform([[qiskit_pred_unscaled[i, j]]])[0][0]
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

n_samples_to_show = 3
Hamiltonian_abs_unscaled = np.abs(X_test_unscaled - Hamiltonian_recon_unscaled)

data = {"ref_qubit_frequency_GHz":[],
        "ref_anharmonicity_MHz":[],
        "ref_connection_pads.readout.claw_length":[],
        "ref_connection_pads.readout.ground_spacing":[],
        "ref_cross_length":[],
        "pred_qubit_frequency_GHz":[],
        "pred_anharmonicity_MHz":[],
        "pred_connection_pads.readout.claw_length":[],
        "pred_connection_pads.readout.ground_spacing":[],
        "pred_cross_length":[]}

print('########## Unscaled Hamiltonian Reconstruction #############')
for i in range(n_samples_to_show):
    rows = []
    for j in range(X_test_unscaled.shape[1]):
        rows.append({'param': Hamiltonian_names[j], 'ref_unscaled': X_test_unscaled[i,j],
                     'pred_unscaled': Hamiltonian_recon_unscaled[i,j], 'abs_error': Hamiltonian_abs_unscaled[i,j]})
        data["ref_"+Hamiltonian_names[j]] += [X_test_unscaled[i,j]]
        data["pred_"+Hamiltonian_names[j]] += [Hamiltonian_recon_unscaled[i,j]]
    print(f'— Sample {i} (Unscaled) — Hamiltonian reconstruction')
    
    print(pd.DataFrame(rows).to_string(index=False))
    
    print(f'\n  Predicted Qiskit Metal params (unscaled):')
    for j, col_name in enumerate(qiskit_names):
        short = col_name.replace('design_options.', '')
        print(f'    {short:40s}  pred={qiskit_pred_unscaled[i,j]:.6f}  ref={y_test_unscaled[i,j]:.6f}  err={abs(qiskit_pred_unscaled[i,j]-y_test_unscaled[i,j]):.6f}')
        data["pred_"+short] += [qiskit_pred_unscaled[i,j]]
        data["ref_"+short] += [y_test_unscaled[i,j]]

        
    print(f'\n  Reference Qiskit Metal params (unscaled):')
    for j, col_name in enumerate(qiskit_names):
        short = col_name.replace('design_options.', '')
        print(f'    {short:40s}  ref={y_test_unscaled[i,j]:.6f}')
    print()

print('Unscaled Hamiltonian reconstruction error stats:')
print('  min:', float(Hamiltonian_abs_unscaled.min()),
      ' median:', float(np.median(Hamiltonian_abs_unscaled)),
      ' max:', float(Hamiltonian_abs_unscaled.max()))
# Out:
# ########## Unscaled Hamiltonian Reconstruction #############
# — Sample 0 (Unscaled) — Hamiltonian reconstruction
#               param  ref_unscaled  pred_unscaled  abs_error
# qubit_frequency_GHz      4.115077       4.112121   0.002957
#   anharmonicity_MHz   -150.844376    -151.553421   0.709045
#
#   Predicted Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.000086  ref=0.000180  err=0.000094
#     connection_pads.readout.ground_spacing    pred=0.000005  ref=0.000005  err=0.000000
#     cross_length                              pred=0.000264  ref=0.000260  err=0.000004
#
#   Reference Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.000180
#     connection_pads.readout.ground_spacing    ref=0.000005
#     cross_length                              ref=0.000260
#
# — Sample 1 (Unscaled) — Hamiltonian reconstruction
#               param  ref_unscaled  pred_unscaled  abs_error
# qubit_frequency_GHz      3.959486       3.955572   0.003914
#   anharmonicity_MHz   -138.744125    -138.754944   0.010818
#
#   Predicted Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.000084  ref=0.000100  err=0.000016
#     connection_pads.readout.ground_spacing    pred=0.000005  ref=0.000010  err=0.000005
#     cross_length                              pred=0.000281  ref=0.000290  err=0.000009
#
#   Reference Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.000100
#     connection_pads.readout.ground_spacing    ref=0.000010
#     cross_length                              ref=0.000290
#
# — Sample 2 (Unscaled) — Hamiltonian reconstruction
#               param  ref_unscaled  pred_unscaled  abs_error
# qubit_frequency_GHz      5.047258       5.043689   0.003570
#   anharmonicity_MHz   -236.389038    -236.804001   0.414963
#
#   Predicted Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       pred=0.000081  ref=0.000110  err=0.000029
#     connection_pads.readout.ground_spacing    pred=0.000005  ref=0.000004  err=0.000000
#     cross_length                              pred=0.000181  ref=0.000180  err=0.000001
#
#   Reference Qiskit Metal params (unscaled):
#     connection_pads.readout.claw_length       ref=0.000110
#     connection_pads.readout.ground_spacing    ref=0.000004
#     cross_length                              ref=0.000180
#
# Unscaled Hamiltonian reconstruction error stats:
#   min: 2.6702880859375e-05  median: 0.0099639892578125  max: 20.960205078125

# %%
pd.DataFrame(data).to_csv("Hamiltonian-based-full_MLP_results.csv",index = False)
