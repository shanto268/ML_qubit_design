# %% [markdown]
# # Model Predictions (coupler_NCap_cap_matrix)
# ## Qiskit Metal --> Capacitance
#
# Ansys surrogate model

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters_surrogate import *

# %% [markdown]
# ## Library

# %%
import os, gc, math
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
def load_scaled_split(kind, split):
    return np.load(f"{DATA_DIR}/npy/{split}_{kind}_encoding_scaled.npy", allow_pickle=True)

# new inputs are our Qiskit Metal params, using good ole linear encoding
X_train = load_scaled_split('linear', 'y_train')
X_val   = load_scaled_split('linear', 'y_val')
X_test  = load_scaled_split('linear', 'y_test')

# new outputs are the capacitance values
y_train = load_scaled_split('linear', 'x_train')
y_val   = load_scaled_split('linear', 'x_val')
y_test  = load_scaled_split('linear', 'x_test')

# load column name files for later reference fer outputs
with open('X_names', 'r') as f:
    cap_column_names = f.read().splitlines()   

# input names
qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist() 

#check to make sure these printouts make sense and we arent flippered
print(f'Inputs (Qiskit params):  {X_train.shape[1]} columns')
print(f'Outputs (Capacitance):    {y_train.shape[1]} columns')
print(f'\nInput columns:  {qiskit_param_names}')
print(f'Output columns: {cap_column_names}')
# Out:
# Inputs (Qiskit params):  4 columns
# Outputs (Capacitance):    6 columns
#
# Input columns:  ['design_options.cap_gap', 'design_options.cap_width', 'design_options.finger_length', 'design_options.finger_count']
# Output columns: ['top_to_top', 'top_to_bottom', 'top_to_ground', 'bottom_to_bottom', 'bottom_to_ground', 'ground_to_ground']

# %% [markdown]
# ### Visualize model

# %%
# Decide which model file to use
encoding = 'model2_surrogate'
chosen_path = f'model/best_keras_model_model2_surrogate.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

# Load output headers (capacitance column names)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Output headers: {headers}')
# Out:
# Model path: model/best_keras_model_model2_surrogate.keras
# Output headers: ['top_to_top', 'top_to_bottom', 'top_to_ground', 'bottom_to_bottom', 'bottom_to_ground', 'ground_to_ground']

# %%
#look at the best model, ooh so pretty
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    y_pred = chosen_model.predict(X_test_cur, verbose=0)

print(f'\n—— {os.path.basename(chosen_path)} ——')
chosen_model.summary()
print(f'Samples: {len(X_test_cur)} | Targets dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771987832.255905  998990 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1065 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:10.0, compute capability: 8.0
# I0000 00:00:1771987832.435720 1737784 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# —— best_keras_model_model2_surrogate.keras ——
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 672)            │         3,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 672)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 672)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │         4,038 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,398 (28.90 KB)
#  Trainable params: 7,398 (28.90 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 65 | Targets dim: 6

# %%
# look at some more specific model params
m = tf.keras.models.load_model(chosen_path, compile=True)

neurons_per_layer = [
    l.units for l in m.layers
    if isinstance(l, tf.keras.layers.Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

dropouts = [
    (l.name, float(l.rate)) for l in m.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')

opt = getattr(m, 'optimizer', None)
if opt is None:
    print('Best learning rate: (no optimizer found on loaded model)')
else:
    lr_obj = opt.learning_rate

    if isinstance(lr_obj, tf.keras.optimizers.schedules.LearningRateSchedule):
        print('Best learning rate: (schedule)', type(lr_obj).__name__)
        try:
            cfg = lr_obj.get_config()
            print('LR schedule config:')
            for k, v in sorted(cfg.items()):
                print(f'  {k}: {v}')
        except Exception as e:
            print('Could not read LR schedule config:', repr(e))
        try:
            step = int(tf.keras.backend.get_value(opt.iterations))
            current_lr = float(lr_obj(step).numpy())
            print(f'Current LR at step {step}:', current_lr)
        except Exception as e:
            print('Could not compute current LR from schedule:', repr(e))
    else:
        try:
            lr_val = float(tf.keras.backend.get_value(lr_obj))
            print('Best learning rate:', lr_val)
        except Exception as e:
            print('Best learning rate: (unreadable)', repr(e))
# Out:
# Best NEURONS_PER_LAYER: [672]
# Best DROPOUT rate(s): [('dropout0', 0.0)]
# Best learning rate: 0.06463316082954407
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50 # change this to print more stuff

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred     = np.asarray(y_pred)

N, P = y_test_cur.shape

# make sure y_pred shape matches
if y_pred.ndim == 3 and y_pred.shape[-1] == 1:
    y_pred = y_pred[..., 0]
if y_pred.ndim == 1:
    y_pred = y_pred.reshape(-1, 1)
assert y_pred.shape == (N, P), f'y_pred shape {y_pred.shape} != expected {(N, P)}'

# scaled errors
sq_errors  = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# building dataframe
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  y_test_cur[i, j],
            'pred': y_pred[i, j],
            'abs_error': abs_errors[i, j],
            'sq_error':  sq_errors[i, j],
        })

df = pd.DataFrame(rows)

# save scaled predictions
out_csv = Path(f'model2_predictions_and_errors_{encoding}.csv')
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

# Pretty print per-sample (scaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    input_str = ', '.join(
        f'{qiskit_param_names[k] if k < len(qiskit_param_names) else f"in_{k}"}={X_test_cur[i,k]:.6g}'
        for k in range(X_test_cur.shape[1])
    )
    print(f'— Sample {i} — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global scaled error stats:')
print('  min abs_error:', float(abs_errors.min()))
print('  median abs_error:', float(np.median(abs_errors)))
print('  max abs_error:', float(abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_model2_surrogate.csv
#
# — Sample 0 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.008322 0.016386   0.008064  0.000065
#    top_to_bottom 0.005650 0.012424   0.006774  0.000046
#    top_to_ground 0.036568 0.030513   0.006054  0.000037
# bottom_to_bottom 0.006921 0.012498   0.005577  0.000031
# bottom_to_ground 0.008502 0.012473   0.003971  0.000016
# ground_to_ground 0.011026 0.012030   0.001004  0.000001
#
# — Sample 1 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.111111
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.091476 0.097741   0.006265 3.924422e-05
#    top_to_bottom 0.064207 0.064638   0.000430 1.850952e-07
#    top_to_ground 0.158028 0.166173   0.008146 6.635272e-05
# bottom_to_bottom 0.111460 0.107911   0.003549 1.259688e-05
# bottom_to_ground 0.142611 0.138859   0.003752 1.407549e-05
# ground_to_ground 0.146250 0.152179   0.005929 3.515191e-05
#
# — Sample 2 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.402785 0.397985   0.004801  0.000023
#    top_to_bottom 0.367666 0.372740   0.005075  0.000026
#    top_to_ground 0.463301 0.443179   0.020122  0.000405
# bottom_to_bottom 0.414302 0.417656   0.003354  0.000011
# bottom_to_ground 0.443569 0.448672   0.005104  0.000026
# ground_to_ground 0.458855 0.453885   0.004970  0.000025
#
# — Sample 3 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.404664 0.381924   0.022741 5.171311e-04
#    top_to_bottom 0.351577 0.349435   0.002142 4.587135e-06
#    top_to_ground 0.497000 0.433128   0.063871 4.079558e-03
# bottom_to_bottom 0.324300 0.332197   0.007897 6.235574e-05
# bottom_to_ground 0.301817 0.319373   0.017555 3.081945e-04
# ground_to_ground 0.357188 0.356228   0.000960 9.215453e-07
#
# — Sample 4 — Inputs: design_options.cap_gap=1, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.213806 0.208052   0.005754  0.000033
#    top_to_bottom 0.207886 0.195486   0.012400  0.000154
#    top_to_ground 0.232536 0.234007   0.001472  0.000002
# bottom_to_bottom 0.231250 0.227459   0.003792  0.000014
# bottom_to_ground 0.244814 0.248652   0.003838  0.000015
# ground_to_ground 0.241262 0.243986   0.002724  0.000007
#
# — Sample 5 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0, design_options.finger_count=0.111111
#            param       ref      pred  abs_error     sq_error
#       top_to_top  0.008338  0.015567   0.007229 5.226560e-05
#    top_to_bottom  0.028416  0.029005   0.000589 3.470051e-07
#    top_to_ground -0.007155 -0.002793   0.004362 1.902770e-05
# bottom_to_bottom  0.031050  0.031556   0.000506 2.555572e-07
# bottom_to_ground  0.033077  0.033716   0.000639 4.079585e-07
# ground_to_ground  0.020011  0.017587   0.002424 5.874982e-06
#
# — Sample 6 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=1, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.283823 0.318718   0.034895  0.001218
#    top_to_bottom 0.327926 0.337840   0.009914  0.000098
#    top_to_ground 0.204258 0.291983   0.087726  0.007696
# bottom_to_bottom 0.248655 0.235408   0.013246  0.000175
# bottom_to_ground 0.193185 0.163743   0.029442  0.000867
# ground_to_ground 0.196034 0.197044   0.001010  0.000001
#
# — Sample 7 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.084377 0.075192   0.009184 8.435228e-05
#    top_to_bottom 0.015754 0.008422   0.007332 5.375499e-05
#    top_to_ground 0.228793 0.224517   0.004276 1.828002e-05
# bottom_to_bottom 0.033242 0.033590   0.000349 1.215556e-07
# bottom_to_ground 0.045173 0.054307   0.009135 8.344023e-05
# ground_to_ground 0.096269 0.095712   0.000557 3.102886e-07
#
# — Sample 8 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.260603 0.279375   0.018772  0.000352
#    top_to_bottom 0.210877 0.215969   0.005092  0.000026
#    top_to_ground 0.353997 0.401240   0.047243  0.002232
# bottom_to_bottom 0.346117 0.340625   0.005493  0.000030
# bottom_to_ground 0.435975 0.425473   0.010502  0.000110
# ground_to_ground 0.419407 0.423000   0.003593  0.000013
#
# — Sample 9 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.047056 0.058538   0.011482  0.000132
#    top_to_bottom 0.039740 0.041344   0.001605  0.000003
#    top_to_ground 0.079736 0.102452   0.022716  0.000516
# bottom_to_bottom 0.084525 0.080141   0.004384  0.000019
# bottom_to_ground 0.114599 0.106879   0.007721  0.000060
# ground_to_ground 0.100402 0.110018   0.009616  0.000092
#
# — Sample 10 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.430105 0.398659   0.031446 9.888421e-04
#    top_to_bottom 0.377793 0.377247   0.000546 2.983539e-07
#    top_to_ground 0.519088 0.427477   0.091611 8.392610e-03
# bottom_to_bottom 0.386090 0.399525   0.013435 1.805116e-04
# bottom_to_ground 0.388879 0.413569   0.024689 6.095511e-04
# ground_to_ground 0.423986 0.421350   0.002636 6.949331e-06
#
# — Sample 11 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.448446 0.423531   0.024915  0.000621
#    top_to_bottom 0.321001 0.305459   0.015542  0.000242
#    top_to_ground 0.670319 0.627007   0.043312  0.001876
# bottom_to_bottom 0.558098 0.563016   0.004918  0.000024
# bottom_to_ground 0.717224 0.733398   0.016173  0.000262
# ground_to_ground 0.709871 0.708352   0.001519  0.000002
#
# — Sample 12 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.148721 0.127711   0.021010  0.000441
#    top_to_bottom 0.158220 0.137788   0.020432  0.000417
#    top_to_ground 0.142871 0.121007   0.021865  0.000478
# bottom_to_bottom 0.129865 0.124653   0.005212  0.000027
# bottom_to_ground 0.108988 0.116046   0.007058  0.000050
# ground_to_ground 0.118296 0.112559   0.005738  0.000033
#
# — Sample 13 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.291762 0.263235   0.028527 8.137825e-04
#    top_to_bottom 0.234925 0.208365   0.026560 7.054442e-04
#    top_to_ground 0.402457 0.354995   0.047463 2.252707e-03
# bottom_to_bottom 0.351839 0.352411   0.000572 3.275669e-07
# bottom_to_ground 0.429628 0.446206   0.016578 2.748231e-04
# ground_to_ground 0.426779 0.428816   0.002038 4.152983e-06
#
# — Sample 14 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.079789 0.079055   0.000734 5.390624e-07
#    top_to_bottom 0.004458 0.004787   0.000329 1.079742e-07
#    top_to_ground 0.237945 0.240201   0.002256 5.091518e-06
# bottom_to_bottom 0.014040 0.012478   0.001562 2.439565e-06
# bottom_to_ground 0.021339 0.019210   0.002128 4.530036e-06
# ground_to_ground 0.078196 0.078700   0.000505 2.548522e-07
#
# — Sample 15 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.276191 0.293637   0.017446 3.043627e-04
#    top_to_bottom 0.271145 0.278985   0.007840 6.146542e-05
#    top_to_ground 0.286324 0.325096   0.038772 1.503305e-03
# bottom_to_bottom 0.355950 0.349434   0.006516 4.245712e-05
# bottom_to_ground 0.412403 0.394190   0.018213 3.317201e-04
# ground_to_ground 0.383440 0.383402   0.000038 1.430342e-09
#
# — Sample 16 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.130494 0.126313   0.004181  0.000017
#    top_to_bottom 0.132689 0.130015   0.002674  0.000007
#    top_to_ground 0.139709 0.132334   0.007375  0.000054
# bottom_to_bottom 0.151183 0.149883   0.001301  0.000002
# bottom_to_ground 0.164225 0.163115   0.001111  0.000001
# ground_to_ground 0.160597 0.153301   0.007297  0.000053
#
# — Sample 17 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.714760 0.716840   0.002080  0.000004
#    top_to_bottom 0.774634 0.766937   0.007697  0.000059
#    top_to_ground 0.566674 0.593177   0.026503  0.000702
# bottom_to_bottom 0.670394 0.665593   0.004801  0.000023
# bottom_to_ground 0.598010 0.588748   0.009262  0.000086
# ground_to_ground 0.600376 0.599035   0.001341  0.000002
#
# — Sample 18 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.499256 0.511486   0.012231  0.000150
#    top_to_bottom 0.468010 0.466403   0.001606  0.000003
#    top_to_ground 0.538020 0.576077   0.038057  0.001448
# bottom_to_bottom 0.489613 0.482690   0.006922  0.000048
# bottom_to_ground 0.503055 0.492133   0.010922  0.000119
# ground_to_ground 0.518191 0.521507   0.003316  0.000011
#
# — Sample 19 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.679516 0.657652   0.021864  0.000478
#    top_to_bottom 0.594847 0.585828   0.009018  0.000081
#    top_to_ground 0.810141 0.754138   0.056003  0.003136
# bottom_to_bottom 0.732685 0.737357   0.004672  0.000022
# bottom_to_ground 0.822124 0.836271   0.014147  0.000200
# ground_to_ground 0.829590 0.821745   0.007845  0.000062
#
# — Sample 20 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.138910 0.155960   0.017050  0.000291
#    top_to_bottom 0.125659 0.129903   0.004244  0.000018
#    top_to_ground 0.175197 0.219803   0.044607  0.001990
# bottom_to_bottom 0.191415 0.189434   0.001981  0.000004
# bottom_to_ground 0.236843 0.231223   0.005620  0.000032
# ground_to_ground 0.223450 0.229983   0.006532  0.000043
#
# — Sample 21 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.473986 0.440589   0.033397 1.115385e-03
#    top_to_bottom 0.400671 0.400929   0.000258 6.653421e-08
#    top_to_ground 0.594963 0.500186   0.094777 8.982747e-03
# bottom_to_bottom 0.398062 0.414990   0.016927 2.865393e-04
# bottom_to_ground 0.395822 0.424313   0.028491 8.117429e-04
# ground_to_ground 0.455432 0.453918   0.001514 2.292900e-06
#
# — Sample 22 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.073038 0.074123   0.001085  0.000001
#    top_to_bottom 0.020032 0.023330   0.003298  0.000011
#    top_to_ground 0.190523 0.193370   0.002847  0.000008
# bottom_to_bottom 0.043571 0.051919   0.008348  0.000070
# bottom_to_ground 0.059566 0.076706   0.017140  0.000294
# ground_to_ground 0.089884 0.102390   0.012507  0.000156
#
# — Sample 23 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.059327 0.053413   0.005915 3.498140e-05
#    top_to_bottom 0.050065 0.054302   0.004237 1.795330e-05
#    top_to_ground 0.094860 0.067200   0.027659 7.650451e-04
# bottom_to_bottom 0.071285 0.074984   0.003699 1.368132e-05
# bottom_to_ground 0.085736 0.091052   0.005316 2.825677e-05
# ground_to_ground 0.084530 0.084524   0.000006 4.005876e-11
#
# — Sample 24 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.048595 0.042123   0.006472  0.000042
#    top_to_bottom 0.006953 0.004533   0.002420  0.000006
#    top_to_ground 0.145796 0.130408   0.015388  0.000237
# bottom_to_bottom 0.022530 0.011306   0.011224  0.000126
# bottom_to_ground 0.033037 0.017835   0.015201  0.000231
# ground_to_ground 0.057189 0.046733   0.010456  0.000109
#
# — Sample 25 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.617564 0.608850   0.008714  0.000076
#    top_to_bottom 0.545968 0.537256   0.008712  0.000076
#    top_to_ground 0.724315 0.714759   0.009556  0.000091
# bottom_to_bottom 0.664435 0.652640   0.011794  0.000139
# bottom_to_ground 0.739095 0.727704   0.011391  0.000130
# ground_to_ground 0.740586 0.726231   0.014355  0.000206
#
# — Sample 26 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.036495 0.052275   0.015780  0.000249
#    top_to_bottom 0.035958 0.049609   0.013651  0.000186
#    top_to_ground 0.057925 0.066910   0.008985  0.000081
# bottom_to_bottom 0.057857 0.060641   0.002784  0.000008
# bottom_to_ground 0.072583 0.069991   0.002593  0.000007
# ground_to_ground 0.066397 0.070127   0.003730  0.000014
#
# — Sample 27 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.229408 0.247469   0.018060 3.261754e-04
#    top_to_bottom 0.209984 0.209176   0.000807 6.518798e-07
#    top_to_ground 0.271286 0.312957   0.041672 1.736541e-03
# bottom_to_bottom 0.273476 0.256504   0.016972 2.880540e-04
# bottom_to_ground 0.316015 0.288385   0.027630 7.634058e-04
# ground_to_ground 0.308735 0.302980   0.005756 3.312614e-05
#
# — Sample 28 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.094704 0.094751   0.000047 2.198739e-09
#    top_to_bottom 0.119400 0.102556   0.016844 2.837174e-04
#    top_to_ground 0.063744 0.089595   0.025852 6.683041e-04
# bottom_to_bottom 0.107488 0.096262   0.011225 1.260082e-04
# bottom_to_ground 0.098611 0.092408   0.006203 3.847866e-05
# ground_to_ground 0.088571 0.086709   0.001863 3.469018e-06
#
# — Sample 29 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.222222
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.122095 0.114859   0.007237  0.000052
#    top_to_bottom 0.084135 0.100696   0.016561  0.000274
#    top_to_ground 0.208211 0.151420   0.056790  0.003225
# bottom_to_bottom 0.112315 0.124807   0.012492  0.000156
# bottom_to_ground 0.130871 0.142980   0.012109  0.000147
# ground_to_ground 0.147332 0.149583   0.002251  0.000005
#
# — Sample 30 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.027098 0.031471   0.004372 1.911724e-05
#    top_to_bottom 0.002107 0.003482   0.001375 1.891773e-06
#    top_to_ground 0.096638 0.093981   0.002657 7.061515e-06
# bottom_to_bottom 0.006607 0.006715   0.000108 1.169345e-08
# bottom_to_ground 0.010188 0.010131   0.000057 3.283157e-09
# ground_to_ground 0.029162 0.030247   0.001085 1.177005e-06
#
# — Sample 31 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.587185 0.555837   0.031348  0.000983
#    top_to_bottom 0.485342 0.483710   0.001632  0.000003
#    top_to_ground 0.751844 0.665909   0.085935  0.007385
# bottom_to_bottom 0.572159 0.592826   0.020668  0.000427
# bottom_to_ground 0.625899 0.664727   0.038828  0.001508
# ground_to_ground 0.664639 0.669029   0.004390  0.000019
#
# — Sample 32 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.392096 0.408216   0.016121  0.000260
#    top_to_bottom 0.392475 0.391000   0.001476  0.000002
#    top_to_ground 0.382292 0.441777   0.059485  0.003538
# bottom_to_bottom 0.410187 0.390718   0.019468  0.000379
# bottom_to_ground 0.419317 0.393598   0.025719  0.000661
# ground_to_ground 0.413538 0.415007   0.001468  0.000002
#
# — Sample 33 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.171594 0.180803   0.009209  0.000085
#    top_to_bottom 0.186373 0.188450   0.002076  0.000004
#    top_to_ground 0.153723 0.178262   0.024539  0.000602
# bottom_to_bottom 0.175244 0.162878   0.012366  0.000153
# bottom_to_ground 0.167240 0.147310   0.019929  0.000397
# ground_to_ground 0.162308 0.156194   0.006114  0.000037
#
# — Sample 34 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.134165 0.153934   0.019769  0.000391
#    top_to_bottom 0.107647 0.116517   0.008870  0.000079
#    top_to_ground 0.194668 0.234581   0.039913  0.001593
# bottom_to_bottom 0.195008 0.190661   0.004347  0.000019
# bottom_to_ground 0.253304 0.242545   0.010759  0.000116
# ground_to_ground 0.242630 0.248013   0.005382  0.000029
#
# — Sample 35 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.484370 0.490664   0.006294  0.000040
#    top_to_bottom 0.424961 0.423640   0.001321  0.000002
#    top_to_ground 0.577986 0.594830   0.016844  0.000284
# bottom_to_bottom 0.525359 0.522358   0.003001  0.000009
# bottom_to_ground 0.589459 0.588322   0.001137  0.000001
# ground_to_ground 0.591555 0.595589   0.004034  0.000016
#
# — Sample 36 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.888889
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.680926 0.637749   0.043178 1.864318e-03
#    top_to_bottom 0.689792 0.675744   0.014048 1.973432e-04
#    top_to_ground 0.643570 0.548393   0.095177 9.058621e-03
# bottom_to_bottom 0.574498 0.588011   0.013512 1.825857e-04
# bottom_to_ground 0.492548 0.522882   0.030334 9.201342e-04
# ground_to_ground 0.539862 0.539255   0.000608 3.691306e-07
#
# — Sample 37 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.484109 0.482083   0.002026  0.000004
#    top_to_bottom 0.360526 0.359305   0.001221  0.000001
#    top_to_ground 0.699071 0.690512   0.008558  0.000073
# bottom_to_bottom 0.635468 0.634047   0.001421  0.000002
# bottom_to_ground 0.821086 0.814156   0.006930  0.000048
# ground_to_ground 0.797880 0.784085   0.013795  0.000190
#
# — Sample 38 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.060299 0.056472   0.003827 1.464239e-05
#    top_to_bottom 0.008687 0.003741   0.004946 2.445844e-05
#    top_to_ground 0.176039 0.174918   0.001121 1.256032e-06
# bottom_to_bottom 0.014931 0.012738   0.002193 4.811337e-06
# bottom_to_ground 0.019436 0.019608   0.000172 2.968575e-08
# ground_to_ground 0.053855 0.058111   0.004255 1.810782e-05
#
# — Sample 39 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.560868 0.559877   0.000991 9.811332e-07
#    top_to_bottom 0.602707 0.586162   0.016545 2.737469e-04
#    top_to_ground 0.460045 0.503913   0.043868 1.924397e-03
# bottom_to_bottom 0.529571 0.511294   0.018276 3.340275e-04
# bottom_to_ground 0.477644 0.457290   0.020354 4.142990e-04
# ground_to_ground 0.481924 0.479825   0.002100 4.408070e-06
#
# — Sample 40 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.499802 0.521866   0.022064  0.000487
#    top_to_bottom 0.466020 0.464354   0.001667  0.000003
#    top_to_ground 0.544451 0.603461   0.059010  0.003482
# bottom_to_bottom 0.539175 0.528303   0.010872  0.000118
# bottom_to_ground 0.588948 0.571881   0.017067  0.000291
# ground_to_ground 0.590531 0.585247   0.005284  0.000028
#
# — Sample 41 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.052282 0.063340   0.011058  0.000122
#    top_to_bottom 0.043787 0.052999   0.009212  0.000085
#    top_to_ground 0.086869 0.091040   0.004171  0.000017
# bottom_to_bottom 0.077188 0.069613   0.007576  0.000057
# bottom_to_ground 0.099567 0.081534   0.018033  0.000325
# ground_to_ground 0.092190 0.087360   0.004830  0.000023
#
# — Sample 42 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.017988 0.027744   0.009756  0.000095
#    top_to_bottom 0.008808 0.013953   0.005145  0.000026
#    top_to_ground 0.057227 0.059810   0.002582  0.000007
# bottom_to_bottom 0.014839 0.019549   0.004710  0.000022
# bottom_to_ground 0.019434 0.022143   0.002708  0.000007
# ground_to_ground 0.019815 0.029032   0.009218  0.000085
#
# — Sample 43 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.222222
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.172355 0.133252   0.039103  0.001529
#    top_to_bottom 0.114619 0.121078   0.006460  0.000042
#    top_to_ground 0.290661 0.168538   0.122123  0.014914
# bottom_to_bottom 0.108830 0.128136   0.019305  0.000373
# bottom_to_ground 0.103569 0.135599   0.032030  0.001026
# ground_to_ground 0.151995 0.149471   0.002524  0.000006
#
# — Sample 44 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.370294 0.390499   0.020205  0.000408
#    top_to_bottom 0.379841 0.380899   0.001058  0.000001
#    top_to_ground 0.346985 0.409390   0.062406  0.003894
# bottom_to_bottom 0.413253 0.397168   0.016085  0.000259
# bottom_to_ground 0.433770 0.408368   0.025401  0.000645
# ground_to_ground 0.416981 0.413932   0.003048  0.000009
#
# — Sample 45 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.222222
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.210038 0.180399   0.029639  0.000878
#    top_to_bottom 0.162100 0.156363   0.005736  0.000033
#    top_to_ground 0.305442 0.230150   0.075292  0.005669
# bottom_to_bottom 0.167147 0.179535   0.012388  0.000153
# bottom_to_ground 0.169341 0.195935   0.026594  0.000707
# ground_to_ground 0.200831 0.210969   0.010138  0.000103
#
# — Sample 46 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.370581 0.351700   0.018881 3.564923e-04
#    top_to_bottom 0.304996 0.300107   0.004888 2.389718e-05
#    top_to_ground 0.490824 0.435399   0.055424 3.071848e-03
# bottom_to_bottom 0.385001 0.393767   0.008766 7.684618e-05
# bottom_to_ground 0.437327 0.456464   0.019137 3.662332e-04
# ground_to_ground 0.455829 0.455226   0.000603 3.639917e-07
#
# — Sample 47 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.419469 0.398798   0.020671  0.000427
#    top_to_bottom 0.343863 0.330441   0.013422  0.000180
#    top_to_ground 0.551974 0.511068   0.040906  0.001673
# bottom_to_bottom 0.509924 0.518861   0.008937  0.000080
# bottom_to_ground 0.618946 0.640265   0.021320  0.000455
# ground_to_ground 0.607929 0.614613   0.006684  0.000045
#
# — Sample 48 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.058123 0.060973   0.002851 8.126840e-06
#    top_to_bottom 0.009784 0.016719   0.006935 4.809078e-05
#    top_to_ground 0.167070 0.166105   0.000965 9.312189e-07
# bottom_to_bottom 0.031604 0.034198   0.002594 6.729117e-06
# bottom_to_ground 0.046336 0.051004   0.004668 2.179264e-05
# ground_to_ground 0.077859 0.079081   0.001222 1.492137e-06
#
# — Sample 49 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.598859 0.557986   0.040872  0.001671
#    top_to_bottom 0.569728 0.566393   0.003335  0.000011
#    top_to_ground 0.630322 0.531320   0.099002  0.009801
# bottom_to_bottom 0.508159 0.532027   0.023868  0.000570
# bottom_to_ground 0.466261 0.508697   0.042436  0.001801
# ground_to_ground 0.519531 0.526487   0.006955  0.000048
#
# Global scaled error stats:
#   min abs_error: 6.329198803500802e-06
#   median abs_error: 0.007880274126332756
#   max abs_error: 0.12505101819209008

# %% [markdown]
# # Unscaled

# %%
# Unscale everything and look at errors in real units that we can actually understand

# Load output capacitance column names
with open('X_names', 'r') as f:
    cap_names = f.read().splitlines()  

qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

# Unscale inputs
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        param_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_linear_{param_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale outputs 
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# Unscale predictions using same X scalers
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape

# Errrs
sq_errors_unscaled  = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# Build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': y_test_unscaled[i, j],
            'pred_unscaled': y_pred_unscaled[i, j],
            'abs_error_unscaled': abs_errors_unscaled[i, j],
            'sq_error_unscaled': sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# Save
out_csv_unscaled = Path(f'model2_predictions_and_errors_unscaled_{encoding}.csv')
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

# Pretty print per-sample 
for i in range(N_SAMPLES_TO_SHOW):
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    input_str = ', '.join(
        f'{qiskit_names[k] if k < len(qiskit_names) else f"col_{k}"}={X_test_unscaled[i,k]:.6g}'
        for k in range(X_test_unscaled.shape[1])
    )
    print(f'— Sample {i} (Unscaled) — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global unscaled error stats:')
print('  min abs_error:', float(abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(abs_errors_unscaled)))
print('  max abs_error:', float(abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_unscaled_model2_surrogate.csv
#
# — Sample 0 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91395      15.566687            0.652737           0.426065
#    top_to_bottom       0.66910       1.035671            0.366571           0.134374
#    top_to_ground      14.05235      13.878706            0.173644           0.030152
# bottom_to_bottom      13.62255      14.363646            0.741096           0.549223
# bottom_to_ground      12.78564      13.096706            0.311066           0.096762
# ground_to_ground      58.01370      58.127594            0.113894           0.012972
#
# — Sample 1 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.64499      22.152081            0.507091           0.257141
#    top_to_bottom       3.83797       3.861252            0.023282           0.000542
#    top_to_ground      17.53586      17.769482            0.233622           0.054579
# bottom_to_bottom      27.51404      27.042410            0.471630           0.222435
# bottom_to_ground      23.29018      22.996313            0.293867           0.086358
# ground_to_ground      73.35986      74.032715            0.672855           0.452734
#
# — Sample 2 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.84435      46.455757            0.388593           0.151004
#    top_to_bottom      20.25982      20.534430            0.274610           0.075410
#    top_to_ground      26.29119      25.714077            0.577113           0.333059
# bottom_to_bottom      67.75657      68.202324            0.445754           0.198697
# bottom_to_ground      46.86370      47.263474            0.399774           0.159819
# ground_to_ground     108.83635     108.272331            0.564019           0.318117
#
# — Sample 3 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.99644      45.155678            1.840762           3.388405
#    top_to_bottom      19.38918      19.273277            0.115903           0.013433
#    top_to_ground      27.25768      25.425829            1.831851           3.355678
# bottom_to_bottom      55.79690      56.846218            1.049318           1.101068
# bottom_to_ground      35.76054      37.135632            1.375092           1.890877
# ground_to_ground      97.29848      97.189537            0.108943           0.011869
#
# — Sample 4 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.54716      31.081419            0.465741           0.216915
#    top_to_bottom      11.61323      10.942190            0.671040           0.450294
#    top_to_ground      19.67277      19.714973            0.042203           0.001781
# bottom_to_bottom      43.43218      42.928314            0.503866           0.253881
# bottom_to_ground      31.29560      31.596209            0.300609           0.090366
# ground_to_ground      84.14240      84.451546            0.309146           0.095571
#
# — Sample 5 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91522      15.500422            0.585202           0.342461
#    top_to_bottom       1.90110       1.932978            0.031878           0.001016
#    top_to_ground      12.79837      12.923475            0.125105           0.015651
# bottom_to_bottom      16.82899      16.896166            0.067176           0.004513
# bottom_to_ground      14.71062      14.760650            0.050030           0.002503
# ground_to_ground      59.03334      58.758266            0.275074           0.075665
#
# — Sample 6 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.21478      40.039375            2.824595           7.978339
#    top_to_bottom      18.10928      18.645800            0.536520           0.287853
#    top_to_ground      18.86175      21.377745            2.515995           6.330229
# bottom_to_bottom      45.74491      43.984692            1.760218           3.098369
# bottom_to_ground      27.25160      24.945427            2.306173           5.318434
# ground_to_ground      79.00961      79.124237            0.114627           0.013139
#
# — Sample 7 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.07032      20.326880            0.743440           0.552704
#    top_to_bottom       1.21587       0.819106            0.396764           0.157422
#    top_to_ground      19.56543      19.442806            0.122624           0.015037
# bottom_to_bottom      17.12018      17.166510            0.046330           0.002146
# bottom_to_ground      15.65802      16.373514            0.715494           0.511932
# ground_to_ground      67.68762      67.624405            0.063215           0.003996
#
# — Sample 8 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      35.33519      36.854710            1.519520           2.308940
#    top_to_bottom      11.77509      12.050639            0.275549           0.075927
#    top_to_ground      23.15632      24.511267            1.354947           1.835881
# bottom_to_bottom      58.69605      57.966137            0.729913           0.532773
# bottom_to_ground      46.26890      45.446270            0.822630           0.676720
# ground_to_ground     104.35958     104.767365            0.407785           0.166288
#
# — Sample 9 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.04935      18.978737            0.929387           0.863760
#    top_to_bottom       2.51389       2.600721            0.086831           0.007540
#    top_to_ground      15.29043      15.941920            0.651490           0.424440
# bottom_to_bottom      23.93490      23.352306            0.582594           0.339415
# bottom_to_ground      21.09610      20.491335            0.604765           0.365741
# ground_to_ground      68.15670      69.247993            1.091293           1.190921
#
# — Sample 10 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      49.05578      46.510349            2.545431           6.479218
#    top_to_bottom      20.80786      20.778301            0.029559           0.000874
#    top_to_ground      27.89118      25.263744            2.627436           6.903418
# bottom_to_bottom      64.00772      65.793068            1.785348           3.187467
# bottom_to_ground      42.57999      44.513844            1.933854           3.739790
# ground_to_ground     104.87919     104.580017            0.299173           0.089504
#
# — Sample 11 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      50.54045      48.523655            2.016795           4.067462
#    top_to_bottom      17.73454      16.893465            0.841075           0.707407
#    top_to_ground      32.22853      30.986317            1.242213           1.543094
# bottom_to_bottom      86.86462      87.518181            0.653561           0.427142
# bottom_to_ground      68.29869      69.565529            1.266839           1.604881
# ground_to_ground     137.32339     137.151062            0.172328           0.029697
#
# — Sample 12 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      26.27875      24.578053            1.700697           2.892372
#    top_to_bottom       8.92551       7.819833            1.105677           1.222521
#    top_to_ground      17.10117      16.474083            0.627087           0.393238
# bottom_to_bottom      29.95980      29.267237            0.692563           0.479644
# bottom_to_ground      20.65658      21.209389            0.552809           0.305597
# ground_to_ground      70.18744      69.536301            0.651139           0.423982
#
# — Sample 13 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.85738      35.548233            2.309147           5.332160
#    top_to_bottom      13.07647      11.639147            1.437323           2.065898
#    top_to_ground      24.54618      23.184937            1.361243           1.852984
# bottom_to_bottom      59.45636      59.532413            0.076053           0.005784
# bottom_to_ground      45.77177      47.070278            1.298508           1.686123
# ground_to_ground     105.19612     105.427391            0.231271           0.053486
#
# — Sample 14 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.69895      20.639519            0.059431           0.003532
#    top_to_bottom       0.60461       0.622392            0.017782           0.000316
#    top_to_ground      19.82790      19.892616            0.064716           0.004188
# bottom_to_bottom      14.56863      14.361078            0.207552           0.043078
# bottom_to_ground      13.79113      13.624417            0.166713           0.027793
# ground_to_ground      65.63654      65.693832            0.057292           0.003282
#
# — Sample 15 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      36.59696      38.009151            1.412191           1.994285
#    top_to_bottom      15.03656      15.460827            0.424267           0.180002
#    top_to_ground      21.21543      22.327436            1.112006           1.236558
# bottom_to_bottom      60.00257      59.136715            0.865855           0.749705
# bottom_to_ground      44.42258      42.995972            1.426608           2.035211
# ground_to_ground     100.27778     100.273491            0.004289           0.000018
#
# — Sample 16 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.80333      24.464878            0.338452           0.114550
#    top_to_bottom       7.54392       7.399206            0.144714           0.020942
#    top_to_ground      17.01049      16.798969            0.211521           0.044741
# bottom_to_bottom      32.79263      32.619778            0.172852           0.029878
# bottom_to_ground      24.98322      24.896202            0.087018           0.007572
# ground_to_ground      74.98806      74.159996            0.828064           0.685690
#
# — Sample 17 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      72.09757      72.265953            0.168383           0.028353
#    top_to_bottom      42.28320      41.866661            0.416539           0.173505
#    top_to_ground      29.25596      30.016075            0.760115           0.577775
# bottom_to_bottom     101.78691     101.148964            0.637946           0.406975
# bottom_to_ground      58.96084      58.235329            0.725511           0.526367
# ground_to_ground     124.89715     124.744972            0.152178           0.023158
#
# — Sample 18 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.65327      55.643303            0.990033           0.980165
#    top_to_bottom      25.69001      25.603083            0.086927           0.007556
#    top_to_ground      28.43415      29.525637            1.091487           1.191343
# bottom_to_bottom      77.76412      76.844246            0.919874           0.846168
# bottom_to_ground      51.52313      50.667645            0.855485           0.731855
# ground_to_ground     115.57029     115.946571            0.376281           0.141588
#
# — Sample 19 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.24473      67.474907            1.769823           3.132274
#    top_to_bottom      32.55387      32.065853            0.488017           0.238160
#    top_to_ground      36.23866      34.632477            1.606183           2.579824
# bottom_to_bottom     110.06436     110.685173            0.620813           0.385409
# bottom_to_ground      76.51531      77.623390            1.108080           1.227842
# ground_to_ground     150.90990     150.019592            0.890308           0.792648
#
# — Sample 20 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.48460      26.864719            1.380119           1.904730
#    top_to_bottom       7.16345       7.393129            0.229679           0.052752
#    top_to_ground      18.02827      19.307610            1.279340           1.636710
# bottom_to_bottom      38.13878      37.875492            0.263288           0.069321
# bottom_to_ground      30.67125      30.231047            0.440203           0.193779
# ground_to_ground      82.12106      82.862381            0.741321           0.549557
#
# — Sample 21 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      52.60779      49.904392            2.703398           7.308359
#    top_to_bottom      22.04591      22.059868            0.013958           0.000195
#    top_to_ground      30.06731      27.349068            2.718242           7.388841
# bottom_to_bottom      65.59865      67.848022            2.249372           5.059676
# bottom_to_ground      43.12377      45.355431            2.231661           4.980309
# ground_to_ground     108.44790     108.276054            0.171846           0.029531
#
# — Sample 22 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.15252      20.240343            0.087823           0.007713
#    top_to_bottom       1.44740       1.625875            0.178475           0.031853
#    top_to_ground      18.46784      18.549500            0.081660           0.006668
# bottom_to_bottom      18.49276      19.602131            1.109371           1.230704
# bottom_to_ground      16.78539      18.127964            1.342574           1.802505
# ground_to_ground      66.96300      68.382339            1.419339           2.014525
#
# — Sample 23 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.04266      18.563902            0.478758       2.292093e-01
#    top_to_bottom       3.07264       3.301935            0.229295       5.257640e-02
#    top_to_ground      15.72419      14.930909            0.793281       6.292945e-01
# bottom_to_bottom      22.17553      22.667042            0.491512       2.415838e-01
# bottom_to_ground      18.83528      19.251650            0.416370       1.733639e-01
# ground_to_ground      66.35541      66.354691            0.000719       5.176058e-07
#
# — Sample 24 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.17391      17.650045            0.523865           0.274434
#    top_to_bottom       0.73958       0.608642            0.130938           0.017145
#    top_to_ground      17.18506      16.743717            0.441343           0.194783
# bottom_to_bottom      15.69679      14.205246            1.491544           2.224704
# bottom_to_ground      14.70742      13.516714            1.190706           1.417781
# ground_to_ground      63.25260      62.065990            1.186610           1.408042
#
# — Sample 25 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      64.22991      63.524567            0.705343           0.497509
#    top_to_bottom      29.90875      29.437294            0.471456           0.222271
#    top_to_ground      33.77716      33.503082            0.274078           0.075119
# bottom_to_bottom     100.99499      99.427734            1.567256           2.456290
# bottom_to_ground      70.01176      69.119507            0.892253           0.796116
# ground_to_ground     140.80910     139.180023            1.629077           2.653891
#
# — Sample 26 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      17.19448      18.471815            1.277335           1.631585
#    top_to_bottom       2.30923       3.047946            0.738716           0.545702
#    top_to_ground      14.66488      14.922578            0.257698           0.066408
# bottom_to_bottom      20.39118      20.761118            0.369938           0.136854
# bottom_to_ground      17.80506      17.601965            0.203095           0.041248
# ground_to_ground      64.29761      64.720894            0.423284           0.179169
#
# — Sample 27 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      32.81010      34.272018            1.461918           2.137206
#    top_to_bottom      11.72675      11.683058            0.043692           0.001909
#    top_to_ground      20.78413      21.979290            1.195160           1.428407
# bottom_to_bottom      49.04328      46.787968            2.255312           5.086434
# bottom_to_ground      36.87262      34.708424            2.164196           4.683746
# ground_to_ground      91.79978      91.146606            0.653174           0.426636
#
# — Sample 28 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.90631      21.910105            0.003795           0.000014
#    top_to_bottom       6.82474       5.913220            0.911520           0.830869
#    top_to_ground      14.83177      15.573201            0.741431           0.549720
# bottom_to_bottom      26.98623      25.494574            1.491656           2.225039
# bottom_to_ground      19.84377      19.357891            0.485879           0.236078
# ground_to_ground      66.81403      66.602661            0.211369           0.044677
#
# — Sample 29 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.12348      23.537710            0.585770           0.343126
#    top_to_bottom       4.91634       5.812549            0.896209           0.803191
#    top_to_ground      18.97512      17.346357            1.628763           2.652868
# bottom_to_bottom      27.62769      29.287704            1.660014           2.755648
# bottom_to_ground      22.37061      23.319120            0.948510           0.899672
# ground_to_ground      73.48264      73.738060            0.255420           0.065239
#
# — Sample 30 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      16.43384      16.787764            0.353924           0.125262
#    top_to_bottom       0.47735       0.551782            0.074432           0.005540
#    top_to_ground      15.77519      15.698977            0.076213           0.005808
# bottom_to_bottom      13.58084      13.595209            0.014369           0.000206
# bottom_to_ground      12.91772      12.913232            0.004488           0.000020
# ground_to_ground      60.07192      60.195042            0.123122           0.015159
#
# — Sample 31 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      61.77084      59.233318            2.537522           6.439016
#    top_to_bottom      26.62797      26.539627            0.088343           0.007804
#    top_to_ground      34.56668      32.102043            2.464637           6.074435
# bottom_to_bottom      88.73307      91.479439            2.746369           7.542541
# bottom_to_ground      61.14529      64.186638            3.041348           9.249797
# ground_to_ground     132.19017     132.688354            0.498184           0.248188
#
# — Sample 32 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      45.97905      47.283966            1.304916           1.702806
#    top_to_bottom      21.60242      21.522564            0.079856           0.006377
#    top_to_ground      23.96784      25.673876            1.706036           2.910558
# bottom_to_bottom      67.20976      64.622757            2.587003           6.692585
# bottom_to_ground      44.96409      42.949585            2.014505           4.058231
# ground_to_ground     103.69355     103.860161            0.166611           0.027759
#
# — Sample 33 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.13024      28.875708            0.745468           0.555722
#    top_to_bottom      10.44906      10.561422            0.112362           0.012625
#    top_to_ground      17.41241      18.116198            0.703788           0.495317
# bottom_to_bottom      35.98982      34.346645            1.643175           2.700023
# bottom_to_ground      25.21932      23.658279            1.561041           2.436848
# ground_to_ground      75.18223      74.488358            0.693872           0.481459
#
# — Sample 34 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.10048      26.700735            1.600255           2.560816
#    top_to_bottom       6.18873       6.668725            0.479995           0.230395
#    top_to_ground      18.58672      19.731424            1.144704           1.310348
# bottom_to_bottom      38.61615      38.038536            0.577614           0.333638
# bottom_to_ground      31.96057      31.117853            0.842717           0.710172
# ground_to_ground      84.29772      84.908554            0.610834           0.373118
#
# — Sample 35 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.44833      53.957832            0.509502           0.259593
#    top_to_bottom      23.36040      23.288921            0.071479           0.005109
#    top_to_ground      29.58039      30.063475            0.483085           0.233371
# bottom_to_bottom      82.51415      82.115433            0.398717           0.158975
# bottom_to_ground      58.29103      58.201946            0.089084           0.007936
# ground_to_ground     123.89606     124.353882            0.457822           0.209601
#
# — Sample 36 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.35887      65.863785            3.495085          12.215621
#    top_to_bottom      37.69192      36.931709            0.760211           0.577920
#    top_to_ground      31.46136      28.731661            2.729699           7.451257
# bottom_to_bottom      89.04400      90.839569            1.795569           3.224068
# bottom_to_ground      50.70017      53.076157            2.375987           5.645312
# ground_to_ground     118.02962     117.960670            0.068950           0.004754
#
# — Sample 37 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.42721      53.263172            0.164038           0.026908
#    top_to_bottom      19.87346      19.807402            0.066058           0.004364
#    top_to_ground      33.05314      32.807682            0.245458           0.060250
# bottom_to_bottom      97.14587      96.957024            0.188846           0.035663
# bottom_to_ground      76.43402      75.891205            0.542815           0.294648
# ground_to_ground     147.31121     145.745651            1.565559           2.450974
#
# — Sample 38 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.12130      18.811556            0.309744           0.095941
#    top_to_bottom       0.83343       0.565798            0.267632           0.071627
#    top_to_ground      18.05242      18.020277            0.032143           0.001033
# bottom_to_bottom      14.68703      14.395555            0.291475           0.084958
# bottom_to_ground      13.64212      13.655616            0.013496           0.000182
# ground_to_ground      62.87424      63.357162            0.482922           0.233214
#
# — Sample 39 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      59.64057      59.560390            0.080180           0.006429
#    top_to_bottom      32.97925      32.083889            0.895361           0.801671
#    top_to_ground      26.19782      27.455965            1.258145           1.582929
# bottom_to_bottom      83.07385      80.645226            2.428624           5.898217
# bottom_to_ground      49.53280      47.938480            1.594320           2.541855
# ground_to_ground     111.45445     111.216179            0.238271           0.056773
#
# — Sample 40 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.69749      56.483490            1.786000           3.189796
#    top_to_bottom      25.58236      25.492167            0.090193           0.008135
#    top_to_ground      28.61859      30.311016            1.692426           2.864306
# bottom_to_bottom      84.35009      82.905449            1.444641           2.086988
# bottom_to_ground      58.25104      56.914200            1.336840           1.787142
# ground_to_ground     123.77985     123.180237            0.599613           0.359536
#
# — Sample 41 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.47237      19.367447            0.895077           0.801163
#    top_to_bottom       2.73292       3.231437            0.498517           0.248519
#    top_to_ground      15.49501      15.614647            0.119637           0.014313
# bottom_to_bottom      22.95995      21.953262            1.006688           1.013420
# bottom_to_ground      19.91865      18.506178            1.412472           1.995077
# ground_to_ground      67.22470      66.676559            0.548141           0.300458
#
# — Sample 42 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      15.69639      16.486135            0.789745           0.623698
#    top_to_bottom       0.83998       1.118398            0.278418           0.077516
#    top_to_ground      14.64488      14.718940            0.074060           0.005485
# bottom_to_bottom      14.67483      15.300709            0.625879           0.391724
# bottom_to_ground      13.64197      13.854115            0.212145           0.045005
# ground_to_ground      59.01106      60.057175            1.046115           1.094356
#
# — Sample 43 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.19186      25.026583            3.165277          10.018980
#    top_to_bottom       6.56601       6.915576            0.349566           0.122197
#    top_to_ground      21.33982      17.837294            3.502526          12.267691
# bottom_to_bottom      27.16464      29.729963            2.565323           6.580884
# bottom_to_ground      20.23212      22.740967            2.508847           6.294312
# ground_to_ground      74.01179      73.725334            0.286456           0.082057
#
# — Sample 44 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.21430      45.849789            1.635489           2.674823
#    top_to_bottom      20.91871      20.975950            0.057240           0.003276
#    top_to_ground      22.95520      24.745010            1.789810           3.203421
# bottom_to_bottom      67.61721      65.479820            2.137390           4.568435
# bottom_to_ground      46.09617      44.106529            1.989641           3.958670
# ground_to_ground     104.08419     103.738235            0.345955           0.119685
#
# — Sample 45 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.24216      28.843002            2.399158           5.755958
#    top_to_bottom       9.13548       8.825049            0.310431           0.096367
#    top_to_ground      21.76376      19.604359            2.159401           4.663014
# bottom_to_bottom      34.91396      36.560059            1.646099           2.709641
# bottom_to_ground      25.38392      27.467014            2.083094           4.339282
# ground_to_ground      79.55404      80.704582            1.150542           1.323747
#
# — Sample 46 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.23756      42.709209            1.528351           2.335855
#    top_to_bottom      16.86840      16.603857            0.264543           0.069983
#    top_to_ground      27.08055      25.490965            1.589585           2.526781
# bottom_to_bottom      63.86300      65.027878            1.164878           1.356940
# bottom_to_ground      46.37482      47.873806            1.498986           2.246959
# ground_to_ground     108.49297     108.424500            0.068470           0.004688
#
# — Sample 47 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      48.19483      46.521603            1.673227           2.799690
#    top_to_bottom      18.97173      18.245396            0.726334           0.527562
#    top_to_ground      28.83436      27.661156            1.173204           1.376408
# bottom_to_bottom      80.46316      81.650757            1.187597           1.410386
# bottom_to_ground      60.60069      62.270611            1.669921           2.788636
# ground_to_ground     125.75437     126.512871            0.758501           0.575323
#
# — Sample 48 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.94514      19.175900            0.230760           0.053250
#    top_to_bottom       0.89281       1.268089            0.375279           0.140834
#    top_to_ground      17.79519      17.767513            0.027677           0.000766
# bottom_to_bottom      16.90262      17.247326            0.344706           0.118822
# bottom_to_ground      15.74914      16.114798            0.365658           0.133705
# ground_to_ground      65.59834      65.736969            0.138629           0.019218
#
# — Sample 49 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      62.71578      59.407310            3.308470          10.945971
#    top_to_bottom      31.19457      31.014112            0.180458           0.032565
#    top_to_ground      31.08140      28.241989            2.839411           8.062254
# bottom_to_bottom      80.22864      83.400322            3.171682          10.059566
# bottom_to_ground      48.64112      51.965057            3.323937          11.048560
# ground_to_ground     115.72236     116.511681            0.789321           0.623027
#
# Global unscaled error stats:
#   min abs_error: 0.0007194482421937209
#   median abs_error: 0.6445427062988287
#   max abs_error: 4.84739190429687

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# Lets see how good we actually did

# %%
# find percentage difference like 100 * abs(pred - re) / abs(ref), with tiny epsilon to avoid division by zero
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(y_pred_unscaled - y_test_unscaled) / (np.abs(y_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_params)]
all_pct = pct_errors_unscaled.ravel()

# %%
# box plot showing % error distribution per capacitance output 
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Percentage Error Distribution per Output')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_boxplot.pdf')
plt.show()
# Out:
# /tmp/ipykernel_998990/2286795443.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,

# %%
# histogram it too
n_cols_grid = 3
n_rows_grid = math.ceil(n_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

# hide unused subplots
for k in range(n_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Model 2: Percentage Error Histograms per Output', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_histograms_per_output.pdf')
plt.show()

# %%
#look at the stats nicely
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'All outputs':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")
# Out:
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# top_to_top                      3.70       3.68       6.43      11.23
# top_to_bottom                   2.94      10.92      32.94      67.99
# top_to_ground                   4.07       4.55       9.29      16.41
# bottom_to_bottom                1.98       2.76       5.81      10.58
# bottom_to_ground                2.68       3.39       6.99      12.40
# ground_to_ground                0.47       0.63       1.40       2.12
# ----------------------------------------------------------------------
# All outputs                     2.20       4.32       8.59      67.99

# %%
# scatter plot with fancy visulaization of points using this grouping thing

fig, ax = plt.subplots(figsize=(12, 6))
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    x = np.full_like(col_pct, j) + np.random.uniform(-0.2, 0.2, size=len(col_pct))
    ax.scatter(x, col_pct, alpha=0.4, s=12, label=short_names[j])
ax.set_xticks(range(n_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Per-Sample Percentage Error by Capacitance Output')
plt.tight_layout()
plt.savefig('plots/model2_pct_error_scatter.pdf')
plt.show()
