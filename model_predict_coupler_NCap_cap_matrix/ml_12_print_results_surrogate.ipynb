# %% [markdown]
# # Model Predictions (coupler_NCap_cap_matrix)
# ## Qiskit Metal --> Capacitance
#
# Ansys surrogate model

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters_surrogate import *

# %% [markdown]
# ## Library

# %%
import os, gc, math
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
def load_scaled_split(kind, split):
    return np.load(f"{DATA_DIR}/npy/{split}_{kind}_encoding_scaled.npy", allow_pickle=True)

# new inputs are our Qiskit Metal params, using good ole linear encoding
X_train = load_scaled_split('linear', 'y_train')
X_val   = load_scaled_split('linear', 'y_val')
X_test  = load_scaled_split('linear', 'y_test')

# new outputs are the capacitance values
y_train = load_scaled_split('linear', 'x_train')
y_val   = load_scaled_split('linear', 'x_val')
y_test  = load_scaled_split('linear', 'x_test')

# load column name files for later reference fer outputs
with open('X_names', 'r') as f:
    cap_column_names = f.read().splitlines()   

# input names
qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist() 

#check to make sure these printouts make sense and we arent flippered
print(f'Inputs (Qiskit params):  {X_train.shape[1]} columns')
print(f'Outputs (Capacitance):    {y_train.shape[1]} columns')
print(f'\nInput columns:  {qiskit_param_names}')
print(f'Output columns: {cap_column_names}')
# Out:
# Inputs (Qiskit params):  4 columns
# Outputs (Capacitance):    6 columns
#
# Input columns:  ['design_options.cap_gap', 'design_options.cap_width', 'design_options.finger_length', 'design_options.finger_count']
# Output columns: ['top_to_top', 'top_to_bottom', 'top_to_ground', 'bottom_to_bottom', 'bottom_to_ground', 'ground_to_ground']

# %% [markdown]
# ### Visualize model

# %%
# Decide which model file to use
encoding = 'model2_surrogate'
chosen_path = f'model/best_keras_model_model2_surrogate.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

# Load output headers (capacitance column names)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Output headers: {headers}')
# Out:
# Model path: model/best_keras_model_model2_surrogate.keras
# Output headers: ['top_to_top', 'top_to_bottom', 'top_to_ground', 'bottom_to_bottom', 'bottom_to_ground', 'ground_to_ground']

# %%
#look at the best model, ooh so pretty
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    y_pred = chosen_model.predict(X_test_cur, verbose=0)

print(f'\n—— {os.path.basename(chosen_path)} ——')
chosen_model.summary()
print(f'Samples: {len(X_test_cur)} | Targets dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772037416.609678   38016 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1064 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:10.0, compute capability: 8.0
# I0000 00:00:1772037416.802334   38680 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# —— best_keras_model_model2_surrogate.keras ——
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 800)            │         4,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │         4,806 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,806 (34.40 KB)
#  Trainable params: 8,806 (34.40 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 65 | Targets dim: 6

# %%
# look at some more specific model params
m = tf.keras.models.load_model(chosen_path, compile=True)

neurons_per_layer = [
    l.units for l in m.layers
    if isinstance(l, tf.keras.layers.Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

dropouts = [
    (l.name, float(l.rate)) for l in m.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')

opt = getattr(m, 'optimizer', None)
if opt is None:
    print('Best learning rate: (no optimizer found on loaded model)')
else:
    lr_obj = opt.learning_rate

    if isinstance(lr_obj, tf.keras.optimizers.schedules.LearningRateSchedule):
        print('Best learning rate: (schedule)', type(lr_obj).__name__)
        try:
            cfg = lr_obj.get_config()
            print('LR schedule config:')
            for k, v in sorted(cfg.items()):
                print(f'  {k}: {v}')
        except Exception as e:
            print('Could not read LR schedule config:', repr(e))
        try:
            step = int(tf.keras.backend.get_value(opt.iterations))
            current_lr = float(lr_obj(step).numpy())
            print(f'Current LR at step {step}:', current_lr)
        except Exception as e:
            print('Could not compute current LR from schedule:', repr(e))
    else:
        try:
            lr_val = float(tf.keras.backend.get_value(lr_obj))
            print('Best learning rate:', lr_val)
        except Exception as e:
            print('Best learning rate: (unreadable)', repr(e))
# Out:
# Best NEURONS_PER_LAYER: [800]
# Best DROPOUT rate(s): [('dropout0', 0.0)]
# Best learning rate: 0.042644038796424866
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50 # change this to print more stuff

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred     = np.asarray(y_pred)

N, P = y_test_cur.shape

# make sure y_pred shape matches
if y_pred.ndim == 3 and y_pred.shape[-1] == 1:
    y_pred = y_pred[..., 0]
if y_pred.ndim == 1:
    y_pred = y_pred.reshape(-1, 1)
assert y_pred.shape == (N, P), f'y_pred shape {y_pred.shape} != expected {(N, P)}'

# scaled errors
sq_errors  = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# building dataframe
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  y_test_cur[i, j],
            'pred': y_pred[i, j],
            'abs_error': abs_errors[i, j],
            'sq_error':  sq_errors[i, j],
        })

df = pd.DataFrame(rows)

# save scaled predictions
out_csv = Path(f'model2_predictions_and_errors_{encoding}.csv')
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

# Pretty print per-sample (scaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    input_str = ', '.join(
        f'{qiskit_param_names[k] if k < len(qiskit_param_names) else f"in_{k}"}={X_test_cur[i,k]:.6g}'
        for k in range(X_test_cur.shape[1])
    )
    print(f'— Sample {i} — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global scaled error stats:')
print('  min abs_error:', float(abs_errors.min()))
print('  median abs_error:', float(np.median(abs_errors)))
print('  max abs_error:', float(abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_model2_surrogate.csv
#
# — Sample 0 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.008322 0.009879   0.001557  0.000002
#    top_to_bottom 0.005650 0.008889   0.003239  0.000010
#    top_to_ground 0.036568 0.033252   0.003316  0.000011
# bottom_to_bottom 0.006921 0.013124   0.006204  0.000038
# bottom_to_ground 0.008502 0.019928   0.011426  0.000131
# ground_to_ground 0.011026 0.017866   0.006840  0.000047
#
# — Sample 1 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.091476 0.099343   0.007866  0.000062
#    top_to_bottom 0.064207 0.066604   0.002397  0.000006
#    top_to_ground 0.158028 0.168870   0.010842  0.000118
# bottom_to_bottom 0.111460 0.104892   0.006568  0.000043
# bottom_to_ground 0.142611 0.132479   0.010132  0.000103
# ground_to_ground 0.146250 0.145034   0.001217  0.000001
#
# — Sample 2 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.402785 0.398564   0.004221 1.781772e-05
#    top_to_bottom 0.367666 0.369099   0.001434 2.055425e-06
#    top_to_ground 0.463301 0.434213   0.029088 8.461371e-04
# bottom_to_bottom 0.414302 0.413835   0.000467 2.177317e-07
# bottom_to_ground 0.443569 0.443505   0.000064 4.051693e-09
# ground_to_ground 0.458855 0.452155   0.006700 4.488591e-05
#
# — Sample 3 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.404664 0.370729   0.033935  0.001152
#    top_to_bottom 0.351577 0.340174   0.011403  0.000130
#    top_to_ground 0.497000 0.401407   0.095592  0.009138
# bottom_to_bottom 0.324300 0.333206   0.008906  0.000079
# bottom_to_ground 0.301817 0.329420   0.027603  0.000762
# ground_to_ground 0.357188 0.353779   0.003408  0.000012
#
# — Sample 4 — Inputs: design_options.cap_gap=1, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.213806 0.220947   0.007141  0.000051
#    top_to_bottom 0.207886 0.206665   0.001221  0.000001
#    top_to_ground 0.232536 0.243687   0.011152  0.000124
# bottom_to_bottom 0.231250 0.227105   0.004145  0.000017
# bottom_to_ground 0.244814 0.242215   0.002599  0.000007
# ground_to_ground 0.241262 0.244184   0.002923  0.000009
#
# — Sample 5 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0, design_options.finger_count=0.111111
#            param       ref     pred  abs_error  sq_error
#       top_to_top  0.008338 0.014792   0.006455  0.000042
#    top_to_bottom  0.028416 0.035013   0.006597  0.000044
#    top_to_ground -0.007155 0.003723   0.010878  0.000118
# bottom_to_bottom  0.031050 0.037024   0.005974  0.000036
# bottom_to_ground  0.033077 0.042072   0.008995  0.000081
# ground_to_ground  0.020011 0.024292   0.004281  0.000018
#
# — Sample 6 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=1, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.283823 0.322819   0.038996  0.001521
#    top_to_bottom 0.327926 0.331539   0.003613  0.000013
#    top_to_ground 0.204258 0.299226   0.094969  0.009019
# bottom_to_bottom 0.248655 0.224870   0.023785  0.000566
# bottom_to_ground 0.193185 0.154255   0.038931  0.001516
# ground_to_ground 0.196034 0.194605   0.001428  0.000002
#
# — Sample 7 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.084377 0.099753   0.015376  0.000236
#    top_to_bottom 0.015754 0.027561   0.011808  0.000139
#    top_to_ground 0.228793 0.243435   0.014642  0.000214
# bottom_to_bottom 0.033242 0.034618   0.001376  0.000002
# bottom_to_ground 0.045173 0.042253   0.002920  0.000009
# ground_to_ground 0.096269 0.094601   0.001668  0.000003
#
# — Sample 8 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.260603 0.263464   0.002861  0.000008
#    top_to_bottom 0.210877 0.200306   0.010571  0.000112
#    top_to_ground 0.353997 0.379122   0.025125  0.000631
# bottom_to_bottom 0.346117 0.333587   0.012531  0.000157
# bottom_to_ground 0.435975 0.423662   0.012313  0.000152
# ground_to_ground 0.419407 0.417817   0.001590  0.000003
#
# — Sample 9 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.111111
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.047056 0.046352   0.000704 4.952534e-07
#    top_to_bottom 0.039740 0.037767   0.001972 3.890268e-06
#    top_to_ground 0.079736 0.077758   0.001978 3.913718e-06
# bottom_to_bottom 0.084525 0.081156   0.003370 1.135495e-05
# bottom_to_ground 0.114599 0.111345   0.003254 1.058949e-05
# ground_to_ground 0.100402 0.102286   0.001884 3.547826e-06
#
# — Sample 10 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.430105 0.396828   0.033277  0.001107
#    top_to_bottom 0.377793 0.372942   0.004851  0.000024
#    top_to_ground 0.519088 0.427931   0.091157  0.008310
# bottom_to_bottom 0.386090 0.395758   0.009668  0.000093
# bottom_to_ground 0.388879 0.412842   0.023962  0.000574
# ground_to_ground 0.423986 0.417987   0.005999  0.000036
#
# — Sample 11 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.448446 0.428529   0.019918  0.000397
#    top_to_bottom 0.321001 0.314764   0.006237  0.000039
#    top_to_ground 0.670319 0.634214   0.036105  0.001304
# bottom_to_bottom 0.558098 0.574353   0.016256  0.000264
# bottom_to_ground 0.717224 0.748475   0.031250  0.000977
# ground_to_ground 0.709871 0.725519   0.015649  0.000245
#
# — Sample 12 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.148721 0.130169   0.018552  0.000344
#    top_to_bottom 0.158220 0.148982   0.009237  0.000085
#    top_to_ground 0.142871 0.105308   0.037563  0.001411
# bottom_to_bottom 0.129865 0.132768   0.002903  0.000008
# bottom_to_ground 0.108988 0.121500   0.012512  0.000157
# ground_to_ground 0.118296 0.114930   0.003366  0.000011
#
# — Sample 13 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.291762 0.275458   0.016303  0.000266
#    top_to_bottom 0.234925 0.232022   0.002903  0.000008
#    top_to_ground 0.402457 0.359553   0.042904  0.001841
# bottom_to_bottom 0.351839 0.360106   0.008267  0.000068
# bottom_to_ground 0.429628 0.447767   0.018138  0.000329
# ground_to_ground 0.426779 0.428190   0.001411  0.000002
#
# — Sample 14 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.079789 0.076275   0.003514 1.234619e-05
#    top_to_bottom 0.004458 0.004920   0.000461 2.126416e-07
#    top_to_ground 0.237945 0.225873   0.012071 1.457122e-04
# bottom_to_bottom 0.014040 0.017809   0.003768 1.420128e-05
# bottom_to_ground 0.021339 0.029396   0.008057 6.492198e-05
# ground_to_ground 0.078196 0.079605   0.001409 1.985579e-06
#
# — Sample 15 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.276191 0.295428   0.019238 3.700941e-04
#    top_to_bottom 0.271145 0.274806   0.003660 1.339825e-05
#    top_to_ground 0.286324 0.327714   0.041391 1.713193e-03
# bottom_to_bottom 0.355950 0.344437   0.011512 1.325297e-04
# bottom_to_ground 0.412403 0.393647   0.018756 3.518033e-04
# ground_to_ground 0.383440 0.383753   0.000313 9.777207e-08
#
# — Sample 16 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.130494 0.133137   0.002643 6.987752e-06
#    top_to_bottom 0.132689 0.133586   0.000897 8.042217e-07
#    top_to_ground 0.139709 0.145208   0.005499 3.023726e-05
# bottom_to_bottom 0.151183 0.154868   0.003685 1.357911e-05
# bottom_to_ground 0.164225 0.168521   0.004296 1.845411e-05
# ground_to_ground 0.160597 0.161648   0.001050 1.103014e-06
#
# — Sample 17 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.714760 0.718150   0.003390  0.000011
#    top_to_bottom 0.774634 0.767273   0.007361  0.000054
#    top_to_ground 0.566674 0.601230   0.034556  0.001194
# bottom_to_bottom 0.670394 0.666965   0.003430  0.000012
# bottom_to_ground 0.598010 0.594604   0.003406  0.000012
# ground_to_ground 0.600376 0.605514   0.005138  0.000026
#
# — Sample 18 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.499256 0.506214   0.006959 4.842273e-05
#    top_to_bottom 0.468010 0.467389   0.000621 3.851855e-07
#    top_to_ground 0.538020 0.546437   0.008417 7.084223e-05
# bottom_to_bottom 0.489613 0.484134   0.005479 3.001622e-05
# bottom_to_ground 0.503055 0.498451   0.004604 2.119629e-05
# ground_to_ground 0.518191 0.517313   0.000878 7.711118e-07
#
# — Sample 19 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.679516 0.652045   0.027471  0.000755
#    top_to_bottom 0.594847 0.586937   0.007910  0.000063
#    top_to_ground 0.810141 0.746444   0.063697  0.004057
# bottom_to_bottom 0.732685 0.744978   0.012293  0.000151
# bottom_to_ground 0.822124 0.848861   0.026737  0.000715
# ground_to_ground 0.829590 0.830597   0.001007  0.000001
#
# — Sample 20 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.555556
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.138910 0.158473   0.019563 3.827182e-04
#    top_to_bottom 0.125659 0.129669   0.004010 1.607908e-05
#    top_to_ground 0.175197 0.213911   0.038714 1.498784e-03
# bottom_to_bottom 0.191415 0.187003   0.004412 1.946619e-05
# bottom_to_ground 0.236843 0.226153   0.010690 1.142718e-04
# ground_to_ground 0.223450 0.223718   0.000268 7.158942e-08
#
# — Sample 21 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.473986 0.434434   0.039552  0.001564
#    top_to_bottom 0.400671 0.393774   0.006897  0.000048
#    top_to_ground 0.594963 0.485007   0.109957  0.012090
# bottom_to_bottom 0.398062 0.415721   0.017658  0.000312
# bottom_to_ground 0.395822 0.431587   0.035765  0.001279
# ground_to_ground 0.455432 0.451898   0.003534  0.000012
#
# — Sample 22 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.073038 0.067802   0.005237  0.000027
#    top_to_bottom 0.020032 0.013137   0.006895  0.000048
#    top_to_ground 0.190523 0.185235   0.005288  0.000028
# bottom_to_bottom 0.043571 0.045986   0.002415  0.000006
# bottom_to_ground 0.059566 0.069097   0.009531  0.000091
# ground_to_ground 0.089884 0.099811   0.009928  0.000099
#
# — Sample 23 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.222222
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.059327 0.051659   0.007668  0.000059
#    top_to_bottom 0.050065 0.048961   0.001104  0.000001
#    top_to_ground 0.094860 0.070684   0.024175  0.000584
# bottom_to_bottom 0.071285 0.078686   0.007401  0.000055
# bottom_to_ground 0.085736 0.096001   0.010265  0.000105
# ground_to_ground 0.084530 0.088107   0.003577  0.000013
#
# — Sample 24 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.048595 0.049661   0.001066  0.000001
#    top_to_bottom 0.006953 0.004563   0.002389  0.000006
#    top_to_ground 0.145796 0.147110   0.001314  0.000002
# bottom_to_bottom 0.022530 0.024138   0.001608  0.000003
# bottom_to_ground 0.033037 0.040120   0.007083  0.000050
# ground_to_ground 0.057189 0.066739   0.009550  0.000091
#
# — Sample 25 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.617564 0.626655   0.009091  0.000083
#    top_to_bottom 0.545968 0.555802   0.009834  0.000097
#    top_to_ground 0.724315 0.721787   0.002528  0.000006
# bottom_to_bottom 0.664435 0.666589   0.002154  0.000005
# bottom_to_ground 0.739095 0.745205   0.006110  0.000037
# ground_to_ground 0.740586 0.747110   0.006525  0.000043
#
# — Sample 26 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.036495 0.041628   0.005133  0.000026
#    top_to_bottom 0.035958 0.040808   0.004850  0.000024
#    top_to_ground 0.057925 0.062144   0.004219  0.000018
# bottom_to_bottom 0.057857 0.058985   0.001128  0.000001
# bottom_to_ground 0.072583 0.071287   0.001296  0.000002
# ground_to_ground 0.066397 0.067713   0.001315  0.000002
#
# — Sample 27 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.229408 0.254030   0.024621  0.000606
#    top_to_bottom 0.209984 0.223153   0.013169  0.000173
#    top_to_ground 0.271286 0.306662   0.035376  0.001251
# bottom_to_bottom 0.273476 0.266072   0.007404  0.000055
# bottom_to_ground 0.316015 0.294536   0.021479  0.000461
# ground_to_ground 0.308735 0.306405   0.002330  0.000005
#
# — Sample 28 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.094704 0.097534   0.002829  0.000008
#    top_to_bottom 0.119400 0.110179   0.009220  0.000085
#    top_to_ground 0.063744 0.089652   0.025909  0.000671
# bottom_to_bottom 0.107488 0.093748   0.013740  0.000189
# bottom_to_ground 0.098611 0.083278   0.015333  0.000235
# ground_to_ground 0.088571 0.080596   0.007975  0.000064
#
# — Sample 29 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.122095 0.090566   0.031529 9.940558e-04
#    top_to_bottom 0.084135 0.070171   0.013963 1.949703e-04
#    top_to_ground 0.208211 0.138978   0.069232 4.793101e-03
# bottom_to_bottom 0.112315 0.111781   0.000534 2.847824e-07
# bottom_to_ground 0.130871 0.139977   0.009106 8.291968e-05
# ground_to_ground 0.147332 0.141635   0.005697 3.245886e-05
#
# — Sample 30 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.027098 0.028189   0.001091 1.189395e-06
#    top_to_bottom 0.002107 0.001914   0.000193 3.709405e-08
#    top_to_ground 0.096638 0.094240   0.002399 5.752888e-06
# bottom_to_bottom 0.006607 0.007774   0.001167 1.362736e-06
# bottom_to_ground 0.010188 0.013228   0.003040 9.239735e-06
# ground_to_ground 0.029162 0.031693   0.002531 6.406020e-06
#
# — Sample 31 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.587185 0.560542   0.026643  0.000710
#    top_to_bottom 0.485342 0.491489   0.006147  0.000038
#    top_to_ground 0.751844 0.659967   0.091877  0.008441
# bottom_to_bottom 0.572159 0.595221   0.023062  0.000532
# bottom_to_ground 0.625899 0.668452   0.042553  0.001811
# ground_to_ground 0.664639 0.672648   0.008009  0.000064
#
# — Sample 32 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.392096 0.426930   0.034834  0.001213
#    top_to_bottom 0.392475 0.401954   0.009479  0.000090
#    top_to_ground 0.382292 0.443263   0.060971  0.003717
# bottom_to_bottom 0.410187 0.397883   0.012304  0.000151
# bottom_to_ground 0.419317 0.393457   0.025859  0.000669
# ground_to_ground 0.413538 0.420414   0.006876  0.000047
#
# — Sample 33 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.171594 0.191534   0.019940  0.000398
#    top_to_bottom 0.186373 0.189976   0.003603  0.000013
#    top_to_ground 0.153723 0.195926   0.042202  0.001781
# bottom_to_bottom 0.175244 0.166430   0.008814  0.000078
# bottom_to_ground 0.167240 0.150671   0.016568  0.000275
# ground_to_ground 0.162308 0.164962   0.002654  0.000007
#
# — Sample 34 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.333333
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.134165 0.147761   0.013596 1.848548e-04
#    top_to_bottom 0.107647 0.113478   0.005831 3.400254e-05
#    top_to_ground 0.194668 0.215316   0.020648 4.263460e-04
# bottom_to_bottom 0.195008 0.193164   0.001844 3.400138e-06
# bottom_to_ground 0.253304 0.246762   0.006541 4.279014e-05
# ground_to_ground 0.242630 0.243370   0.000740 5.476381e-07
#
# — Sample 35 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.484370 0.493634   0.009265 8.583197e-05
#    top_to_bottom 0.424961 0.424805   0.000156 2.426063e-08
#    top_to_ground 0.577986 0.599697   0.021711 4.713623e-04
# bottom_to_bottom 0.525359 0.521866   0.003492 1.219537e-05
# bottom_to_ground 0.589459 0.589756   0.000297 8.837337e-08
# ground_to_ground 0.591555 0.598860   0.007305 5.336469e-05
#
# — Sample 36 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.888889
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.680926 0.647265   0.033661 1.133061e-03
#    top_to_bottom 0.689792 0.681603   0.008189 6.705762e-05
#    top_to_ground 0.643570 0.549382   0.094188 8.871436e-03
# bottom_to_bottom 0.574498 0.590164   0.015666 2.454180e-04
# bottom_to_ground 0.492548 0.522843   0.030295 9.177925e-04
# ground_to_ground 0.539862 0.540556   0.000694 4.813404e-07
#
# — Sample 37 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.484109 0.479944   0.004165  0.000017
#    top_to_bottom 0.360526 0.354366   0.006160  0.000038
#    top_to_ground 0.699071 0.707139   0.008068  0.000065
# bottom_to_bottom 0.635468 0.644060   0.008591  0.000074
# bottom_to_ground 0.821086 0.838642   0.017555  0.000308
# ground_to_ground 0.797880 0.810989   0.013109  0.000172
#
# — Sample 38 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.060299 0.068853   0.008554  0.000073
#    top_to_bottom 0.008687 0.015004   0.006318  0.000040
#    top_to_ground 0.176039 0.184125   0.008087  0.000065
# bottom_to_bottom 0.014931 0.016848   0.001917  0.000004
# bottom_to_ground 0.019436 0.021974   0.002538  0.000006
# ground_to_ground 0.053855 0.061366   0.007511  0.000056
#
# — Sample 39 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.560868 0.578790   0.017922  0.000321
#    top_to_bottom 0.602707 0.600165   0.002542  0.000006
#    top_to_ground 0.460045 0.499205   0.039160  0.001533
# bottom_to_bottom 0.529571 0.514731   0.014839  0.000220
# bottom_to_ground 0.477644 0.452120   0.025525  0.000652
# ground_to_ground 0.481924 0.476650   0.005275  0.000028
#
# — Sample 40 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.499802 0.527902   0.028100 7.896024e-04
#    top_to_bottom 0.466020 0.465250   0.000771 5.944017e-07
#    top_to_ground 0.544451 0.607222   0.062771 3.940206e-03
# bottom_to_bottom 0.539175 0.525572   0.013603 1.850406e-04
# bottom_to_ground 0.588948 0.569431   0.019517 3.809112e-04
# ground_to_ground 0.590531 0.596357   0.005826 3.394450e-05
#
# — Sample 41 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.052282 0.053252   0.000970 9.411772e-07
#    top_to_bottom 0.043787 0.040162   0.003625 1.314258e-05
#    top_to_ground 0.086869 0.092987   0.006118 3.743506e-05
# bottom_to_bottom 0.077188 0.075664   0.001525 2.324988e-06
# bottom_to_ground 0.099567 0.100327   0.000760 5.779661e-07
# ground_to_ground 0.092190 0.099313   0.007123 5.073645e-05
#
# — Sample 42 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.017988 0.021317   0.003329  0.000011
#    top_to_bottom 0.008808 0.011923   0.003115  0.000010
#    top_to_ground 0.057227 0.058321   0.001094  0.000001
# bottom_to_bottom 0.014839 0.021776   0.006936  0.000048
# bottom_to_ground 0.019434 0.030256   0.010822  0.000117
# ground_to_ground 0.019815 0.034317   0.014503  0.000210
#
# — Sample 43 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.172355 0.138035   0.034320 1.177889e-03
#    top_to_bottom 0.114619 0.115295   0.000676 4.567082e-07
#    top_to_ground 0.290661 0.180615   0.110046 1.211007e-02
# bottom_to_bottom 0.108830 0.132732   0.023901 5.712645e-04
# bottom_to_ground 0.103569 0.142302   0.038733 1.500211e-03
# ground_to_ground 0.151995 0.152820   0.000825 6.804909e-07
#
# — Sample 44 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.370294 0.388461   0.018166  0.000330
#    top_to_bottom 0.379841 0.381700   0.001859  0.000003
#    top_to_ground 0.346985 0.379178   0.032194  0.001036
# bottom_to_bottom 0.413253 0.405706   0.007547  0.000057
# bottom_to_ground 0.433770 0.421524   0.012246  0.000150
# ground_to_ground 0.416981 0.421370   0.004389  0.000019
#
# — Sample 45 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.210038 0.187162   0.022877 5.233375e-04
#    top_to_bottom 0.162100 0.162281   0.000181 3.271784e-08
#    top_to_ground 0.305442 0.236665   0.068778 4.730388e-03
# bottom_to_bottom 0.167147 0.184583   0.017435 3.039939e-04
# bottom_to_ground 0.169341 0.203779   0.034438 1.185970e-03
# ground_to_ground 0.200831 0.218899   0.018068 3.264371e-04
#
# — Sample 46 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.370581 0.364791   0.005791  0.000034
#    top_to_bottom 0.304996 0.313465   0.008469  0.000072
#    top_to_ground 0.490824 0.443522   0.047301  0.002237
# bottom_to_bottom 0.385001 0.392818   0.007817  0.000061
# bottom_to_ground 0.437327 0.449690   0.012363  0.000153
# ground_to_ground 0.455829 0.457891   0.002062  0.000004
#
# — Sample 47 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.419469 0.409143   0.010326 1.066302e-04
#    top_to_bottom 0.343863 0.344740   0.000877 7.692382e-07
#    top_to_ground 0.551974 0.525121   0.026853 7.210756e-04
# bottom_to_bottom 0.509924 0.519814   0.009890 9.780628e-05
# bottom_to_ground 0.618946 0.635830   0.016885 2.850908e-04
# ground_to_ground 0.607929 0.613887   0.005958 3.549237e-05
#
# — Sample 48 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.058123 0.059700   0.001577 2.487290e-06
#    top_to_bottom 0.009784 0.003589   0.006195 3.837716e-05
#    top_to_ground 0.167070 0.177922   0.010852 1.177720e-04
# bottom_to_bottom 0.031604 0.027537   0.004068 1.654585e-05
# bottom_to_ground 0.046336 0.045508   0.000828 6.858453e-07
# ground_to_ground 0.077859 0.079100   0.001241 1.539690e-06
#
# — Sample 49 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.598859 0.573477   0.025382 6.442212e-04
#    top_to_bottom 0.569728 0.572711   0.002982 8.895066e-06
#    top_to_ground 0.630322 0.528006   0.102316 1.046854e-02
# bottom_to_bottom 0.508159 0.528203   0.020044 4.017444e-04
# bottom_to_ground 0.466261 0.495025   0.028764 8.273913e-04
# ground_to_ground 0.519531 0.520232   0.000700 4.902720e-07
#
# Global scaled error stats:
#   min abs_error: 6.365290983212368e-05
#   median abs_error: 0.007402260255461084
#   max abs_error: 0.1186768974798098

# %% [markdown]
# # Unscaled

# %%
# Unscale everything and look at errors in real units that we can actually understand

# Load output capacitance column names
with open('X_names', 'r') as f:
    cap_names = f.read().splitlines()  

qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

# Unscale inputs
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        param_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_linear_{param_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale outputs 
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# Unscale predictions using same X scalers
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape

# Errrs
sq_errors_unscaled  = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# Build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': y_test_unscaled[i, j],
            'pred_unscaled': y_pred_unscaled[i, j],
            'abs_error_unscaled': abs_errors_unscaled[i, j],
            'sq_error_unscaled': sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# Save
out_csv_unscaled = Path(f'model2_predictions_and_errors_unscaled_{encoding}.csv')
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

# Pretty print per-sample 
for i in range(N_SAMPLES_TO_SHOW):
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    input_str = ', '.join(
        f'{qiskit_names[k] if k < len(qiskit_names) else f"col_{k}"}={X_test_unscaled[i,k]:.6g}'
        for k in range(X_test_unscaled.shape[1])
    )
    print(f'— Sample {i} (Unscaled) — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global unscaled error stats:')
print('  min abs_error:', float(abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(abs_errors_unscaled)))
print('  max abs_error:', float(abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_unscaled_model2_surrogate.csv
#
# — Sample 0 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91395      15.040012            0.126062           0.015892
#    top_to_bottom       0.66910       0.844393            0.175293           0.030728
#    top_to_ground      14.05235      13.957248            0.095102           0.009044
# bottom_to_bottom      13.62255      14.446895            0.824345           0.679544
# bottom_to_ground      12.78564      13.680641            0.895001           0.801027
# ground_to_ground      58.01370      58.789936            0.776236           0.602542
#
# — Sample 1 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.64499      22.281742            0.636752           0.405453
#    top_to_bottom       3.83797       3.967683            0.129713           0.016826
#    top_to_ground      17.53586      17.846811            0.310951           0.096691
# bottom_to_bottom      27.51404      26.641294            0.872746           0.761685
# bottom_to_ground      23.29018      22.496586            0.793594           0.629792
# ground_to_ground      73.35986      73.221771            0.138089           0.019069
#
# — Sample 2 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.84435      46.502666            0.341684           0.116748
#    top_to_bottom      20.25982      20.337404            0.077584           0.006019
#    top_to_ground      26.29119      25.456924            0.834266           0.695999
# bottom_to_bottom      67.75657      67.694565            0.062005           0.003845
# bottom_to_ground      46.86370      46.858715            0.004985           0.000025
# ground_to_ground     108.83635     108.076019            0.760331           0.578103
#
# — Sample 3 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.99644      44.249508            2.746932           7.545636
#    top_to_bottom      19.38918      18.772072            0.617108           0.380822
#    top_to_ground      27.25768      24.516062            2.741618           7.516470
# bottom_to_bottom      55.79690      56.980366            1.183466           1.400591
# bottom_to_ground      35.76054      37.922626            2.162086           4.674618
# ground_to_ground      97.29848      96.911667            0.386813           0.149624
#
# — Sample 4 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.54716      32.125229            0.578069           0.334164
#    top_to_bottom      11.61323      11.547159            0.066071           0.004365
#    top_to_ground      19.67277      19.992605            0.319835           0.102295
# bottom_to_bottom      43.43218      42.881355            0.550825           0.303408
# bottom_to_ground      31.29560      31.092035            0.203565           0.041439
# ground_to_ground      84.14240      84.474091            0.331691           0.110019
#
# — Sample 5 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91522      15.437690            0.522470           0.272975
#    top_to_bottom       1.90110       2.258079            0.356979           0.127434
#    top_to_ground      12.79837      13.110352            0.311982           0.097332
# bottom_to_bottom      16.82899      17.622774            0.793784           0.630093
# bottom_to_ground      14.71062      15.415164            0.704544           0.496382
# ground_to_ground      59.03334      59.519207            0.485867           0.236067
#
# — Sample 6 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.21478      40.371334            3.156554           9.963834
#    top_to_bottom      18.10928      18.304787            0.195507           0.038223
#    top_to_ground      18.86175      21.585482            2.723732           7.418714
# bottom_to_bottom      45.74491      42.584286            3.160624           9.989546
# bottom_to_ground      27.25160      24.202236            3.049364           9.298620
# ground_to_ground      79.00961      78.847511            0.162099           0.026276
#
# — Sample 7 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.07032      22.314955            1.244635           1.549116
#    top_to_bottom       1.21587       1.854848            0.638978           0.408293
#    top_to_ground      19.56543      19.985363            0.419933           0.176344
# bottom_to_bottom      17.12018      17.303028            0.182848           0.033433
# bottom_to_ground      15.65802      15.429313            0.228707           0.052307
# ground_to_ground      67.68762      67.498283            0.189337           0.035848
#
# — Sample 8 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      35.33519      35.566772            0.231582           0.053630
#    top_to_bottom      11.77509      11.203040            0.572050           0.327241
#    top_to_ground      23.15632      23.876902            0.720582           0.519238
# bottom_to_bottom      58.69605      57.030922            1.665128           2.772651
# bottom_to_ground      46.26890      45.304443            0.964457           0.930177
# ground_to_ground     104.35958     104.179085            0.180495           0.032579
#
# — Sample 9 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.04935      17.992384            0.056966           0.003245
#    top_to_bottom       2.51389       2.407154            0.106736           0.011393
#    top_to_ground      15.29043      15.233691            0.056739           0.003219
# bottom_to_bottom      23.93490      23.487123            0.447777           0.200504
# bottom_to_ground      21.09610      20.841208            0.254892           0.064970
# ground_to_ground      68.15670      68.370461            0.213761           0.045694
#
# — Sample 10 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      49.05578      46.362137            2.693643           7.255713
#    top_to_bottom      20.80786      20.545336            0.262524           0.068919
#    top_to_ground      27.89118      25.276770            2.614410           6.835142
# bottom_to_bottom      64.00772      65.292450            1.284730           1.650531
# bottom_to_ground      42.57999      44.456894            1.876904           3.522768
# ground_to_ground     104.87919     104.198425            0.680765           0.463441
#
# — Sample 11 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      50.54045      48.928188            1.612262           2.599388
#    top_to_bottom      17.73454      17.397038            0.337502           0.113908
#    top_to_ground      32.22853      31.193035            1.035495           1.072250
# bottom_to_bottom      86.86462      89.024719            2.160099           4.666029
# bottom_to_ground      68.29869      70.746475            2.447785           5.991652
# ground_to_ground     137.32339     139.099289            1.775899           3.153817
#
# — Sample 12 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      26.27875      24.776999            1.501751           2.255258
#    top_to_bottom       8.92551       8.425617            0.499893           0.249893
#    top_to_ground      17.10117      16.023844            1.077326           1.160632
# bottom_to_bottom      29.95980      30.345551            0.385751           0.148803
# bottom_to_ground      20.65658      21.636642            0.980062           0.960522
# ground_to_ground      70.18744      69.805389            0.382051           0.145963
#
# — Sample 13 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.85738      36.537685            1.319695           1.741594
#    top_to_bottom      13.07647      12.919369            0.157101           0.024681
#    top_to_ground      24.54618      23.315680            1.230500           1.514131
# bottom_to_bottom      59.45636      60.554943            1.098583           1.206885
# bottom_to_ground      45.77177      47.192509            1.420739           2.018498
# ground_to_ground     105.19612     105.356270            0.160150           0.025648
#
# — Sample 14 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.69895      20.414528            0.284422           0.080896
#    top_to_bottom       0.60461       0.629564            0.024954           0.000623
#    top_to_ground      19.82790      19.481697            0.346203           0.119856
# bottom_to_bottom      14.56863      15.069394            0.500764           0.250765
# bottom_to_ground      13.79113      14.422254            0.631124           0.398317
# ground_to_ground      65.63654      65.796455            0.159915           0.025573
#
# — Sample 15 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      36.59696      38.154194            1.557234           2.424977
#    top_to_bottom      15.03656      15.234643            0.198083           0.039237
#    top_to_ground      21.21543      22.402529            1.187099           1.409203
# bottom_to_bottom      60.00257      58.472801            1.529769           2.340193
# bottom_to_ground      44.42258      42.953423            1.469157           2.158424
# ground_to_ground     100.27778     100.313263            0.035483           0.001259
#
# — Sample 16 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.80333      25.017307            0.213977           0.045786
#    top_to_bottom       7.54392       7.592450            0.048530           0.002355
#    top_to_ground      17.01049      17.168198            0.157708           0.024872
# bottom_to_bottom      32.79263      33.282303            0.489673           0.239780
# bottom_to_ground      24.98322      25.319704            0.336484           0.113222
# ground_to_ground      74.98806      75.107246            0.119186           0.014205
#
# — Sample 17 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      72.09757      72.372009            0.274439           0.075317
#    top_to_bottom      42.28320      41.884861            0.398339           0.158674
#    top_to_ground      29.25596      30.247026            0.991066           0.982213
# bottom_to_bottom     101.78691     101.331169            0.455741           0.207700
# bottom_to_ground      58.96084      58.694069            0.266771           0.071167
# ground_to_ground     124.89715     125.480202            0.583052           0.339949
#
# — Sample 18 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.65327      55.216549            0.563279           0.317283
#    top_to_bottom      25.69001      25.656424            0.033586           0.001128
#    top_to_ground      28.43415      28.675547            0.241397           0.058272
# bottom_to_bottom      77.76412      77.036095            0.728025           0.530021
# bottom_to_ground      51.52313      51.162510            0.360620           0.130047
# ground_to_ground     115.57029     115.470634            0.099656           0.009931
#
# — Sample 19 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.24473      67.021042            2.223688           4.944789
#    top_to_bottom      32.55387      32.125839            0.428031           0.183210
#    top_to_ground      36.23866      34.411823            1.826837           3.337332
# bottom_to_bottom     110.06436     111.697861            1.633501           2.668325
# bottom_to_ground      76.51531      78.609589            2.094279           4.386003
# ground_to_ground     150.90990     151.024185            0.114285           0.013061
#
# — Sample 20 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.48460      27.068171            1.583571           2.507696
#    top_to_bottom       7.16345       7.380447            0.216997           0.047088
#    top_to_ground      18.02827      19.138603            1.110333           1.232840
# bottom_to_bottom      38.13878      37.552494            0.586286           0.343731
# bottom_to_ground      30.67125      29.833937            0.837313           0.701094
# ground_to_ground      82.12106      82.151428            0.030368           0.000922
#
# — Sample 21 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      52.60779      49.406219            3.201571          10.250054
#    top_to_bottom      22.04591      21.672701            0.373209           0.139285
#    top_to_ground      30.06731      26.913719            3.153591           9.945135
# bottom_to_bottom      65.59865      67.945152            2.346502           5.506073
# bottom_to_ground      43.12377      45.925156            2.801386           7.847762
# ground_to_ground     108.44790     108.046814            0.401086           0.160870
#
# — Sample 22 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.15252      19.728636            0.423884           0.179678
#    top_to_bottom       1.44740       1.074269            0.373131           0.139226
#    top_to_ground      18.46784      18.316172            0.151668           0.023003
# bottom_to_bottom      18.49276      18.813688            0.320928           0.102995
# bottom_to_ground      16.78539      17.531960            0.746570           0.557366
# ground_to_ground      66.96300      68.089645            1.126645           1.269330
#
# — Sample 23 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.04266      18.421955            0.620705           0.385275
#    top_to_bottom       3.07264       3.012914            0.059726           0.003567
#    top_to_ground      15.72419      15.030829            0.693361           0.480749
# bottom_to_bottom      22.17553      23.158953            0.983423           0.967120
# bottom_to_ground      18.83528      19.639296            0.804016           0.646441
# ground_to_ground      66.35541      66.761398            0.405988           0.164827
#
# — Sample 24 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.17391      18.260168            0.086258           0.007440
#    top_to_bottom       0.73958       0.610273            0.129307           0.016720
#    top_to_ground      17.18506      17.222742            0.037682           0.001420
# bottom_to_bottom      15.69679      15.910473            0.213683           0.045660
# bottom_to_ground      14.70742      15.262229            0.554809           0.307813
# ground_to_ground      63.25260      64.336365            1.083765           1.174546
#
# — Sample 25 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      64.22991      64.965797            0.735887           0.541530
#    top_to_bottom      29.90875      30.440941            0.532191           0.283227
#    top_to_ground      33.77716      33.704647            0.072513           0.005258
# bottom_to_bottom     100.99499     101.281242            0.286252           0.081940
# bottom_to_ground      70.01176      70.490334            0.478574           0.229033
# ground_to_ground     140.80910     141.549576            0.740476           0.548304
#
# — Sample 26 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      17.19448      17.609949            0.415469           0.172615
#    top_to_bottom       2.30923       2.571672            0.262442           0.068876
#    top_to_ground      14.66488      14.785888            0.121008           0.014643
# bottom_to_bottom      20.39118      20.541031            0.149851           0.022455
# bottom_to_ground      17.80506      17.703539            0.101521           0.010307
# ground_to_ground      64.29761      64.446869            0.149259           0.022278
#
# — Sample 27 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      32.81010      34.803116            1.993016           3.972112
#    top_to_bottom      11.72675      12.439425            0.712675           0.507906
#    top_to_ground      20.78413      21.798725            1.014595           1.029403
# bottom_to_bottom      49.04328      48.059433            0.983847           0.967955
# bottom_to_ground      36.87262      35.190231            1.682389           2.830432
# ground_to_ground      91.79978      91.535347            0.264433           0.069925
#
# — Sample 28 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.90631      22.135332            0.229022           0.052451
#    top_to_bottom       6.82474       6.325775            0.498965           0.248966
#    top_to_ground      14.83177      15.574834            0.743064           0.552144
# bottom_to_bottom      26.98623      25.160437            1.825793           3.333521
# bottom_to_ground      19.84377      18.642725            1.201045           1.442509
# ground_to_ground      66.81403      65.909004            0.905026           0.819072
#
# — Sample 29 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.12348      21.571348            2.552132           6.513377
#    top_to_bottom       4.91634       4.160713            0.755627           0.570972
#    top_to_ground      18.97512      16.989519            1.985601           3.942611
# bottom_to_bottom      27.62769      27.556776            0.070914           0.005029
# bottom_to_ground      22.37061      23.083870            0.713260           0.508740
# ground_to_ground      73.48264      72.836075            0.646565           0.418047
#
# — Sample 30 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      16.43384      16.522120            0.088280           0.007793
#    top_to_bottom       0.47735       0.466927            0.010423           0.000109
#    top_to_ground      15.77519      15.706400            0.068790           0.004732
# bottom_to_bottom      13.58084      13.735963            0.155123           0.024063
# bottom_to_ground      12.91772      13.155814            0.238094           0.056689
# ground_to_ground      60.07192      60.359158            0.287238           0.082505
#
# — Sample 31 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      61.77084      59.614166            2.156674           4.651242
#    top_to_bottom      26.62797      26.960604            0.332634           0.110645
#    top_to_ground      34.56668      31.931625            2.635055           6.943513
# bottom_to_bottom      88.73307      91.797630            3.064560           9.391530
# bottom_to_ground      61.14529      64.478416            3.333126          11.109732
# ground_to_ground     132.19017     133.099045            0.908875           0.826053
#
# — Sample 32 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      45.97905      48.798748            2.819698           7.950697
#    top_to_bottom      21.60242      22.115381            0.512961           0.263129
#    top_to_ground      23.96784      25.716509            1.748669           3.057843
# bottom_to_bottom      67.20976      65.574768            1.634992           2.673199
# bottom_to_ground      44.96409      42.938560            2.025530           4.102770
# ground_to_ground     103.69355     104.473831            0.780281           0.608839
#
# — Sample 33 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.13024      29.744328            1.614088           2.605279
#    top_to_bottom      10.44906      10.644038            0.194978           0.038016
#    top_to_ground      17.41241      18.622786            1.210376           1.465009
# bottom_to_bottom      35.98982      34.818581            1.171239           1.371802
# bottom_to_ground      25.21932      23.921555            1.297765           1.684195
# ground_to_ground      75.18223      75.483429            0.301199           0.090721
#
# — Sample 34 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.10048      26.201038            1.100558           1.211229
#    top_to_bottom       6.18873       6.504288            0.315558           0.099577
#    top_to_ground      18.58672      19.178915            0.592195           0.350695
# bottom_to_bottom      38.61615      38.371120            0.245030           0.060039
# bottom_to_ground      31.96057      31.448193            0.512377           0.262531
# ground_to_ground      84.29772      84.381706            0.083986           0.007054
#
# — Sample 35 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.44833      54.198261            0.749931           0.562397
#    top_to_bottom      23.36040      23.351971            0.008429           0.000071
#    top_to_ground      29.58039      30.203064            0.622674           0.387723
# bottom_to_bottom      82.51415      82.050095            0.464055           0.215347
# bottom_to_ground      58.29103      58.314316            0.023286           0.000542
# ground_to_ground     123.89606     124.725098            0.829038           0.687303
#
# — Sample 36 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.35887      66.634132            2.724738           7.424195
#    top_to_bottom      37.69192      37.248772            0.443148           0.196380
#    top_to_ground      31.46136      28.760012            2.701348           7.297283
# bottom_to_bottom      89.04400      91.125725            2.081725           4.333578
# bottom_to_ground      50.70017      53.073132            2.372962           5.630947
# ground_to_ground     118.02962     118.108353            0.078733           0.006199
#
# — Sample 37 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.42721      53.090031            0.337179           0.113690
#    top_to_bottom      19.87346      19.540085            0.333375           0.111139
#    top_to_ground      33.05314      33.284531            0.231391           0.053542
# bottom_to_bottom      97.14587      98.287498            1.141628           1.303316
# bottom_to_ground      76.43402      77.809097            1.375077           1.890838
# ground_to_ground     147.31121     148.798950            1.487740           2.213371
#
# — Sample 38 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.12130      19.813732            0.692432           0.479462
#    top_to_bottom       0.83343       1.175310            0.341880           0.116882
#    top_to_ground      18.05242      18.284353            0.231933           0.053793
# bottom_to_bottom      14.68703      14.941739            0.254709           0.064877
# bottom_to_ground      13.64212      13.840885            0.198765           0.039508
# ground_to_ground      62.87424      63.726627            0.852387           0.726564
#
# — Sample 39 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      59.64057      61.091270            1.450700           2.104532
#    top_to_bottom      32.97925      32.841663            0.137587           0.018930
#    top_to_ground      26.19782      27.320936            1.123116           1.261390
# bottom_to_bottom      83.07385      81.101952            1.971898           3.888383
# bottom_to_ground      49.53280      47.533497            1.999303           3.997213
# ground_to_ground     111.45445     110.855843            0.598607           0.358331
#
# — Sample 40 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.69749      56.972073            2.274583           5.173726
#    top_to_bottom      25.58236      25.540638            0.041722           0.001741
#    top_to_ground      28.61859      30.418882            1.800292           3.241053
# bottom_to_bottom      84.35009      82.542488            1.807602           3.267425
# bottom_to_ground      58.25104      56.722309            1.528731           2.337018
# ground_to_ground     123.77985     124.441048            0.661198           0.437182
#
# — Sample 41 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.47237      18.550900            0.078530           0.006167
#    top_to_bottom       2.73292       2.536736            0.196184           0.038488
#    top_to_ground      15.49501      15.670488            0.175478           0.030793
# bottom_to_bottom      22.95995      22.757332            0.202618           0.041054
# bottom_to_ground      19.91865      19.978199            0.059549           0.003546
# ground_to_ground      67.22470      68.033058            0.808358           0.653443
#
# — Sample 42 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      15.69639      15.965825            0.269435           0.072595
#    top_to_bottom       0.83998       1.008558            0.168578           0.028419
#    top_to_ground      14.64488      14.676249            0.031369           0.000984
# bottom_to_bottom      14.67483      15.596550            0.921720           0.849568
# bottom_to_ground      13.64197      14.489650            0.847680           0.718561
# ground_to_ground      59.01106      60.656921            1.645861           2.708860
#
# — Sample 43 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.19186      25.413748            2.778112           7.717907
#    top_to_bottom       6.56601       6.602582            0.036572           0.001337
#    top_to_ground      21.33982      18.183674            3.156146           9.961258
# bottom_to_bottom      27.16464      30.340694            3.176054          10.087322
# bottom_to_ground      20.23212      23.265976            3.033856           9.204282
# ground_to_ground      74.01179      74.105408            0.093618           0.008764
#
# — Sample 44 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.21430      45.684814            1.470514           2.162413
#    top_to_bottom      20.91871      21.019289            0.100579           0.010116
#    top_to_ground      22.95520      23.878531            0.923331           0.852539
# bottom_to_bottom      67.61721      66.614349            1.002861           1.005729
# bottom_to_ground      46.09617      45.136978            0.959192           0.920049
# ground_to_ground     104.08419     104.582306            0.498116           0.248119
#
# — Sample 45 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.24216      29.390383            1.851777           3.429079
#    top_to_bottom       9.13548       9.145268            0.009788           0.000096
#    top_to_ground      21.76376      19.791191            1.972569           3.891028
# bottom_to_bottom      34.91396      37.230831            2.316871           5.367892
# bottom_to_ground      25.38392      28.081383            2.697463           7.276305
# ground_to_ground      79.55404      81.604469            2.050429           4.204260
#
# — Sample 46 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.23756      43.768837            0.468723           0.219701
#    top_to_bottom      16.86840      17.326689            0.458289           0.210029
#    top_to_ground      27.08055      25.723936            1.356614           1.840401
# bottom_to_bottom      63.86300      64.901810            1.038810           1.079126
# bottom_to_ground      46.37482      47.343159            0.968339           0.937680
# ground_to_ground     108.49297     108.727036            0.234066           0.054787
#
# — Sample 47 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      48.19483      47.358963            0.835867           0.698674
#    top_to_bottom      18.97173      19.019194            0.047464           0.002253
#    top_to_ground      28.83436      28.064213            0.770147           0.593127
# bottom_to_bottom      80.46316      81.777336            1.314176           1.727059
# bottom_to_ground      60.60069      61.923233            1.322543           1.749120
# ground_to_ground     125.75437     126.430473            0.676103           0.457116
#
# — Sample 48 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.94514      19.072802            0.127662           0.016297
#    top_to_bottom       0.89281       0.557567            0.335243           0.112388
#    top_to_ground      17.79519      18.106436            0.311246           0.096874
# bottom_to_bottom      16.90262      16.362097            0.540523           0.292165
# bottom_to_ground      15.74914      15.684272            0.064868           0.004208
# ground_to_ground      65.59834      65.739159            0.140819           0.019830
#
# — Sample 49 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      62.71578      60.661236            2.054544           4.221152
#    top_to_bottom      31.19457      31.355968            0.161398           0.026049
#    top_to_ground      31.08140      28.146950            2.934450           8.610998
# bottom_to_bottom      80.22864      82.892090            2.663450           7.093965
# bottom_to_ground      48.64112      50.894188            2.253068           5.076315
# ground_to_ground     115.72236     115.801826            0.079466           0.006315
#
# Global unscaled error stats:
#   min abs_error: 0.0049849426269545916
#   median abs_error: 0.5846688360595635
#   max abs_error: 3.4568868212890678

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# Lets see how good we actually did

# %%
# find percentage difference like 100 * abs(pred - re) / abs(ref), with tiny epsilon to avoid division by zero
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(y_pred_unscaled - y_test_unscaled) / (np.abs(y_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_params)]
all_pct = pct_errors_unscaled.ravel()

# %%
# box plot showing % error distribution per capacitance output 
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Percentage Error Distribution per Output')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_boxplot.pdf')
plt.show()
# Out:
# /tmp/ipykernel_38016/2286795443.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,

# %%
# histogram it too
n_cols_grid = 3
n_rows_grid = math.ceil(n_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

# hide unused subplots
for k in range(n_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Model 2: Percentage Error Histograms per Output', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_histograms_per_output.pdf')
plt.show()

# %%
#look at the stats nicely
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'All outputs':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")
# Out:
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# top_to_top                      3.26       3.40       6.08      11.66
# top_to_bottom                   2.33       8.27      23.50     101.86
# top_to_ground                   3.39       4.56       9.81      14.79
# bottom_to_bottom                2.01       2.61       5.80      11.69
# bottom_to_ground                3.41       3.72       6.57      15.00
# ground_to_ground                0.49       0.64       1.36       2.79
# ----------------------------------------------------------------------
# All outputs                     2.03       3.87       7.26     101.86

# %%
# scatter plot with fancy visulaization of points using this grouping thing

fig, ax = plt.subplots(figsize=(12, 6))
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    x = np.full_like(col_pct, j) + np.random.uniform(-0.2, 0.2, size=len(col_pct))
    ax.scatter(x, col_pct, alpha=0.4, s=12, label=short_names[j])
ax.set_xticks(range(n_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Per-Sample Percentage Error by Capacitance Output')
plt.tight_layout()
plt.savefig('plots/model2_pct_error_scatter.pdf')
plt.show()
