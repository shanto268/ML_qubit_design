# %% [markdown]
# # Model 2 Predictions (Qiskit Metal → Capacitance)
#
# This notebook loads the trained Model 2 (Ansys surrogate) and evaluates its predictions
# on the test set. It shows both scaled and unscaled errors.
#
# **Key difference from Model 1:** Inputs are Qiskit Metal design parameters,
# outputs are capacitance values. No one-hot encoding, no finger_count classification.

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters import *

# %% [markdown]
# ## Library

# %%
import os, gc
from pathlib import Path
import numpy as np
import pandas as pd
import joblib

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load
#
# **FLIPPED:** We load old Y (Qiskit params) as inputs and old X (capacitance) as outputs,
# matching what the Model 2 training notebook does.

# %%
def load_scaled_split(kind, split):
    return np.load(f"{DATA_DIR}/npy/{split}_{kind}_encoding_scaled.npy", allow_pickle=True)

# New inputs = old Y (Qiskit Metal params, linear encoding)
X_train = load_scaled_split('linear', 'y_train')
X_val   = load_scaled_split('linear', 'y_val')
X_test  = load_scaled_split('linear', 'y_test')

# New outputs = old X (capacitance values)
y_train = load_scaled_split('linear', 'x_train')
y_val   = load_scaled_split('linear', 'x_val')
y_test  = load_scaled_split('linear', 'x_test')

# Load column names
with open('X_names', 'r') as f:
    cap_column_names = f.read().splitlines()   # capacitance names (our outputs)

qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

print(f'Inputs (Qiskit params):  {X_test.shape}')
print(f'Outputs (Capacitance):   {y_test.shape}')
# Out:
# Inputs (Qiskit params):  (65, 4)
# Outputs (Capacitance):   (65, 6)

# %% [markdown]
# ### Visualize

# %%
# Decide which model file to use
encoding = 'model2_surrogate'
chosen_path = f'model/best_keras_model_model2_surrogate.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

# Load output headers (capacitance column names)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Output headers: {headers}')
# Out:
# Model path: model/best_keras_model_model2_surrogate.keras
# Output headers: ['top_to_top', 'top_to_bottom', 'top_to_ground', 'bottom_to_bottom', 'bottom_to_ground', 'ground_to_ground']

# %%
# Run on CPU
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    y_pred = chosen_model.predict(X_test_cur, verbose=0)

print(f'\n—— {os.path.basename(chosen_path)} ——')
chosen_model.summary()
print(f'Samples: {len(X_test_cur)} | Targets dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771952390.467600 1034616 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1062 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:10.0, compute capability: 8.0
# I0000 00:00:1771952390.667421 3032289 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# —— best_keras_model_model2_surrogate.keras ——
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 480)            │         2,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │         2,886 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,286 (20.65 KB)
#  Trainable params: 5,286 (20.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 65 | Targets dim: 6

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred     = np.asarray(y_pred)

N, P = y_test_cur.shape

# Ensure y_pred shape matches
if y_pred.ndim == 3 and y_pred.shape[-1] == 1:
    y_pred = y_pred[..., 0]
if y_pred.ndim == 1:
    y_pred = y_pred.reshape(-1, 1)
assert y_pred.shape == (N, P), f'y_pred shape {y_pred.shape} != expected {(N, P)}'

# Scaled errors
sq_errors  = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# Build dataframe
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  y_test_cur[i, j],
            'pred': y_pred[i, j],
            'abs_error': abs_errors[i, j],
            'sq_error':  sq_errors[i, j],
        })

df = pd.DataFrame(rows)

# Save scaled predictions
out_csv = Path(f'model2_predictions_and_errors_{encoding}.csv')
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

# Pretty print per-sample (scaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    input_str = ', '.join(
        f'{qiskit_param_names[k] if k < len(qiskit_param_names) else f"in_{k}"}={X_test_cur[i,k]:.6g}'
        for k in range(X_test_cur.shape[1])
    )
    print(f'— Sample {i} — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global scaled error stats:')
print('  min abs_error:', float(abs_errors.min()))
print('  median abs_error:', float(np.median(abs_errors)))
print('  max abs_error:', float(abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_model2_surrogate.csv
#
# — Sample 0 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.008322 0.015856   0.007534  0.000057
#    top_to_bottom 0.005650 0.014411   0.008761  0.000077
#    top_to_ground 0.036568 0.040873   0.004305  0.000019
# bottom_to_bottom 0.006921 0.019332   0.012411  0.000154
# bottom_to_ground 0.008502 0.021953   0.013452  0.000181
# ground_to_ground 0.011026 0.022841   0.011815  0.000140
#
# — Sample 1 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.091476 0.106304   0.014828  0.000220
#    top_to_bottom 0.064207 0.061841   0.002367  0.000006
#    top_to_ground 0.158028 0.211946   0.053918  0.002907
# bottom_to_bottom 0.111460 0.096215   0.015245  0.000232
# bottom_to_ground 0.142611 0.119307   0.023304  0.000543
# ground_to_ground 0.146250 0.143222   0.003028  0.000009
#
# — Sample 2 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.402785 0.379095   0.023690  0.000561
#    top_to_bottom 0.367666 0.354246   0.013420  0.000180
#    top_to_ground 0.463301 0.416641   0.046660  0.002177
# bottom_to_bottom 0.414302 0.408529   0.005773  0.000033
# bottom_to_ground 0.443569 0.440727   0.002842  0.000008
# ground_to_ground 0.458855 0.445352   0.013503  0.000182
#
# — Sample 3 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.404664 0.370993   0.033671  0.001134
#    top_to_bottom 0.351577 0.341945   0.009632  0.000093
#    top_to_ground 0.497000 0.403610   0.093389  0.008722
# bottom_to_bottom 0.324300 0.333264   0.008964  0.000080
# bottom_to_ground 0.301817 0.323692   0.021875  0.000479
# ground_to_ground 0.357188 0.352175   0.005013  0.000025
#
# — Sample 4 — Inputs: design_options.cap_gap=1, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.213806 0.214727   0.000921 8.482382e-07
#    top_to_bottom 0.207886 0.200156   0.007730 5.974608e-05
#    top_to_ground 0.232536 0.245071   0.012535 1.571263e-04
# bottom_to_bottom 0.231250 0.221052   0.010199 1.040160e-04
# bottom_to_ground 0.244814 0.233335   0.011479 1.317757e-04
# ground_to_ground 0.241262 0.238170   0.003091 9.557312e-06
#
# — Sample 5 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0, design_options.finger_count=0.111111
#            param       ref     pred  abs_error  sq_error
#       top_to_top  0.008338 0.024461   0.016124  0.000260
#    top_to_bottom  0.028416 0.036127   0.007711  0.000059
#    top_to_ground -0.007155 0.027705   0.034861  0.001215
# bottom_to_bottom  0.031050 0.036167   0.005116  0.000026
# bottom_to_ground  0.033077 0.035225   0.002148  0.000005
# ground_to_ground  0.020011 0.029477   0.009466  0.000090
#
# — Sample 6 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=1, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.283823 0.307743   0.023920  0.000572
#    top_to_bottom 0.327926 0.332073   0.004147  0.000017
#    top_to_ground 0.204258 0.254654   0.050396  0.002540
# bottom_to_bottom 0.248655 0.244012   0.004643  0.000022
# bottom_to_ground 0.193185 0.180737   0.012449  0.000155
# ground_to_ground 0.196034 0.202820   0.006786  0.000046
#
# — Sample 7 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.084377 0.073743   0.010634  0.000113
#    top_to_bottom 0.015754 0.018097   0.002344  0.000005
#    top_to_ground 0.228793 0.208432   0.020361  0.000415
# bottom_to_bottom 0.033242 0.037304   0.004062  0.000017
# bottom_to_ground 0.045173 0.050811   0.005638  0.000032
# ground_to_ground 0.096269 0.090377   0.005892  0.000035
#
# — Sample 8 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.260603 0.270406   0.009803 9.609785e-05
#    top_to_bottom 0.210877 0.212501   0.001624 2.636829e-06
#    top_to_ground 0.353997 0.379829   0.025832 6.673074e-04
# bottom_to_bottom 0.346117 0.339224   0.006894 4.752462e-05
# bottom_to_ground 0.435975 0.423260   0.012715 1.616611e-04
# ground_to_ground 0.419407 0.419021   0.000386 1.492429e-07
#
# — Sample 9 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.047056 0.056269   0.009213  0.000085
#    top_to_bottom 0.039740 0.036430   0.003310  0.000011
#    top_to_ground 0.079736 0.109501   0.029765  0.000886
# bottom_to_bottom 0.084525 0.081841   0.002684  0.000007
# bottom_to_ground 0.114599 0.111016   0.003584  0.000013
# ground_to_ground 0.100402 0.110809   0.010406  0.000108
#
# — Sample 10 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.430105 0.400395   0.029710  0.000883
#    top_to_bottom 0.377793 0.366884   0.010909  0.000119
#    top_to_ground 0.519088 0.442192   0.076896  0.005913
# bottom_to_bottom 0.386090 0.390559   0.004469  0.000020
# bottom_to_ground 0.388879 0.402742   0.013863  0.000192
# ground_to_ground 0.423986 0.420369   0.003617  0.000013
#
# — Sample 11 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.448446 0.443195   0.005252  0.000028
#    top_to_bottom 0.321001 0.339688   0.018686  0.000349
#    top_to_ground 0.670319 0.623645   0.046674  0.002178
# bottom_to_bottom 0.558098 0.560888   0.002790  0.000008
# bottom_to_ground 0.717224 0.705120   0.012104  0.000147
# ground_to_ground 0.709871 0.693260   0.016611  0.000276
#
# — Sample 12 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.148721 0.140172   0.008548  0.000073
#    top_to_bottom 0.158220 0.151993   0.006226  0.000039
#    top_to_ground 0.142871 0.132068   0.010804  0.000117
# bottom_to_bottom 0.129865 0.134630   0.004765  0.000023
# bottom_to_ground 0.108988 0.122006   0.013018  0.000169
# ground_to_ground 0.118296 0.124103   0.005807  0.000034
#
# — Sample 13 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.291762 0.289437   0.002324  0.000005
#    top_to_bottom 0.234925 0.239773   0.004848  0.000023
#    top_to_ground 0.402457 0.385114   0.017344  0.000301
# bottom_to_bottom 0.351839 0.367617   0.015778  0.000249
# bottom_to_ground 0.429628 0.450391   0.020763  0.000431
# ground_to_ground 0.426779 0.441413   0.014635  0.000214
#
# — Sample 14 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.079789 0.062305   0.017484 3.057015e-04
#    top_to_bottom 0.004458 0.004669   0.000210 4.425802e-08
#    top_to_ground 0.237945 0.201882   0.036063 1.300523e-03
# bottom_to_bottom 0.014040 0.024139   0.010099 1.019873e-04
# bottom_to_ground 0.021339 0.039243   0.017905 3.205799e-04
# ground_to_ground 0.078196 0.076606   0.001590 2.527693e-06
#
# — Sample 15 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.276191 0.288065   0.011874 1.409997e-04
#    top_to_bottom 0.271145 0.271445   0.000299 8.960774e-08
#    top_to_ground 0.286324 0.324631   0.038307 1.467453e-03
# bottom_to_bottom 0.355950 0.346020   0.009930 9.860563e-05
# bottom_to_ground 0.412403 0.393968   0.018435 3.398570e-04
# ground_to_ground 0.383440 0.383703   0.000263 6.935976e-08
#
# — Sample 16 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.444444
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.130494 0.123829   0.006665 4.442073e-05
#    top_to_bottom 0.132689 0.129553   0.003136 9.835472e-06
#    top_to_ground 0.139709 0.129175   0.010535 1.109819e-04
# bottom_to_bottom 0.151183 0.152027   0.000843 7.109847e-07
# bottom_to_ground 0.164225 0.166766   0.002540 6.452763e-06
# ground_to_ground 0.160597 0.158480   0.002118 4.484075e-06
#
# — Sample 17 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.714760 0.708668   0.006091  0.000037
#    top_to_bottom 0.774634 0.741307   0.033327  0.001111
#    top_to_ground 0.566674 0.597128   0.030454  0.000927
# bottom_to_bottom 0.670394 0.655759   0.014635  0.000214
# bottom_to_ground 0.598010 0.589851   0.008160  0.000067
# ground_to_ground 0.600376 0.606950   0.006574  0.000043
#
# — Sample 18 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.499256 0.499785   0.000530 2.806636e-07
#    top_to_bottom 0.468010 0.455185   0.012825 1.644756e-04
#    top_to_ground 0.538020 0.548646   0.010626 1.129061e-04
# bottom_to_bottom 0.489613 0.476094   0.013519 1.827678e-04
# bottom_to_ground 0.503055 0.484463   0.018591 3.456366e-04
# ground_to_ground 0.518191 0.513353   0.004839 2.341570e-05
#
# — Sample 19 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.679516 0.662315   0.017201  0.000296
#    top_to_bottom 0.594847 0.604661   0.009815  0.000096
#    top_to_ground 0.810141 0.738322   0.071819  0.005158
# bottom_to_bottom 0.732685 0.738391   0.005705  0.000033
# bottom_to_ground 0.822124 0.820102   0.002022  0.000004
# ground_to_ground 0.829590 0.813761   0.015828  0.000251
#
# — Sample 20 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.138910 0.152274   0.013363  0.000179
#    top_to_bottom 0.125659 0.130348   0.004689  0.000022
#    top_to_ground 0.175197 0.204803   0.029606  0.000877
# bottom_to_bottom 0.191415 0.188337   0.003079  0.000009
# bottom_to_ground 0.236843 0.227310   0.009533  0.000091
# ground_to_ground 0.223450 0.224659   0.001208  0.000001
#
# — Sample 21 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.473986 0.431995   0.041991  0.001763
#    top_to_bottom 0.400671 0.387575   0.013096  0.000171
#    top_to_ground 0.594963 0.488342   0.106621  0.011368
# bottom_to_bottom 0.398062 0.408384   0.010321  0.000107
# bottom_to_ground 0.395822 0.418265   0.022443  0.000504
# ground_to_ground 0.455432 0.446846   0.008586  0.000074
#
# — Sample 22 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.073038 0.065002   0.008037  0.000065
#    top_to_bottom 0.020032 0.014172   0.005860  0.000034
#    top_to_ground 0.190523 0.185726   0.004797  0.000023
# bottom_to_bottom 0.043571 0.051991   0.008420  0.000071
# bottom_to_ground 0.059566 0.077256   0.017690  0.000313
# ground_to_ground 0.089884 0.105971   0.016088  0.000259
#
# — Sample 23 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.059327 0.058359   0.000969 9.385539e-07
#    top_to_bottom 0.050065 0.055568   0.005503 3.028418e-05
#    top_to_ground 0.094860 0.080691   0.014169 2.007680e-04
# bottom_to_bottom 0.071285 0.077725   0.006440 4.146995e-05
# bottom_to_ground 0.085736 0.091875   0.006139 3.769262e-05
# ground_to_ground 0.084530 0.087513   0.002983 8.900602e-06
#
# — Sample 24 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.048595 0.036399   0.012196  0.000149
#    top_to_bottom 0.006953 0.000711   0.006242  0.000039
#    top_to_ground 0.145796 0.123692   0.022104  0.000489
# bottom_to_bottom 0.022530 0.026290   0.003760  0.000014
# bottom_to_ground 0.033037 0.043934   0.010898  0.000119
# ground_to_ground 0.057189 0.062526   0.005337  0.000028
#
# — Sample 25 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.617564 0.623169   0.005605  0.000031
#    top_to_bottom 0.545968 0.549850   0.003882  0.000015
#    top_to_ground 0.724315 0.721943   0.002373  0.000006
# bottom_to_bottom 0.664435 0.656833   0.007601  0.000058
# bottom_to_ground 0.739095 0.722206   0.016888  0.000285
# ground_to_ground 0.740586 0.735957   0.004629  0.000021
#
# — Sample 26 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.036495 0.052701   0.016206  0.000263
#    top_to_bottom 0.035958 0.044933   0.008975  0.000081
#    top_to_ground 0.057925 0.090953   0.033028  0.001091
# bottom_to_bottom 0.057857 0.059619   0.001761  0.000003
# bottom_to_ground 0.072583 0.068626   0.003958  0.000016
# ground_to_ground 0.066397 0.071336   0.004938  0.000024
#
# — Sample 27 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.229408 0.243030   0.013622  0.000186
#    top_to_bottom 0.209984 0.213384   0.003401  0.000012
#    top_to_ground 0.271286 0.303574   0.032288  0.001043
# bottom_to_bottom 0.273476 0.263714   0.009763  0.000095
# bottom_to_ground 0.316015 0.295223   0.020792  0.000432
# ground_to_ground 0.308735 0.304372   0.004363  0.000019
#
# — Sample 28 — Inputs: design_options.cap_gap=0, design_options.cap_width=0, design_options.finger_length=0.333333, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.094704 0.104832   0.010128  0.000103
#    top_to_bottom 0.119400 0.112561   0.006839  0.000047
#    top_to_ground 0.063744 0.108522   0.044778  0.002005
# bottom_to_bottom 0.107488 0.101346   0.006142  0.000038
# bottom_to_ground 0.098611 0.093257   0.005355  0.000029
# ground_to_ground 0.088571 0.094975   0.006404  0.000041
#
# — Sample 29 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.222222
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.122095 0.108099   0.013996  0.000196
#    top_to_bottom 0.084135 0.088308   0.004174  0.000017
#    top_to_ground 0.208211 0.160007   0.048204  0.002324
# bottom_to_bottom 0.112315 0.120267   0.007952  0.000063
# bottom_to_ground 0.130871 0.140090   0.009220  0.000085
# ground_to_ground 0.147332 0.145958   0.001374  0.000002
#
# — Sample 30 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.027098 0.024152   0.002946  0.000009
#    top_to_bottom 0.002107 0.007772   0.005665  0.000032
#    top_to_ground 0.096638 0.079034   0.017604  0.000310
# bottom_to_bottom 0.006607 0.019402   0.012795  0.000164
# bottom_to_ground 0.010188 0.027193   0.017005  0.000289
# ground_to_ground 0.029162 0.036141   0.006979  0.000049
#
# — Sample 31 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.587185 0.552717   0.034468  0.001188
#    top_to_bottom 0.485342 0.480466   0.004876  0.000024
#    top_to_ground 0.751844 0.654933   0.096911  0.009392
# bottom_to_bottom 0.572159 0.582104   0.009946  0.000099
# bottom_to_ground 0.625899 0.644719   0.018821  0.000354
# ground_to_ground 0.664639 0.660194   0.004445  0.000020
#
# — Sample 32 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.392096 0.402061   0.009965 9.930661e-05
#    top_to_bottom 0.392475 0.386946   0.005530 3.057890e-05
#    top_to_ground 0.382292 0.416309   0.034016 1.157114e-03
# bottom_to_bottom 0.410187 0.396344   0.013843 1.916307e-04
# bottom_to_ground 0.419317 0.398826   0.020490 4.198521e-04
# ground_to_ground 0.413538 0.414411   0.000873 7.619215e-07
#
# — Sample 33 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.2, design_options.finger_length=0.666667, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.171594 0.182427   0.010833  0.000117
#    top_to_bottom 0.186373 0.176130   0.010244  0.000105
#    top_to_ground 0.153723 0.208062   0.054339  0.002953
# bottom_to_bottom 0.175244 0.162005   0.013239  0.000175
# bottom_to_ground 0.167240 0.151290   0.015949  0.000254
# ground_to_ground 0.162308 0.166685   0.004377  0.000019
#
# — Sample 34 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0, design_options.finger_count=0.333333
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.134165 0.144425   0.010260  0.000105
#    top_to_bottom 0.107647 0.111241   0.003594  0.000013
#    top_to_ground 0.194668 0.216099   0.021431  0.000459
# bottom_to_bottom 0.195008 0.191096   0.003912  0.000015
# bottom_to_ground 0.253304 0.243376   0.009928  0.000099
# ground_to_ground 0.242630 0.239839   0.002792  0.000008
#
# — Sample 35 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.484370 0.483631   0.000739 5.464916e-07
#    top_to_bottom 0.424961 0.414545   0.010416 1.084890e-04
#    top_to_ground 0.577986 0.585833   0.007847 6.158038e-05
# bottom_to_bottom 0.525359 0.507936   0.017423 3.035645e-04
# bottom_to_ground 0.589459 0.565968   0.023491 5.518409e-04
# ground_to_ground 0.591555 0.582706   0.008849 7.830158e-05
#
# — Sample 36 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.888889
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.680926 0.638524   0.042402  0.001798
#    top_to_bottom 0.689792 0.665154   0.024638  0.000607
#    top_to_ground 0.643570 0.544403   0.099167  0.009834
# bottom_to_bottom 0.574498 0.584682   0.010183  0.000104
# bottom_to_ground 0.492548 0.523237   0.030689  0.000942
# ground_to_ground 0.539862 0.543793   0.003931  0.000015
#
# — Sample 37 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0, design_options.finger_count=1
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.484109 0.502594   0.018485  0.000342
#    top_to_bottom 0.360526 0.391795   0.031269  0.000978
#    top_to_ground 0.699071 0.691553   0.007517  0.000057
# bottom_to_bottom 0.635468 0.629772   0.005697  0.000032
# bottom_to_ground 0.821086 0.784238   0.036848  0.001358
# ground_to_ground 0.797880 0.770764   0.027116  0.000735
#
# — Sample 38 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.666667, design_options.finger_count=0
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.060299 0.051824   0.008475  0.000072
#    top_to_bottom 0.008687 0.014993   0.006306  0.000040
#    top_to_ground 0.176039 0.153502   0.022537  0.000508
# bottom_to_bottom 0.014931 0.025746   0.010815  0.000117
# bottom_to_ground 0.019436 0.033603   0.014167  0.000201
# ground_to_ground 0.053855 0.060162   0.006307  0.000040
#
# — Sample 39 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=1, design_options.finger_count=0.777778
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.560868 0.567204   0.006336 4.014290e-05
#    top_to_bottom 0.602707 0.587117   0.015590 2.430597e-04
#    top_to_ground 0.460045 0.492495   0.032450 1.052988e-03
# bottom_to_bottom 0.529571 0.513927   0.015644 2.447303e-04
# bottom_to_ground 0.477644 0.458706   0.018939 3.586708e-04
# ground_to_ground 0.481924 0.481431   0.000493 2.431241e-07
#
# — Sample 40 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.666667, design_options.finger_count=0.555556
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.499802 0.529029   0.029227  0.000854
#    top_to_bottom 0.466020 0.482763   0.016743  0.000280
#    top_to_ground 0.544451 0.591938   0.047488  0.002255
# bottom_to_bottom 0.539175 0.540788   0.001613  0.000003
# bottom_to_ground 0.588948 0.575114   0.013835  0.000191
# ground_to_ground 0.590531 0.592129   0.001598  0.000003
#
# — Sample 41 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.111111
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.052282 0.066373   0.014091  0.000199
#    top_to_bottom 0.043787 0.049167   0.005380  0.000029
#    top_to_ground 0.086869 0.119655   0.032786  0.001075
# bottom_to_bottom 0.077188 0.074036   0.003152  0.000010
# bottom_to_ground 0.099567 0.089612   0.009955  0.000099
# ground_to_ground 0.092190 0.095844   0.003654  0.000013
#
# — Sample 42 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0, design_options.finger_count=0
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.017988 0.023592   0.005604 3.139953e-05
#    top_to_bottom 0.008808 0.016720   0.007912 6.259784e-05
#    top_to_ground 0.057227 0.057616   0.000388 1.507131e-07
# bottom_to_bottom 0.014839 0.029793   0.014954 2.236144e-04
# bottom_to_ground 0.019434 0.037603   0.018169 3.301072e-04
# ground_to_ground 0.019815 0.039527   0.019712 3.885701e-04
#
# — Sample 43 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.2, design_options.finger_length=1, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.172355 0.146363   0.025992 6.756050e-04
#    top_to_bottom 0.114619 0.112654   0.001964 3.858900e-06
#    top_to_ground 0.290661 0.229518   0.061143 3.738498e-03
# bottom_to_bottom 0.108830 0.121997   0.013166 1.733475e-04
# bottom_to_ground 0.103569 0.127274   0.023704 5.618977e-04
# ground_to_ground 0.151995 0.151617   0.000377 1.424843e-07
#
# — Sample 44 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.4, design_options.finger_length=0.333333, design_options.finger_count=0.777778
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.370294 0.373194   0.002900  0.000008
#    top_to_bottom 0.379841 0.365353   0.014488  0.000210
#    top_to_ground 0.346985 0.380198   0.033213  0.001103
# bottom_to_bottom 0.413253 0.393417   0.019836  0.000393
# bottom_to_ground 0.433770 0.408699   0.025071  0.000629
# ground_to_ground 0.416981 0.411255   0.005726  0.000033
#
# — Sample 45 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=0.666667, design_options.finger_count=0.222222
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.210038 0.184183   0.025855 6.684741e-04
#    top_to_bottom 0.162100 0.153778   0.008321 6.924535e-05
#    top_to_ground 0.305442 0.259235   0.046207 2.135106e-03
# bottom_to_bottom 0.167147 0.168958   0.001811 3.280050e-06
# bottom_to_ground 0.169341 0.178035   0.008693 7.557659e-05
# ground_to_ground 0.200831 0.201724   0.000894 7.984339e-07
#
# — Sample 46 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0.333333, design_options.finger_count=0.444444
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.370581 0.364230   0.006351  0.000040
#    top_to_bottom 0.304996 0.312750   0.007754  0.000060
#    top_to_ground 0.490824 0.453121   0.037703  0.001421
# bottom_to_bottom 0.385001 0.406126   0.021125  0.000446
# bottom_to_ground 0.437327 0.465490   0.028163  0.000793
# ground_to_ground 0.455829 0.472000   0.016171  0.000262
#
# — Sample 47 — Inputs: design_options.cap_gap=0, design_options.cap_width=1, design_options.finger_length=0, design_options.finger_count=0.666667
#            param      ref     pred  abs_error  sq_error
#       top_to_top 0.419469 0.417558   0.001911  0.000004
#    top_to_bottom 0.343863 0.352990   0.009127  0.000083
#    top_to_ground 0.551974 0.532069   0.019905  0.000396
# bottom_to_bottom 0.509924 0.519798   0.009874  0.000097
# bottom_to_ground 0.618946 0.627009   0.008063  0.000065
# ground_to_ground 0.607929 0.611944   0.004015  0.000016
#
# — Sample 48 — Inputs: design_options.cap_gap=1, design_options.cap_width=0.8, design_options.finger_length=0.333333, design_options.finger_count=0
#            param      ref      pred  abs_error  sq_error
#       top_to_top 0.058123  0.048383   0.009739  0.000095
#    top_to_bottom 0.009784 -0.002392   0.012176  0.000148
#    top_to_ground 0.167070  0.162210   0.004859  0.000024
# bottom_to_bottom 0.031604  0.038938   0.007334  0.000054
# bottom_to_ground 0.046336  0.067303   0.020967  0.000440
# ground_to_ground 0.077859  0.091396   0.013537  0.000183
#
# — Sample 49 — Inputs: design_options.cap_gap=0, design_options.cap_width=0.6, design_options.finger_length=1, design_options.finger_count=0.666667
#            param      ref     pred  abs_error     sq_error
#       top_to_top 0.598859 0.565954   0.032904 1.082703e-03
#    top_to_bottom 0.569728 0.567439   0.002289 5.240226e-06
#    top_to_ground 0.630322 0.530671   0.099651 9.930329e-03
# bottom_to_bottom 0.508159 0.527529   0.019370 3.752004e-04
# bottom_to_ground 0.466261 0.495718   0.029457 8.677299e-04
# ground_to_ground 0.519531 0.519297   0.000234 5.497440e-08
#
# Global scaled error stats:
#   min abs_error: 0.0001262053212150449
#   median abs_error: 0.010032071927289783
#   max abs_error: 0.12087243457011132

# %% [markdown]
# # Unscaled

# %%
# Unscale everything and look at errors in real units
# For Model 2: inputs are Qiskit params (old Y), outputs are capacitance (old X)
# So we use Y scalers for inputs and X scalers for outputs

# Load column names
with open('X_names', 'r') as f:
    cap_names = f.read().splitlines()  # capacitance column names (our outputs)

qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

# Unscale inputs (Qiskit params) using OLD Y scalers (linear encoding)
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        param_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_linear_{param_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale outputs (capacitance) using OLD X scalers
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# Unscale predictions (capacitance) using same X scalers
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape

# Errors
sq_errors_unscaled  = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# Build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': y_test_unscaled[i, j],
            'pred_unscaled': y_pred_unscaled[i, j],
            'abs_error_unscaled': abs_errors_unscaled[i, j],
            'sq_error_unscaled': sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# Save
out_csv_unscaled = Path(f'model2_predictions_and_errors_unscaled_{encoding}.csv')
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

# Pretty print per-sample (unscaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    input_str = ', '.join(
        f'{qiskit_names[k] if k < len(qiskit_names) else f"col_{k}"}={X_test_unscaled[i,k]:.6g}'
        for k in range(X_test_unscaled.shape[1])
    )
    print(f'— Sample {i} (Unscaled) — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global unscaled error stats:')
print('  min abs_error:', float(abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(abs_errors_unscaled)))
print('  max abs_error:', float(abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_coupler_NCap_cap_matrix/model2_predictions_and_errors_unscaled_model2_surrogate.csv
#
# — Sample 0 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91395      15.523781            0.609831           0.371894
#    top_to_bottom       0.66910       1.143189            0.474089           0.224761
#    top_to_ground      14.05235      14.175821            0.123471           0.015245
# bottom_to_bottom      13.62255      15.271770            1.649220           2.719925
# bottom_to_ground      12.78564      13.839286            1.053646           1.110170
# ground_to_ground      58.01370      59.354542            1.340842           1.797857
#
# — Sample 1 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.64499      22.845261            1.200271           1.440650
#    top_to_bottom       3.83797       3.709889            0.128081           0.016405
#    top_to_ground      17.53586      19.082256            1.546396           2.391342
# bottom_to_bottom      27.51404      25.488281            2.025759           4.103699
# bottom_to_ground      23.29018      21.464817            1.825363           3.331950
# ground_to_ground      73.35986      73.016205            0.343655           0.118099
#
# — Sample 2 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.84435      44.926739            1.917611           3.677233
#    top_to_bottom      20.25982      19.533615            0.726205           0.527374
#    top_to_ground      26.29119      24.952967            1.338223           1.790842
# bottom_to_bottom      67.75657      66.989487            0.767083           0.588417
# bottom_to_ground      46.86370      46.641106            0.222594           0.049548
# ground_to_ground     108.83635     107.303947            1.532403           2.348258
#
# — Sample 3 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      46.99644      44.270905            2.725535           7.428544
#    top_to_bottom      19.38918      18.867922            0.521258           0.271710
#    top_to_ground      27.25768      24.579247            2.678433           7.174006
# bottom_to_bottom      55.79690      56.988041            1.191141           1.418817
# bottom_to_ground      35.76054      37.474003            1.713463           2.935955
# ground_to_ground      97.29848      96.729622            0.568858           0.323600
#
# — Sample 4 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.54716      31.621712            0.074552           0.005558
#    top_to_bottom      11.61323      11.194940            0.418290           0.174967
#    top_to_ground      19.67277      20.032278            0.359508           0.129246
# bottom_to_bottom      43.43218      42.076931            1.355249           1.836700
# bottom_to_ground      31.29560      30.396441            0.899159           0.808488
# ground_to_ground      84.14240      83.791557            0.350843           0.123091
#
# — Sample 5 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      14.91522      16.220369            1.305149           1.703415
#    top_to_bottom       1.90110       2.318366            0.417266           0.174111
#    top_to_ground      12.79837      13.798180            0.999810           0.999619
# bottom_to_bottom      16.82899      17.508875            0.679885           0.462243
# bottom_to_ground      14.71062      14.878868            0.168248           0.028307
# ground_to_ground      59.03334      60.107586            1.074246           1.154004
#
# — Sample 6 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.21478      39.150990            1.936210           3.748907
#    top_to_bottom      18.10928      18.333698            0.224418           0.050364
#    top_to_ground      18.86175      20.307135            1.445385           2.089137
# bottom_to_bottom      45.74491      45.127949            0.616961           0.380641
# bottom_to_ground      27.25160      26.276506            0.975094           0.950807
# ground_to_ground      79.00961      79.779747            0.770137           0.593111
#
# — Sample 7 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.07032      20.209545            0.860775           0.740933
#    top_to_bottom       1.21587       1.342691            0.126821           0.016084
#    top_to_ground      19.56543      18.981470            0.583960           0.341009
# bottom_to_bottom      17.12018      17.659994            0.539814           0.291399
# bottom_to_ground      15.65802      16.099625            0.441605           0.195015
# ground_to_ground      67.68762      67.018982            0.668638           0.447077
#
# — Sample 8 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      35.33519      36.128704            0.793514           0.629665
#    top_to_bottom      11.77509      11.862965            0.087875           0.007722
#    top_to_ground      23.15632      23.897198            0.740878           0.548900
# bottom_to_bottom      58.69605      57.779980            0.916070           0.839185
# bottom_to_ground      46.26890      45.272987            0.995913           0.991842
# ground_to_ground     104.35958     104.315735            0.043845           0.001922
#
# — Sample 9 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.04935      18.795084            0.745734           0.556119
#    top_to_bottom       2.51389       2.334769            0.179121           0.032084
#    top_to_ground      15.29043      16.144089            0.853659           0.728733
# bottom_to_bottom      23.93490      23.578232            0.356668           0.127212
# bottom_to_ground      21.09610      20.815376            0.280724           0.078806
# ground_to_ground      68.15670      69.337685            1.180985           1.394725
#
# — Sample 10 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      49.05578      46.650867            2.404913           5.783604
#    top_to_bottom      20.80786      20.217499            0.590361           0.348526
#    top_to_ground      27.89118      25.685781            2.205399           4.863783
# bottom_to_bottom      64.00772      64.601555            0.593835           0.352640
# bottom_to_ground      42.57999      43.665829            1.085839           1.179046
# ground_to_ground     104.87919     104.468704            0.410486           0.168499
#
# — Sample 11 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      50.54045      50.115349            0.425101           0.180711
#    top_to_bottom      17.73454      18.745771            1.011231           1.022589
#    top_to_ground      32.22853      30.889914            1.338616           1.791894
# bottom_to_bottom      86.86462      87.235420            0.370800           0.137493
# bottom_to_ground      68.29869      67.350601            0.948089           0.898872
# ground_to_ground     137.32339     135.438232            1.885158           3.553819
#
# — Sample 12 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      26.27875      25.586781            0.691969           0.478822
#    top_to_bottom       8.92551       8.588567            0.336943           0.113531
#    top_to_ground      17.10117      16.791317            0.309853           0.096009
# bottom_to_bottom      29.95980      30.593008            0.633208           0.400952
# bottom_to_ground      20.65658      21.676243            1.019663           1.039712
# ground_to_ground      70.18744      70.846428            0.658988           0.434265
#
# — Sample 13 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      37.85738      37.669231            0.188149           0.035400
#    top_to_bottom      13.07647      13.338798            0.262328           0.068816
#    top_to_ground      24.54618      24.048759            0.497421           0.247427
# bottom_to_bottom      59.45636      61.552940            2.096580           4.395649
# bottom_to_ground      45.77177      47.398109            1.626339           2.644980
# ground_to_ground     105.19612     106.856995            1.660875           2.758505
#
# — Sample 14 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.69895      19.283657            1.415293           2.003054
#    top_to_bottom       0.60461       0.615995            0.011385           0.000130
#    top_to_ground      19.82790      18.793610            1.034290           1.069757
# bottom_to_bottom      14.56863      15.910599            1.341969           1.800880
# bottom_to_ground      13.79113      15.193579            1.402449           1.966862
# ground_to_ground      65.63654      65.456108            0.180432           0.032556
#
# — Sample 15 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      36.59696      37.558144            0.961184           0.923874
#    top_to_bottom      15.03656      15.052759            0.016199           0.000262
#    top_to_ground      21.21543      22.314096            1.098666           1.207068
# bottom_to_bottom      60.00257      58.683037            1.319533           1.741168
# bottom_to_ground      44.42258      42.978580            1.444000           2.085135
# ground_to_ground     100.27778     100.307671            0.029891           0.000893
#
# — Sample 16 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.80333      24.263832            0.539498           0.291058
#    top_to_bottom       7.54392       7.374205            0.169715           0.028803
#    top_to_ground      17.01049      16.708349            0.302141           0.091289
# bottom_to_bottom      32.79263      32.904678            0.112048           0.012555
# bottom_to_ground      24.98322      25.182192            0.198972           0.039590
# ground_to_ground      74.98806      74.747742            0.240318           0.057753
#
# — Sample 17 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      72.09757      71.604485            0.493085           0.243133
#    top_to_bottom      42.28320      40.479706            1.803494           3.252591
#    top_to_ground      29.25596      30.129385            0.873425           0.762871
# bottom_to_bottom     101.78691      99.842201            1.944709           3.781892
# bottom_to_ground      58.96084      58.321720            0.639120           0.408474
# ground_to_ground     124.89715     125.643166            0.746016           0.556539
#
# — Sample 18 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.65327      54.696152            0.042882           0.001839
#    top_to_bottom      25.69001      24.995987            0.694023           0.481668
#    top_to_ground      28.43415      28.738899            0.304749           0.092872
# bottom_to_bottom      77.76412      75.967651            1.796469           3.227300
# bottom_to_ground      51.52313      50.066906            1.456224           2.120588
# ground_to_ground     115.57029     115.021133            0.549157           0.301573
#
# — Sample 19 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.24473      67.852348            1.392382           1.938727
#    top_to_bottom      32.55387      33.084991            0.531121           0.282090
#    top_to_ground      36.23866      34.178879            2.059781           4.242699
# bottom_to_bottom     110.06436     110.822495            0.758135           0.574768
# bottom_to_ground      76.51531      76.356903            0.158407           0.025093
# ground_to_ground     150.90990     149.113586            1.796314           3.226742
#
# — Sample 20 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.48460      26.566319            1.081719           1.170115
#    top_to_bottom       7.16345       7.417217            0.253767           0.064398
#    top_to_ground      18.02827      18.877380            0.849110           0.720988
# bottom_to_bottom      38.13878      37.729645            0.409135           0.167392
# bottom_to_ground      30.67125      29.924541            0.746709           0.557574
# ground_to_ground      82.12106      82.258202            0.137142           0.018808
#
# — Sample 21 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      52.60779      49.208744            3.399046          11.553513
#    top_to_bottom      22.04591      21.337236            0.708674           0.502218
#    top_to_ground      30.06731      27.009384            3.057926           9.350910
# bottom_to_bottom      65.59865      66.970161            1.371511           1.881044
# bottom_to_ground      43.12377      44.881695            1.757925           3.090300
# ground_to_ground     108.44790     107.473511            0.974389           0.949434
#
# — Sample 22 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      20.15252      19.501980            0.650540           0.423203
#    top_to_bottom       1.44740       1.130277            0.317123           0.100567
#    top_to_ground      18.46784      18.330267            0.137573           0.018926
# bottom_to_bottom      18.49276      19.611635            1.118875           1.251882
# bottom_to_ground      16.78539      18.171034            1.385644           1.920009
# ground_to_ground      66.96300      68.788719            1.825719           3.333251
#
# — Sample 23 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.04266      18.964239            0.078421           0.006150
#    top_to_bottom       3.07264       3.370444            0.297804           0.088687
#    top_to_ground      15.72419      15.317811            0.406379           0.165144
# bottom_to_bottom      22.17553      23.031260            0.855730           0.732273
# bottom_to_ground      18.83528      19.316172            0.480892           0.231257
# ground_to_ground      66.35541      66.693985            0.338575           0.114633
#
# — Sample 24 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.17391      17.186668            0.987242           0.974646
#    top_to_bottom       0.73958       0.401796            0.337784           0.114098
#    top_to_ground      17.18506      16.551105            0.633955           0.401898
# bottom_to_bottom      15.69679      16.196400            0.499610           0.249610
# bottom_to_ground      14.70742      15.561020            0.853600           0.728633
# ground_to_ground      63.25260      63.858265            0.605665           0.366830
#
# — Sample 25 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      64.22991      64.683624            0.453714           0.205857
#    top_to_bottom      29.90875      30.118845            0.210095           0.044140
#    top_to_ground      33.77716      33.709114            0.068046           0.004630
# bottom_to_bottom     100.99499      99.984917            1.010073           1.020248
# bottom_to_ground      70.01176      68.688919            1.322841           1.749908
# ground_to_ground     140.80910     140.283813            0.525287           0.275926
#
# — Sample 26 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      17.19448      18.506271            1.311791           1.720797
#    top_to_bottom       2.30923       2.794942            0.485712           0.235917
#    top_to_ground      14.66488      15.612129            0.947249           0.897281
# bottom_to_bottom      20.39118      20.625233            0.234053           0.054781
# bottom_to_ground      17.80506      17.495070            0.309990           0.096094
# ground_to_ground      64.29761      64.858025            0.560415           0.314065
#
# — Sample 27 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      32.81010      33.912712            1.102612           1.215753
#    top_to_bottom      11.72675      11.910770            0.184020           0.033864
#    top_to_ground      20.78413      21.710169            0.926039           0.857548
# bottom_to_bottom      49.04328      47.745995            1.297285           1.682949
# bottom_to_ground      36.87262      35.244049            1.628571           2.652243
# ground_to_ground      91.79978      91.304642            0.495138           0.245162
#
# — Sample 28 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=4.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      21.90631      22.726112            0.819802           0.672076
#    top_to_bottom       6.82474       6.454644            0.370096           0.136971
#    top_to_ground      14.83177      16.116009            1.284239           1.649269
# bottom_to_bottom      26.98623      26.170095            0.816135           0.666076
# bottom_to_ground      19.84377      19.424358            0.419412           0.175906
# ground_to_ground      66.81403      67.540802            0.726772           0.528198
#
# — Sample 29 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      24.12348      22.990585            1.132895           1.283450
#    top_to_bottom       4.91634       5.142197            0.225857           0.051011
#    top_to_ground      18.97512      17.592615            1.382505           1.911320
# bottom_to_bottom      27.62769      28.684357            1.056667           1.116544
# bottom_to_ground      22.37061      23.092758            0.722148           0.521498
# ground_to_ground      73.48264      73.326706            0.155934           0.024315
#
# — Sample 30 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      16.43384      16.195356            0.238484           0.056874
#    top_to_bottom       0.47735       0.783940            0.306590           0.093997
#    top_to_ground      15.77519      15.270304            0.504886           0.254910
# bottom_to_bottom      13.58084      15.281096            1.700256           2.890869
# bottom_to_ground      12.91772      14.249693            1.331973           1.774152
# ground_to_ground      60.07192      60.863926            0.792006           0.627273
#
# — Sample 31 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      61.77084      58.980751            2.790089           7.784596
#    top_to_bottom      26.62797      26.364080            0.263890           0.069638
#    top_to_ground      34.56668      31.787256            2.779424           7.725196
# bottom_to_bottom      88.73307      90.054703            1.321633           1.746713
# bottom_to_ground      61.14529      62.619473            1.474183           2.173214
# ground_to_ground     132.19017     131.685699            0.504471           0.254491
#
# — Sample 32 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      45.97905      46.785702            0.806652           0.650687
#    top_to_bottom      21.60242      21.303169            0.299251           0.089551
#    top_to_ground      23.96784      24.943439            0.975599           0.951794
# bottom_to_bottom      67.20976      65.370255            1.839505           3.383780
# bottom_to_ground      44.96409      43.359119            1.604971           2.575931
# ground_to_ground     103.69355     103.792610            0.099060           0.009813
#
# — Sample 33 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.13024      29.007153            0.876913           0.768976
#    top_to_bottom      10.44906       9.894711            0.554349           0.307303
#    top_to_ground      17.41241      18.970858            1.558448           2.428759
# bottom_to_bottom      35.98982      34.230618            1.759202           3.094793
# bottom_to_ground      25.21932      23.970030            1.249290           1.560726
# ground_to_ground      75.18223      75.678940            0.496710           0.246721
#
# — Sample 34 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=1.59e-05, design_options.finger_count=4
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      25.10048      25.931015            0.830535           0.689788
#    top_to_bottom       6.18873       6.383240            0.194510           0.037834
#    top_to_ground      18.58672      19.201374            0.614654           0.377800
# bottom_to_bottom      38.61615      38.096329            0.519821           0.270214
# bottom_to_ground      31.96057      31.182917            0.777653           0.604745
# ground_to_ground      84.29772      83.980896            0.316824           0.100377
#
# — Sample 35 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.44833      53.388489            0.059841           0.003581
#    top_to_bottom      23.36040      22.796741            0.563659           0.317711
#    top_to_ground      29.58039      29.805454            0.225064           0.050654
# bottom_to_bottom      82.51415      80.198914            2.315236           5.360320
# bottom_to_ground      58.29103      56.450996            1.840034           3.385724
# ground_to_ground     123.89606     122.891838            1.004222           1.008462
#
# — Sample 36 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=9
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      69.35887      65.926559            3.432311          11.780756
#    top_to_bottom      37.69192      36.358601            1.333319           1.777741
#    top_to_ground      31.46136      28.617208            2.844152           8.089198
# bottom_to_bottom      89.04400      90.397148            1.353148           1.831010
# bottom_to_ground      50.70017      53.103985            2.403815           5.778326
# ground_to_ground     118.02962     118.475685            0.446065           0.198974
#
# — Sample 37 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=1.59e-05, design_options.finger_count=10
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      53.42721      54.923508            1.496298           2.238907
#    top_to_bottom      19.87346      21.565615            1.692155           2.863388
#    top_to_ground      33.05314      32.837540            0.215600           0.046484
# bottom_to_bottom      97.14587      96.388855            0.757015           0.573072
# bottom_to_ground      76.43402      73.547760            2.886260           8.330497
# ground_to_ground     147.31121     144.233948            3.077262           9.469543
#
# — Sample 38 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=3.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      19.12130      18.435299            0.686001           0.470597
#    top_to_bottom       0.83343       1.174693            0.341263           0.116461
#    top_to_ground      18.05242      17.406059            0.646361           0.417782
# bottom_to_bottom      14.68703      16.124199            1.437169           2.065454
# bottom_to_ground      13.64212      14.751799            1.109679           1.231387
# ground_to_ground      62.87424      63.589954            0.715714           0.512247
#
# — Sample 39 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      59.64057      60.153435            0.512865           0.263030
#    top_to_bottom      32.97925      32.135567            0.843683           0.711801
#    top_to_ground      26.19782      27.128489            0.930669           0.866144
# bottom_to_bottom      83.07385      80.995049            2.078801           4.321416
# bottom_to_ground      49.53280      48.049370            1.483430           2.200565
# ground_to_ground     111.45445     111.398491            0.055959           0.003131
#
# — Sample 40 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=3.59e-05, design_options.finger_count=6
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      54.69749      57.063305            2.365815           5.597080
#    top_to_bottom      25.58236      26.488401            0.906041           0.820911
#    top_to_ground      28.61859      29.980547            1.361957           1.854927
# bottom_to_bottom      84.35009      84.564430            0.214340           0.045942
# bottom_to_ground      58.25104      57.167404            1.083636           1.174267
# ground_to_ground     123.77985     123.961166            0.181316           0.032876
#
# — Sample 41 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=2
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.47237      19.612982            1.140612           1.300995
#    top_to_bottom       2.73292       3.024038            0.291118           0.084749
#    top_to_ground      15.49501      16.435308            0.940298           0.884161
# bottom_to_bottom      22.95995      22.541100            0.418850           0.175436
# bottom_to_ground      19.91865      19.138891            0.779759           0.608024
# ground_to_ground      67.22470      67.639381            0.414681           0.171961
#
# — Sample 42 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=1.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      15.69639      16.149975            0.453585           0.205739
#    top_to_bottom       0.83998       1.268137            0.428157           0.183318
#    top_to_ground      14.64488      14.656014            0.011134           0.000124
# bottom_to_bottom      14.67483      16.661928            1.987098           3.948559
# bottom_to_ground      13.64197      15.065105            1.423135           2.025314
# ground_to_ground      59.01106      61.248135            2.237075           5.004503
#
# — Sample 43 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=6.9e-06, design_options.finger_length=4.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      28.19186      26.087868            2.103992           4.426783
#    top_to_bottom       6.56601       6.459705            0.106305           0.011301
#    top_to_ground      21.33982      19.586212            1.753608           3.075140
# bottom_to_bottom      27.16464      28.914198            1.749558           3.060953
# bottom_to_ground      20.23212      22.088844            1.856724           3.447425
# ground_to_ground      74.01179      73.968948            0.042842           0.001835
#
# — Sample 44 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=8.9e-06, design_options.finger_length=2.59e-05, design_options.finger_count=8
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.21430      44.449047            0.234747           0.055106
#    top_to_bottom      20.91871      20.134676            0.784034           0.614709
#    top_to_ground      22.95520      23.907770            0.952570           0.907390
# bottom_to_bottom      67.61721      64.981300            2.635910           6.948020
# bottom_to_ground      46.09617      44.132427            1.963743           3.856286
# ground_to_ground     104.08419     103.434380            0.649810           0.422254
#
# — Sample 45 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=3.59e-05, design_options.finger_count=3
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      31.24216      29.149302            2.092858           4.380057
#    top_to_bottom       9.13548       8.685163            0.450317           0.202786
#    top_to_ground      21.76376      20.438524            1.325236           1.756250
# bottom_to_bottom      34.91396      35.154625            0.240665           0.057920
# bottom_to_ground      25.38392      26.064865            0.680945           0.463686
# ground_to_ground      79.55404      79.655449            0.101409           0.010284
#
# — Sample 46 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=2.59e-05, design_options.finger_count=5
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      44.23756      43.723438            0.514122           0.264321
#    top_to_bottom      16.86840      17.288021            0.419621           0.176082
#    top_to_ground      27.08055      25.999228            1.081322           1.169258
# bottom_to_bottom      63.86300      66.670135            2.807135           7.880010
# bottom_to_ground      46.37482      48.580776            2.205956           4.866243
# ground_to_ground     108.49297     110.328217            1.835247           3.368130
#
# — Sample 47 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.49e-05, design_options.finger_length=1.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      48.19483      48.040165            0.154665           0.023921
#    top_to_bottom      18.97173      19.465639            0.493909           0.243946
#    top_to_ground      28.83436      28.263481            0.570879           0.325903
# bottom_to_bottom      80.46316      81.775230            1.312070           1.721529
# bottom_to_ground      60.60069      61.232239            0.631549           0.398854
# ground_to_ground     125.75437     126.210014            0.455644           0.207612
#
# — Sample 48 (Unscaled) — Inputs: design_options.cap_gap=4.1e-06, design_options.cap_width=1.29e-05, design_options.finger_length=2.59e-05, design_options.finger_count=1
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      18.94514      18.156769            0.788371           0.621529
#    top_to_bottom       0.89281       0.233895            0.658915           0.434169
#    top_to_ground      17.79519      17.655823            0.139367           0.019423
# bottom_to_bottom      16.90262      17.877136            0.974516           0.949682
# bottom_to_ground      15.74914      17.391445            1.642305           2.697166
# ground_to_ground      65.59834      67.134636            1.536296           2.360205
#
# — Sample 49 (Unscaled) — Inputs: design_options.cap_gap=2.1e-06, design_options.cap_width=1.09e-05, design_options.finger_length=4.59e-05, design_options.finger_count=7
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#       top_to_top      62.71578      60.052280            2.663500           7.094230
#    top_to_bottom      31.19457      31.070690            0.123880           0.015346
#    top_to_ground      31.08140      28.223379            2.858021           8.168283
# bottom_to_bottom      80.22864      82.802597            2.573957           6.625255
# bottom_to_ground      48.64112      50.948456            2.307336           5.323799
# ground_to_ground     115.72236     115.695747            0.026613           0.000708
#
# Global unscaled error stats:
#   min abs_error: 0.0036194241333014077
#   median abs_error: 0.7818964001464845
#   max abs_error: 4.667159174804681

# %%
import matplotlib.pyplot as plt
import math

# Percentage difference: 100 * |pred - ref| / |ref|, with a small epsilon to avoid division by zero
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(y_pred_unscaled - y_test_unscaled) / (np.abs(y_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_params)]
all_pct = pct_errors_unscaled.ravel()

# --- Box plot: % error distribution per capacitance output (with outliers) ---
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Percentage Error Distribution per Output (Unscaled)')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_boxplot.pdf')
plt.show()

# --- Subplot grid: one histogram per capacitance output ---
n_cols_grid = 3
n_rows_grid = math.ceil(n_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

# hide unused subplots
for k in range(n_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Model 2: Percentage Error Histograms per Output (Unscaled)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_histograms_per_output.pdf')
plt.show()

# --- Per-output summary stats ---
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'ALL OUTPUTS':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")

# --- Scatter plot: % error per sample, grouped by capacitance output ---
fig, ax = plt.subplots(figsize=(12, 6))
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    x = np.full_like(col_pct, j) + np.random.uniform(-0.2, 0.2, size=len(col_pct))
    ax.scatter(x, col_pct, alpha=0.4, s=12, label=short_names[j])
ax.set_xticks(range(n_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Per-Sample Percentage Error by Capacitance Output (Unscaled)')
plt.tight_layout()
plt.savefig('plots/model2_pct_error_scatter.pdf')
plt.show()
# Out:
# /tmp/ipykernel_1034616/1292334100.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# top_to_top                      3.36       3.51       6.35       8.75
# top_to_bottom                   3.54      12.55      48.85      88.73
# top_to_ground                   4.44       4.69       8.90      11.64
# bottom_to_bottom                2.65       3.47       6.99      13.54
# bottom_to_ground                3.40       4.06       8.20      10.43
# ground_to_ground                0.61       0.85       1.78       3.79
# ----------------------------------------------------------------------
# ALL OUTPUTS                     2.81       4.86       8.24      88.73

# %%
m = tf.keras.models.load_model(chosen_path, compile=True)

# ---- neurons per layer ----
neurons_per_layer = [
    l.units for l in m.layers
    if isinstance(l, tf.keras.layers.Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

# ---- dropout rate(s) from Dropout layers ----
dropouts = [
    (l.name, float(l.rate)) for l in m.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')

# ---- learning rate / schedule details ----
opt = getattr(m, 'optimizer', None)
if opt is None:
    print('Best learning rate: (no optimizer found on loaded model)')
else:
    lr_obj = opt.learning_rate

    if isinstance(lr_obj, tf.keras.optimizers.schedules.LearningRateSchedule):
        print('Best learning rate: (schedule)', type(lr_obj).__name__)
        try:
            cfg = lr_obj.get_config()
            print('LR schedule config:')
            for k, v in sorted(cfg.items()):
                print(f'  {k}: {v}')
        except Exception as e:
            print('Could not read LR schedule config:', repr(e))
        try:
            step = int(tf.keras.backend.get_value(opt.iterations))
            current_lr = float(lr_obj(step).numpy())
            print(f'Current LR at step {step}:', current_lr)
        except Exception as e:
            print('Could not compute current LR from schedule:', repr(e))
    else:
        try:
            lr_val = float(tf.keras.backend.get_value(lr_obj))
            print('Best learning rate:', lr_val)
        except Exception as e:
            print('Best learning rate: (unreadable)', repr(e))
# Out:
# Best NEURONS_PER_LAYER: [480]
# Best DROPOUT rate(s): [('dropout0', 0.4)]
# Best learning rate: 0.003000000026077032
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
