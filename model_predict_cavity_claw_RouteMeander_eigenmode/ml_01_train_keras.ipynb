# %% [markdown]
# # Model Training (cavity_claw_RouteMeander_eigenmode)

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters import *

# %% [markdown]
# ## Library

# %%
import os, gc, joblib

# Disable some console warnings so you can be free of them printing. 
# Comment the next two lines if you are a professional and like looking at warnings.
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
# os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

os.environ.pop("TF_XLA_FLAGS", None)      # disable XLA 
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # show warnings/errors while debugging
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import tensorflow as tf, gc
gpus = tf.config.list_physical_devices('GPU')
for g in gpus:
    tf.config.experimental.set_memory_growth(g, True)

tf.keras.backend.set_floatx("float32") # make the backend use float32 which will be the same as the data--helps speed it up


from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, LeakyReLU
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from keras_tuner import HyperModel, RandomSearch
from tensorflow.keras.models import load_model, Model

from pathlib import Path

import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, LeakyReLU
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import numpy as np
import pandas as pd

# %%
seed = 0

# Input seed value. If this value is the same, the random number generator 
# will generate the same set of random values every time. We like reproducibility:)
np.random.seed(seed)

# Set the seed value for reproducibility in tensorflow
tf.random.set_seed(seed)

# %% [markdown]
# ## Check GPU

# %%
from tensorflow.python.client import device_lib

# Look at what you are working with. If you dont have a nice GPU I highly reccomend finding one
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4547047963153546102
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 39704002560
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17959127450956478290
# physical_device_desc: "device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:11.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771286788.755519  111428 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1771286788.755862  111428 gpu_device.cc:2020] Created device /device:GPU:0 with 37864 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:11.0, compute capability: 8.0

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
# Load all of the nice data you saved from the previous notebook, or downloaded from the drive

if DATA_AUGMENTATION:
    if 'Try Both' not in ENCODING_TYPE:
        encoding = ENCODING_TYPE.replace(' ','_')
        X_train = np.load('{}/npy/x_train_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        X_val = np.load('{}/npy/x_val_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        X_test = np.load('{}/npy/x_test_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_train = np.load('{}/npy/y_train_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_val = np.load('{}/npy/y_val_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_test = np.load('{}/npy/y_test_{}_encoding_augmented.npy'.format(DATA_DIR, encoding), allow_pickle=True)
    
    elif 'Try Both' in ENCODING_TYPE:
        X_train_one_hot_encoding = np.load('{}/npy/x_train_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        X_val_one_hot_encoding = np.load('{}/npy/x_val_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        X_test_one_hot_encoding = np.load('{}/npy/x_test_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_train_one_hot_encoding = np.load('{}/npy/y_train_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_val_one_hot_encoding = np.load('{}/npy/y_val_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_test_one_hot_encoding = np.load('{}/npy/y_test_one_hot_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)

        X_train_linear_encoding = np.load('{}/npy/x_train_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        X_val_linear_encoding = np.load('{}/npy/x_val_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        X_test_linear_encoding = np.load('{}/npy/x_test_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_train_linear_encoding = np.load('{}/npy/y_train_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_val_linear_encoding = np.load('{}/npy/y_val_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)
        y_test_linear_encoding = np.load('{}/npy/y_test_linear_encoding_augmented.npy'.format(DATA_DIR), allow_pickle=True)

else:
    if 'Try Both' not in ENCODING_TYPE:
        X_train = np.load('{}/npy/x_train_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        X_val = np.load('{}/npy/x_val_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        X_test = np.load('{}/npy/x_test_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_train = np.load('{}/npy/y_train_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_val = np.load('{}/npy/y_val_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
        y_test = np.load('{}/npy/y_test_{}_encoding.npy'.format(DATA_DIR, encoding), allow_pickle=True)
    
    elif 'Try Both' in ENCODING_TYPE:
        X_train_one_hot_encoding = np.load('{}/npy/x_train_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        X_val_one_hot_encoding = np.load('{}/npy/x_val_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        X_test_one_hot_encoding = np.load('{}/npy/x_test_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_train_one_hot_encoding = np.load('{}/npy/y_train_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_val_one_hot_encoding = np.load('{}/npy/y_val_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_test_one_hot_encoding = np.load('{}/npy/y_test_one_hot_encoding.npy'.format(DATA_DIR), allow_pickle=True)

        X_train_linear_encoding = np.load('{}/npy/x_train_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        X_val_linear_encoding = np.load('{}/npy/x_val_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        X_test_linear_encoding = np.load('{}/npy/x_test_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_train_linear_encoding = np.load('{}/npy/y_train_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_val_linear_encoding = np.load('{}/npy/y_val_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)
        y_test_linear_encoding = np.load('{}/npy/y_test_linear_encoding.npy'.format(DATA_DIR), allow_pickle=True)

# %% [markdown]
# ### Visualize

# %%
# Look at the shapes of training and test sets incase you want to orient yourself
if 'Try Both' not in ENCODING_TYPE:
    print('X_train.shape: ', X_train.shape)
    print('X_val.shape: ', X_val.shape)
    print('y_train.shape: ', y_train.shape)
    print('y_val.shape: ', y_val.shape)
    print('y_train[0]: ', y_train[0])
else:
    print('X_train_linear_encoding.shape: ', X_train_linear_encoding.shape)
    print('X_val_linear_encoding.shape: ', X_val_linear_encoding.shape)
    print('y_train_linear_encoding.shape: ', y_train_linear_encoding.shape)
    print('y_val_linear_encoding.shape: ', y_val_linear_encoding.shape)
    print('y_train_linear_encoding[0]: ', y_train_linear_encoding[0])

    print('X_train_one_hot_encoding.shape: ', X_train_one_hot_encoding.shape)
    print('X_val_one_hot_encoding.shape: ', X_val_one_hot_encoding.shape)
    print('y_train_one_hot_encoding.shape: ', y_train_one_hot_encoding.shape)
    print('y_val_one_hot_encoding.shape: ', y_val_one_hot_encoding.shape)
    print('y_train_one_hot_encoding[0]: ', y_train_one_hot_encoding[0])
# Out:
# X_train.shape:  (567, 2)
# X_val.shape:  (121, 2)
# y_train.shape:  (567, 5)
# y_val.shape:  (121, 5)
# y_train[0]:  [0.49261084 1.         0.225      0.82608696 0.25      ]

# %%
if 'Try Both' not in ENCODING_TYPE:
    display(X_train) #can check this in previous script as well after loading to make sure it matches
else:
    display(X_train_one_hot_encoding)
    display(X_train_linear_encoding)
# Out:
# array([[0.49693532, 0.13212398],
#        [0.27712997, 0.10060883],
#        [0.67692671, 0.1959024 ],
#        ...,
#        [0.45454713, 0.01514764],
#        [0.28232844, 0.10324655],
#        [0.60788921, 0.14034753]])

# %%
# Look at how it was split and decide if you like the split

if 'Try Both' not in ENCODING_TYPE:
    total = len(X_train) + len(X_test) + len(X_val)
    print('---------------------------------------')  
    print('Train set shape x:                {}, {:.2f}%'.format(len(X_train), (len(X_train)*100.)/total))
    print('Validation set shape x:           {}, {:.2f}%'.format(len(X_train), (len(X_val)*100.)/total))
    print('Test set shape x:                 {}, {:.2f}%'.format(len(X_test), (len(X_test)*100.)/total))
    print('---------------------------------------')

    total = len(y_train) + len(y_test) + len(y_val)
    print('---------------------------------------')  
    print('Train set shape y:                {}, {:.2f}%'.format(len(y_train), (len(y_train)*100.)/total))
    print('Validation set shape y:           {}, {:.2f}%'.format(len(y_val), (len(y_val)*100.)/total))
    print('Test set shape y:                 {}, {:.2f}%'.format(len(y_test), (len(y_test)*100.)/total))
    print('---------------------------------------')
else:
    total = len(X_train_one_hot_encoding) + len(X_test_one_hot_encoding) + len(X_val_one_hot_encoding)
    print('---------------------------------------')  
    print('Train set shape x one_hot_encoding:      {}, {:.2f}%'.format(len(X_train_one_hot_encoding), (len(X_train_one_hot_encoding)*100.)/total))
    print('Validation set shape x one_hot_encoding: {}, {:.2f}%'.format(len(X_train_one_hot_encoding), (len(X_val_one_hot_encoding)*100.)/total))
    print('Test set shape x one_hot_encoding:       {}, {:.2f}%'.format(len(X_test_one_hot_encoding), (len(X_test_one_hot_encoding)*100.)/total))
    print('---------------------------------------')

    total = len(y_train_one_hot_encoding) + len(y_test_one_hot_encoding) + len(y_val_one_hot_encoding)
    print('---------------------------------------')  
    print('Train set shape y one_hot_encoding:         {}, {:.2f}%'.format(len(y_train_one_hot_encoding), (len(y_train_one_hot_encoding)*100.)/total))
    print('Validation set shape y one_hot_encoding:    {}, {:.2f}%'.format(len(y_val_one_hot_encoding), (len(y_val_one_hot_encoding)*100.)/total))
    print('Test set shape y one_hot_encoding:          {}, {:.2f}%'.format(len(y_test_one_hot_encoding), (len(y_test_one_hot_encoding)*100.)/total))


    total = len(X_train_linear_encoding) + len(X_test_linear_encoding) + len(X_val_linear_encoding)
    print('---------------------------------------')  
    print('Train set shape x linear_encoding:      {}, {:.2f}%'.format(len(X_train_linear_encoding), (len(X_train_linear_encoding)*100.)/total))
    print('Validation set shape x linear_encoding: {}, {:.2f}%'.format(len(X_train_linear_encoding), (len(X_val_linear_encoding)*100.)/total))
    print('Test set shape x linear_encoding:       {}, {:.2f}%'.format(len(X_test_linear_encoding), (len(X_test_linear_encoding)*100.)/total))
    print('---------------------------------------')

    total = len(y_train_linear_encoding) + len(y_test_linear_encoding) + len(y_val_linear_encoding)
    print('---------------------------------------')  
    print('Train set shape y linear_encoding:         {}, {:.2f}%'.format(len(y_train_linear_encoding), (len(y_train_linear_encoding)*100.)/total))
    print('Validation set shape y linear_encoding:    {}, {:.2f}%'.format(len(y_val_linear_encoding), (len(y_val_linear_encoding)*100.)/total))
    print('Test set shape y linear_encoding:          {}, {:.2f}%'.format(len(y_test_linear_encoding), (len(y_test_linear_encoding)*100.)/total))
# Out:
# ---------------------------------------
# Train set shape x:                567, 70.00%
# Validation set shape x:           567, 14.94%
# Test set shape x:                 122, 15.06%
# ---------------------------------------
# ---------------------------------------
# Train set shape y:                567, 70.00%
# Validation set shape y:           121, 14.94%
# Test set shape y:                 122, 15.06%
# ---------------------------------------

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
# Bin the data and look at how its distributed, probably the more random/spread out the better 
# for training, but this will improve as the database fills out

if 'Try Both' not in ENCODING_TYPE:
    #--------------------Training Set---------------------
    save_encoding = ENCODING_TYPE.replace(' ','_')
    
    num_cols = X_train.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    
    for i in range(num_cols):
        axes[i].hist(X_train[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Training Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig(f'plots/training_set_data_distribution{save_encoding}.pdf')
    plt.show()

    #--------------------Validation Set---------------------
    num_cols = X_val.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    
    for i in range(num_cols):
        axes[i].hist(X_val[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Validation Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig(f'plots/validation_set_data_distribution{save_encoding}.pdf')
    plt.show()
    
    #--------------------Test Set---------------------
    num_cols = X_test.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    
    for i in range(num_cols):
        axes[i].hist(X_test[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Test Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig(f'plots/test_set_data_distribution{save_encoding}.pdf')
    plt.show()
    
else: #just plot linear encoding for now to not get plot overwhelm
    #--------------------Training Set---------------------
    num_cols = X_train_linear_encoding.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    
    for i in range(num_cols):
        axes[i].hist(X_train_linear_encoding[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Training Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig('plots/training_set_data_distribution_linear_encoding.pdf')
    plt.show()

    #--------------------Validation Set---------------------
    num_cols = X_val_linear_encoding.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    
    for i in range(num_cols):
        axes[i].hist(X_val_linear_encoding[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Validation Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig('plots/validation_set_data_distribution_linear_encoding.pdf')
    plt.show()
    
    
    #--------------------Test Set---------------------
    num_cols = X_test_linear_encoding.shape[1]
    num_rows = math.ceil(num_cols / 3)
    
    fig, axes = plt.subplots(num_rows, 3, figsize=(10, 3 * num_rows))
    axes = axes.ravel()
    
    with open('X_names', 'r') as f:
        column_labels = f.read().splitlines()
    
    for i in range(num_cols):
        axes[i].hist(X_test_linear_encoding[:, i], bins=30, edgecolor='black')
        axes[i].set_title(f'Test Set {column_labels[i]}')
        axes[i].set_xlabel(f'{column_labels[i]}')
        axes[i].set_ylabel('Frequency')
    
    # Remove unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.savefig('plots/test_set_data_distribution_linear_encoding.pdf')
    plt.show()

# %%
steps_per_epoch = int(np.ceil(len(X_train) / TRAIN_BATCH_SIZE))
LR_DECAY_STEPS = steps_per_epoch * 20   # decay every ~10 epochs

# %% [markdown]
# ## MLP

# %% [markdown]
# ### Create model

# %% [markdown]
# Create a classical multi-layer perceptron for regression. Taking some inspiration from [Deep learning-based I-V Global Parameter Extraction for BSIM-CMG](https://www.sciencedirect.com/science/article/pii/S003811012300179X), Solid-State Electronics, Vol. 209, November 2023.
#
# The above publication predicted parameters for BSIM, which is a physics model for advanced transistors that is complicated and might be a similar complexity to the physics we are trying to target/map with these SC qubit hamiltonian values

# %% [markdown]
# Reccomended to download a third party app like "Sleep control Center" or "Amphetamine" to prevent computer from sleeping during the many hour/day long training process

# %%
def elementwise_value_loss(loss_name):
    name = str(loss_name).lower()

    if name in ["mse", "mean_squared_error", "mean square error"]:
        def _loss(y_true, y_pred):
            y_true = tf.cast(y_true, y_pred.dtype)
            return tf.math.squared_difference(y_true, y_pred)  # (N,D)
        return _loss

    if name in ["mae", "mean_absolute_error", "mean absolute error"]:
        def _loss(y_true, y_pred):
            y_true = tf.cast(y_true, y_pred.dtype)
            return tf.abs(y_true - y_pred)  # (N,D)
        return _loss

    print(f"[WARN] TRAIN_LOSS='{loss_name}' not recognized; defaulting to elementwise MSE.")
    def _loss(y_true, y_pred):
        y_true = tf.cast(y_true, y_pred.dtype)
        return tf.math.squared_difference(y_true, y_pred)
    return _loss


VALUE_LOSS_FN = elementwise_value_loss(TRAIN_LOSS)

# %% [markdown]
# ### Create Model by Hand

# %%
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    # n output neurons for n parameters (value and exists heads both use this size)
    if 'Try Both' not in ENCODING_TYPE:
        # Multilayer perceptron (MLP)
        model_shape = f'mlp_{len(X_test[0])}_'
        # inner layer sizes
        model_shape += '_'.join(str(l) for l in NEURONS_PER_LAYER)
        print(len(y_value_train[0]))
        model_shape += f'_{len(y_value_train[0])}'
    else:
        # Multilayer perceptron (MLP) for both encodings
        model_shape_one_hot_encoding = f'mlp_{len(X_test_one_hot_encoding[0])}_'
        model_shape_linear_encoding = f'mlp_{len(X_test_linear_encoding[0])}_'
        model_shape_one_hot_encoding += '_'.join(str(l) for l in NEURONS_PER_LAYER)
        model_shape_linear_encoding += '_'.join(str(l) for l in NEURONS_PER_LAYER)

        print('one hot:', len(y_value_train_one_hot_encoding[0]))
        model_shape_one_hot_encoding += f'_{len(y_value_train_one_hot_encoding[0])}'
        print('linear:', len(y_value_train_linear_encoding[0]))
        model_shape_linear_encoding += f'_{len(y_value_train_linear_encoding[0])}'

# %%
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    if 'Try Both' not in ENCODING_TYPE:
        #initialize a model, which lets us build a stack of layers
        inputs = Input(shape=(len(X_test[0]),), name='input1')
        x = inputs

        #iterate over the configuration of neurons for each hidden layer specified in NEURONS_PER_LAYER
        for i, n in enumerate(NEURONS_PER_LAYER):
            # add a fully connected (dense) hidden layer with specified number of neurons
            # the LeCun uniform initializer is used when initializing weights, this makes the model more stable
            # l2 regularization is used in each layer to penalizing large weights, which prevents overfitting
            x = Dense(n, name='fc{}'.format(i), kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)

            # apply a Leaky ReLU activation function to the outputs of the dense layer
            # this introduces non-linearities, allowing the network to learn complex functions
            #leaky ReLU is chosen over standard ReLU to help mitigate the "dying ReLU" problem:
            #     - this problem is when neurons using the ReLU activation function output zero for all inputs and stop learning
            #     - can be mitigated by using variations like Leaky ReLU or proper initialization
            x = LeakyReLU(negative_slope=0.01, name='leaky_relu{}'.format(i))(x)
            
            # add a dropout layer to reduce overfitting -- randomly drops a set fraction (like 30%) of outputs from the layer
            x = Dropout(rate=TRAIN_DROPOUT_RATE, name='dropout{}'.format(i))(x)
        
        # add the output layers consisting of # neurons, corresponding to the # target variables we aim to predict.
        # value_out predicts the numerical parameter values; exists_out predicts if each parameter is defined (0/1).
        value_out = Dense(len(y_value_train[0]), activation='linear', name='value_out', kernel_initializer='lecun_uniform')(x)

        model = tf.keras.Model(
            inputs=inputs,
            outputs={'value_out': value_out},
            name='mlp_single_output'
        )

    
    else:
        # One-hot encoding model
        inputs_one_hot = Input(shape=(len(X_test_one_hot_encoding[0]),), name='input1')
        x_oh = inputs_one_hot
        for i, n in enumerate(NEURONS_PER_LAYER):
            x_oh = Dense(n, name='fc{}'.format(i), kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x_oh)
            x_oh = LeakyReLU(negative_slope=0.01, name='leaky_relu{}'.format(i))(x_oh)
            x_oh = Dropout(rate=TRAIN_DROPOUT_RATE, name='dropout{}'.format(i))(x_oh)
        value_out_oh = Dense(len(y_value_train_one_hot_encoding[0]), activation='linear', name='value_out', kernel_initializer='lecun_uniform')(x_oh)
        model_one_hot_encoding = tf.keras.Model(
            inputs=inputs_one_hot,
            outputs={'value_out': value_out_oh},
            name='mlp_single_output_one_hot'
        )

        # Linear encoding model
        inputs_lin = Input(shape=(len(X_test_linear_encoding[0]),), name='input1')
        x_lin = inputs_lin
        for i, n in enumerate(NEURONS_PER_LAYER):
            x_lin = Dense(n, name='fc{}'.format(i), kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x_lin)
            x_lin = LeakyReLU(negative_slope=0.01, name='leaky_relu{}'.format(i))(x_lin)
            x_lin = Dropout(rate=TRAIN_DROPOUT_RATE, name='dropout{}'.format(i))(x_lin)
        value_out_lin = Dense(len(y_value_train_linear_encoding[0]), activation='linear', name='value_out', kernel_initializer='lecun_uniform')(x_lin)
        model_linear_encoding = tf.keras.Model(
            inputs=inputs_lin,
            outputs={'value_out': value_out_lin},
            name='mlp_single_output_linear'
        )

# %%
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    # The exponential decay learning rate schedule gradually reduces the learning rate, fine-tuning the learning process for better convergence
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=LR_INITIAL,
        decay_steps=LR_DECAY_STEPS,
        decay_rate=LR_DECAY_RATE,
        staircase=LR_STAIRCASE
    )
    
    if 'Try Both' not in ENCODING_TYPE:
        # Set model to minimize loss specified by TRAIN_LOSS, and also to report the loss during training
        model.compile(
            optimizer=tf.optimizers.Adam(learning_rate=lr_schedule),
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]}
        )
    else:
        # Linear encoding model
        model_linear_encoding.compile(
            optimizer=tf.optimizers.Adam(learning_rate=lr_schedule),
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]}
        )
        # One-hot encoding model
        model_one_hot_encoding.compile(
            optimizer=tf.optimizers.Adam(learning_rate=lr_schedule),
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]}
        )

# %%
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    # !mkdir -p model
    if 'Try Both' not in ENCODING_TYPE:
        best_model_file = 'model/{}_best_model.keras'.format(model_shape)
        last_model_file = 'model/{}_last_model.keras'.format(model_shape)
    else:
        best_model_file_one_hot_encoding = 'model/{}_best_model_one_hot_encoding.keras'.format(model_shape_one_hot_encoding)
        last_model_file_one_hot_encoding = 'model/{}_last_model_one_hot_encoding.keras'.format(model_shape_one_hot_encoding)
    
        best_model_file_linear_encoding = 'model/{}_best_model_linear_encoding.keras'.format(model_shape_linear_encoding)
        last_model_file_linear_encoding = 'model/{}_last_model_linear_encoding.keras'.format(model_shape_linear_encoding)

# %% [markdown]
# Enable training (`train_and_save`) to overwrite the model file.

# %%
train_and_save = True

# %% [markdown]
# We use Adam optimizer, minimize the Mean Squared Logarithmic Error, and early stop.

# %% [markdown]
# #### Training

# %%
from IPython.display import clear_output
# Set up monitors and plots for later tracking purposes

if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    class TrainingPlot(tf.keras.callbacks.Callback):
         
        # This function is called when the training begins
        def on_train_begin(self, logs={}):
            # Initialize the lists for holding the logs, losses 
            self.losses = []
            self.val_losses = []
            self.logs = []
        
        # This function is called at the end of each epoch
        def on_epoch_end(self, epoch, logs={}):
            
            # Append the logs, losses  to the lists
            self.logs.append(logs)
            self.losses.append(logs.get('loss'))
            self.val_losses.append(logs.get('val_loss'))
            
            # Before plotting ensure at least 2 epochs have passed
            if len(self.losses) > 1:
                
                # Clear the previous plot
                clear_output(wait=True)
                N = np.arange(0, len(self.losses))
                
                # Plot train loss, train acc, val loss and val acc against epochs passed
                plt.figure()
                plt.plot(N, self.losses, label = "train_loss")
                plt.plot(N, self.val_losses, label = "val_loss")
                plt.title("Training Loss [Epoch {}]".format(epoch))
                plt.xlabel("Epoch #")
                plt.ylabel("Loss/Accuracy")
                plt.legend()
                plt.show()
           

class LearningRateMonitor(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.learning_rates = []

    #we have to do some checking for versions here or else we will get an Adam error when using this monitor
    def _current_lr(self, optimizer):
        # look and see if you get "lr" ir "learning_rate" depending on the version
        lr = getattr(optimizer, "lr", None) or getattr(optimizer, "learning_rate", None)

        # if this is a shecdule then evaluate it at current iteration step
        if isinstance(lr, tf.keras.optimizers.schedules.LearningRateSchedule):
            return float(lr(optimizer.iterations).numpy())

        # if not a schedule, its a scalar/variable/tensor
        return float(tf.keras.backend.get_value(lr))

    def on_epoch_end(self, epoch, logs=None):
        try:
            lr_val = self._current_lr(self.model.optimizer)
        except Exception:
            # for anything else fallback
            lr_val = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        self.learning_rates.append(lr_val)

# %%
# %%time

# Train the model
history = None  
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    if train_and_save: 
        # Set up early stopping to prevent overfitting by halting training when validation loss stops improving
        early_stopping = EarlyStopping(
            monitor='val_value_out_loss',                      # Monitor validation loss for stopping criteria 
            mode='min',                              # Stop when the monitored quantity has stopped decreasing
            patience=TRAIN_EARLY_STOPPING_PATIENCE,  # Number of epochs to wait after last improvement
            verbose=1                                # Enable logging when early stopping happens
        )
    
        # Train the model on the training data and validate on a portion of it
        if 'Try Both' not in ENCODING_TYPE:
            plot_callback = TrainingPlot()      # Plot training progress
            lr_monitor = LearningRateMonitor()  # Watch learning rate changes
            
            # (single-head model) train only on value_out targets
            
            # Set up model checkpointing to save the model at its best validation loss:
            model_checkpoint = ModelCheckpoint(
                filepath=best_model_file,          
                monitor='val_value_out_loss',            # Save the model based on validation loss improvement
                mode='min',                    # Favor lower validation loss values for saving (minimize)
                save_best_only=True,           # Save only when validation loss improves
                verbose=0                      # No logging for model saving
            )
   
            history = model.fit(
                np.asarray(X_train),
                {
                    "value_out": np.asarray(y_value_train),
                },
                validation_data=(
                    np.asarray(X_val),
                    {
                        "value_out": np.asarray(y_value_val),
                    },
                ),
                epochs=EPOCHS,
                batch_size=TRAIN_BATCH_SIZE,
                callbacks=[early_stopping, model_checkpoint, plot_callback, lr_monitor],
                verbose=1,
            )
                    
            model.save(last_model_file)  # Save the final model when done training!
        
        else:
            #-----------------------------------------linear--------------------------------------------
            plot_callback_linear_encoding = TrainingPlot()      # Plot training progress
            lr_monitor_linear_encoding = LearningRateMonitor()  # Watch learning rate changes
            
            # (single-head model) train only on value_out targets
            
            # Set up model checkpointing to save the model at its best validation loss:
            model_checkpoint_linear_encoding = ModelCheckpoint(
                filepath=best_model_file_linear_encoding,          
                monitor='val_value_out_loss',            # Save the model based on validation loss improvement
                mode='min',                    # Favor lower validation loss values for saving (minimize)
                save_best_only=True,           # Save only when validation loss improves
                verbose=0                      # No logging for model saving
            )
            
            history_linear_encoding = model_linear_encoding.fit(
                np.asarray(X_train_linear_encoding),
                {
                    "value_out": np.asarray(y_value_train_linear_encoding),
                },
                validation_data=(
                    np.asarray(X_val_linear_encoding),
                    {
                        "value_out": np.asarray(y_value_val_linear_encoding),
                    },
                ),
                epochs=EPOCHS,
                batch_size=TRAIN_BATCH_SIZE,
                callbacks=[early_stopping, model_checkpoint_linear_encoding, plot_callback_linear_encoding, lr_monitor_linear_encoding],
                verbose=1
            )
            
            model_linear_encoding.save(last_model_file_linear_encoding)  # Save the final model when done training!
            
            #-----------------------------------------one hot--------------------------------------------
            plot_callback_one_hot_encoding = TrainingPlot()      # Plot training progress
            lr_monitor_one_hot_encoding = LearningRateMonitor()  # Watch learning rate changes
            
            # (single-head model) train only on value_out targets
            
            # Set up model checkpointing to save the model at its best validation loss:
            model_checkpoint_one_hot_encoding = ModelCheckpoint(
                filepath=best_model_file_one_hot_encoding,          
                monitor='val_value_out_loss',            # Save the model based on validation loss improvement
                mode='min',                    # Favor lower validation loss values for saving (minimize)
                save_best_only=True,           # Save only when validation loss improves
                verbose=0                      # No logging for model saving
            )
            
            history_one_hot_encoding = model_one_hot_encoding.fit(
                np.asarray(X_train_one_hot_encoding),
                {
                    'value_out': np.asarray(y_value_train_one_hot_encoding),
                },
                validation_data=(
                    np.asarray(X_val_one_hot_encoding),
                    {
                        'value_out': np.asarray(y_value_val_one_hot_encoding),
                    },
                ),
                epochs=EPOCHS,
                batch_size=TRAIN_BATCH_SIZE,
                callbacks=[early_stopping, model_checkpoint_one_hot_encoding, plot_callback_one_hot_encoding, lr_monitor_one_hot_encoding],
                verbose=1
            )
            
            model_one_hot_encoding.save(last_model_file_one_hot_encoding)  # Save the final model when done training!
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 7.87 μs

# %% [markdown]
# Load the saved best model and use it from now on.

# %%
from keras.saving import load_model

if not KERAS_TUNER and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    if 'Try Both' not in ENCODING_TYPE:
        model = load_model(best_model_file, compile=False)
        model.compile(
            optimizer=model.optimizer if hasattr(model, "optimizer") else "adam",
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]},
        )
    else:
        model_one_hot_encoding = load_model(best_model_file_one_hot_encoding, compile=False)
        model_one_hot_encoding.compile(
            optimizer=model_one_hot_encoding.optimizer if hasattr(model_one_hot_encoding, "optimizer") else "adam",
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]},
        )

        model_linear_encoding = load_model(best_model_file_linear_encoding, compile=False)
        model_linear_encoding.compile(
            optimizer=model_linear_encoding.optimizer if hasattr(model_linear_encoding, "optimizer") else "adam",
            loss={'value_out': VALUE_LOSS_FN},
            metrics={'value_out': [VALUE_LOSS_FN]},
        )

# %% [markdown]
# ### Sweep total number of parameters to find the right range

# %%
if SWEEP_PARAM_NUM:
    
    def build_masked_mlp(neurons_per_layer, input_dim, output_dim):
        x_in = Input(shape=(input_dim,), name="input1")
        x = x_in

        for i, n in enumerate(neurons_per_layer):
            x = Dense(
                n,
                name=f"fc{i}",
                kernel_initializer="lecun_uniform",
                kernel_regularizer=tf.keras.regularizers.l2(1e-5),
            )(x)
            x = LeakyReLU(negative_slope=0.01, name=f"leaky_relu{i}")(x)
            x = Dropout(rate=TRAIN_DROPOUT_RATE, name=f"dropout{i}")(x)

        value_out = Dense(
            output_dim,
            activation="linear",
            name="value_out",
            kernel_initializer="lecun_uniform",
            dtype="float32",
        )(x)

        return Model(inputs=x_in, outputs={"value_out": value_out})

    def make_optimizer():
        lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=LR_INITIAL,
            decay_steps=LR_DECAY_STEPS,
            decay_rate=LR_DECAY_RATE,
            staircase=LR_STAIRCASE
        )
        return tf.keras.optimizers.Adam(learning_rate=lr_schedule)

    def train_one_config(neurons_per_layer, seed=0):
        tf.keras.backend.clear_session()
        tf.random.set_seed(seed)
        np.random.seed(seed)

        model = build_masked_mlp(
            neurons_per_layer=neurons_per_layer,
            input_dim=X_train.shape[1],
            output_dim=y_value_train.shape[1],
        )

        # keep your elementwise MAE loss if you want (works fine as a loss)
        def elementwise_mae(y_true, y_pred):
            return tf.abs(y_true - y_pred)

        model.compile(
            optimizer=make_optimizer(),
            loss={"value_out": elementwise_mae},  # or VALUE_LOSS_FN if you prefer
            metrics={"value_out": [tf.keras.metrics.MeanAbsoluteError(name="mae")]},
            # If your Keras supports it, this helps avoid XLA weirdness:
            jit_compile=False,
        )

        early_stopping = EarlyStopping(
            monitor='val_value_out_loss',
            mode="min",
            patience=TRAIN_EARLY_STOPPING_PATIENCE,
            verbose=0,
            restore_best_weights=True,
        )

        Xtr = np.asarray(X_train)
        Xva = np.asarray(X_val)

        yv_tr = np.asarray(y_value_train)
        yv_va = np.asarray(y_value_val)
        
        history = model.fit(
            Xtr,
            {"value_out": yv_tr},
            validation_data=(
                Xva,
                {"value_out": yv_va},
            ),
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping],
            verbose=0,
        )

        best_val_loss = float(np.min(history.history["val_value_out_loss"]))
        best_epoch = int(np.argmin(history.history["val_value_out_loss"]) + 1)

        return {
            "neurons_per_layer": tuple(neurons_per_layer),
            "depth": len(neurons_per_layer),
            "width": int(neurons_per_layer[0]),
            "total_params": int(model.count_params()),
            "best_val_loss": best_val_loss,
            "best_epoch": best_epoch,
        }

    configs = []
    for depth in [6,7]:
        for width in [64, 256, 1024, 4096]:
            configs.append([width] * depth)

    # remove duplicates if any
    configs = [list(x) for x in {tuple(c) for c in configs}]

    results = []
    for cfg in sorted(configs, key=lambda c: (len(c), c[0])):
        out = train_one_config(cfg, seed=0)
        results.append(out)
        print(out)

    df = pd.DataFrame(results).sort_values("total_params")

# %%
if SWEEP_PARAM_NUM:
    # save the data

    from datetime import datetime
    
    run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
    out_dir = "sweep_outputs"
    os.makedirs(out_dir, exist_ok=True)
    
    csv_path = os.path.join(out_dir, f"sweep_results_{run_id}.csv")
    df.to_csv(csv_path, index=False)
    print("Saved:", csv_path)

# %%
if SWEEP_PARAM_NUM:
    plt.figure()
    plt.scatter(df["total_params"], df["best_val_loss"])
    plt.xscale("log")  # will be helpful if params grow fast
    plt.xlabel("Total parameters (log scale)")
    plt.ylabel("Best val_loss")
    plt.title("Best val_loss vs model size")
    plt.savefig('plots/params_vs_loss.png')
    plt.show()

    df2 = df.copy()
    
    plt.figure()
    sc = plt.scatter(
        df2["total_params"],
        df2["best_val_loss"],
        c=df2["depth"],
        s=20 + 10*np.log2(df2["width"]),
    )
    plt.xscale("log")
    plt.xlabel("Total parameters (log scale)")
    plt.ylabel("Best val_loss")
    plt.title("Best val_loss vs model size (color=depth, size=width)")
    plt.colorbar(sc, label="Depth")
    plt.savefig("plots/params_vs_loss_width_color_coded.png")
    plt.show()

# %%
if SWEEP_PARAM_NUM:
    df.to_csv("sweep_results.csv", index=False)

    old = pd.read_csv("sweep_results.csv")
    combined = pd.concat([old, df], ignore_index=True).drop_duplicates(
        subset=["neurons_per_layer"], keep="last"
    )
    combined.to_csv("sweep_results.csv", index=False)

# %% [markdown]
# ### Sweep amount of data used in training to determine if data amount is limiting

# %%
if SWEEP_DATA_AMOUNT:

    FIXED_DEPTH = 5
    FIXED_WIDTH = 512
    FIXED_NEURONS = [FIXED_WIDTH] * FIXED_DEPTH

    TRAIN_FRACTIONS = np.linspace(0.3, 1.0, 10)

    # avg over many seeds for error bars
    SWEEP_SEEDS = [0, 1]

    def build_masked_mlp(neurons_per_layer, input_dim, output_dim):
        x_in = Input(shape=(input_dim,), name="input1")
        x = x_in

        for i, n in enumerate(neurons_per_layer):
            x = Dense(
                n,
                name=f"fc{i}",
                kernel_initializer="lecun_uniform",
                kernel_regularizer=tf.keras.regularizers.l2(1e-5),
            )(x)
            x = LeakyReLU(negative_slope=0.01, name=f"leaky_relu{i}")(x)
            x = Dropout(rate=TRAIN_DROPOUT_RATE, name=f"dropout{i}")(x)

        value_out = Dense(
            output_dim,
            activation="linear",
            name="value_out",
            kernel_initializer="lecun_uniform",
            dtype="float32",
        )(x)

        return Model(inputs=x_in, outputs={"value_out": value_out})

    def make_optimizer():
        lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=LR_INITIAL,
            decay_steps=LR_DECAY_STEPS,
            decay_rate=LR_DECAY_RATE,
            staircase=LR_STAIRCASE,
        )
        return tf.keras.optimizers.Adam(learning_rate=lr_schedule)

    def elementwise_mae(y_true, y_pred):
        return tf.abs(y_true - y_pred)  

    def make_subset(X, y_value, frac, seed):
        assert 0 < frac <= 1.0
        n = len(X)
        m = max(1, int(np.floor(frac * n)))
        rng = np.random.default_rng(seed)
        idx = rng.choice(n, size=m, replace=False)
        return X[idx], y_value[idx], m

    def train_one_fraction(neurons_per_layer, train_frac, seed=0):
        tf.keras.backend.clear_session()
        tf.random.set_seed(seed)
        np.random.seed(seed)

        # Full arrays
        Xtr_full = np.asarray(X_train)
        Xva = np.asarray(X_val)

        yv_tr_full = np.asarray(y_value_train)
        yv_va = np.asarray(y_value_val)

        Xtr, yv_tr, n_sub = make_subset(Xtr_full, yv_tr_full, train_frac, seed)

        model = build_masked_mlp(
            neurons_per_layer=neurons_per_layer,
            input_dim=Xtr.shape[1],
            output_dim=yv_tr.shape[1],
        )

        model.compile(
            optimizer=make_optimizer(),
            loss={"value_out": elementwise_mae},
            metrics={"value_out": [tf.keras.metrics.MeanAbsoluteError(name="mae")]},
            jit_compile=False,
        )

        early_stopping = EarlyStopping(
            monitor="val_value_out_loss",
            mode="min",
            patience=TRAIN_EARLY_STOPPING_PATIENCE,
            verbose=0,
            restore_best_weights=True,
        )

        history = model.fit(
            Xtr,
            {"value_out": yv_tr},
            validation_data=(
                Xva,
                {"value_out": yv_va},
            ),
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping],
            verbose=0,
        )

        # grab best epoch by val_value_out_loss
        val_loss_hist = np.asarray(history.history["val_value_out_loss"], dtype=float)
        best_i = int(np.argmin(val_loss_hist))
        best_epoch = best_i + 1

        out = {
            "train_frac": float(train_frac),
            "train_n": int(n_sub),
            "seed": int(seed),
            "neurons_per_layer": str(list(neurons_per_layer)),
            "total_params": int(model.count_params()),
            "best_val_value_out_loss": float(val_loss_hist[best_i]),
            "best_epoch": int(best_epoch),
        }
        return out

    results = []
    for frac in TRAIN_FRACTIONS:
        for seed in SWEEP_SEEDS:
            out = train_one_fraction(FIXED_NEURONS, train_frac=frac, seed=seed)
            results.append(out)
            print(out)
            tf.keras.backend.clear_session()
            gc.collect()

    df = pd.DataFrame(results).sort_values(["train_frac", "seed"]).reset_index(drop=True)

    summary = (
        df.groupby(["train_frac", "train_n", "total_params"], as_index=False)
          .agg(
              best_val_value_out_loss_mean=("best_val_value_out_loss", "mean"),
              best_val_value_out_loss_std=("best_val_value_out_loss", "std"),
              best_epoch_mean=("best_epoch", "mean"),
          )
          .sort_values("train_frac")
          .reset_index(drop=True)
    )

    # save to csv
    import time
    run_id = time.strftime("%Y%m%d_%H%M%S")
    out_dir = os.path.join("sweeps", f"data_fraction_sweep_{run_id}")
    os.makedirs(out_dir, exist_ok=True)

    df_path = os.path.join(out_dir, "sweep_raw.csv")
    summary_path = os.path.join(out_dir, "sweep_summary.csv")
    meta_path = os.path.join(out_dir, "metadata.json")
    fig_path = os.path.join(out_dir, "val_loss_vs_train_fraction.png")

    df.to_csv(df_path, index=False)
    summary.to_csv(summary_path, index=False)

# %%
if SWEEP_DATA_AMOUNT:
    import json
    def _jsonify(o):
        if isinstance(o, np.ndarray): return o.tolist()

    # save to csv
    run_id = time.strftime("%Y%m%d_%H%M%S")
    out_dir = os.path.join("sweeps", f"data_fraction_sweep_{run_id}")
    os.makedirs(out_dir, exist_ok=True)

    df_path = os.path.join(out_dir, "sweep_raw.csv")
    summary_path = os.path.join(out_dir, "sweep_summary.csv")
    meta_path = os.path.join(out_dir, "metadata.json")
    fig_path = os.path.join(out_dir, "val_loss_vs_train_fraction.png")

    df.to_csv(df_path, index=False)
    summary.to_csv(summary_path, index=False)

    metadata = {
        "run_id": run_id,
        "fixed_depth": FIXED_DEPTH,
        "fixed_width": FIXED_WIDTH,
        "fixed_neurons": FIXED_NEURONS,
        "train_fractions": TRAIN_FRACTIONS,
        "seeds": SWEEP_SEEDS,
        "batch_size": int(TRAIN_BATCH_SIZE),
        "early_stopping_patience": int(TRAIN_EARLY_STOPPING_PATIENCE),
        "notes": "Subset sampling only on TRAIN split. Single-head model trained on value_out only (no exists mask / sample_weight).",
    }

    with open(meta_path, "w") as f:
        json.dump(metadata, f, indent=2, default=_jsonify)

    plt.figure()
    y = summary["best_val_value_out_loss_mean"].to_numpy()
    x = summary["train_frac"].to_numpy()
    if len(SWEEP_SEEDS) > 1:
        yerr = summary["best_val_value_out_loss_std"].fillna(0.0).to_numpy()
        plt.errorbar(x, y, yerr=yerr, marker="o")
        plt.ylabel("Best val value_out loss (mean ± std)")
    else:
        plt.plot(x, y, marker="o")
        plt.ylabel("Best val value_out loss")

    plt.xlabel("Training data fraction")
    plt.title(f"Val loss vs training fraction (depth={FIXED_DEPTH}, width={FIXED_WIDTH})")
    plt.tight_layout()
    plt.savefig(fig_path, dpi=200)
    plt.show()

    print(f"\nSaved:\n- {df_path}\n- {summary_path}\n- {meta_path}\n- {fig_path}")

# %% [markdown]
# ### Keras Tuner to Find Best Hyperparameters and Model

# %% [markdown]
# Run this if you want to use keras tuner to make the model rather than doing it by hand

# %%
if KERAS_TUNER:
    from tensorflow.keras import Sequential
    from tensorflow.keras.layers import Dense, Input, Dropout
    from tensorflow.keras.regularizers import l2
    from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras_tuner import HyperModel, RandomSearch
    from tensorflow.keras.models import load_model

# %%
if KERAS_TUNER:
    if 'Try Both' not in ENCODING_TYPE:
        def build_hypermodel(hp):
            tf.keras.backend.clear_session()
            gc.collect()
            # Hyperparameters to tune
            neurons_per_layer = [hp.Int(f'neurons_{i}', min_value=150, max_value=700,  step=10) for i in range(5)]
            dropout_rate = hp.Float('dropout_rate', TRAIN_DROPOUT_RATE, 0.5, step=0.1)
            
            # Create Model in the same way that we do by hand
            inputs = Input(shape=(len(X_test[0]),), name='input1')
            x = inputs
        
            for i, n in enumerate(neurons_per_layer):
                x = Dense(n, name=f'fc{i}', kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
                x = LeakyReLU(negative_slope=0.01, name=f'leaky_relu{i}')(x)
                x = Dropout(rate=dropout_rate, name=f'dropout{i}')(x)
        
            # multi-output heads: value_out (regression) and exists_out (existence classification)
            value_out = Dense(y_train.shape[1], name='value_out', activation='linear', kernel_initializer='lecun_uniform')(x)
            model = tf.keras.Model(inputs=inputs, outputs={"value_out": value_out})
        
            # Learning rate configuration
            lr_initial = hp.Float('learning_rate', 2e-3, 5e-3, sampling='LOG', default=0.0001)
            lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
                initial_learning_rate=lr_initial,
                decay_steps=LR_DECAY_STEPS,
                decay_rate=LR_DECAY_RATE,
                staircase=LR_STAIRCASE
            )
        
            model.compile(
                optimizer=tf.optimizers.Adam(learning_rate=lr_schedule),
                loss={'value_out': VALUE_LOSS_FN},
                metrics={'value_out': [VALUE_LOSS_FN]}
            )

            return model
    else:
        def build_hypermodel_one_hot_encoding(hp):
            tf.keras.backend.clear_session()
            gc.collect()
            # Hyperparameters to tune
            neurons_per_layer = [hp.Int(f'neurons_{i}', min_value=150, max_value=700,  step=10) for i in range(5)]
            dropout_rate = hp.Float('dropout_rate', TRAIN_DROPOUT_RATE, 0.5, step=0.1)
            
            #----------------------------------------------one hot-------------------------------------------
            # Create Model in the same way that we do by hand
            inputs = Input(shape=(len(X_test_one_hot_encoding[0]),), name='input1')
            x = inputs
        
            for i, n in enumerate(neurons_per_layer):
                x = Dense(n, name=f'fc{i}', kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
                x = LeakyReLU(negative_slope=0.01, name=f'leaky_relu{i}')(x)
                x = Dropout(rate=dropout_rate, name=f'dropout{i}')(x)
        
            value_out = Dense(y_train.shape[1], name='value_out', activation='linear', kernel_initializer='lecun_uniform')(x)
            model_one_hot_encoding = tf.keras.Model(inputs=inputs, outputs={"value_out": value_out})
            
            # Learning rate configuration
            lr_initial = hp.Float('learning_rate', 2e-3, 5e-3, sampling='LOG', default=0.0001)
            lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
                initial_learning_rate=lr_initial,
                decay_steps=LR_DECAY_STEPS,
                decay_rate=LR_DECAY_RATE,
                staircase=LR_STAIRCASE
            )
            optimizer = tf.optimizers.Adam(learning_rate=lr_schedule)

            model_one_hot_encoding.compile(
                optimizer=optimizer,
                loss={'value_out': VALUE_LOSS_FN},
                metrics={'value_out': [VALUE_LOSS_FN]}
            )

            return model_one_hot_encoding

        def build_hypermodel_linear_encoding(hp):
            tf.keras.backend.clear_session()
            gc.collect()
            
            # Hyperparameters to tune
            neurons_per_layer = [hp.Int(f'neurons_{i}', min_value=150, max_value=700, step=50) for i in range(5)]
            dropout_rate = hp.Float('dropout_rate', TRAIN_DROPOUT_RATE, 0.5, step=0.1)
            
            #----------------------------------------------linear------------------------------------------- 
            # Create Model in the same way that we do by hand
            inputs = Input(shape=(len(X_test_linear_encoding[0]),), name='input1')
            x = inputs
        
            for i, n in enumerate(neurons_per_layer):
                x = Dense(n, name=f'fc{i}', kernel_initializer='lecun_uniform', kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)
                x = LeakyReLU(negative_slope=0.01, name=f'leaky_relu{i}')(x)
                x = Dropout(rate=dropout_rate, name=f'dropout{i}')(x)
        
            value_out = Dense(y_train.shape[1], name='value_out', activation='linear', kernel_initializer='lecun_uniform')(x)
            model_linear_encoding = tf.keras.Model(inputs=inputs, outputs={"value_out": value_out})
            #----------------------------------------------continue-------------------------------------------

            # Learning rate configuration
            lr_initial = hp.Float('learning_rate', 2e-3, 5e-3, sampling='LOG', default=0.0001)
            lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
                initial_learning_rate=lr_initial,
                decay_steps=LR_DECAY_STEPS,
                decay_rate=LR_DECAY_RATE,
                staircase=LR_STAIRCASE
            )
            optimizer = tf.optimizers.Adam(learning_rate=lr_schedule)

            model_linear_encoding.compile(
                optimizer=optimizer,
                loss={'value_out': VALUE_LOSS_FN},
                metrics={'value_out': [VALUE_LOSS_FN]}
            )

            return model_linear_encoding

# %%
from keras_tuner import Objective

# use val_loss (always present)
objective = Objective("val_loss", direction="min")

if 'Try Both' not in ENCODING_TYPE:
    if KERAS_TUNER:
        tuner = RandomSearch(
            build_hypermodel,
            objective=Objective("val_loss", direction="min"),
            max_trials=KERAS_TUNER_TRIALS,
            executions_per_trial=1,
            directory=KERAS_DIR + f'/hyper_tuning_{encoding}_encoding',
            project_name=f'mlp_tuning_{encoding}_encoding'
        )
else:
    if KERAS_TUNER:
        tuner_linear_encoding = RandomSearch(
            build_hypermodel_linear_encoding,
            objective=Objective("val_loss", direction="min"),
            max_trials=KERAS_TUNER_TRIALS,
            executions_per_trial=1,
            directory=KERAS_DIR + '/hyper_tuning_linear_encoding',
            project_name='mlp_tuning_linear_encoding'
        )

        tuner_one_hot_encoding = RandomSearch(
            build_hypermodel_one_hot_encoding,
            objective=Objective("val_loss", direction="min"),
            max_trials=KERAS_TUNER_TRIALS,
            executions_per_trial=1,
            directory=KERAS_DIR + '/hyper_tuning_one_hot_encoding',
            project_name='mlp_tuning_one_hot_encoding'
        )
# Out:
# Reloading Tuner from keras/hyper_tuning_one_hot_encoding/mlp_tuning_one_hot_encoding/tuner0.json

# %%
if KERAS_TUNER:
    # Setup Callbacks
    early_stopping = EarlyStopping(
        monitor='val_value_out_loss',
        mode='min',
        patience=TRAIN_EARLY_STOPPING_PATIENCE,
        verbose=1
    )

# %%
if KERAS_TUNER:
    
    if 'Try Both' not in ENCODING_TYPE:
        # Perform hyperparameter tuning
        tuner.search(
            np.asarray(X_train),
            {'value_out': np.asarray(y_train)},
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            validation_data=(
                np.asarray(X_val),
                {'value_out': np.asarray(y_val)}
            ),
            callbacks=[early_stopping],
            verbose=1
        )


    else:
           
        # one-hot encoding branch
        tuner_one_hot_encoding.search(
            np.asarray(X_train_one_hot_encoding),
            {'value_out': np.asarray(y_train_one_hot_encoding)},
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            validation_data=(
                np.asarray(X_val_one_hot_encoding),
                {'value_out': np.asarray(y_val_one_hot_encoding)}
            ),
            callbacks=[early_stopping],
            verbose=1
        )

        # linear encoding branch
        tuner_linear_encoding.search(
            np.asarray(X_train_linear_encoding),
            {'value_out': np.asarray(y_train_linear_encoding)},
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            validation_data=(
                np.asarray(X_val_linear_encoding),
                {'value_out': np.asarray(y_val_linear_encoding)}
            ),
            callbacks=[early_stopping],
            verbose=1
        )
# Out:
# Trial 401 Complete [00h 00m 55s]
# val_loss: 0.06474103033542633
#
# Best val_loss So Far: 0.03363464027643204
# Total elapsed time: 20h 52m 45s

# %%
if KERAS_TUNER:
    if 'Try Both' not in ENCODING_TYPE:
        os.makedirs('model', exist_ok=True)
        best_model_file= f'model/best_keras_model_{encoding}_encoding.keras'

        best_model = tuner.get_best_models(1)[0]
        best_model.save(best_model_file)

        #gpu is thowing errors, lets try to clear its memory
        tf.keras.backend.clear_session()
        gc.collect()
        
        #lets not compile to help with the memory bug
        with tf.device('/CPU:0'):
            loaded_model = load_model(best_model_file, compile=False)
    else:
        os.makedirs('model', exist_ok=True)
        best_model_file_linear = 'model/best_keras_model_linear_encoding.keras'
        best_model_file_onehot = 'model/best_keras_model_one_hot_encoding.keras'
        
        best_linear_model = tuner_linear_encoding.get_best_models(1)[0]
        best_onehot_model = tuner_one_hot_encoding.get_best_models(1)[0]
        
        best_linear_model.save(best_model_file_linear)
        best_onehot_model.save(best_model_file_onehot)
        
        #gpu is thowing errors, lets try to clear its memory
        tf.keras.backend.clear_session()
        gc.collect()
        
        #lets not compile to help with the memory bug
        with tf.device('/CPU:0'):
            loaded_linear_model = load_model(best_model_file_linear, compile=False)
            loaded_onehot_model = load_model(best_model_file_onehot, compile=False)
# Out:
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 1 variables whereas the saved optimizer has 25 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ### View the model

# %%
if KERAS_TUNER:
    if 'Try Both' not in ENCODING_TYPE:
        best_model.summary()
    else:
        best_onehot_model.summary()
        best_linear_model.summary()
        
if not KERAS_TUNER  and not SWEEP_PARAM_NUM and not SWEEP_DATA_AMOUNT:
    if 'Try Both' not in ENCODING_TYPE:
        print("\n---- Model Summary ----")
        model.summary()
    else:
        print("\n---- Linear Encoding Model Summary ----")
        model_linear_encoding.summary()
        
        print("\n---- One-Hot Encoding Model Summary ----")
        model_one_hot_encoding.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input1 (InputLayer)             │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc0 (Dense)                     │ (None, 160)            │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 390)            │        62,790 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu1 (LeakyReLU)         │ (None, 390)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 390)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 550)            │       215,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu2 (LeakyReLU)         │ (None, 550)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 550)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 660)            │       363,660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu3 (LeakyReLU)         │ (None, 660)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout3 (Dropout)              │ (None, 660)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc4 (Dense)                     │ (None, 410)            │       271,010 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu4 (LeakyReLU)         │ (None, 410)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout4 (Dropout)              │ (None, 410)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ value_out (Dense)               │ (None, 5)              │         2,055 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 915,045 (3.49 MB)
#  Trainable params: 915,045 (3.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [raw]
# if KERAS_TUNER:
#     keras2ascii(model)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Although we may plot and print many metrics, we focus only on **Mean Squared Error (MSE).**

# %% [markdown]
# Plot training history.

# %%
#%matplotlib ipympl
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Visualize gradients for best model

# %%
if 'Try Both' not in ENCODING_TYPE:
    if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
        class GradientNormLogger(tf.keras.callbacks.Callback):
            """
            Logs gradient norms on a fixed probe batch at epoch end.
            Works for:
              - single-output models (y_true array)
              - multi-output dict models (e.g., {"value_out":..., "exists_out":...})
            Supports passing sample_weight (incl. per-output dict), which is required for masked losses.
            """
            def __init__(
                self,
                x_probe,
                y_probe,
                sample_weight_probe=None,
                layer_name_prefixes=("fc", "value_out", "exists_out"),
                log_every=1,
                verbose=1
            ):
                super().__init__()
                self.x_probe = tf.convert_to_tensor(x_probe)
                self.y_probe = y_probe  # keep as-is; we will convert lazily (dict vs array)
                self.sample_weight_probe = sample_weight_probe
                self.layer_name_prefixes = tuple(layer_name_prefixes)
                self.log_every = int(log_every)
                self.verbose = int(verbose)
                self.records = []
        
            def _to_tensor_tree(self, obj):
                # converts arrays (or dict of arrays) to tensors
                if obj is None:
                    return None
                if isinstance(obj, dict):
                    return {k: tf.convert_to_tensor(v) for k, v in obj.items()}
                return tf.convert_to_tensor(obj)
        
            def _want_var(self, var_name: str) -> bool:
                # var_name like "fc0/kernel:0", "value_out/bias:0", etc.
                base = var_name.split(":")[0]
                return any(base.startswith(pfx) for pfx in self.layer_name_prefixes)
        
            def on_epoch_end(self, epoch, logs=None):
                logs = logs or {}
                if (epoch + 1) % self.log_every != 0:
                    return
        
                y_probe_t = self._to_tensor_tree(self.y_probe)
                sw_probe_t = self._to_tensor_tree(self.sample_weight_probe)
        
                with tf.GradientTape() as tape:
                    y_pred = self.model(self.x_probe, training=True)
                    # IMPORTANT: use compiled_loss the same way training does
                    loss = self.model.compiled_loss(
                        y_probe_t,
                        y_pred,
                        sample_weight=sw_probe_t,
                        regularization_losses=self.model.losses
                    )
        
                grads = tape.gradient(loss, self.model.trainable_weights)
        
                rec = {"epoch": int(epoch + 1), "probe_loss": float(loss.numpy())}
        
                per_layer = {}
                for w, g in zip(self.model.trainable_weights, grads):
                    if g is None:
                        continue
        
                    wname = w.name  # includes :0
                    if not self._want_var(wname):
                        continue
        
                    wbase = wname.split(":")[0]
                    g_norm = float(tf.linalg.global_norm([g]).numpy().item())
                    rec[f"grad_norm__{wbase}"] = g_norm
        
                    layer_key = wbase.split("/")[0]
                    per_layer.setdefault(layer_key, []).append(g_norm)
        
                for layer_key, norms in per_layer.items():
                    rec[f"grad_mean__{layer_key}"] = float(np.mean(norms))
                    rec[f"grad_max__{layer_key}"] = float(np.max(norms))
        
                g_all = [g for g in grads if g is not None]
                rec["grad_global_norm"] = float(tf.linalg.global_norm(g_all).numpy().item()) if g_all else float("nan")
        
                self.records.append(rec)
        
                # push scalars into History
                for k, v in rec.items():
                    if k != "epoch":
                        logs[k] = v
        
                if self.verbose:
                    msg = f"[Grad] epoch={rec['epoch']} probe_loss={rec['probe_loss']:.6g} global={rec['grad_global_norm']:.3g}"
                    # show a couple common layers if present
                    for lk in ("fc0", "value_out", "exists_out"):
                        mk = f"grad_mean__{lk}"
                        xk = f"grad_max__{lk}"
                        if mk in rec:
                            msg += f" | {lk}:mean={rec[mk]:.3g} max={rec[xk]:.3g}"
                    print(msg)
        
            def to_csv(self, path: str):
                import csv, os
                os.makedirs(os.path.dirname(path), exist_ok=True)
                if not self.records:
                    return
                keys = sorted({k for r in self.records for k in r.keys()})
                with open(path, "w", newline="") as f:
                    w = csv.DictWriter(f, fieldnames=keys)
                    w.writeheader()
                    w.writerows(self.records)

# %%
if 'Try Both' not in ENCODING_TYPE:
    if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
        probe_n = min(256, len(X_train))

        x_probe = np.asarray(X_train[:probe_n])

        # y_true dict for the notebook model
        y_probe = {"value_out": np.asarray(y_value_train[:probe_n])}

        grad_logger = GradientNormLogger(
            x_probe=x_probe,
            y_probe=y_probe,
            sample_weight_probe=sw_probe,
            layer_name_prefixes=("fc0", "value_out"),  
            log_every=1,
            verbose=1
        )

        best_hp = tuner.get_best_hyperparameters(1)[0]
        model = tuner.hypermodel.build(best_hp)

        lr_monitor = LearningRateMonitor()

        history = model.fit(
            np.asarray(X_train),
            np.asarray(y_value_train),
            validation_data=(np.asarray(X_val), np.asarray(y_value_val)),
            epochs=400,
            batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping, lr_monitor, grad_logger],
            verbose=1
        )

        grad_logger.to_csv(f"plots/{encoding}_gradients.csv")

        del model
        tf.keras.backend.clear_session()
        gc.collect()

# %%
if 'Try Both' not in ENCODING_TYPE:
    if KERAS_TUNER and not SWEEP_PARAM_NUM and VISUALIZE_GRADIENTS:
        dfg = pd.DataFrame(grad_logger.records)
        
        # Plot global grad norm
        plt.figure()
        plt.plot(dfg["epoch"], dfg["grad_global_norm"])
        plt.yscale("log")  # very helpful to see vanishing/exploding
        plt.title("Gradient tracking for a single batch across epochs")
        plt.xlabel("Epoch")
        plt.ylabel("Gradient magnitude (log scale)")
        plt.tight_layout()
        plt.savefig(f"plots/{encoding}_grad_global_norm.pdf")
        plt.show()
        
        # Plot fc0 and output mean norms if present
        for lk in ["fc0", "output"]:
            col = f"grad_mean__{lk}"
            if col in dfg.columns:
                plt.figure()
                plt.plot(dfg["epoch"], dfg[col])
                plt.yscale("log")
                plt.title(f"Gradient Mean Norm: {lk} (probe batch)")
                plt.xlabel("Epoch")
                plt.ylabel("Mean grad norm (log scale)")
                plt.tight_layout()
                plt.savefig(f"plots/{encoding}_grad_mean_{lk}.pdf")
                plt.show()

# %% [markdown]
# ### Look at the best model

# %%
if 'Try Both' not in ENCODING_TYPE:
    if KERAS_TUNER:
        best_hp = tuner.get_best_hyperparameters(1)[0]
        model = tuner.hypermodel.build(best_hp)
        
        lr_monitor = LearningRateMonitor()
        
        history = model.fit(
            np.asarray(X_train),
            {"value_out": np.asarray(y_train)},
            validation_data=(
                np.asarray(X_val),
                {"value_out": np.asarray(y_val)},
            ),
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping, lr_monitor],
            verbose=1,
        )
        
        del model
        tf.keras.backend.clear_session()
        gc.collect()


    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Model loss")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="best")
    plt.tight_layout()
    plt.savefig(f"plots/{encoding}_history.pdf")
    plt.show()

    plt.plot(lr_monitor.learning_rates)
    plt.title("Learning Rate over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Learning Rate")
    plt.tight_layout()
    plt.savefig(f"plots/{encoding}_learning_rate.pdf")
    plt.show()

else:
    if KERAS_TUNER:
        best_hp = tuner.get_best_hyperparameters(1)[0]
        model = tuner.hypermodel.build(best_hp)
        
        lr_monitor = LearningRateMonitor()
        
        history = model.fit(
            np.asarray(X_train),
            {"value_out": np.asarray(y_train)},
            validation_data=(
                np.asarray(X_val),
                {"value_out": np.asarray(y_val)},
            ),
            epochs=EPOCHS,
            batch_size=TRAIN_BATCH_SIZE,
            callbacks=[early_stopping, lr_monitor],
            verbose=1,
        )
        
        del model
        tf.keras.backend.clear_session()
        gc.collect()


    plt.plot(history_linear_encoding.history["loss"])
    plt.plot(history_linear_encoding.history["val_loss"])
    plt.title("Model loss linear encoding")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="best")
    plt.tight_layout()
    plt.savefig("plots/linear_encoding_history.pdf")
    plt.show()

    plt.plot(lr_monitor_linear_encoding.learning_rates)
    plt.title("Learning Rate over Epochs linear encoding")
    plt.xlabel("Epoch")
    plt.ylabel("Learning Rate")
    plt.tight_layout()
    plt.savefig("plots/linear_encoding_learning_rate.pdf")
    plt.show()
# Out:
# Epoch 1/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - _loss: 0.4264 - loss: 0.4477 - val__loss: 0.3306 - val_loss: 0.3514
# Epoch 2/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.2943 - loss: 0.3147 - val__loss: 0.3480 - val_loss: 0.3679
# Epoch 3/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.2519 - loss: 0.2716 - val__loss: 0.2264 - val_loss: 0.2454
# Epoch 4/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1853 - loss: 0.2041 - val__loss: 0.1618 - val_loss: 0.1799
# Epoch 5/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1541 - loss: 0.1720 - val__loss: 0.1530 - val_loss: 0.1704
# Epoch 6/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1368 - loss: 0.1540 - val__loss: 0.1314 - val_loss: 0.1481
# Epoch 7/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1233 - loss: 0.1398 - val__loss: 0.1206 - val_loss: 0.1367
# Epoch 8/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1164 - loss: 0.1323 - val__loss: 0.1160 - val_loss: 0.1316
# Epoch 9/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.1086 - loss: 0.1239 - val__loss: 0.1204 - val_loss: 0.1355
# Epoch 10/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.1106 - loss: 0.1255 - val__loss: 0.1059 - val_loss: 0.1206
# Epoch 11/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1030 - loss: 0.1175 - val__loss: 0.1065 - val_loss: 0.1208
# Epoch 12/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1036 - loss: 0.1178 - val__loss: 0.1064 - val_loss: 0.1204
# Epoch 13/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - _loss: 0.1060 - loss: 0.1198 - val__loss: 0.1035 - val_loss: 0.1172
# Epoch 14/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.1013 - loss: 0.1148 - val__loss: 0.1066 - val_loss: 0.1199
# Epoch 15/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0992 - loss: 0.1125 - val__loss: 0.1045 - val_loss: 0.1176
# Epoch 16/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0947 - loss: 0.1077 - val__loss: 0.0988 - val_loss: 0.1117
# Epoch 17/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0921 - loss: 0.1049 - val__loss: 0.1041 - val_loss: 0.1167
# Epoch 18/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0941 - loss: 0.1067 - val__loss: 0.0896 - val_loss: 0.1021
# Epoch 19/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0862 - loss: 0.0986 - val__loss: 0.0887 - val_loss: 0.1010
# Epoch 20/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0833 - loss: 0.0956 - val__loss: 0.0928 - val_loss: 0.1049
# Epoch 21/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0830 - loss: 0.0951 - val__loss: 0.0906 - val_loss: 0.1025
# Epoch 22/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0795 - loss: 0.0914 - val__loss: 0.0901 - val_loss: 0.1020
# Epoch 23/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0800 - loss: 0.0918 - val__loss: 0.0794 - val_loss: 0.0911
# Epoch 24/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0719 - loss: 0.0836 - val__loss: 0.0825 - val_loss: 0.0941
# Epoch 25/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0722 - loss: 0.0838 - val__loss: 0.0774 - val_loss: 0.0889
# Epoch 26/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0719 - loss: 0.0834 - val__loss: 0.0801 - val_loss: 0.0915
# Epoch 27/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0698 - loss: 0.0812 - val__loss: 0.0796 - val_loss: 0.0909
# Epoch 28/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0700 - loss: 0.0812 - val__loss: 0.0770 - val_loss: 0.0882
# Epoch 29/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0680 - loss: 0.0791 - val__loss: 0.0812 - val_loss: 0.0922
# Epoch 30/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0676 - loss: 0.0786 - val__loss: 0.0800 - val_loss: 0.0910
# Epoch 31/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0672 - loss: 0.0782 - val__loss: 0.0801 - val_loss: 0.0909
# Epoch 32/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - _loss: 0.0680 - loss: 0.0789 - val__loss: 0.0868 - val_loss: 0.0975
# Epoch 33/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0697 - loss: 0.0804 - val__loss: 0.0816 - val_loss: 0.0922
# Epoch 34/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0684 - loss: 0.0790 - val__loss: 0.0738 - val_loss: 0.0843
# Epoch 35/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0663 - loss: 0.0769 - val__loss: 0.0749 - val_loss: 0.0854
# Epoch 36/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0650 - loss: 0.0754 - val__loss: 0.0821 - val_loss: 0.0925
# Epoch 37/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0671 - loss: 0.0774 - val__loss: 0.0741 - val_loss: 0.0844
# Epoch 38/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0628 - loss: 0.0730 - val__loss: 0.0702 - val_loss: 0.0804
# Epoch 39/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0610 - loss: 0.0712 - val__loss: 0.0738 - val_loss: 0.0839
# Epoch 40/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0629 - loss: 0.0730 - val__loss: 0.0789 - val_loss: 0.0889
# Epoch 41/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0633 - loss: 0.0733 - val__loss: 0.0714 - val_loss: 0.0814
# Epoch 42/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0623 - loss: 0.0722 - val__loss: 0.0693 - val_loss: 0.0791
# Epoch 43/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0655 - loss: 0.0753 - val__loss: 0.0742 - val_loss: 0.0840
# Epoch 44/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0680 - loss: 0.0778 - val__loss: 0.0737 - val_loss: 0.0834
# Epoch 45/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0674 - loss: 0.0771 - val__loss: 0.0817 - val_loss: 0.0913
# Epoch 46/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0661 - loss: 0.0758 - val__loss: 0.0809 - val_loss: 0.0905
# Epoch 47/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0652 - loss: 0.0748 - val__loss: 0.0738 - val_loss: 0.0833
# Epoch 48/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0615 - loss: 0.0710 - val__loss: 0.0686 - val_loss: 0.0781
# Epoch 49/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0591 - loss: 0.0686 - val__loss: 0.0680 - val_loss: 0.0774
# Epoch 50/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0583 - loss: 0.0677 - val__loss: 0.0714 - val_loss: 0.0808
# Epoch 51/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0594 - loss: 0.0688 - val__loss: 0.0669 - val_loss: 0.0762
# Epoch 52/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0596 - loss: 0.0689 - val__loss: 0.0746 - val_loss: 0.0839
# Epoch 53/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0614 - loss: 0.0706 - val__loss: 0.0723 - val_loss: 0.0815
# Epoch 54/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0603 - loss: 0.0695 - val__loss: 0.0698 - val_loss: 0.0789
# Epoch 55/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0597 - loss: 0.0688 - val__loss: 0.0710 - val_loss: 0.0801
# Epoch 56/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0601 - loss: 0.0692 - val__loss: 0.0688 - val_loss: 0.0779
# Epoch 57/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0609 - loss: 0.0699 - val__loss: 0.0686 - val_loss: 0.0776
# Epoch 58/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0595 - loss: 0.0685 - val__loss: 0.0717 - val_loss: 0.0806
# Epoch 59/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0591 - loss: 0.0680 - val__loss: 0.0672 - val_loss: 0.0761
# Epoch 60/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0598 - loss: 0.0687 - val__loss: 0.0682 - val_loss: 0.0770
# Epoch 61/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0590 - loss: 0.0678 - val__loss: 0.0706 - val_loss: 0.0794
# Epoch 62/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0616 - loss: 0.0703 - val__loss: 0.0763 - val_loss: 0.0850
# Epoch 63/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0618 - loss: 0.0705 - val__loss: 0.0694 - val_loss: 0.0781
# Epoch 64/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0602 - loss: 0.0688 - val__loss: 0.0658 - val_loss: 0.0745
# Epoch 65/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0581 - loss: 0.0667 - val__loss: 0.0678 - val_loss: 0.0764
# Epoch 66/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0584 - loss: 0.0670 - val__loss: 0.0709 - val_loss: 0.0795
# Epoch 67/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0590 - loss: 0.0675 - val__loss: 0.0682 - val_loss: 0.0767
# Epoch 68/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0594 - loss: 0.0679 - val__loss: 0.0662 - val_loss: 0.0746
# Epoch 69/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0579 - loss: 0.0663 - val__loss: 0.0639 - val_loss: 0.0723
# Epoch 70/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0550 - loss: 0.0634 - val__loss: 0.0623 - val_loss: 0.0706
# Epoch 71/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0548 - loss: 0.0631 - val__loss: 0.0641 - val_loss: 0.0724
# Epoch 72/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0553 - loss: 0.0636 - val__loss: 0.0664 - val_loss: 0.0747
# Epoch 73/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0562 - loss: 0.0645 - val__loss: 0.0639 - val_loss: 0.0721
# Epoch 74/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0541 - loss: 0.0623 - val__loss: 0.0600 - val_loss: 0.0682
# Epoch 75/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0522 - loss: 0.0604 - val__loss: 0.0605 - val_loss: 0.0686
# Epoch 76/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - _loss: 0.0518 - loss: 0.0599 - val__loss: 0.0623 - val_loss: 0.0703
# Epoch 77/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0523 - loss: 0.0604 - val__loss: 0.0623 - val_loss: 0.0704
# Epoch 78/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0555 - loss: 0.0635 - val__loss: 0.0652 - val_loss: 0.0732
# Epoch 79/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0560 - loss: 0.0640 - val__loss: 0.0617 - val_loss: 0.0697
# Epoch 80/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0565 - loss: 0.0645 - val__loss: 0.0642 - val_loss: 0.0722
# Epoch 81/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0580 - loss: 0.0659 - val__loss: 0.0666 - val_loss: 0.0745
# Epoch 82/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0570 - loss: 0.0649 - val__loss: 0.0698 - val_loss: 0.0776
# Epoch 83/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0576 - loss: 0.0655 - val__loss: 0.0645 - val_loss: 0.0723
# Epoch 84/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0566 - loss: 0.0644 - val__loss: 0.0666 - val_loss: 0.0744
# Epoch 85/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0556 - loss: 0.0634 - val__loss: 0.0596 - val_loss: 0.0673
# Epoch 86/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0519 - loss: 0.0596 - val__loss: 0.0573 - val_loss: 0.0650
# Epoch 87/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0499 - loss: 0.0576 - val__loss: 0.0612 - val_loss: 0.0689
# Epoch 88/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0529 - loss: 0.0605 - val__loss: 0.0614 - val_loss: 0.0690
# Epoch 89/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0550 - loss: 0.0627 - val__loss: 0.0616 - val_loss: 0.0692
# Epoch 90/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - _loss: 0.0522 - loss: 0.0598 - val__loss: 0.0594 - val_loss: 0.0670
# Epoch 91/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0519 - loss: 0.0595 - val__loss: 0.0644 - val_loss: 0.0720
# Epoch 92/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0555 - loss: 0.0630 - val__loss: 0.0694 - val_loss: 0.0769
# Epoch 93/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0569 - loss: 0.0644 - val__loss: 0.0627 - val_loss: 0.0702
# Epoch 94/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0554 - loss: 0.0629 - val__loss: 0.0623 - val_loss: 0.0698
# Epoch 95/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0560 - loss: 0.0634 - val__loss: 0.0610 - val_loss: 0.0684
# Epoch 96/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0526 - loss: 0.0600 - val__loss: 0.0604 - val_loss: 0.0678
# Epoch 97/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0523 - loss: 0.0597 - val__loss: 0.0611 - val_loss: 0.0685
# Epoch 98/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0515 - loss: 0.0588 - val__loss: 0.0610 - val_loss: 0.0684
# Epoch 99/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0517 - loss: 0.0591 - val__loss: 0.0579 - val_loss: 0.0653
# Epoch 100/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0516 - loss: 0.0589 - val__loss: 0.0582 - val_loss: 0.0655
# Epoch 101/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0500 - loss: 0.0573 - val__loss: 0.0590 - val_loss: 0.0663
# Epoch 102/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0518 - loss: 0.0590 - val__loss: 0.0599 - val_loss: 0.0671
# Epoch 103/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0509 - loss: 0.0581 - val__loss: 0.0586 - val_loss: 0.0657
# Epoch 104/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0514 - loss: 0.0586 - val__loss: 0.0566 - val_loss: 0.0638
# Epoch 105/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0503 - loss: 0.0575 - val__loss: 0.0567 - val_loss: 0.0638
# Epoch 106/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0505 - loss: 0.0576 - val__loss: 0.0573 - val_loss: 0.0644
# Epoch 107/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0510 - loss: 0.0581 - val__loss: 0.0588 - val_loss: 0.0659
# Epoch 108/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0523 - loss: 0.0594 - val__loss: 0.0591 - val_loss: 0.0662
# Epoch 109/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0524 - loss: 0.0594 - val__loss: 0.0586 - val_loss: 0.0656
# Epoch 110/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0514 - loss: 0.0584 - val__loss: 0.0600 - val_loss: 0.0670
# Epoch 111/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0512 - loss: 0.0582 - val__loss: 0.0581 - val_loss: 0.0650
# Epoch 112/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0502 - loss: 0.0572 - val__loss: 0.0578 - val_loss: 0.0647
# Epoch 113/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0511 - loss: 0.0580 - val__loss: 0.0591 - val_loss: 0.0660
# Epoch 114/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0521 - loss: 0.0590 - val__loss: 0.0600 - val_loss: 0.0668
# Epoch 115/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0504 - loss: 0.0572 - val__loss: 0.0554 - val_loss: 0.0623
# Epoch 116/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0500 - loss: 0.0569 - val__loss: 0.0609 - val_loss: 0.0677
# Epoch 117/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0527 - loss: 0.0595 - val__loss: 0.0592 - val_loss: 0.0660
# Epoch 118/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0516 - loss: 0.0584 - val__loss: 0.0584 - val_loss: 0.0652
# Epoch 119/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0505 - loss: 0.0573 - val__loss: 0.0575 - val_loss: 0.0642
# Epoch 120/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0514 - loss: 0.0582 - val__loss: 0.0575 - val_loss: 0.0643
# Epoch 121/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0517 - loss: 0.0585 - val__loss: 0.0599 - val_loss: 0.0667
# Epoch 122/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0530 - loss: 0.0597 - val__loss: 0.0671 - val_loss: 0.0738
# Epoch 123/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0555 - loss: 0.0622 - val__loss: 0.0639 - val_loss: 0.0706
# Epoch 124/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0536 - loss: 0.0603 - val__loss: 0.0602 - val_loss: 0.0669
# Epoch 125/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0523 - loss: 0.0590 - val__loss: 0.0602 - val_loss: 0.0669
# Epoch 126/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0514 - loss: 0.0581 - val__loss: 0.0565 - val_loss: 0.0632
# Epoch 127/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0495 - loss: 0.0562 - val__loss: 0.0539 - val_loss: 0.0605
# Epoch 128/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0480 - loss: 0.0547 - val__loss: 0.0549 - val_loss: 0.0616
# Epoch 129/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0475 - loss: 0.0542 - val__loss: 0.0558 - val_loss: 0.0625
# Epoch 130/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0457 - loss: 0.0524 - val__loss: 0.0512 - val_loss: 0.0579
# Epoch 131/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0438 - loss: 0.0505 - val__loss: 0.0505 - val_loss: 0.0572
# Epoch 132/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0432 - loss: 0.0499 - val__loss: 0.0463 - val_loss: 0.0530
# Epoch 133/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - _loss: 0.0422 - loss: 0.0489 - val__loss: 0.0463 - val_loss: 0.0530
# Epoch 134/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0435 - loss: 0.0502 - val__loss: 0.0442 - val_loss: 0.0509
# Epoch 135/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0435 - loss: 0.0502 - val__loss: 0.0472 - val_loss: 0.0539
# Epoch 136/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0474 - loss: 0.0541 - val__loss: 0.0517 - val_loss: 0.0584
# Epoch 137/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0469 - loss: 0.0536 - val__loss: 0.0504 - val_loss: 0.0571
# Epoch 138/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0455 - loss: 0.0522 - val__loss: 0.0514 - val_loss: 0.0581
# Epoch 139/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0447 - loss: 0.0514 - val__loss: 0.0457 - val_loss: 0.0524
# Epoch 140/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0427 - loss: 0.0494 - val__loss: 0.0480 - val_loss: 0.0547
# Epoch 141/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0423 - loss: 0.0490 - val__loss: 0.0415 - val_loss: 0.0482
# Epoch 142/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0406 - loss: 0.0473 - val__loss: 0.0446 - val_loss: 0.0513
# Epoch 143/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0427 - loss: 0.0494 - val__loss: 0.0477 - val_loss: 0.0544
# Epoch 144/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0444 - loss: 0.0511 - val__loss: 0.0488 - val_loss: 0.0555
# Epoch 145/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - _loss: 0.0426 - loss: 0.0493 - val__loss: 0.0423 - val_loss: 0.0489
# Epoch 146/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0420 - loss: 0.0486 - val__loss: 0.0433 - val_loss: 0.0499
# Epoch 147/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0410 - loss: 0.0477 - val__loss: 0.0427 - val_loss: 0.0493
# Epoch 148/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0404 - loss: 0.0471 - val__loss: 0.0416 - val_loss: 0.0482
# Epoch 149/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0395 - loss: 0.0461 - val__loss: 0.0452 - val_loss: 0.0518
# Epoch 150/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0424 - loss: 0.0490 - val__loss: 0.0460 - val_loss: 0.0526
# Epoch 151/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0406 - loss: 0.0471 - val__loss: 0.0425 - val_loss: 0.0491
# Epoch 152/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0404 - loss: 0.0470 - val__loss: 0.0476 - val_loss: 0.0542
# Epoch 153/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0405 - loss: 0.0471 - val__loss: 0.0429 - val_loss: 0.0495
# Epoch 154/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0403 - loss: 0.0468 - val__loss: 0.0392 - val_loss: 0.0458
# Epoch 155/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0391 - loss: 0.0456 - val__loss: 0.0440 - val_loss: 0.0505
# Epoch 156/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0407 - loss: 0.0472 - val__loss: 0.0433 - val_loss: 0.0498
# Epoch 157/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0410 - loss: 0.0475 - val__loss: 0.0480 - val_loss: 0.0545
# Epoch 158/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0411 - loss: 0.0476 - val__loss: 0.0409 - val_loss: 0.0474
# Epoch 159/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0387 - loss: 0.0451 - val__loss: 0.0451 - val_loss: 0.0516
# Epoch 160/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0404 - loss: 0.0469 - val__loss: 0.0410 - val_loss: 0.0475
# Epoch 161/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0388 - loss: 0.0452 - val__loss: 0.0423 - val_loss: 0.0487
# Epoch 162/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0392 - loss: 0.0456 - val__loss: 0.0430 - val_loss: 0.0494
# Epoch 163/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0392 - loss: 0.0457 - val__loss: 0.0402 - val_loss: 0.0466
# Epoch 164/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0405 - loss: 0.0469 - val__loss: 0.0414 - val_loss: 0.0479
# Epoch 165/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0393 - loss: 0.0457 - val__loss: 0.0455 - val_loss: 0.0519
# Epoch 166/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0431 - loss: 0.0495 - val__loss: 0.0401 - val_loss: 0.0465
# Epoch 167/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0379 - loss: 0.0443 - val__loss: 0.0384 - val_loss: 0.0448
# Epoch 168/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0389 - loss: 0.0453 - val__loss: 0.0409 - val_loss: 0.0473
# Epoch 169/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0394 - loss: 0.0457 - val__loss: 0.0396 - val_loss: 0.0459
# Epoch 170/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0381 - loss: 0.0445 - val__loss: 0.0415 - val_loss: 0.0479
# Epoch 171/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0395 - loss: 0.0458 - val__loss: 0.0373 - val_loss: 0.0436
# Epoch 172/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0378 - loss: 0.0442 - val__loss: 0.0386 - val_loss: 0.0449
# Epoch 173/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0389 - loss: 0.0452 - val__loss: 0.0398 - val_loss: 0.0461
# Epoch 174/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0399 - loss: 0.0462 - val__loss: 0.0494 - val_loss: 0.0557
# Epoch 175/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0429 - loss: 0.0492 - val__loss: 0.0403 - val_loss: 0.0466
# Epoch 176/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0394 - loss: 0.0457 - val__loss: 0.0389 - val_loss: 0.0452
# Epoch 177/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0367 - loss: 0.0430 - val__loss: 0.0411 - val_loss: 0.0474
# Epoch 178/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0367 - loss: 0.0430 - val__loss: 0.0416 - val_loss: 0.0479
# Epoch 179/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0386 - loss: 0.0449 - val__loss: 0.0417 - val_loss: 0.0480
# Epoch 180/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0393 - loss: 0.0456 - val__loss: 0.0402 - val_loss: 0.0465
# Epoch 181/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0394 - loss: 0.0457 - val__loss: 0.0410 - val_loss: 0.0472
# Epoch 182/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0396 - loss: 0.0458 - val__loss: 0.0388 - val_loss: 0.0450
# Epoch 183/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0378 - loss: 0.0441 - val__loss: 0.0388 - val_loss: 0.0450
# Epoch 184/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0372 - loss: 0.0434 - val__loss: 0.0376 - val_loss: 0.0438
# Epoch 185/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0366 - loss: 0.0428 - val__loss: 0.0413 - val_loss: 0.0475
# Epoch 186/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0392 - loss: 0.0454 - val__loss: 0.0400 - val_loss: 0.0462
# Epoch 187/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0391 - loss: 0.0452 - val__loss: 0.0414 - val_loss: 0.0476
# Epoch 188/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - _loss: 0.0395 - loss: 0.0456 - val__loss: 0.0414 - val_loss: 0.0476
# Epoch 189/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0388 - loss: 0.0450 - val__loss: 0.0381 - val_loss: 0.0443
# Epoch 190/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0370 - loss: 0.0431 - val__loss: 0.0355 - val_loss: 0.0416
# Epoch 191/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0359 - loss: 0.0421 - val__loss: 0.0384 - val_loss: 0.0445
# Epoch 192/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0355 - loss: 0.0417 - val__loss: 0.0371 - val_loss: 0.0432
# Epoch 193/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0369 - loss: 0.0430 - val__loss: 0.0390 - val_loss: 0.0452
# Epoch 194/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0359 - loss: 0.0421 - val__loss: 0.0360 - val_loss: 0.0422
# Epoch 195/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0335 - loss: 0.0396 - val__loss: 0.0356 - val_loss: 0.0417
# Epoch 196/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0353 - loss: 0.0414 - val__loss: 0.0411 - val_loss: 0.0472
# Epoch 197/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0379 - loss: 0.0439 - val__loss: 0.0381 - val_loss: 0.0441
# Epoch 198/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0368 - loss: 0.0429 - val__loss: 0.0416 - val_loss: 0.0477
# Epoch 199/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0391 - loss: 0.0452 - val__loss: 0.0433 - val_loss: 0.0494
# Epoch 200/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0379 - loss: 0.0440 - val__loss: 0.0383 - val_loss: 0.0444
# Epoch 201/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0369 - loss: 0.0430 - val__loss: 0.0396 - val_loss: 0.0457
# Epoch 202/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0355 - loss: 0.0416 - val__loss: 0.0382 - val_loss: 0.0442
# Epoch 203/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0380 - loss: 0.0441 - val__loss: 0.0435 - val_loss: 0.0495
# Epoch 204/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0373 - loss: 0.0433 - val__loss: 0.0418 - val_loss: 0.0478
# Epoch 205/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - _loss: 0.0381 - loss: 0.0442 - val__loss: 0.0395 - val_loss: 0.0455
# Epoch 206/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0398 - loss: 0.0458 - val__loss: 0.0399 - val_loss: 0.0459
# Epoch 207/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0353 - loss: 0.0413 - val__loss: 0.0400 - val_loss: 0.0460
# Epoch 208/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0377 - loss: 0.0437 - val__loss: 0.0388 - val_loss: 0.0448
# Epoch 209/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0368 - loss: 0.0428 - val__loss: 0.0351 - val_loss: 0.0411
# Epoch 210/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0341 - loss: 0.0401 - val__loss: 0.0372 - val_loss: 0.0432
# Epoch 211/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0348 - loss: 0.0408 - val__loss: 0.0372 - val_loss: 0.0433
# Epoch 212/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0348 - loss: 0.0408 - val__loss: 0.0419 - val_loss: 0.0480
# Epoch 213/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0381 - loss: 0.0441 - val__loss: 0.0389 - val_loss: 0.0449
# Epoch 214/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0381 - loss: 0.0441 - val__loss: 0.0376 - val_loss: 0.0436
# Epoch 215/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0361 - loss: 0.0420 - val__loss: 0.0388 - val_loss: 0.0447
# Epoch 216/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0375 - loss: 0.0434 - val__loss: 0.0362 - val_loss: 0.0422
# Epoch 217/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0347 - loss: 0.0407 - val__loss: 0.0380 - val_loss: 0.0439
# Epoch 218/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0358 - loss: 0.0418 - val__loss: 0.0381 - val_loss: 0.0440
# Epoch 219/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0362 - loss: 0.0421 - val__loss: 0.0375 - val_loss: 0.0434
# Epoch 220/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0349 - loss: 0.0409 - val__loss: 0.0391 - val_loss: 0.0450
# Epoch 221/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0342 - loss: 0.0401 - val__loss: 0.0371 - val_loss: 0.0430
# Epoch 222/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0344 - loss: 0.0404 - val__loss: 0.0363 - val_loss: 0.0422
# Epoch 223/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0331 - loss: 0.0391 - val__loss: 0.0370 - val_loss: 0.0429
# Epoch 224/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0349 - loss: 0.0409 - val__loss: 0.0381 - val_loss: 0.0441
# Epoch 225/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0343 - loss: 0.0402 - val__loss: 0.0386 - val_loss: 0.0445
# Epoch 226/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0348 - loss: 0.0407 - val__loss: 0.0341 - val_loss: 0.0401
# Epoch 227/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0368 - loss: 0.0427 - val__loss: 0.0418 - val_loss: 0.0477
# Epoch 228/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0366 - loss: 0.0425 - val__loss: 0.0404 - val_loss: 0.0463
# Epoch 229/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0369 - loss: 0.0428 - val__loss: 0.0369 - val_loss: 0.0428
# Epoch 230/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0345 - loss: 0.0404 - val__loss: 0.0375 - val_loss: 0.0434
# Epoch 231/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0328 - loss: 0.0387 - val__loss: 0.0354 - val_loss: 0.0413
# Epoch 232/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0345 - loss: 0.0404 - val__loss: 0.0402 - val_loss: 0.0461
# Epoch 233/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0368 - loss: 0.0427 - val__loss: 0.0405 - val_loss: 0.0464
# Epoch 234/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0380 - loss: 0.0439 - val__loss: 0.0412 - val_loss: 0.0471
# Epoch 235/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0371 - loss: 0.0430 - val__loss: 0.0408 - val_loss: 0.0467
# Epoch 236/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0379 - loss: 0.0438 - val__loss: 0.0400 - val_loss: 0.0459
# Epoch 237/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0358 - loss: 0.0417 - val__loss: 0.0393 - val_loss: 0.0452
# Epoch 238/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0360 - loss: 0.0419 - val__loss: 0.0361 - val_loss: 0.0420
# Epoch 239/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0336 - loss: 0.0395 - val__loss: 0.0368 - val_loss: 0.0426
# Epoch 240/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0350 - loss: 0.0409 - val__loss: 0.0397 - val_loss: 0.0455
# Epoch 241/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0340 - loss: 0.0399 - val__loss: 0.0359 - val_loss: 0.0418
# Epoch 242/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0347 - loss: 0.0406 - val__loss: 0.0352 - val_loss: 0.0410
# Epoch 243/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0320 - loss: 0.0378 - val__loss: 0.0370 - val_loss: 0.0429
# Epoch 244/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0338 - loss: 0.0396 - val__loss: 0.0422 - val_loss: 0.0480
# Epoch 245/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0348 - loss: 0.0406 - val__loss: 0.0362 - val_loss: 0.0419
# Epoch 246/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0344 - loss: 0.0401 - val__loss: 0.0419 - val_loss: 0.0477
# Epoch 247/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0333 - loss: 0.0391 - val__loss: 0.0391 - val_loss: 0.0449
# Epoch 248/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0352 - loss: 0.0410 - val__loss: 0.0352 - val_loss: 0.0409
# Epoch 249/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0347 - loss: 0.0404 - val__loss: 0.0453 - val_loss: 0.0510
# Epoch 250/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0357 - loss: 0.0414 - val__loss: 0.0342 - val_loss: 0.0400
# Epoch 251/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0353 - loss: 0.0411 - val__loss: 0.0354 - val_loss: 0.0412
# Epoch 252/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0338 - loss: 0.0395 - val__loss: 0.0356 - val_loss: 0.0414
# Epoch 253/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0337 - loss: 0.0394 - val__loss: 0.0378 - val_loss: 0.0436
# Epoch 254/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0355 - loss: 0.0413 - val__loss: 0.0402 - val_loss: 0.0459
# Epoch 255/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0344 - loss: 0.0401 - val__loss: 0.0381 - val_loss: 0.0438
# Epoch 256/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0343 - loss: 0.0400 - val__loss: 0.0402 - val_loss: 0.0459
# Epoch 257/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0326 - loss: 0.0383 - val__loss: 0.0390 - val_loss: 0.0447
# Epoch 258/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0342 - loss: 0.0399 - val__loss: 0.0363 - val_loss: 0.0420
# Epoch 259/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0331 - loss: 0.0388 - val__loss: 0.0340 - val_loss: 0.0397
# Epoch 260/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0312 - loss: 0.0369 - val__loss: 0.0334 - val_loss: 0.0391
# Epoch 261/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - _loss: 0.0334 - loss: 0.0391 - val__loss: 0.0343 - val_loss: 0.0400
# Epoch 262/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0320 - loss: 0.0377 - val__loss: 0.0385 - val_loss: 0.0441
# Epoch 263/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0333 - loss: 0.0390 - val__loss: 0.0395 - val_loss: 0.0451
# Epoch 264/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0329 - loss: 0.0386 - val__loss: 0.0348 - val_loss: 0.0405
# Epoch 265/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0309 - loss: 0.0366 - val__loss: 0.0342 - val_loss: 0.0398
# Epoch 266/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0330 - loss: 0.0387 - val__loss: 0.0356 - val_loss: 0.0413
# Epoch 267/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0315 - loss: 0.0371 - val__loss: 0.0341 - val_loss: 0.0397
# Epoch 268/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0350 - loss: 0.0406 - val__loss: 0.0362 - val_loss: 0.0418
# Epoch 269/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0316 - loss: 0.0372 - val__loss: 0.0396 - val_loss: 0.0452
# Epoch 270/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0337 - loss: 0.0393 - val__loss: 0.0374 - val_loss: 0.0430
# Epoch 271/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0310 - loss: 0.0366 - val__loss: 0.0343 - val_loss: 0.0398
# Epoch 272/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0329 - loss: 0.0384 - val__loss: 0.0389 - val_loss: 0.0444
# Epoch 273/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0340 - loss: 0.0395 - val__loss: 0.0356 - val_loss: 0.0411
# Epoch 274/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0327 - loss: 0.0383 - val__loss: 0.0363 - val_loss: 0.0419
# Epoch 275/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0308 - loss: 0.0364 - val__loss: 0.0355 - val_loss: 0.0410
# Epoch 276/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0338 - loss: 0.0394 - val__loss: 0.0375 - val_loss: 0.0430
# Epoch 277/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0323 - loss: 0.0379 - val__loss: 0.0353 - val_loss: 0.0409
# Epoch 278/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0324 - loss: 0.0379 - val__loss: 0.0341 - val_loss: 0.0397
# Epoch 279/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0307 - loss: 0.0362 - val__loss: 0.0343 - val_loss: 0.0398
# Epoch 280/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0315 - loss: 0.0370 - val__loss: 0.0344 - val_loss: 0.0399
# Epoch 281/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0317 - loss: 0.0372 - val__loss: 0.0349 - val_loss: 0.0404
# Epoch 282/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0320 - loss: 0.0375 - val__loss: 0.0358 - val_loss: 0.0413
# Epoch 283/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0319 - loss: 0.0375 - val__loss: 0.0352 - val_loss: 0.0407
# Epoch 284/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0334 - loss: 0.0389 - val__loss: 0.0345 - val_loss: 0.0400
# Epoch 285/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0290 - loss: 0.0345 - val__loss: 0.0354 - val_loss: 0.0409
# Epoch 286/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0309 - loss: 0.0364 - val__loss: 0.0353 - val_loss: 0.0408
# Epoch 287/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0309 - loss: 0.0364 - val__loss: 0.0348 - val_loss: 0.0403
# Epoch 288/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0324 - loss: 0.0379 - val__loss: 0.0357 - val_loss: 0.0412
# Epoch 289/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0303 - loss: 0.0358 - val__loss: 0.0351 - val_loss: 0.0406
# Epoch 290/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0309 - loss: 0.0363 - val__loss: 0.0369 - val_loss: 0.0423
# Epoch 291/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0305 - loss: 0.0359 - val__loss: 0.0343 - val_loss: 0.0398
# Epoch 292/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0320 - loss: 0.0374 - val__loss: 0.0351 - val_loss: 0.0405
# Epoch 293/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0302 - loss: 0.0357 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 294/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0309 - loss: 0.0363 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 295/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0318 - loss: 0.0372 - val__loss: 0.0412 - val_loss: 0.0466
# Epoch 296/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0318 - loss: 0.0372 - val__loss: 0.0398 - val_loss: 0.0452
# Epoch 297/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0338 - loss: 0.0392 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 298/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0337 - loss: 0.0391 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 299/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0314 - loss: 0.0367 - val__loss: 0.0320 - val_loss: 0.0374
# Epoch 300/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0354 - loss: 0.0408 - val__loss: 0.0348 - val_loss: 0.0402
# Epoch 301/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0331 - loss: 0.0385 - val__loss: 0.0362 - val_loss: 0.0415
# Epoch 302/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0316 - loss: 0.0370 - val__loss: 0.0386 - val_loss: 0.0440
# Epoch 303/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0333 - loss: 0.0387 - val__loss: 0.0317 - val_loss: 0.0371
# Epoch 304/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0310 - loss: 0.0364 - val__loss: 0.0359 - val_loss: 0.0413
# Epoch 305/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - _loss: 0.0322 - loss: 0.0377 - val__loss: 0.0364 - val_loss: 0.0418
# Epoch 306/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - _loss: 0.0322 - loss: 0.0376 - val__loss: 0.0376 - val_loss: 0.0430
# Epoch 307/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0323 - loss: 0.0377 - val__loss: 0.0339 - val_loss: 0.0393
# Epoch 308/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0312 - loss: 0.0366 - val__loss: 0.0380 - val_loss: 0.0434
# Epoch 309/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0330 - loss: 0.0384 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 310/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0343 - loss: 0.0397 - val__loss: 0.0388 - val_loss: 0.0442
# Epoch 311/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0306 - loss: 0.0360 - val__loss: 0.0348 - val_loss: 0.0402
# Epoch 312/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0325 - loss: 0.0378 - val__loss: 0.0341 - val_loss: 0.0394
# Epoch 313/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0294 - loss: 0.0348 - val__loss: 0.0334 - val_loss: 0.0387
# Epoch 314/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0316 - loss: 0.0370 - val__loss: 0.0339 - val_loss: 0.0393
# Epoch 315/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0293 - loss: 0.0347 - val__loss: 0.0352 - val_loss: 0.0405
# Epoch 316/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0320 - loss: 0.0374 - val__loss: 0.0388 - val_loss: 0.0442
# Epoch 317/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0320 - loss: 0.0374 - val__loss: 0.0353 - val_loss: 0.0407
# Epoch 318/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0290 - loss: 0.0344 - val__loss: 0.0346 - val_loss: 0.0400
# Epoch 319/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0300 - loss: 0.0354 - val__loss: 0.0374 - val_loss: 0.0428
# Epoch 320/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0290 - loss: 0.0344 - val__loss: 0.0347 - val_loss: 0.0400
# Epoch 321/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - _loss: 0.0360 - loss: 0.0414 - val__loss: 0.0377 - val_loss: 0.0431
# Epoch 322/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0306 - loss: 0.0359 - val__loss: 0.0387 - val_loss: 0.0441
# Epoch 323/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0337 - loss: 0.0391 - val__loss: 0.0342 - val_loss: 0.0396
# Epoch 324/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0315 - loss: 0.0369 - val__loss: 0.0341 - val_loss: 0.0395
# Epoch 325/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0296 - loss: 0.0350 - val__loss: 0.0327 - val_loss: 0.0381
# Epoch 326/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0309 - loss: 0.0362 - val__loss: 0.0357 - val_loss: 0.0411
# Epoch 327/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0330 - loss: 0.0384 - val__loss: 0.0345 - val_loss: 0.0399
# Epoch 328/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0334 - loss: 0.0387 - val__loss: 0.0378 - val_loss: 0.0431
# Epoch 329/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0322 - loss: 0.0375 - val__loss: 0.0341 - val_loss: 0.0395
# Epoch 330/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0328 - loss: 0.0382 - val__loss: 0.0366 - val_loss: 0.0419
# Epoch 331/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0354 - loss: 0.0407 - val__loss: 0.0344 - val_loss: 0.0398
# Epoch 332/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0328 - loss: 0.0381 - val__loss: 0.0391 - val_loss: 0.0445
# Epoch 333/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0351 - loss: 0.0405 - val__loss: 0.0402 - val_loss: 0.0456
# Epoch 334/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0331 - loss: 0.0384 - val__loss: 0.0363 - val_loss: 0.0416
# Epoch 335/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0328 - loss: 0.0382 - val__loss: 0.0387 - val_loss: 0.0441
# Epoch 336/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0319 - loss: 0.0373 - val__loss: 0.0349 - val_loss: 0.0402
# Epoch 337/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0322 - loss: 0.0375 - val__loss: 0.0345 - val_loss: 0.0398
# Epoch 338/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0304 - loss: 0.0357 - val__loss: 0.0367 - val_loss: 0.0420
# Epoch 339/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0294 - loss: 0.0347 - val__loss: 0.0316 - val_loss: 0.0370
# Epoch 340/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0296 - loss: 0.0349 - val__loss: 0.0379 - val_loss: 0.0432
# Epoch 341/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0331 - loss: 0.0385 - val__loss: 0.0376 - val_loss: 0.0429
# Epoch 342/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0312 - loss: 0.0365 - val__loss: 0.0332 - val_loss: 0.0385
# Epoch 343/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0315 - loss: 0.0368 - val__loss: 0.0359 - val_loss: 0.0412
# Epoch 344/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0285 - loss: 0.0338 - val__loss: 0.0349 - val_loss: 0.0402
# Epoch 345/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0320 - loss: 0.0374 - val__loss: 0.0349 - val_loss: 0.0402
# Epoch 346/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0292 - loss: 0.0345 - val__loss: 0.0370 - val_loss: 0.0423
# Epoch 347/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0318 - loss: 0.0371 - val__loss: 0.0381 - val_loss: 0.0434
# Epoch 348/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0312 - loss: 0.0365 - val__loss: 0.0340 - val_loss: 0.0394
# Epoch 349/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0325 - loss: 0.0379 - val__loss: 0.0322 - val_loss: 0.0375
# Epoch 350/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0285 - loss: 0.0338 - val__loss: 0.0331 - val_loss: 0.0385
# Epoch 351/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0296 - loss: 0.0349 - val__loss: 0.0353 - val_loss: 0.0406
# Epoch 352/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0304 - loss: 0.0357 - val__loss: 0.0363 - val_loss: 0.0417
# Epoch 353/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0300 - loss: 0.0354 - val__loss: 0.0349 - val_loss: 0.0403
# Epoch 354/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0300 - loss: 0.0353 - val__loss: 0.0344 - val_loss: 0.0397
# Epoch 355/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0315 - loss: 0.0368 - val__loss: 0.0366 - val_loss: 0.0419
# Epoch 356/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0317 - loss: 0.0370 - val__loss: 0.0374 - val_loss: 0.0427
# Epoch 357/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0304 - loss: 0.0357 - val__loss: 0.0363 - val_loss: 0.0416
# Epoch 358/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0292 - loss: 0.0345 - val__loss: 0.0358 - val_loss: 0.0411
# Epoch 359/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0305 - loss: 0.0358 - val__loss: 0.0328 - val_loss: 0.0381
# Epoch 360/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0303 - loss: 0.0356 - val__loss: 0.0365 - val_loss: 0.0418
# Epoch 361/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0308 - loss: 0.0361 - val__loss: 0.0339 - val_loss: 0.0392
# Epoch 362/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0295 - loss: 0.0348 - val__loss: 0.0350 - val_loss: 0.0403
# Epoch 363/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0317 - loss: 0.0370 - val__loss: 0.0326 - val_loss: 0.0379
# Epoch 364/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0290 - loss: 0.0343 - val__loss: 0.0344 - val_loss: 0.0397
# Epoch 365/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0302 - loss: 0.0355 - val__loss: 0.0324 - val_loss: 0.0377
# Epoch 366/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0283 - loss: 0.0336 - val__loss: 0.0316 - val_loss: 0.0369
# Epoch 367/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - _loss: 0.0282 - loss: 0.0335 - val__loss: 0.0363 - val_loss: 0.0416
# Epoch 368/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0280 - loss: 0.0332 - val__loss: 0.0334 - val_loss: 0.0387
# Epoch 369/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0291 - loss: 0.0344 - val__loss: 0.0329 - val_loss: 0.0382
# Epoch 370/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0307 - loss: 0.0359 - val__loss: 0.0398 - val_loss: 0.0451
# Epoch 371/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0291 - loss: 0.0344 - val__loss: 0.0324 - val_loss: 0.0377
# Epoch 372/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0287 - loss: 0.0339 - val__loss: 0.0327 - val_loss: 0.0380
# Epoch 373/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0291 - loss: 0.0343 - val__loss: 0.0348 - val_loss: 0.0401
# Epoch 374/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - _loss: 0.0302 - loss: 0.0354 - val__loss: 0.0307 - val_loss: 0.0359
# Epoch 375/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0290 - loss: 0.0342 - val__loss: 0.0355 - val_loss: 0.0407
# Epoch 376/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0301 - loss: 0.0354 - val__loss: 0.0321 - val_loss: 0.0374
# Epoch 377/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - _loss: 0.0285 - loss: 0.0338 - val__loss: 0.0365 - val_loss: 0.0417
# Epoch 378/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0286 - loss: 0.0338 - val__loss: 0.0283 - val_loss: 0.0335
# Epoch 379/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - _loss: 0.0287 - loss: 0.0340 - val__loss: 0.0289 - val_loss: 0.0341
# Epoch 380/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0288 - loss: 0.0341 - val__loss: 0.0362 - val_loss: 0.0414
# Epoch 381/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0305 - loss: 0.0358 - val__loss: 0.0345 - val_loss: 0.0397
# Epoch 382/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0330 - loss: 0.0382 - val__loss: 0.0306 - val_loss: 0.0358
# Epoch 383/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0343 - loss: 0.0395 - val__loss: 0.0390 - val_loss: 0.0443
# Epoch 384/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0316 - loss: 0.0369 - val__loss: 0.0374 - val_loss: 0.0426
# Epoch 385/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0390 - loss: 0.0442 - val__loss: 0.0398 - val_loss: 0.0450
# Epoch 386/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0323 - loss: 0.0376 - val__loss: 0.0379 - val_loss: 0.0432
# Epoch 387/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0319 - loss: 0.0372 - val__loss: 0.0357 - val_loss: 0.0410
# Epoch 388/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0301 - loss: 0.0354 - val__loss: 0.0368 - val_loss: 0.0420
# Epoch 389/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0295 - loss: 0.0348 - val__loss: 0.0371 - val_loss: 0.0424
# Epoch 390/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0291 - loss: 0.0345 - val__loss: 0.0332 - val_loss: 0.0385
# Epoch 391/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0281 - loss: 0.0334 - val__loss: 0.0338 - val_loss: 0.0392
# Epoch 392/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0279 - loss: 0.0333 - val__loss: 0.0373 - val_loss: 0.0426
# Epoch 393/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0286 - loss: 0.0339 - val__loss: 0.0307 - val_loss: 0.0361
# Epoch 394/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0309 - loss: 0.0363 - val__loss: 0.0371 - val_loss: 0.0424
# Epoch 395/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - _loss: 0.0294 - loss: 0.0347 - val__loss: 0.0339 - val_loss: 0.0393
# Epoch 396/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - _loss: 0.0305 - loss: 0.0358 - val__loss: 0.0368 - val_loss: 0.0421
# Epoch 397/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0288 - loss: 0.0341 - val__loss: 0.0322 - val_loss: 0.0375
# Epoch 398/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0303 - loss: 0.0356 - val__loss: 0.0380 - val_loss: 0.0433
# Epoch 399/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - _loss: 0.0300 - loss: 0.0353 - val__loss: 0.0325 - val_loss: 0.0378
# Epoch 400/400
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - _loss: 0.0298 - loss: 0.0351 - val__loss: 0.0307 - val_loss: 0.0360

# %%
#I needed to restart the kernal and skip the block above to run this block-otherwise i got memory allocation error. 
#theres probably a better way to do this--like clearing the memory before running this block so you can run both models sequentially

if 'Try Both' in ENCODING_TYPE and KERAS_TUNER:
    # Clear TF graph + Python refs BEFORE building the next model
    tf.keras.backend.clear_session()
    gc.collect()

    best_hp_onehot = tuner_one_hot_encoding.get_best_hyperparameters(1)[0]
    model_onehot = tuner_one_hot_encoding.hypermodel.build(best_hp_onehot)

    lr_monitor_one_hot_encoding = LearningRateMonitor()  # make learning rate monitor
    
    history_one_hot_encoding = model_onehot.fit(
        np.asarray(X_train_one_hot_encoding),
        {"value_out": np.asarray(y_train_one_hot_encoding)},
        epochs=EPOCHS,
        batch_size=TRAIN_BATCH_SIZE,
        validation_data=(
            np.asarray(X_val_one_hot_encoding),
            {"value_out": np.asarray(y_val_one_hot_encoding)},
        ),
        callbacks=[early_stopping, lr_monitor_one_hot_encoding],
        verbose=1
    )

    # Free memory after training this model too
    del model_onehot
    tf.keras.backend.clear_session()
    gc.collect()

    plt.plot(history_one_hot_encoding.history['loss'])
    plt.plot(history_one_hot_encoding.history['val_loss'])
    plt.title('Model loss one hot encoding')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='best')
    plt.tight_layout()
    plt.savefig('plots/one_hot_encoding_history.pdf')
    plt.show()
    
    plt.plot(lr_monitor_one_hot_encoding.learning_rates)
    plt.title("Learning Rate over Epochs one hot encoding")
    plt.xlabel("Epoch")
    plt.ylabel("Learning Rate")
    plt.tight_layout()
    plt.savefig('plots/one_hot_encoding_learning_rate.pdf')
    plt.show()

# %% [markdown]
# Measure and print metrics.

# %%
#take a look at the loss results and save them 

# clear everything so we start with a blank slate memory wise
tf.keras.backend.clear_session()                         #clear tf backend
gc.collect()                                             #just collect stray things
#tf.config.experimental.reset_memory_stats('GPU:0')       #clear gpus


def get_loss(eval_out):
    # eval_out can be float, list/tuple/ndarray, or dict
    if isinstance(eval_out, dict):
        return float(eval_out.get('loss', list(eval_out.values())[0]))
    if isinstance(eval_out, (list, tuple, np.ndarray)):
        return float(eval_out[0])
    return float(eval_out)

def mlp_signature(m, prefix="mlp"):
    #get the model input sizze first
    in_shape = m.input_shape
    if isinstance(in_shape, list):     #just get the first one
        in_shape = in_shape[0]
    dims = [d for d in in_shape[1:] if d is not None]
    input_size = int(np.prod(dims)) if dims else "None"

    # now get the dense laysers in order
    dense_units = [l.units for l in m.layers if isinstance(l, Dense)]

    parts = [prefix, str(input_size)] + [str(u) for u in dense_units]
    return "_".join(parts)

    
if 'Try Both' not in ENCODING_TYPE:
    model = load_model(best_model_file, compile=False)
    model.compile(
        optimizer='adam',
        loss={'value_out': VALUE_LOSS_FN},
        metrics={'value_out': [VALUE_LOSS_FN]}
    )

    test_loss_result = model.evaluate(
        np.asarray(X_test),
        {'value_out': np.asarray(y_test)},
        verbose=0
    )

    test_loss_result = get_loss(test_loss_result)
    
    #save the shape for the next block so we can save it using the definition above
    model_shape = mlp_signature(model)

    print('Current loss {} encoding {}: {}'.format(encoding, TRAIN_LOSS, test_loss_result))
    
    results_df = pd.DataFrame([
        {'Encoding Type': f'{ENCODING_TYPE} Encoding', 'Train Loss Metric': TRAIN_LOSS, 'Test Loss': test_loss_result},
        ])

else:
    # we need to do some fancy allocation of recources if we are going to load both models
    # do the first on one GPU
    linear_model = load_model(best_model_file_linear, compile=False)
    linear_model.compile(
        optimizer='adam',
        loss={'value_out': VALUE_LOSS_FN}
    )
    test_loss_result_linear_encoding = linear_model.evaluate(
        np.asarray(X_test_linear_encoding),
        {'value_out': np.asarray(y_test_linear_encoding)},
        verbose=0
    )

    test_loss_result_linear_encoding = get_loss(test_loss_result_linear_encoding)
    
    # now do on CPU to avoid GPU allocation
    with tf.device('/CPU:0'):
        onehot_model = load_model(best_model_file_onehot, compile=False)
        onehot_model.compile(
            optimizer='adam',
            loss={'value_out': VALUE_LOSS_FN}
        )
        test_loss_result_one_hot_encoding = onehot_model.evaluate(
            np.asarray(X_test_one_hot_encoding),
            {'value_out': np.asarray(y_test_one_hot_encoding)},
            verbose=0
        )
        test_loss_result_one_hot_encoding = get_loss(test_loss_result_one_hot_encoding)

    #save the shape for the next block so we can save it using the definition above
    model_shape_one_hot_encoding = mlp_signature(onehot_model)
    model_shape_linear_encoding  = mlp_signature(linear_model)
    
    print('Current loss linear encoding {}: {}'.format(TRAIN_LOSS, test_loss_result_linear_encoding))
    print('Current loss one hot encoding {}: {}'.format(TRAIN_LOSS, test_loss_result_one_hot_encoding))
    
    results_df = pd.DataFrame([
        {'Encoding Type': 'linear Encoding', 'Train Loss Metric': TRAIN_LOSS, 'Test Loss': test_loss_result_linear_encoding},
        {'Encoding Type': 'One Hot Encoding', 'Train Loss Metric': TRAIN_LOSS, 'Test Loss': test_loss_result_one_hot_encoding}
    ])

print(results_df.to_string(index=False))
results_df.to_csv('test_loss_results.csv', index=False)
# Out:
# Current loss one_hot encoding mae: 0.03342903032898903
#    Encoding Type Train Loss Metric  Test Loss
# one hot Encoding               mae   0.033429

# %% [markdown]
# ## Compare predictions vs. test set

# %%
import csv
if 'Try Both' not in ENCODING_TYPE:
    csv_data = [[
        DATA_AUGMENTATION,
        model_shape,
        ENCODING_TYPE,
        test_loss_result,
        TRAIN_LOSS,
        TRAIN_DROPOUT_RATE,
        TRAIN_EARLY_STOPPING_PATIENCE,
        TRAIN_BATCH_SIZE,
        '0.15/0.15',
        LR_INITIAL,
        LR_DECAY_STEPS,
        LR_DECAY_RATE,
        LR_STAIRCASE
        ]]
    
    csv_file = 'history_losses.csv'  #this doesnt reqrite this file so you need to delete this if you want something fresh
    
    if not os.path.exists(csv_file):
        with open(csv_file, 'w') as file:
            file.write('data_augmentation,model_shape,encoding_type,test_loss,train_loss,train_dropout_rate,train_early_stop_patience,'+
                        'train_batch_size,train_val_split,lr_initial,lr_decay_step,lr_decay_rate,lr_stair_case\n')
    
    with open(csv_file, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(csv_data)
    
    # Convert data to DataFrame for easier display
    df = pd.read_csv(csv_file)
    
    def color_red_column(s):
        return ['color: red' if v else '' for v in s]
    
    styled_df = df.style.apply(color_red_column, subset=['test_loss'])
    
    # Display the DataFrame as a table
    display(styled_df)
    #qgrid_widget = qgrid.show_grid(df, show_toolbar=True)

else:
    #---------------------------------------------------one hot---------------------------------------
    csv_data = [[
        DATA_AUGMENTATION,
        model_shape_one_hot_encoding,
        'One Hot',
        test_loss_result_one_hot_encoding,
        TRAIN_LOSS,
        TRAIN_DROPOUT_RATE,
        TRAIN_EARLY_STOPPING_PATIENCE,
        TRAIN_BATCH_SIZE,
        '0.15/0.15',
        LR_INITIAL,
        LR_DECAY_STEPS,
        LR_DECAY_RATE,
        LR_STAIRCASE
        ]]
    
    csv_file = 'history_losses.csv'  #this doesnt reqrite this file so you need to delete this if you want something fresh
    
    if not os.path.exists(csv_file):
        with open(csv_file, 'w') as file:
            file.write('data_augmentation,model_shape,encoding_type,test_loss,train_loss,train_dropout_rate,train_early_stop_patience,'+
                        'train_batch_size,train_val_split,lr_initial,lr_decay_step,lr_decay_rate,lr_stair_case\n')
            
    with open(csv_file, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(csv_data)
    
    # Convert data to DataFrame for easier display
    df_one_hot_encoding = pd.read_csv(csv_file)
    
    def color_red_column(s):
        return ['color: red' if v else '' for v in s]
    
    styled_df_one_hot_encoding = df_one_hot_encoding.style.apply(color_red_column, subset=['test_loss'])
    #---------------------------------------------------linear---------------------------------------
    csv_data_linear_encoding = [[
        DATA_AUGMENTATION,
        model_shape_linear_encoding,
        'linear',
        test_loss_result_linear_encoding,
        TRAIN_LOSS,
        TRAIN_DROPOUT_RATE,
        TRAIN_EARLY_STOPPING_PATIENCE,
        TRAIN_BATCH_SIZE,
        '0.15/0.15',
        LR_INITIAL,
        LR_DECAY_STEPS,
        LR_DECAY_RATE,
        LR_STAIRCASE
        ]]
    
    csv_file_linear_encoding = 'history_losses.csv'  #this doesnt reqrite this file so you need to delete this if you want something fresh
    
    with open(csv_file_linear_encoding, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(csv_data_linear_encoding)
    
    # Convert data to DataFrame for easier display
    df_linear_encoding = pd.read_csv(csv_file_linear_encoding)
    
    def color_red_column(s):
        return ['color: red' if v else '' for v in s]
    
    styled_df_linear_encoding = df_linear_encoding.style.apply(color_red_column, subset=['test_loss'])
    
    # Display the DataFrame as a table
    display(styled_df_linear_encoding)
    #qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
# Out:
# <style type="text/css">
# #T_e3728_row0_col3, #T_e3728_row1_col3, #T_e3728_row2_col3, #T_e3728_row3_col3, #T_e3728_row4_col3, #T_e3728_row5_col3, #T_e3728_row6_col3, #T_e3728_row7_col3, #T_e3728_row8_col3, #T_e3728_row9_col3, #T_e3728_row10_col3, #T_e3728_row11_col3, #T_e3728_row12_col3, #T_e3728_row13_col3, #T_e3728_row14_col3, #T_e3728_row15_col3, #T_e3728_row16_col3, #T_e3728_row17_col3, #T_e3728_row18_col3, #T_e3728_row19_col3, #T_e3728_row20_col3, #T_e3728_row21_col3, #T_e3728_row22_col3, #T_e3728_row23_col3, #T_e3728_row24_col3, #T_e3728_row25_col3, #T_e3728_row26_col3, #T_e3728_row27_col3 {
#   color: red;
# }
# </style>
# <table id="T_e3728">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3728_level0_col0" class="col_heading level0 col0" >data_augmentation</th>
#       <th id="T_e3728_level0_col1" class="col_heading level0 col1" >model_shape</th>
#       <th id="T_e3728_level0_col2" class="col_heading level0 col2" >encoding_type</th>
#       <th id="T_e3728_level0_col3" class="col_heading level0 col3" >test_loss</th>
#       <th id="T_e3728_level0_col4" class="col_heading level0 col4" >train_loss</th>
#       <th id="T_e3728_level0_col5" class="col_heading level0 col5" >train_dropout_rate</th>
#       <th id="T_e3728_level0_col6" class="col_heading level0 col6" >train_early_stop_patience</th>
#       <th id="T_e3728_level0_col7" class="col_heading level0 col7" >train_batch_size</th>
#       <th id="T_e3728_level0_col8" class="col_heading level0 col8" >train_val_split</th>
#       <th id="T_e3728_level0_col9" class="col_heading level0 col9" >lr_initial</th>
#       <th id="T_e3728_level0_col10" class="col_heading level0 col10" >lr_decay_step</th>
#       <th id="T_e3728_level0_col11" class="col_heading level0 col11" >lr_decay_rate</th>
#       <th id="T_e3728_level0_col12" class="col_heading level0 col12" >lr_stair_case</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3728_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3728_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_e3728_row0_col1" class="data row0 col1" >mlp_2_1500_2800_1300_2100_45</td>
#       <td id="T_e3728_row0_col2" class="data row0 col2" >One Hot</td>
#       <td id="T_e3728_row0_col3" class="data row0 col3" >0.026580</td>
#       <td id="T_e3728_row0_col4" class="data row0 col4" >mean_squared_error</td>
#       <td id="T_e3728_row0_col5" class="data row0 col5" >0.400000</td>
#       <td id="T_e3728_row0_col6" class="data row0 col6" >50</td>
#       <td id="T_e3728_row0_col7" class="data row0 col7" >32</td>
#       <td id="T_e3728_row0_col8" class="data row0 col8" >0.15/0.15</td>
#       <td id="T_e3728_row0_col9" class="data row0 col9" >0.001456</td>
#       <td id="T_e3728_row0_col10" class="data row0 col10" >100</td>
#       <td id="T_e3728_row0_col11" class="data row0 col11" >0.990000</td>
#       <td id="T_e3728_row0_col12" class="data row0 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3728_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3728_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_e3728_row1_col1" class="data row1 col1" >mlp_2_600_100_2600_5000_45</td>
#       <td id="T_e3728_row1_col2" class="data row1 col2" >Linear</td>
#       <td id="T_e3728_row1_col3" class="data row1 col3" >0.027197</td>
#       <td id="T_e3728_row1_col4" class="data row1 col4" >mean_squared_error</td>
#       <td id="T_e3728_row1_col5" class="data row1 col5" >0.400000</td>
#       <td id="T_e3728_row1_col6" class="data row1 col6" >50</td>
#       <td id="T_e3728_row1_col7" class="data row1 col7" >32</td>
#       <td id="T_e3728_row1_col8" class="data row1 col8" >0.15/0.15</td>
#       <td id="T_e3728_row1_col9" class="data row1 col9" >0.001456</td>
#       <td id="T_e3728_row1_col10" class="data row1 col10" >100</td>
#       <td id="T_e3728_row1_col11" class="data row1 col11" >0.990000</td>
#       <td id="T_e3728_row1_col12" class="data row1 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3728_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3728_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_e3728_row2_col1" class="data row2 col1" >mlp_2_1500_2800_1300_2100_45</td>
#       <td id="T_e3728_row2_col2" class="data row2 col2" >one hot</td>
#       <td id="T_e3728_row2_col3" class="data row2 col3" >0.026581</td>
#       <td id="T_e3728_row2_col4" class="data row2 col4" >mean_squared_error</td>
#       <td id="T_e3728_row2_col5" class="data row2 col5" >0.400000</td>
#       <td id="T_e3728_row2_col6" class="data row2 col6" >50</td>
#       <td id="T_e3728_row2_col7" class="data row2 col7" >32</td>
#       <td id="T_e3728_row2_col8" class="data row2 col8" >0.15/0.15</td>
#       <td id="T_e3728_row2_col9" class="data row2 col9" >0.001456</td>
#       <td id="T_e3728_row2_col10" class="data row2 col10" >100</td>
#       <td id="T_e3728_row2_col11" class="data row2 col11" >0.990000</td>
#       <td id="T_e3728_row2_col12" class="data row2 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3728_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3728_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_e3728_row3_col1" class="data row3 col1" >mlp_2_3300_200_4600_1700_45</td>
#       <td id="T_e3728_row3_col2" class="data row3 col2" >one hot</td>
#       <td id="T_e3728_row3_col3" class="data row3 col3" >0.023184</td>
#       <td id="T_e3728_row3_col4" class="data row3 col4" >mean_squared_error</td>
#       <td id="T_e3728_row3_col5" class="data row3 col5" >0.400000</td>
#       <td id="T_e3728_row3_col6" class="data row3 col6" >50</td>
#       <td id="T_e3728_row3_col7" class="data row3 col7" >32</td>
#       <td id="T_e3728_row3_col8" class="data row3 col8" >0.15/0.15</td>
#       <td id="T_e3728_row3_col9" class="data row3 col9" >0.001456</td>
#       <td id="T_e3728_row3_col10" class="data row3 col10" >100</td>
#       <td id="T_e3728_row3_col11" class="data row3 col11" >0.990000</td>
#       <td id="T_e3728_row3_col12" class="data row3 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3728_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3728_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_e3728_row4_col1" class="data row4 col1" >mlp_2_3300_200_4600_1700_45</td>
#       <td id="T_e3728_row4_col2" class="data row4 col2" >one hot</td>
#       <td id="T_e3728_row4_col3" class="data row4 col3" >0.023925</td>
#       <td id="T_e3728_row4_col4" class="data row4 col4" >mean_squared_error</td>
#       <td id="T_e3728_row4_col5" class="data row4 col5" >0.400000</td>
#       <td id="T_e3728_row4_col6" class="data row4 col6" >50</td>
#       <td id="T_e3728_row4_col7" class="data row4 col7" >32</td>
#       <td id="T_e3728_row4_col8" class="data row4 col8" >0.15/0.15</td>
#       <td id="T_e3728_row4_col9" class="data row4 col9" >0.001456</td>
#       <td id="T_e3728_row4_col10" class="data row4 col10" >100</td>
#       <td id="T_e3728_row4_col11" class="data row4 col11" >0.990000</td>
#       <td id="T_e3728_row4_col12" class="data row4 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3728_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3728_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_e3728_row5_col1" class="data row5 col1" >mlp_2_700_3800_400_1800_16</td>
#       <td id="T_e3728_row5_col2" class="data row5 col2" >one hot</td>
#       <td id="T_e3728_row5_col3" class="data row5 col3" >0.045630</td>
#       <td id="T_e3728_row5_col4" class="data row5 col4" >mean_squared_error</td>
#       <td id="T_e3728_row5_col5" class="data row5 col5" >0.400000</td>
#       <td id="T_e3728_row5_col6" class="data row5 col6" >50</td>
#       <td id="T_e3728_row5_col7" class="data row5 col7" >32</td>
#       <td id="T_e3728_row5_col8" class="data row5 col8" >0.15/0.15</td>
#       <td id="T_e3728_row5_col9" class="data row5 col9" >0.001456</td>
#       <td id="T_e3728_row5_col10" class="data row5 col10" >100</td>
#       <td id="T_e3728_row5_col11" class="data row5 col11" >0.990000</td>
#       <td id="T_e37

# %%
# Decide which model file & test set to use
if 'Try Both' not in ENCODING_TYPE:
    chosen_path = best_model_file
    X_test_cur = np.asarray(X_test)
    y_test_cur = np.asarray(y_test)
else:
    if test_loss_result_linear_encoding < test_loss_result_one_hot_encoding:
        chosen_path = best_model_file_linear
        X_test_cur = np.asarray(X_test_linear_encoding)
        y_test_cur = np.asarray(y_test_linear_encoding)
        y_encoding_format_name = 'linear'
    else:
        chosen_path = best_model_file_onehot
        X_test_cur = np.asarray(X_test_one_hot_encoding)
        y_test_cur = np.asarray(y_test_one_hot_encoding)
        y_encoding_format_name = 'one_hot'

# clear everything again, then load & predict on one cpu device to avoid the memory thing again
tf.keras.backend.clear_session()
gc.collect()

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    pred = chosen_model.predict(X_test_cur, verbose=0)

# Unpack model outputs into proper numeric arrays
if isinstance(pred, dict):
    y_pred = np.asarray(pred['value_out'])
else:
    y_pred = np.asarray(pred)

# %%
#now lets look at a specfic case to see how the model predicts things
if 'Try Both' not in ENCODING_TYPE:
    y_encoding_format_name = encoding
    
y_value_meta = Path(f"y_characteristics_{y_encoding_format_name}_encoding.csv")
# y_exists_meta = Path(f"y_exists_characteristics_{y_encoding_format_name}_encoding.csv")

headers_value = pd.read_csv(y_value_meta, nrows=0).columns.tolist()

# shape must match
assert len(headers_value) == y_test_cur.shape[1], (
    f"Header/value mismatch: {len(headers_value)} vs {y_test_cur.shape[1]}"
)
headers = headers_value

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred = np.asarray(y_pred)

n_samples, n_params = y_test_cur.shape
#change nsamples if you dont want to look at everything
n_samples = 3

# raw errors
sq_errors = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# make a nice dataframe so the output is comprehensible
rows = []
for i in range(n_samples):
    cav_freq, kappa = X_test_cur[i, 0], X_test_cur[i, 1]
    for j in range(n_params):
        rows.append({
            "sample_idx": i,
            "cavity_frequency": cav_freq,
            "kappa": kappa,
            "param": headers[j],
            "ref": y_test_cur[i, j],
            "pred": y_pred[i, j],
            "abs_error": abs_errors[i, j],
            "sq_error": sq_errors[i, j],
        })

df = pd.DataFrame(rows)

#save it incase we want to do stuff with this in the future
out_csv = Path(f"predictions_and_errors_{y_encoding_format_name}.csv")
df.to_csv(out_csv, index=False, float_format="%.6g")
print(f"\nSaved CSV -> {out_csv.resolve()}\n")

# print it out nicely 
for i in range(n_samples):
    sub = df[df["sample_idx"] == i].copy()
    sub = sub[["param", "ref", "pred", "abs_error", "sq_error"]]
    header_line = (
        f"— Sample {i} — "
        f"X: cavity_frequency={X_test_cur[i,0]:.6g}, kappa={X_test_cur[i,1]:.6g}"
    )
    print(header_line)
    print(sub.to_string(index=False))
    print() 

# (Optional) quick global stats
print("Global error stats:")
print("  min abs_error:", float(np.min(abs_errors)))
print("  median abs_error:", float(np.median(abs_errors)))
print("  max abs_error:", float(np.max(abs_errors)))

''' 
Here onehot/linear encoding and the mlp which maps categorical data to 1s and 0s is probably 
throwing off the global average. These will be rounded in the future and will probably always 
round to the right number to reconstruct the correct category-- but for now it might throw off 
the overall average error. In the future we might want to just have it consider the non categorical 
data when finding an overall average and reporting that number.
'''
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_cavity_claw_RouteMeander_eigenmode/predictions_and_errors_one_hot.csv
#
# — Sample 0 — X: cavity_frequency=0.287346, kappa=0.0044512
#                                                           param      ref      pred  abs_error     sq_error
#    design_options.claw_opts.connection_pads.readout.claw_length 0.571429  0.579318   0.007889 6.223818e-05
# design_options.claw_opts.connection_pads.readout.ground_spacing 0.000000  0.000316   0.000316 9.976627e-08
#                            design_options.cpw_opts.total_length 0.600000  0.603239   0.003239 1.048919e-05
#                       design_options.cpw_opts.meander.asymmetry 0.521739  0.529111   0.007372 5.434838e-05
#                        design_options.cplr_opts.coupling_length 0.000000 -0.002457   0.002457 6.034837e-06
#
# — Sample 1 — X: cavity_frequency=0.711785, kappa=0.150955
#                                                           param      ref     pred  abs_error  sq_error
#    design_options.claw_opts.connection_pads.readout.claw_length 0.413793 0.405533   0.008260  0.000068
# design_options.claw_opts.connection_pads.readout.ground_spacing 0.000000 0.002699   0.002699  0.000007
#                            design_options.cpw_opts.total_length 0.000000 0.011039   0.011039  0.000122
#                       design_options.cpw_opts.meander.asymmetry 0.391304 0.594570   0.203265  0.041317
#                        design_options.cplr_opts.coupling_length 0.250000 0.242469   0.007531  0.000057
#
# — Sample 2 — X: cavity_frequency=0.579751, kappa=0.493966
#                                                           param      ref     pred  abs_error  sq_error
#    design_options.claw_opts.connection_pads.readout.claw_length 0.571429 0.576144   0.004716  0.000022
# design_options.claw_opts.connection_pads.readout.ground_spacing 0.000000 0.001942   0.001942  0.000004
#                            design_options.cpw_opts.total_length 0.000000 0.009973   0.009973  0.000099
#                       design_options.cpw_opts.meander.asymmetry 0.956522 0.973679   0.017158  0.000294
#                        design_options.cplr_opts.coupling_length 0.625000 0.630006   0.005006  0.000025
#
# Global error stats:
#   min abs_error: 0.0
#   median abs_error: 0.004689928110972075
#   max abs_error: 0.8025168776512146
# ' \nHere onehot/linear encoding and the mlp which maps categorical data to 1s and 0s is probably \nthrowing off the global average. These will be rounded in the future and will probably always \nround to the right number to reconstruct the correct category-- but for now it might throw off \nthe overall average error. In the future we might want to just have it consider the non categorical \ndata when finding an overall average and reporting that number.\n'

# %% [markdown]
# ### Unscaled test vs predictions

# %%
#unscale everything and look at errors again. 
#You can compare the unscaled actual values to the ml_00...py notebook to convice yourself that unscaling worked

with open('X_names', 'r') as f:
    X_index_names = f.read().splitlines()

# unscaling x
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        scaler = joblib.load(f'scalers/scaler_X_{X_index_names[j]}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# unscaling y (value head only)
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        scaler = joblib.load(f'scalers/scaler_y_value__{headers[j]}_{y_encoding_format_name}_encoding.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# unscaling y predictions (value head only)
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        scaler = joblib.load(f'scalers/scaler_y_value__{headers[j]}_{y_encoding_format_name}_encoding.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape
n_samples = 3 

# find how good or bad we did (the errors)
sq_errors_unscaled = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# mask out parameters that are not defined according to ground-truth exists flag
sq_errors_unscaled_masked = sq_errors_unscaled
abs_errors_unscaled_masked = abs_errors_unscaled

# making a nice fancy dataframe, we like fancy things
rows_unscaled = []
for i in range(n_samples):
    cav_freq, kappa = X_test_unscaled[i, 0], X_test_unscaled[i, 1]
    for j in range(n_params):
        rows_unscaled.append({
            "sample_idx": i,
            "cavity_frequency": cav_freq,
            "kappa": kappa,
            "param": headers[j],
            "ref_unscaled": y_test_unscaled[i, j],
            "pred_unscaled": y_pred_unscaled[i, j],
            "abs_error_unscaled": abs_errors_unscaled_masked[i, j],
            "sq_error_unscaled": sq_errors_unscaled_masked[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# save csv of unscaled results uncase we lose this notebook due to github blowing up, ya never know
out_csv_unscaled = Path(f"predictions_and_errors_unscaled_{y_encoding_format_name}.csv")
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format="%.6g")
print(f"\nSaved CSV -> {out_csv_unscaled.resolve()}\n")

# print out stuff so you can see it here if you are to lazy like me to open a csv
for i in range(n_samples):
    sub = df_unscaled[df_unscaled["sample_idx"] == i].copy()
    sub = sub[["param", "ref_unscaled", "pred_unscaled", "abs_error_unscaled", "sq_error_unscaled"]]
    header_line = (
        f"— Sample {i} (Unscaled) — "
        f"X: cavity_frequency={X_test_unscaled[i,0]:.6g}, kappa={X_test_unscaled[i,1]:.6g}"
    )
    print(header_line)
    print(sub.to_string(index=False))
    print()

# look at overall stats, see below comment for a caviat 
print("Global unscaled error stats (defined parameters only):")
print("  min abs_error:", float(np.min(abs_errors_unscaled_masked)))
print("  median abs_error:", float(np.median(abs_errors_unscaled_masked)))
print("  max abs_error:", float(np.max(abs_errors_unscaled_masked)))

'''
Here onehot/linear encoding and the MLP which maps categorical data to 1s and 0s is probably 
throwing off the global average. These will be rounded in the future and will probably always 
round to the right number to reconstruct the correct category-- but for now it might throw off 
the overall average error. In the future we might want to just have it consider the non-categorical 
data when finding an overall average and reporting that number.
'''
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_cavity_claw_RouteMeander_eigenmode/predictions_and_errors_unscaled_one_hot.csv
#
# — Sample 0 (Unscaled) — X: cavity_frequency=6.19193e+09, kappa=24653.2
#                                                           param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#    design_options.claw_opts.connection_pads.readout.claw_length      0.000360       0.000364        4.003732e-06       1.602987e-11
# design_options.claw_opts.connection_pads.readout.ground_spacing      0.000004       0.000004        1.863396e-09       3.472247e-18
#                            design_options.cpw_opts.total_length      0.003900       0.003906        6.477243e-06       4.195467e-11
#                       design_options.cpw_opts.meander.asymmetry     -0.000050      -0.000047        2.825987e-06       7.986202e-12
#                        design_options.cplr_opts.coupling_length      0.000100       0.000099        9.826352e-07       9.655718e-13
#
# — Sample 1 (Unscaled) — X: cavity_frequency=8.34374e+09, kappa=166528
#                                                           param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#    design_options.claw_opts.connection_pads.readout.claw_length      0.000280       0.000276        4.191963e-06       1.757255e-11
# design_options.claw_opts.connection_pads.readout.ground_spacing      0.000004       0.000004        1.592328e-08       2.535507e-16
#                            design_options.cpw_opts.total_length      0.002700       0.002722        2.207800e-05       4.874382e-10
#                       design_options.cpw_opts.meander.asymmetry     -0.000100      -0.000022        7.791833e-05       6.071267e-09
#                        design_options.cplr_opts.coupling_length      0.000200       0.000197        3.012310e-06       9.074010e-12
#
# — Sample 2 (Unscaled) — X: cavity_frequency=7.67436e+09, kappa=498701
#                                                           param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#    design_options.claw_opts.connection_pads.readout.claw_length      0.000360       0.000362        2.393126e-06       5.727053e-12
# design_options.claw_opts.connection_pads.readout.ground_spacing      0.000004       0.000004        1.145629e-08       1.312466e-16
#                            design_options.cpw_opts.total_length      0.002700       0.002720        1.994667e-05       3.978697e-10
#                       design_options.cpw_opts.meander.asymmetry      0.000117       0.000123        6.577069e-06       4.325783e-11
#                        design_options.cplr_opts.coupling_length      0.000350       0.000352        2.002506e-06       4.010029e-12
#
# Global unscaled error stats (defined parameters only):
#   min abs_error: 1.0104849953746636e-11
#   median abs_error: 2.716662846505676e-06
#   max abs_error: 0.0004201434321701525
# '\nHere onehot/linear encoding and the MLP which maps categorical data to 1s and 0s is probably \nthrowing off the global average. These will be rounded in the future and will probably always \nround to the right number to reconstruct the correct category-- but for now it might throw off \nthe overall average error. In the future we might want to just have it consider the non-categorical \ndata when finding an overall average and reporting that number.\n'
