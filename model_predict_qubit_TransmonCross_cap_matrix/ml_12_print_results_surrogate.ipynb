# %% [markdown]
# # Model Predictions (qubit_TransmonCross_cap_matrix)
# ## Qiskit Metal --> Capacitance
#
# Ansys surrogate model

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters_surrogate import *

# %% [markdown]
# ## Library

# %%
import os, gc, math
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
def load_scaled_split(kind, split):
    return np.load(f"{DATA_DIR}/npy/{split}_{kind}_encoding_scaled.npy", allow_pickle=True)

# new inputs are our Qiskit Metal params, using good ole linear encoding
X_train = load_scaled_split('linear', 'y_train')
X_val   = load_scaled_split('linear', 'y_val')
X_test  = load_scaled_split('linear', 'y_test')

# new outputs are the capacitance values
y_train = load_scaled_split('linear', 'x_train')
y_val   = load_scaled_split('linear', 'x_val')
y_test  = load_scaled_split('linear', 'x_test')

# load column name files for later reference fer outputs
with open('X_names', 'r') as f:
    cap_column_names = f.read().splitlines()   

# input names
qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist() 

#check to make sure these printouts make sense and we arent flippered
print(f'Inputs (Qiskit params):  {X_train.shape[1]} columns')
print(f'Outputs (Capacitance):    {y_train.shape[1]} columns')
print(f'\nInput columns:  {qiskit_param_names}')
print(f'Output columns: {cap_column_names}')
# Out:
# Inputs (Qiskit params):  3 columns
# Outputs (Capacitance):    6 columns
#
# Input columns:  ['design_options.connection_pads.readout.claw_length', 'design_options.connection_pads.readout.ground_spacing', 'design_options.cross_length']
# Output columns: ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']

# %% [markdown]
# ### Visualize model

# %%
# Decide which model file to use
encoding = 'model2_surrogate'
chosen_path = f'model/best_keras_model_model2_surrogate.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

# Load output headers (capacitance column names)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Output headers: {headers}')
# Out:
# Model path: model/best_keras_model_model2_surrogate.keras
# Output headers: ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']

# %%
#look at the best model, ooh so pretty
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    y_pred = chosen_model.predict(X_test_cur, verbose=0)

print(f'\n—— {os.path.basename(chosen_path)} ——')
chosen_model.summary()
print(f'Samples: {len(X_test_cur)} | Targets dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771990509.163599  423382 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1064 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:10.0, compute capability: 8.0
# I0000 00:00:1771990509.364809  424063 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# —— best_keras_model_model2_surrogate.keras ——
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 160)            │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │           966 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,606 (6.27 KB)
#  Trainable params: 1,606 (6.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 291 | Targets dim: 6

# %%
# look at some more specific model params
m = tf.keras.models.load_model(chosen_path, compile=True)

neurons_per_layer = [
    l.units for l in m.layers
    if isinstance(l, tf.keras.layers.Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

dropouts = [
    (l.name, float(l.rate)) for l in m.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')

opt = getattr(m, 'optimizer', None)
if opt is None:
    print('Best learning rate: (no optimizer found on loaded model)')
else:
    lr_obj = opt.learning_rate

    if isinstance(lr_obj, tf.keras.optimizers.schedules.LearningRateSchedule):
        print('Best learning rate: (schedule)', type(lr_obj).__name__)
        try:
            cfg = lr_obj.get_config()
            print('LR schedule config:')
            for k, v in sorted(cfg.items()):
                print(f'  {k}: {v}')
        except Exception as e:
            print('Could not read LR schedule config:', repr(e))
        try:
            step = int(tf.keras.backend.get_value(opt.iterations))
            current_lr = float(lr_obj(step).numpy())
            print(f'Current LR at step {step}:', current_lr)
        except Exception as e:
            print('Could not compute current LR from schedule:', repr(e))
    else:
        try:
            lr_val = float(tf.keras.backend.get_value(lr_obj))
            print('Best learning rate:', lr_val)
        except Exception as e:
            print('Best learning rate: (unreadable)', repr(e))
# Out:
# Best NEURONS_PER_LAYER: [160]
# Best DROPOUT rate(s): [('dropout0', 0.05)]
# Best learning rate: 0.03198777511715889
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50 # change this to print more stuff

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred     = np.asarray(y_pred)

N, P = y_test_cur.shape

# make sure y_pred shape matches
if y_pred.ndim == 3 and y_pred.shape[-1] == 1:
    y_pred = y_pred[..., 0]
if y_pred.ndim == 1:
    y_pred = y_pred.reshape(-1, 1)
assert y_pred.shape == (N, P), f'y_pred shape {y_pred.shape} != expected {(N, P)}'

# scaled errors
sq_errors  = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# building dataframe
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  y_test_cur[i, j],
            'pred': y_pred[i, j],
            'abs_error': abs_errors[i, j],
            'sq_error':  sq_errors[i, j],
        })

df = pd.DataFrame(rows)

# save scaled predictions
out_csv = Path(f'model2_predictions_and_errors_{encoding}.csv')
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

# Pretty print per-sample (scaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    input_str = ', '.join(
        f'{qiskit_param_names[k] if k < len(qiskit_param_names) else f"in_{k}"}={X_test_cur[i,k]:.6g}'
        for k in range(X_test_cur.shape[1])
    )
    print(f'— Sample {i} — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global scaled error stats:')
print('  min abs_error:', float(abs_errors.min()))
print('  median abs_error:', float(np.median(abs_errors)))
print('  max abs_error:', float(abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/model2_predictions_and_errors_model2_surrogate.csv
#
# — Sample 0 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.515152
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.486726 0.485759   0.000967 9.355963e-07
#   claw_to_ground 0.332857 0.331766   0.001091 1.189963e-06
#    cross_to_claw 0.333689 0.325222   0.008467 7.169478e-05
#   cross_to_cross 0.486726 0.486254   0.000473 2.234384e-07
#     claw_to_claw 0.339616 0.337742   0.001873 3.509473e-06
# ground_to_ground 0.442740 0.440823   0.001917 3.673852e-06
#
# — Sample 1 — Inputs: design_options.connection_pads.readout.claw_length=0.0909091, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.606061
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.568657 0.568265   0.000392 1.538193e-07
#   claw_to_ground 0.118193 0.114969   0.003223 1.038930e-05
#    cross_to_claw 0.051998 0.054600   0.002602 6.770506e-06
#   cross_to_cross 0.568657 0.567977   0.000680 4.623582e-07
#     claw_to_claw 0.111141 0.107484   0.003656 1.336920e-05
# ground_to_ground 0.415697 0.414958   0.000739 5.460807e-07
#
# — Sample 2 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.272727
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.239722 0.248682   0.008960 8.028116e-05
#   claw_to_ground 0.109517 0.110114   0.000597 3.558525e-07
#    cross_to_claw 0.165374 0.159923   0.005452 2.972132e-05
#   cross_to_cross 0.239722 0.248109   0.008387 7.034670e-05
#     claw_to_claw 0.114911 0.114304   0.000607 3.684788e-07
# ground_to_ground 0.195275 0.200361   0.005087 2.587351e-05
#
# — Sample 3 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.363636
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.345244 0.350120   0.004876 2.377629e-05
#   claw_to_ground 0.192985 0.193954   0.000969 9.383782e-07
#    cross_to_claw 0.205119 0.204106   0.001013 1.025396e-06
#   cross_to_cross 0.345244 0.349949   0.004706 2.214430e-05
#     claw_to_claw 0.196844 0.196830   0.000014 1.843196e-10
# ground_to_ground 0.294791 0.298373   0.003582 1.283184e-05
#
# — Sample 4 — Inputs: design_options.connection_pads.readout.claw_length=0.0606061, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.212121
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.202381 0.214626   0.012246  0.000150
#   claw_to_ground 0.080307 0.084258   0.003951  0.000016
#    cross_to_claw 0.111293 0.112822   0.001530  0.000002
#   cross_to_cross 0.202381 0.213958   0.011577  0.000134
#     claw_to_claw 0.082236 0.085382   0.003145  0.000010
# ground_to_ground 0.158240 0.166692   0.008452  0.000071
#
# — Sample 5 — Inputs: design_options.connection_pads.readout.claw_length=0.0909091, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.484848
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.471814 0.472874   0.001060  0.000001
#   claw_to_ground 0.110928 0.114498   0.003570  0.000013
#    cross_to_claw 0.120708 0.123133   0.002424  0.000006
#   cross_to_cross 0.471814 0.472892   0.001078  0.000001
#     claw_to_claw 0.111184 0.114104   0.002920  0.000009
# ground_to_ground 0.347032 0.349481   0.002448  0.000006
#
# — Sample 6 — Inputs: design_options.connection_pads.readout.claw_length=0.212121, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.424242
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.409661 0.408361   0.001301 1.691424e-06
#   claw_to_ground 0.248461 0.249394   0.000933 8.705532e-07
#    cross_to_claw 0.155454 0.159634   0.004180 1.747077e-05
#   cross_to_cross 0.409661 0.408771   0.000891 7.935166e-07
#     claw_to_claw 0.243760 0.244448   0.000687 4.726012e-07
# ground_to_ground 0.358368 0.358364   0.000004 1.926320e-11
#
# — Sample 7 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.757576
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.716106 0.715340   0.000766 5.873635e-07
#   claw_to_ground 0.005657 0.007246   0.001589 2.523348e-06
#    cross_to_claw 0.049830 0.051318   0.001488 2.215573e-06
#   cross_to_cross 0.716106 0.715664   0.000442 1.957050e-07
#     claw_to_claw 0.005583 0.005999   0.000415 1.725693e-07
# ground_to_ground 0.469783 0.470969   0.001186 1.406148e-06
#
# — Sample 8 — Inputs: design_options.connection_pads.readout.claw_length=0.575758, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.787879
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.725292 0.726649   0.001357  0.000002
#   claw_to_ground 0.565051 0.571975   0.006923  0.000048
#    cross_to_claw 0.360801 0.364528   0.003727  0.000014
#   cross_to_cross 0.725292 0.728318   0.003027  0.000009
#     claw_to_claw 0.559253 0.566592   0.007339  0.000054
# ground_to_ground 0.689142 0.691991   0.002849  0.000008
#
# — Sample 9 — Inputs: design_options.connection_pads.readout.claw_length=0.151515, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.484848
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.475451 0.472117   0.003334  0.000011
#   claw_to_ground 0.195778 0.189996   0.005782  0.000033
#    cross_to_claw 0.111282 0.114803   0.003521  0.000012
#   cross_to_cross 0.475451 0.472470   0.002981  0.000009
#     claw_to_claw 0.189464 0.184203   0.005261  0.000028
# ground_to_ground 0.381446 0.378527   0.002919  0.000009
#
# — Sample 10 — Inputs: design_options.connection_pads.readout.claw_length=0.030303, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.606061
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.597472 0.592142   0.005330 2.841285e-05
#   claw_to_ground 0.055336 0.060369   0.005033 2.532943e-05
#    cross_to_claw 0.070012 0.078090   0.008079 6.526780e-05
#   cross_to_cross 0.597472 0.592138   0.005334 2.845098e-05
#     claw_to_claw 0.054058 0.058711   0.004653 2.164868e-05
# ground_to_ground 0.408613 0.407927   0.000686 4.704660e-07
#
# — Sample 11 — Inputs: design_options.connection_pads.readout.claw_length=0.30303, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.515152
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.488788 0.488546   0.000243 5.886498e-08
#   claw_to_ground 0.305407 0.304322   0.001085 1.177312e-06
#    cross_to_claw 0.304667 0.298640   0.006027 3.632611e-05
#   cross_to_cross 0.488788 0.488952   0.000163 2.662359e-08
#     claw_to_claw 0.311031 0.309420   0.001612 2.597236e-06
# ground_to_ground 0.433640 0.431552   0.002088 4.359605e-06
#
# — Sample 12 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.575758
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.533250 0.532707   0.000543 2.943372e-07
#   claw_to_ground 0.112940 0.112288   0.000652 4.249591e-07
#    cross_to_claw 0.147654 0.149471   0.001817 3.302772e-06
#   cross_to_cross 0.533250 0.532958   0.000292 8.530477e-08
#     claw_to_claw 0.115663 0.114643   0.001020 1.040742e-06
# ground_to_ground 0.391134 0.389934   0.001200 1.440666e-06
#
# — Sample 13 — Inputs: design_options.connection_pads.readout.claw_length=0.454545, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.939394
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.917929 0.903002   0.014927  0.000223
#   claw_to_ground 0.487229 0.474754   0.012475  0.000156
#    cross_to_claw 0.282345 0.280158   0.002186  0.000005
#   cross_to_cross 0.917929 0.904110   0.013819  0.000191
#     claw_to_claw 0.478485 0.467080   0.011405  0.000130
# ground_to_ground 0.781127 0.770777   0.010350  0.000107
#
# — Sample 14 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.151515
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.132011 0.146017   0.014006  0.000196
#   claw_to_ground 0.002703 0.008865   0.006162  0.000038
#    cross_to_claw 0.068873 0.072806   0.003933  0.000015
#   cross_to_cross 0.132011 0.144974   0.012963  0.000168
#     claw_to_claw 0.005543 0.011107   0.005564  0.000031
# ground_to_ground 0.082652 0.092805   0.010152  0.000103
#
# — Sample 15 — Inputs: design_options.connection_pads.readout.claw_length=0.848485, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=1
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.942876 0.951064   0.008189  0.000067
#   claw_to_ground 0.795840 0.798691   0.002851  0.000008
#    cross_to_claw 0.827238 0.823798   0.003439  0.000012
#   cross_to_cross 0.942876 0.954585   0.011710  0.000137
#     claw_to_claw 0.820564 0.824204   0.003640  0.000013
# ground_to_ground 0.916598 0.924757   0.008159  0.000067
#
# — Sample 16 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0
#            param       ref      pred  abs_error     sq_error
#  cross_to_ground -0.009019 -0.046582   0.037563 1.410977e-03
#   claw_to_ground -0.001285 -0.026467   0.025182 6.341503e-04
#    cross_to_claw  0.102722  0.102181   0.000542 2.933423e-07
#   cross_to_cross -0.009019 -0.040972   0.031953 1.021015e-03
#     claw_to_claw  0.005781 -0.020910   0.026691 7.124084e-04
# ground_to_ground -0.013951 -0.049052   0.035101 1.232060e-03
#
# — Sample 17 — Inputs: design_options.connection_pads.readout.claw_length=0.030303, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.151515
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.134756 0.141194   0.006438 4.144926e-05
#   claw_to_ground 0.059336 0.060359   0.001023 1.046855e-06
#    cross_to_claw 0.035844 0.039893   0.004049 1.639204e-05
#   cross_to_cross 0.134756 0.141216   0.006460 4.173718e-05
#     claw_to_claw 0.055225 0.055928   0.000703 4.939097e-07
# ground_to_ground 0.106649 0.110766   0.004117 1.695099e-05
#
# — Sample 18 — Inputs: design_options.connection_pads.readout.claw_length=0.636364, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.969697
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.925295 0.924799   0.000496 2.456003e-07
#   claw_to_ground 0.603840 0.605928   0.002088 4.361373e-06
#    cross_to_claw 0.615412 0.607574   0.007838 6.143600e-05
#   cross_to_cross 0.925295 0.926309   0.001015 1.029579e-06
#     claw_to_claw 0.620342 0.623552   0.003210 1.030357e-05
# ground_to_ground 0.831788 0.833947   0.002159 4.661016e-06
#
# — Sample 19 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.515152
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.459715 0.458473   0.001242 1.542490e-06
#   claw_to_ground 0.297220 0.296855   0.000365 1.335885e-07
#    cross_to_claw 0.344106 0.339257   0.004849 2.351063e-05
#   cross_to_cross 0.459715 0.458890   0.000825 6.813727e-07
#     claw_to_claw 0.307416 0.307329   0.000087 7.564686e-09
# ground_to_ground 0.413454 0.411131   0.002323 5.397041e-06
#
# — Sample 20 — Inputs: design_options.connection_pads.readout.claw_length=0.727273, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.939394
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.891126 0.880966   0.010159  0.000103
#   claw_to_ground 0.687122 0.677296   0.009826  0.000097
#    cross_to_claw 0.710181 0.691475   0.018706  0.000350
#   cross_to_cross 0.891126 0.883038   0.008088  0.000065
#     claw_to_claw 0.707411 0.698524   0.008887  0.000079
# ground_to_ground 0.842361 0.832850   0.009511  0.000090
#
# — Sample 21 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.212121
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.202373 0.211442   0.009070 8.226133e-05
#   claw_to_ground 0.159411 0.159797   0.000385 1.485320e-07
#    cross_to_claw 0.110617 0.109108   0.001508 2.275059e-06
#   cross_to_cross 0.202373 0.211258   0.008885 7.894347e-05
#     claw_to_claw 0.156303 0.155810   0.000493 2.433378e-07
# ground_to_ground 0.187902 0.193317   0.005415 2.932359e-05
#
# — Sample 22 — Inputs: design_options.connection_pads.readout.claw_length=0.545455, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.727273
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.690080 0.687186   0.002894  0.000008
#   claw_to_ground 0.530881 0.527933   0.002948  0.000009
#    cross_to_claw 0.512295 0.500830   0.011465  0.000131
#   cross_to_cross 0.690080 0.688180   0.001900  0.000004
#     claw_to_claw 0.541992 0.538954   0.003038  0.000009
# ground_to_ground 0.650914 0.647447   0.003467  0.000012
#
# — Sample 23 — Inputs: design_options.connection_pads.readout.claw_length=0.393939, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.787879
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.768000 0.759714   0.008286  0.000069
#   claw_to_ground 0.424016 0.418448   0.005568  0.000031
#    cross_to_claw 0.266492 0.264091   0.002401  0.000006
#   cross_to_cross 0.768000 0.760438   0.007562  0.000057
#     claw_to_claw 0.417928 0.413189   0.004739  0.000022
# ground_to_ground 0.660838 0.654177   0.006660  0.000044
#
# — Sample 24 — Inputs: design_options.connection_pads.readout.claw_length=0.212121, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.272727
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.251434 0.262835   0.011401 1.299782e-04
#   claw_to_ground 0.217736 0.218873   0.001137 1.293180e-06
#    cross_to_claw 0.253574 0.255716   0.002142 4.589435e-06
#   cross_to_cross 0.251434 0.262272   0.010838 1.174670e-04
#     claw_to_claw 0.224982 0.225931   0.000948 8.991724e-07
# ground_to_ground 0.243345 0.249484   0.006139 3.768217e-05
#
# — Sample 25 — Inputs: design_options.connection_pads.readout.claw_length=0.515152, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.909091
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.872704 0.853508   0.019196  0.000368
#   claw_to_ground 0.493030 0.482587   0.010443  0.000109
#    cross_to_claw 0.503275 0.492851   0.010424  0.000109
#   cross_to_cross 0.872704 0.854822   0.017882  0.000320
#     claw_to_claw 0.505818 0.496429   0.009388  0.000088
# ground_to_ground 0.756324 0.741024   0.015300  0.000234
#
# — Sample 26 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.818182
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.753493 0.748793   0.004700 2.208575e-05
#   claw_to_ground 0.382811 0.383613   0.000802 6.429369e-07
#    cross_to_claw 0.405561 0.404705   0.000856 7.326436e-07
#   cross_to_cross 0.753493 0.749847   0.003646 1.329575e-05
#     claw_to_claw 0.393197 0.394890   0.001693 2.866563e-06
# ground_to_ground 0.638737 0.635418   0.003318 1.101034e-05
#
# — Sample 27 — Inputs: design_options.connection_pads.readout.claw_length=0.545455, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.545455
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.501089 0.503553   0.002465 6.075435e-06
#   claw_to_ground 0.523028 0.520046   0.002982 8.892513e-06
#    cross_to_claw 0.576329 0.551610   0.024719 6.110413e-04
#   cross_to_cross 0.501089 0.504084   0.002995 8.970164e-06
#     claw_to_claw 0.541770 0.537206   0.004565 2.083568e-05
# ground_to_ground 0.524667 0.524302   0.000365 1.332775e-07
#
# — Sample 28 — Inputs: design_options.connection_pads.readout.claw_length=0.545455, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.575758
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.541798 0.539644   0.002154  0.000005
#   claw_to_ground 0.562624 0.554205   0.008418  0.000071
#    cross_to_claw 0.420279 0.424519   0.004240  0.000018
#   cross_to_cross 0.541798 0.540568   0.001229  0.000002
#     claw_to_claw 0.563381 0.556180   0.007202  0.000052
# ground_to_ground 0.564738 0.560150   0.004588  0.000021
#
# — Sample 29 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.636364
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.599330 0.596551   0.002779  0.000008
#   claw_to_ground 0.147673 0.143372   0.004300  0.000018
#    cross_to_claw 0.068813 0.071938   0.003125  0.000010
#   cross_to_cross 0.599330 0.596494   0.002837  0.000008
#     claw_to_claw 0.140389 0.135876   0.004512  0.000020
# ground_to_ground 0.446727 0.444181   0.002546  0.000006
#
# — Sample 30 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.606061
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.563456 0.562668   0.000788 6.212557e-07
#   claw_to_ground 0.113649 0.112494   0.001155 1.334713e-06
#    cross_to_claw 0.147264 0.149470   0.002205 4.862978e-06
#   cross_to_cross 0.563456 0.563014   0.000442 1.949550e-07
#     claw_to_claw 0.116366 0.114781   0.001584 2.510408e-06
# ground_to_ground 0.410518 0.410374   0.000144 2.068607e-08
#
# — Sample 31 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.666667
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.654750 0.649968   0.004782  0.000023
#   claw_to_ground 0.221304 0.219614   0.001690  0.000003
#    cross_to_claw 0.124458 0.126324   0.001866  0.000003
#   cross_to_cross 0.654750 0.650359   0.004392  0.000019
#     claw_to_claw 0.214333 0.212911   0.001421  0.000002
# ground_to_ground 0.509216 0.506794   0.002422  0.000006
#
# — Sample 32 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.666667
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.608084 0.610039   0.001955 3.821939e-06
#   claw_to_ground 0.299349 0.300777   0.001428 2.040128e-06
#    cross_to_claw 0.329689 0.329601   0.000089 7.904631e-09
#   cross_to_cross 0.608084 0.610764   0.002679 7.179254e-06
#     claw_to_claw 0.307841 0.309708   0.001867 3.487451e-06
# ground_to_ground 0.511702 0.512777   0.001075 1.154877e-06
#
# — Sample 33 — Inputs: design_options.connection_pads.readout.claw_length=0.030303, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.0909091
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.073345 0.085398   0.012053  0.000145
#   claw_to_ground 0.027923 0.032602   0.004679  0.000022
#    cross_to_claw 0.105816 0.116233   0.010417  0.000109
#   cross_to_cross 0.073345 0.084111   0.010766  0.000116
#     claw_to_claw 0.033140 0.037953   0.004813  0.000023
# ground_to_ground 0.052779 0.061517   0.008738  0.000076
#
# — Sample 34 — Inputs: design_options.connection_pads.readout.claw_length=0.242424, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.666667
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.651676 0.647791   0.003885 1.509585e-05
#   claw_to_ground 0.278998 0.278821   0.000176 3.106661e-08
#    cross_to_claw 0.165402 0.166691   0.001289 1.662546e-06
#   cross_to_cross 0.651676 0.648299   0.003377 1.140272e-05
#     claw_to_claw 0.272336 0.272446   0.000109 1.196362e-08
# ground_to_ground 0.529156 0.527276   0.001880 3.533914e-06
#
# — Sample 35 — Inputs: design_options.connection_pads.readout.claw_length=0.393939, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.69697
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.634838 0.635406   0.000568 3.226812e-07
#   claw_to_ground 0.353608 0.354313   0.000705 4.977090e-07
#    cross_to_claw 0.383906 0.383047   0.000859 7.379984e-07
#   cross_to_cross 0.634838 0.636253   0.001415 2.001473e-06
#     claw_to_claw 0.364234 0.365314   0.001079 1.165002e-06
# ground_to_ground 0.548552 0.549778   0.001226 1.503925e-06
#
# — Sample 36 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.636364
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.614330 0.610325   0.004005 1.603855e-05
#   claw_to_ground 0.455792 0.448233   0.007558 5.712712e-05
#    cross_to_claw 0.297193 0.298055   0.000862 7.435776e-07
#   cross_to_cross 0.614330 0.611280   0.003050 9.302558e-06
#     claw_to_claw 0.451349 0.444386   0.006963 4.848662e-05
# ground_to_ground 0.571021 0.566970   0.004051 1.641146e-05
#
# — Sample 37 — Inputs: design_options.connection_pads.readout.claw_length=0.151515, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.818182
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.811485 0.799525   0.011960 1.430328e-04
#   claw_to_ground 0.194001 0.191255   0.002746 7.541613e-06
#    cross_to_claw 0.101129 0.100653   0.000476 2.261610e-07
#   cross_to_cross 0.811485 0.799983   0.011502 1.322985e-04
#     claw_to_claw 0.186254 0.183631   0.002623 6.881763e-06
# ground_to_ground 0.601232 0.594804   0.006428 4.132219e-05
#
# — Sample 38 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.575758
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.534790 0.533506   0.001285 1.650205e-06
#   claw_to_ground 0.201489 0.200300   0.001189 1.414294e-06
#    cross_to_claw 0.107891 0.111048   0.003157 9.966405e-06
#   cross_to_cross 0.534790 0.533881   0.000910 8.273186e-07
#     claw_to_claw 0.194643 0.193247   0.001395 1.946761e-06
# ground_to_ground 0.425505 0.423720   0.001785 3.186629e-06
#
# — Sample 39 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.818182
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.767509 0.769338   0.001829  0.000003
#   claw_to_ground 0.343787 0.345164   0.001377  0.000002
#    cross_to_claw 0.195615 0.196944   0.001329  0.000002
#   cross_to_cross 0.767509 0.770301   0.002792  0.000008
#     claw_to_claw 0.335825 0.337509   0.001683  0.000003
# ground_to_ground 0.631981 0.634077   0.002096  0.000004
#
# — Sample 40 — Inputs: design_options.connection_pads.readout.claw_length=0.575758, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.848485
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.771335 0.772430   0.001095  0.000001
#   claw_to_ground 0.513315 0.519906   0.006590  0.000043
#    cross_to_claw 0.539221 0.542326   0.003105  0.000010
#   cross_to_cross 0.771335 0.773820   0.002485  0.000006
#     claw_to_claw 0.528965 0.536529   0.007563  0.000057
# ground_to_ground 0.700258 0.702658   0.002400  0.000006
#
# — Sample 41 — Inputs: design_options.connection_pads.readout.claw_length=0.30303, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.30303
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.273747 0.287090   0.013344  0.000178
#   claw_to_ground 0.298716 0.302294   0.003578  0.000013
#    cross_to_claw 0.364832 0.351270   0.013562  0.000184
#   cross_to_cross 0.273747 0.286534   0.012787  0.000164
#     claw_to_claw 0.311758 0.313691   0.001933  0.000004
# ground_to_ground 0.288918 0.297727   0.008809  0.000078
#
# — Sample 42 — Inputs: design_options.connection_pads.readout.claw_length=0.242424, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.636364
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.617744 0.614098   0.003647  0.000013
#   claw_to_ground 0.252306 0.251240   0.001065  0.000001
#    cross_to_claw 0.241833 0.238720   0.003113  0.000010
#   cross_to_cross 0.617744 0.614570   0.003174  0.000010
#     claw_to_claw 0.255228 0.253424   0.001804  0.000003
# ground_to_ground 0.497259 0.495054   0.002205  0.000005
#
# — Sample 43 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.454545
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.421622 0.428009   0.006387  0.000041
#   claw_to_ground 0.005276 0.011451   0.006175  0.000038
#    cross_to_claw 0.055988 0.053254   0.002734  0.000007
#   cross_to_cross 0.421622 0.427855   0.006233  0.000039
#     claw_to_claw 0.005749 0.011010   0.005261  0.000028
# ground_to_ground 0.275457 0.281192   0.005735  0.000033
#
# — Sample 44 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.545455
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.499898 0.501743   0.001845 3.403068e-06
#   claw_to_ground 0.166051 0.165203   0.000848 7.185457e-07
#    cross_to_claw 0.200627 0.202584   0.001957 3.830511e-06
#   cross_to_cross 0.499898 0.502027   0.002129 4.532620e-06
#     claw_to_claw 0.170539 0.169551   0.000988 9.761056e-07
# ground_to_ground 0.390008 0.389446   0.000562 3.159122e-07
#
# — Sample 45 — Inputs: design_options.connection_pads.readout.claw_length=0.242424, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.333333
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.315866 0.321890   0.006025 3.629722e-05
#   claw_to_ground 0.274294 0.275636   0.001342 1.800843e-06
#    cross_to_claw 0.190783 0.190825   0.000042 1.746013e-09
#   cross_to_cross 0.315866 0.322140   0.006275 3.937110e-05
#     claw_to_claw 0.271615 0.272578   0.000963 9.275901e-07
# ground_to_ground 0.306559 0.311064   0.004505 2.029502e-05
#
# — Sample 46 — Inputs: design_options.connection_pads.readout.claw_length=0.69697, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.878788
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.793547 0.805727   0.012180  0.000148
#   claw_to_ground 0.620552 0.633393   0.012841  0.000165
#    cross_to_claw 0.658440 0.656764   0.001676  0.000003
#   cross_to_cross 0.793547 0.807555   0.014008  0.000196
#     claw_to_claw 0.640584 0.654199   0.013615  0.000185
# ground_to_ground 0.755254 0.767504   0.012249  0.000150
#
# — Sample 47 — Inputs: design_options.connection_pads.readout.claw_length=0.272727, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.757576
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.710157 0.711595   0.001438 2.068694e-06
#   claw_to_ground 0.287530 0.288139   0.000608 3.702347e-07
#    cross_to_claw 0.158300 0.159030   0.000731 5.338232e-07
#   cross_to_cross 0.710157 0.712430   0.002273 5.168150e-06
#     claw_to_claw 0.279898 0.280211   0.000313 9.788489e-08
# ground_to_ground 0.573021 0.574325   0.001304 1.701476e-06
#
# — Sample 48 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.424242
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.388436 0.395153   0.006717 4.511753e-05
#   claw_to_ground 0.415531 0.406879   0.008653 7.486592e-05
#    cross_to_claw 0.470388 0.445892   0.024495 6.000292e-04
#   cross_to_cross 0.388436 0.395243   0.006807 4.633878e-05
#     claw_to_claw 0.431202 0.420592   0.010611 1.125859e-04
# ground_to_ground 0.408667 0.409319   0.000653 4.258154e-07
#
# — Sample 49 — Inputs: design_options.connection_pads.readout.claw_length=0.363636, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.636364
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.576431 0.579452   0.003021  0.000009
#   claw_to_ground 0.324808 0.326356   0.001548  0.000002
#    cross_to_claw 0.360080 0.358960   0.001119  0.000001
#   cross_to_cross 0.576431 0.580190   0.003759  0.000014
#     claw_to_claw 0.335047 0.336736   0.001689  0.000003
# ground_to_ground 0.500103 0.502428   0.002324  0.000005
#
# Global scaled error stats:
#   min abs_error: 4.388986216907753e-06
#   median abs_error: 0.0028856356657991356
#   max abs_error: 0.03756298021895621

# %% [markdown]
# # Unscaled

# %%
# Unscale everything and look at errors in real units that we can actually understand

# Load output capacitance column names
with open('X_names', 'r') as f:
    cap_names = f.read().splitlines()  

qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

# Unscale inputs
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        param_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_linear_{param_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale outputs 
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# Unscale predictions using same X scalers
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape

# Errrs
sq_errors_unscaled  = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# Build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': y_test_unscaled[i, j],
            'pred_unscaled': y_pred_unscaled[i, j],
            'abs_error_unscaled': abs_errors_unscaled[i, j],
            'sq_error_unscaled': sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# Save
out_csv_unscaled = Path(f'model2_predictions_and_errors_unscaled_{encoding}.csv')
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

# Pretty print per-sample 
for i in range(N_SAMPLES_TO_SHOW):
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    input_str = ', '.join(
        f'{qiskit_names[k] if k < len(qiskit_names) else f"col_{k}"}={X_test_unscaled[i,k]:.6g}'
        for k in range(X_test_unscaled.shape[1])
    )
    print(f'— Sample {i} (Unscaled) — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global unscaled error stats:')
print('  min abs_error:', float(abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(abs_errors_unscaled)))
print('  max abs_error:', float(abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/model2_predictions_and_errors_unscaled_model2_surrogate.csv
#
# — Sample 0 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00018, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00026
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     133.51715     133.336380            0.180770           0.032678
#   claw_to_ground      96.70298      96.566833            0.136147           0.018536
#    cross_to_claw       5.98705       5.875684            0.111366           0.012402
#   cross_to_cross     133.51715     133.428802            0.088348           0.007805
#     claw_to_claw     103.12264     102.871796            0.250844           0.062923
# ground_to_ground     287.80599     287.170715            0.635275           0.403574
#
# — Sample 1 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0001, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00029
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     148.82923     148.755936            0.073294           0.005372
#   claw_to_ground      69.91185      69.509575            0.402275           0.161825
#    cross_to_claw       2.28210       2.316323            0.034223           0.001171
#   cross_to_cross     148.82923     148.702148            0.127082           0.016150
#     claw_to_claw      72.52964      72.040047            0.489593           0.239702
# ground_to_ground     278.84301     278.598083            0.244927           0.059989
#
# — Sample 2 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00018
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      87.35435      89.028885            1.674535           2.804067
#   claw_to_ground      68.82915      68.903603            0.074453           0.005543
#    cross_to_claw       3.77328       3.701576            0.071704           0.005141
#   cross_to_cross      87.35435      88.921860            1.567510           2.457087
#     claw_to_claw      73.03445      72.953171            0.081279           0.006606
# ground_to_ground     205.78769     207.473557            1.685867           2.842146
#
# — Sample 3 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00013, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00021
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     107.07535     107.986649            0.911299           0.830465
#   claw_to_ground      79.24633      79.367226            0.120896           0.014616
#    cross_to_claw       4.29602       4.282701            0.013319           0.000177
#   cross_to_cross     107.07535     107.954819            0.879469           0.773465
#     claw_to_claw      84.00537      84.003555            0.001815           0.000003
# ground_to_ground     238.77069     239.957932            1.187242           1.409542
#
# — Sample 4 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=9e-05, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00016
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      80.37558      82.664177            2.288597           5.237676
#   claw_to_ground      65.18354      65.676613            0.493073           0.243121
#    cross_to_claw       3.06197       3.082091            0.020121           0.000405
#   cross_to_cross      80.37558      82.539246            2.163666           4.681449
#     claw_to_claw      68.65929      69.080444            0.421154           0.177371
# ground_to_ground     193.51323     196.314346            2.801116           7.846253
#
# — Sample 5 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0001, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00025
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     130.73017     130.928284            0.198114           0.039249
#   claw_to_ground      69.00516      69.450760            0.445600           0.198559
#    cross_to_claw       3.18581       3.217698            0.031888           0.001017
#   cross_to_cross     130.73017     130.931702            0.201532           0.040615
#     claw_to_claw      72.53547      72.926468            0.390998           0.152879
# ground_to_ground     256.08539     256.896820            0.811430           0.658419
#
# — Sample 6 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00014, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00023
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     119.11446     118.871399            0.243061           0.059079
#   claw_to_ground      86.16996      86.286407            0.116447           0.013560
#    cross_to_claw       3.64280       3.697775            0.054975           0.003022
#   cross_to_cross     119.11446     118.947975            0.166485           0.027717
#     claw_to_claw      90.28754      90.379593            0.092053           0.008474
# ground_to_ground     259.84254     259.841095            0.001445           0.000002
#
# — Sample 7 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=7e-05, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00034
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     176.38608     176.242844            0.143236           0.020517
#   claw_to_ground      55.86690      56.065151            0.198251           0.039304
#    cross_to_claw       2.25358       2.273157            0.019577           0.000383
#   cross_to_cross     176.38608     176.303406            0.082674           0.006835
#     claw_to_claw      58.39537      58.450993            0.055623           0.003094
# ground_to_ground     296.76901     297.162018            0.393008           0.154455
#
# — Sample 8 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00026, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00035
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     178.10282     178.356461            0.253641           0.064334
#   claw_to_ground     125.68193     126.545975            0.864045           0.746573
#    cross_to_claw       6.34363       6.392653            0.049023           0.002403
#   cross_to_cross     178.10282     178.668472            0.565652           0.319963
#     claw_to_claw     132.53235     133.515045            0.982695           0.965690
# ground_to_ground     369.47224     370.416412            0.944172           0.891461
#
# — Sample 9 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00012, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00025
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     131.40994     130.786865            0.623075           0.388222
#   claw_to_ground      79.59486      78.873230            0.721630           0.520750
#    cross_to_claw       3.06183       3.108135            0.046305           0.002144
#   cross_to_cross     131.40994     130.852737            0.557203           0.310475
#     claw_to_claw      83.01717      82.312675            0.704495           0.496313
# ground_to_ground     267.49113     266.523682            0.967448           0.935956
#
# — Sample 10 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=8e-05, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00029
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     154.21450     153.218307            0.996193           0.992400
#   claw_to_ground      62.06707      62.695190            0.628120           0.394535
#    cross_to_claw       2.51902       2.625277            0.106257           0.011291
#   cross_to_cross     154.21450     153.217636            0.996864           0.993738
#     claw_to_claw      64.88617      65.509186            0.623016           0.388149
# ground_to_ground     276.49530     276.267975            0.227325           0.051677
#
# — Sample 11 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00017, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00026
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     133.90254     133.857193            0.045347           0.002056
#   claw_to_ground      93.27707      93.141655            0.135415           0.018337
#    cross_to_claw       5.60533       5.526058            0.079272           0.006284
#   cross_to_cross     133.90254     133.933029            0.030489           0.000930
#     claw_to_claw      99.29517      99.079376            0.215794           0.046567
# ground_to_ground     284.79018     284.098145            0.692035           0.478913
#
# — Sample 12 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00028
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     142.21198     142.110580            0.101400           0.010282
#   claw_to_ground      69.25635      69.174988            0.081362           0.006620
#    cross_to_claw       3.54021       3.564113            0.023903           0.000571
#   cross_to_cross     142.21198     142.157394            0.054586           0.002980
#     claw_to_claw      73.13514      72.998535            0.136605           0.018661
# ground_to_ground     270.70230     270.304474            0.397826           0.158266
#
# — Sample 13 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00022, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.0004
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     214.10489     211.315155            2.789735           7.782621
#   claw_to_ground     115.96938     114.412407            1.556973           2.424165
#    cross_to_claw       5.31174       5.282982            0.028758           0.000827
#   cross_to_cross     214.10489     211.522263            2.582627           6.669964
#     claw_to_claw     121.71747     120.190262            1.527208           2.332365
# ground_to_ground     399.95898     396.528778            3.430202          11.766285
#
# — Sample 14 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=7e-05, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00014
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      67.22414      69.841675            2.617535           6.851488
#   claw_to_ground      55.49827      56.267273            0.769003           0.591366
#    cross_to_claw       2.50404       2.555770            0.051730           0.002676
#   cross_to_cross      67.22414      69.646851            2.422711           5.869527
#     claw_to_claw      58.39002      59.135059            0.745039           0.555084
# ground_to_ground     168.46092     171.825668            3.364748          11.321531
#
# — Sample 15 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00035, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00042
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     218.76721     220.297592            1.530382           2.342070
#   claw_to_ground     154.48543     154.841248            0.355818           0.126606
#    cross_to_claw      12.47846      12.433224            0.045236           0.002046
#   cross_to_cross     218.76721     220.955673            2.188463           4.789371
#     claw_to_claw     167.52220     168.009552            0.487352           0.237512
# ground_to_ground     444.85877     447.562897            2.704127           7.312301
#
# — Sample 16 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=7e-05, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=9e-05
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      40.86700      33.846828            7.020172          49.282808
#   claw_to_ground      55.00050      51.857628            3.142872           9.877645
#    cross_to_claw       2.94925       2.942127            0.007123           0.000051
#   cross_to_cross      40.86700      34.895222            5.971778          35.662136
#     claw_to_claw      58.42185      54.847900            3.573950          12.773116
# ground_to_ground     136.44316     124.809601           11.633559         135.339699
#
# — Sample 17 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=8e-05, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00014
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      67.73716      68.940384            1.203224           1.447748
#   claw_to_ground      62.56628      62.693974            0.127694           0.016306
#    cross_to_claw       2.06963       2.122881            0.053251           0.002836
#   cross_to_cross      67.73716      68.944557            1.207397           1.457808
#     claw_to_claw      65.04248      65.136581            0.094101           0.008855
# ground_to_ground     176.41409     177.778656            1.364566           1.862040
#
# — Sample 18 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00028, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00041
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     215.48153     215.388916            0.092614           0.008577
#   claw_to_ground     130.52289     130.783524            0.260634           0.067930
#    cross_to_claw       9.69242       9.589329            0.103091           0.010628
#   cross_to_cross     215.48153     215.671158            0.189628           0.035959
#     claw_to_claw     140.71220     141.142014            0.429814           0.184740
# ground_to_ground     416.74987     417.465424            0.715554           0.512017
#
# — Sample 19 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00018, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00026
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     128.46907     128.236954            0.232116           0.053878
#   claw_to_ground      92.25534      92.209724            0.045616           0.002081
#    cross_to_claw       6.12405       6.060277            0.063773           0.004067
#   cross_to_cross     128.46907     128.314804            0.154266           0.023798
#     claw_to_claw      98.81104      98.799393            0.011647           0.000136
# ground_to_ground     278.09981     277.329834            0.769976           0.592863
#
# — Sample 20 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00031, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.0004
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     209.09563     207.196930            1.898700           3.605062
#   claw_to_ground     140.91684     139.690552            1.226288           1.503783
#    cross_to_claw      10.93887      10.692841            0.246029           0.060530
#   cross_to_cross     209.09563     207.584045            1.511585           2.284888
#     claw_to_claw     152.37090     151.180939            1.189961           1.416008
# ground_to_ground     420.25420     417.101837            3.152363           9.937391
#
# — Sample 21 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00016
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      80.37409      82.069153            1.695063           2.873238
#   claw_to_ground      75.05616      75.104263            0.048103           0.002314
#    cross_to_claw       3.05308       3.033242            0.019838           0.000394
#   cross_to_cross      80.37409      82.034615            1.660525           2.757342
#     claw_to_claw      78.57692      78.510864            0.066056           0.004363
# ground_to_ground     203.34418     205.138931            1.794751           3.221132
#
# — Sample 22 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00025, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00033
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     171.52216     170.981308            0.540852           0.292521
#   claw_to_ground     121.41730     121.049393            0.367907           0.135356
#    cross_to_claw       8.33617       8.185370            0.150800           0.022741
#   cross_to_cross     171.52216     171.166977            0.355183           0.126155
#     claw_to_claw     130.22102     129.814285            0.406735           0.165433
# ground_to_ground     356.80193     355.652954            1.148976           1.320146
#
# — Sample 23 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0002, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00035
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     186.08458     184.536041            1.548539           2.397972
#   claw_to_ground     108.08004     107.385124            0.694916           0.482908
#    cross_to_claw       5.10324       5.071655            0.031585           0.000998
#   cross_to_cross     186.08458     184.671371            1.413209           1.997158
#     claw_to_claw     113.60879     112.974251            0.634539           0.402640
# ground_to_ground     360.09105     357.883606            2.207444           4.872809
#
# — Sample 24 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00014, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00018
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      89.54317      91.673874            2.130704           4.539899
#   claw_to_ground      82.33529      82.477219            0.141929           0.020144
#    cross_to_claw       4.93333       4.961507            0.028177           0.000794
#   cross_to_cross      89.54317      91.568733            2.025563           4.102906
#     claw_to_claw      87.77313      87.900101            0.126971           0.016122
# ground_to_ground     221.72004     223.754578            2.034538           4.139343
#
# — Sample 25 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00024, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00039
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     205.65276     202.065292            3.587468          12.869924
#   claw_to_ground     116.69334     115.389946            1.303394           1.698836
#    cross_to_claw       8.21753       8.080429            0.137101           0.018797
#   cross_to_cross     205.65276     202.310730            3.342030          11.169165
#     claw_to_claw     125.37727     124.120148            1.257122           1.580356
# ground_to_ground     391.73856     386.667511            5.071049          25.715538
#
# — Sample 26 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00021, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00036
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     183.37338     182.495071            0.878309           0.771426
#   claw_to_ground     102.93749     103.037560            0.100070           0.010014
#    cross_to_claw       6.93234       6.921082            0.011258           0.000127
#   cross_to_cross     183.37338     182.691910            0.681470           0.464402
#     claw_to_claw     110.29724     110.523949            0.226709           0.051397
# ground_to_ground     352.76604     351.666290            1.099750           1.209449
#
# — Sample 27 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00025, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00027
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     136.20133     136.661987            0.460657           0.212205
#   claw_to_ground     120.43722     120.065048            0.372172           0.138512
#    cross_to_claw       9.17838       8.853259            0.325121           0.105704
#   cross_to_cross     136.20133     136.761078            0.559748           0.313318
#     claw_to_claw     130.19136     129.580154            0.611206           0.373572
# ground_to_ground     314.95950     314.838501            0.120999           0.014641
#
# — Sample 28 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00025, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00028
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     143.80946     143.406937            0.402523           0.162025
#   claw_to_ground     125.37892     124.328293            1.050627           1.103817
#    cross_to_claw       7.12592       7.181693            0.055773           0.003111
#   cross_to_cross     143.80946     143.579758            0.229702           0.052763
#     claw_to_claw     133.08513     132.120834            0.964296           0.929866
# ground_to_ground     328.24034     326.719788            1.520552           2.312080
#
# — Sample 29 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.0003
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     154.56183     154.042404            0.519426           0.269803
#   claw_to_ground      73.59109      73.054390            0.536700           0.288047
#    cross_to_claw       2.50326       2.544356            0.041096           0.001689
#   cross_to_cross     154.56183     154.031708            0.530122           0.281030
#     claw_to_claw      76.44597      75.841766            0.604204           0.365062
# ground_to_ground     289.12750     288.283752            0.843748           0.711910
#
# — Sample 30 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00029
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     147.85719     147.709885            0.147305           0.021699
#   claw_to_ground      69.34483      69.200645            0.144185           0.020789
#    cross_to_claw       3.53509       3.564094            0.029004           0.000841
#   cross_to_cross     147.85719     147.774673            0.082517           0.006809
#     claw_to_claw      73.22926      73.017105            0.212155           0.045010
# ground_to_ground     277.12653     277.078857            0.047673           0.002273
#
# — Sample 31 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00013, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00031
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     164.91926     164.025558            0.893702           0.798702
#   claw_to_ground      82.78064      82.569679            0.210961           0.044504
#    cross_to_claw       3.23513       3.259673            0.024543           0.000602
#   cross_to_cross     164.91926     164.098526            0.820734           0.673604
#     claw_to_claw      86.34713      86.156822            0.190308           0.036217
# ground_to_ground     309.83839     309.035706            0.802684           0.644302
#
# — Sample 32 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00018, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00031
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     156.19781     156.563171            0.365361           0.133489
#   claw_to_ground      92.52097      92.699234            0.178264           0.031778
#    cross_to_claw       5.93444       5.933270            0.001170           0.000001
#   cross_to_cross     156.19781     156.698563            0.500753           0.250753
#     claw_to_claw      98.86794      99.117996            0.250056           0.062528
# ground_to_ground     310.66254     311.018707            0.356167           0.126855
#
# — Sample 33 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=8e-05, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00012
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      56.26003      58.512714            2.252684           5.074587
#   claw_to_ground      58.64577      59.229713            0.583943           0.340990
#    cross_to_claw       2.98994       3.126953            0.137013           0.018773
#   cross_to_cross      56.26003      58.272060            2.012030           4.048266
#     claw_to_claw      62.08519      62.729702            0.644512           0.415396
# ground_to_ground     158.55983     161.455978            2.896148           8.387676
#
# — Sample 34 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00015, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00031
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     164.34477     163.618637            0.726133           0.527269
#   claw_to_ground      89.98109      89.959091            0.021999           0.000484
#    cross_to_claw       3.77364       3.790599            0.016959           0.000288
#   cross_to_cross     164.34477     163.713684            0.631086           0.398269
#     claw_to_claw      94.11389      94.128532            0.014642           0.000214
# ground_to_ground     316.44733     315.824280            0.623050           0.388192
#
# — Sample 35 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0002, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00032
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     161.19793     161.304092            0.106162           0.011270
#   claw_to_ground      99.29276      99.380806            0.088046           0.007752
#    cross_to_claw       6.64752       6.636221            0.011299           0.000128
#   cross_to_cross     161.19793     161.462326            0.264396           0.069905
#     claw_to_claw     106.41913     106.563660            0.144530           0.020889
# ground_to_ground     322.87581     323.282257            0.406447           0.165199
#
# — Sample 36 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00021, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.0003
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     157.36511     156.616653            0.748457           0.560187
#   claw_to_ground     112.04578     111.102478            0.943302           0.889819
#    cross_to_claw       5.50703       5.518372            0.011342           0.000129
#   cross_to_cross     157.36511     156.795090            0.570020           0.324923
#     claw_to_claw     118.08393     117.151543            0.932387           0.869346
# ground_to_ground     330.32287     328.980194            1.342676           1.802779
#
# — Sample 37 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00012, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.00036
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     194.21152     191.976379            2.235141           4.995854
#   claw_to_ground      79.37310      79.030365            0.342735           0.117467
#    cross_to_claw       2.92829       2.922035            0.006255           0.000039
#   cross_to_cross     194.21152     192.061890            2.149630           4.620911
#     claw_to_claw      82.58741      82.236145            0.351265           0.123387
# ground_to_ground     340.33584     338.205292            2.130548           4.539236
#
# — Sample 38 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00013, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00028
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     142.49987     142.259796            0.240074           0.057635
#   claw_to_ground      80.30763      80.159210            0.148420           0.022028
#    cross_to_claw       3.01723       3.058752            0.041522           0.001724
#   cross_to_cross     142.49987     142.329880            0.169990           0.028897
#     claw_to_claw      83.71061      83.523781            0.186829           0.034905
# ground_to_ground     282.09379     281.502136            0.591654           0.350054
#
# — Sample 39 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00018, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00036
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     185.99283     186.334610            0.341780           0.116814
#   claw_to_ground      98.06706      98.238892            0.171832           0.029526
#    cross_to_claw       4.17102       4.188506            0.017486           0.000306
#   cross_to_cross     185.99283     186.514542            0.521712           0.272183
#     claw_to_claw     102.61514     102.840530            0.225390           0.050801
# ground_to_ground     350.52690     351.221680            0.694780           0.482719
#
# — Sample 40 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00026, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00037
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     186.70783     186.912537            0.204707           0.041905
#   claw_to_ground     119.22500     120.047508            0.822508           0.676520
#    cross_to_claw       8.69031       8.731151            0.040841           0.001668
#   cross_to_cross     186.70783     187.172287            0.464457           0.215720
#     claw_to_claw     128.47678     129.489502            1.012722           1.025606
# ground_to_ground     373.15637     373.951813            0.795443           0.632729
#
# — Sample 41 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00017, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00019
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      93.71326      96.207047            2.493787           6.218971
#   claw_to_ground      92.44203      92.888535            0.446505           0.199366
#    cross_to_claw       6.39665       6.218277            0.178373           0.031817
#   cross_to_cross      93.71326      96.103111            2.389851           5.711389
#     claw_to_claw      99.39243      99.651291            0.258861           0.067009
# ground_to_ground     236.82421     239.743866            2.919656           8.524391
#
# — Sample 42 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00015, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.0003
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     158.00323     157.321655            0.681575           0.464544
#   claw_to_ground      86.64982      86.516853            0.132967           0.017680
#    cross_to_claw       4.77891       4.737967            0.040943           0.001676
#   cross_to_cross     158.00323     157.410034            0.593196           0.351881
#     claw_to_claw      91.82307      91.581482            0.241588           0.058365
# ground_to_ground     305.87565     305.144928            0.730722           0.533955
#
# — Sample 43 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=7e-05, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00024
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     121.34979     122.543411            1.193621           1.424732
#   claw_to_ground      55.81940      56.590050            0.770650           0.593901
#    cross_to_claw       2.33458       2.298621            0.035959           0.001293
#   cross_to_cross     121.34979     122.514671            1.164881           1.356949
#     claw_to_claw      58.41760      59.121990            0.704390           0.496166
# ground_to_ground     232.36298     234.263718            1.900738           3.612804
#
# — Sample 44 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00013, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00027
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     135.97879     136.323547            0.344757           0.118858
#   claw_to_ground      75.88477      75.778976            0.105794           0.011192
#    cross_to_claw       4.23694       4.262682            0.025742           0.000663
#   cross_to_cross     135.97879     136.376678            0.397888           0.158315
#     claw_to_claw      80.48310      80.350807            0.132293           0.017501
# ground_to_ground     270.32897     270.142670            0.186300           0.034708
#
# — Sample 45 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00015, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.0002
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     101.58489     102.710854            1.125964       1.267794e+00
#   claw_to_ground      89.39401      89.561493            0.167483       2.805053e-02
#    cross_to_claw       4.10747       4.108019            0.000549       3.017876e-07
#   cross_to_cross     101.58489     102.757561            1.172671       1.375157e+00
#     claw_to_claw      94.01724      94.146202            0.128962       1.663122e-02
# ground_to_ground     242.67125     244.164352            1.493102       2.229355e+00
#
# — Sample 46 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0003, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00038
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     190.85907     193.135452            2.276382           5.181916
#   claw_to_ground     132.60867     134.211319            1.602649           2.568484
#    cross_to_claw      10.25834      10.236300            0.022040           0.000486
#   cross_to_cross     190.85907     193.476990            2.617920           6.853504
#     claw_to_claw     143.42262     145.245743            1.823123           3.323777
# ground_to_ground     391.38400     395.443817            4.059817          16.482115
#
# — Sample 47 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00016, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00034
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     175.27419     175.542999            0.268809           0.072258
#   claw_to_ground      91.04597      91.121910            0.075940           0.005767
#    cross_to_claw       3.68023       3.689840            0.009610           0.000092
#   cross_to_cross     175.27419     175.699066            0.424876           0.180520
#     claw_to_claw      95.12638      95.168274            0.041894           0.001755
# ground_to_ground     330.98552     331.417847            0.432327           0.186906
#
# — Sample 48 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00021, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00023
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     115.14761     116.402946            1.255336           1.575870
#   claw_to_ground     107.02111     105.941238            1.079872           1.166123
#    cross_to_claw       7.78498       7.462802            0.322178           0.103798
#   cross_to_cross     115.14761     116.419823            1.272213           1.618525
#     claw_to_claw     115.38621     113.965431            1.420779           2.018612
# ground_to_ground     276.51308     276.729370            0.216290           0.046781
#
# — Sample 49 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00019, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.0003
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     150.28208     150.846649            0.564569           0.318738
#   claw_to_ground      95.69848      95.891624            0.193144           0.037305
#    cross_to_claw       6.33415       6.319427            0.014723           0.000217
#   cross_to_cross     150.28208     150.984680            0.702600           0.493647
#     claw_to_claw     102.51089     102.737106            0.226216           0.051174
# ground_to_ground     306.81832     307.588623            0.770303           0.593367
#
# Global unscaled error stats:
#   min abs_error: 0.0005493519592283391
#   median abs_error: 0.3838072705078446
#   max abs_error: 11.633559169921881

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# Lets see how good we actually did

# %%
# find percentage difference like 100 * abs(pred - re) / abs(ref), with tiny epsilon to avoid division by zero
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(y_pred_unscaled - y_test_unscaled) / (np.abs(y_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_params)]
all_pct = pct_errors_unscaled.ravel()

# %%
# box plot showing % error distribution per capacitance output 
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Percentage Error Distribution per Output')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_boxplot.pdf')
plt.show()
# Out:
# /tmp/ipykernel_423382/2286795443.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,

# %%
# histogram it too
n_cols_grid = 3
n_rows_grid = math.ceil(n_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

# hide unused subplots
for k in range(n_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Model 2: Percentage Error Histograms per Output', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_histograms_per_output.pdf')
plt.show()

# %%
#look at the stats nicely
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'All outputs':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")
# Out:
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# cross_to_ground                 0.44       0.80       1.80      17.18
# claw_to_ground                  0.37       0.54       1.21       5.71
# cross_to_claw                   0.80       1.11       2.25      17.30
# cross_to_cross                  0.39       0.76       1.78      14.61
# claw_to_claw                    0.36       0.53       1.18       6.12
# ground_to_ground                0.27       0.46       1.04       8.53
# ----------------------------------------------------------------------
# All outputs                     0.41       0.70       1.53      17.30

# %%
# scatter plot with fancy visulaization of points using this grouping thing

fig, ax = plt.subplots(figsize=(12, 6))
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    x = np.full_like(col_pct, j) + np.random.uniform(-0.2, 0.2, size=len(col_pct))
    ax.scatter(x, col_pct, alpha=0.4, s=12, label=short_names[j])
ax.set_xticks(range(n_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Per-Sample Percentage Error by Capacitance Output')
plt.tight_layout()
plt.savefig('plots/model2_pct_error_scatter.pdf')
plt.show()
