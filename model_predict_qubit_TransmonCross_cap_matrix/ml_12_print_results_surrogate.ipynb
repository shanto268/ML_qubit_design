# %% [markdown]
# # Model Predictions (qubit_TransmonCross_cap_matrix)
# ## Qiskit Metal --> Capacitance
#
# Ansys surrogate model

# %% [markdown]
# ## Configuration

# %%
# The parameter file is where the hyperparameters are set. 
# It's reccomended to look at that file first, its interesting and you can set stuff there

from parameters_surrogate import *

# %% [markdown]
# ## Library

# %%
import os, gc, math
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
def load_scaled_split(kind, split):
    return np.load(f"{DATA_DIR}/npy/{split}_{kind}_encoding_scaled.npy", allow_pickle=True)

# new inputs are our Qiskit Metal params, using good ole linear encoding
X_train = load_scaled_split('linear', 'y_train')
X_val   = load_scaled_split('linear', 'y_val')
X_test  = load_scaled_split('linear', 'y_test')

# new outputs are the capacitance values
y_train = load_scaled_split('linear', 'x_train')
y_val   = load_scaled_split('linear', 'x_val')
y_test  = load_scaled_split('linear', 'x_test')

# load column name files for later reference fer outputs
with open('X_names', 'r') as f:
    cap_column_names = f.read().splitlines()   

# input names
qiskit_param_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist() 

#check to make sure these printouts make sense and we arent flippered
print(f'Inputs (Qiskit params):  {X_train.shape[1]} columns')
print(f'Outputs (Capacitance):    {y_train.shape[1]} columns')
print(f'\nInput columns:  {qiskit_param_names}')
print(f'Output columns: {cap_column_names}')
# Out:
# Inputs (Qiskit params):  3 columns
# Outputs (Capacitance):    6 columns
#
# Input columns:  ['design_options.connection_pads.readout.claw_length', 'design_options.connection_pads.readout.ground_spacing', 'design_options.cross_length']
# Output columns: ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']

# %% [markdown]
# ### Visualize model

# %%
# Decide which model file to use
encoding = 'model2_surrogate'
chosen_path = f'model/best_keras_model_model2_surrogate.keras'
X_test_cur = np.asarray(X_test)
y_test_cur = np.asarray(y_test)

# Load output headers (capacitance column names)
headers = cap_column_names
print(f'Model path: {chosen_path}')
print(f'Output headers: {headers}')
# Out:
# Model path: model/best_keras_model_model2_surrogate.keras
# Output headers: ['cross_to_ground', 'claw_to_ground', 'cross_to_claw', 'cross_to_cross', 'claw_to_claw', 'ground_to_ground']

# %%
#look at the best model, ooh so pretty
tf.keras.backend.clear_session()
gc.collect()
try:
    tf.config.experimental.reset_memory_stats('GPU:0')
except Exception:
    pass

with tf.device('/CPU:0'):
    chosen_model = load_model(chosen_path, compile=False)
    y_pred = chosen_model.predict(X_test_cur, verbose=0)

print(f'\n—— {os.path.basename(chosen_path)} ——')
chosen_model.summary()
print(f'Samples: {len(X_test_cur)} | Targets dim: {y_test_cur.shape[1]}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772221666.196940 2178590 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 37364 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 4g.40gb, pci bus id: 0000:00:10.0, compute capability: 8.0
# I0000 00:00:1772221666.413072 2179268 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# —— best_keras_model_model2_surrogate.keras ——
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ fc0 (Dense)                     │ (None, 352)            │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_relu0 (LeakyReLU)         │ (None, 352)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout0 (Dropout)              │ (None, 352)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 6)              │         2,118 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,526 (13.77 KB)
#  Trainable params: 3,526 (13.77 KB)
#  Non-trainable params: 0 (0.00 B)
# Samples: 291 | Targets dim: 6

# %%
# look at some more specific model params
m = tf.keras.models.load_model(chosen_path, compile=True)

neurons_per_layer = [
    l.units for l in m.layers
    if isinstance(l, tf.keras.layers.Dense) and l.name.startswith('fc')
]
print('Best NEURONS_PER_LAYER:', neurons_per_layer)

dropouts = [
    (l.name, float(l.rate)) for l in m.layers
    if isinstance(l, tf.keras.layers.Dropout)
]
if dropouts:
    print('Best DROPOUT rate(s):', dropouts)
else:
    print('Best DROPOUT rate(s): none found')

opt = getattr(m, 'optimizer', None)
if opt is None:
    print('Best learning rate: (no optimizer found on loaded model)')
else:
    lr_obj = opt.learning_rate

    if isinstance(lr_obj, tf.keras.optimizers.schedules.LearningRateSchedule):
        print('Best learning rate: (schedule)', type(lr_obj).__name__)
        try:
            cfg = lr_obj.get_config()
            print('LR schedule config:')
            for k, v in sorted(cfg.items()):
                print(f'  {k}: {v}')
        except Exception as e:
            print('Could not read LR schedule config:', repr(e))
        try:
            step = int(tf.keras.backend.get_value(opt.iterations))
            current_lr = float(lr_obj(step).numpy())
            print(f'Current LR at step {step}:', current_lr)
        except Exception as e:
            print('Could not compute current LR from schedule:', repr(e))
    else:
        try:
            lr_val = float(tf.keras.backend.get_value(lr_obj))
            print('Best learning rate:', lr_val)
        except Exception as e:
            print('Best learning rate: (unreadable)', repr(e))
# Out:
# Best NEURONS_PER_LAYER: [352]
# Best DROPOUT rate(s): [('dropout0', 0.0)]
# Best learning rate: 0.029999999329447746
# /home/olivias/.local/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Scaled

# %%
N_SAMPLES_TO_SHOW = 50 # change this to print more stuff

X_test_cur = np.asarray(X_test_cur)
y_test_cur = np.asarray(y_test_cur)
y_pred     = np.asarray(y_pred)

N, P = y_test_cur.shape

# make sure y_pred shape matches
if y_pred.ndim == 3 and y_pred.shape[-1] == 1:
    y_pred = y_pred[..., 0]
if y_pred.ndim == 1:
    y_pred = y_pred.reshape(-1, 1)
assert y_pred.shape == (N, P), f'y_pred shape {y_pred.shape} != expected {(N, P)}'

# scaled errors
sq_errors  = (y_test_cur - y_pred) ** 2
abs_errors = np.abs(y_test_cur - y_pred)

# building dataframe
rows = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(P):
        label = headers[j] if j < len(headers) else f'cap_col_{j}'
        rows.append({
            'sample_idx': i,
            'param': label,
            'ref':  y_test_cur[i, j],
            'pred': y_pred[i, j],
            'abs_error': abs_errors[i, j],
            'sq_error':  sq_errors[i, j],
        })

df = pd.DataFrame(rows)

# save scaled predictions
out_csv = Path(f'model2_predictions_and_errors_{encoding}.csv')
df.to_csv(out_csv, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv.resolve()}\n')

# Pretty print per-sample (scaled)
for i in range(N_SAMPLES_TO_SHOW):
    sub = df[df['sample_idx'] == i].copy()
    sub = sub[['param', 'ref', 'pred', 'abs_error', 'sq_error']]
    input_str = ', '.join(
        f'{qiskit_param_names[k] if k < len(qiskit_param_names) else f"in_{k}"}={X_test_cur[i,k]:.6g}'
        for k in range(X_test_cur.shape[1])
    )
    print(f'— Sample {i} — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global scaled error stats:')
print('  min abs_error:', float(abs_errors.min()))
print('  median abs_error:', float(np.median(abs_errors)))
print('  max abs_error:', float(abs_errors.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/model2_predictions_and_errors_model2_surrogate.csv
#
# — Sample 0 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.515152
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.486726 0.487631   0.000905 8.188796e-07
#   claw_to_ground 0.332857 0.334324   0.001467 2.151797e-06
#    cross_to_claw 0.333689 0.329799   0.003890 1.513394e-05
#   cross_to_cross 0.486726 0.487516   0.000790 6.233969e-07
#     claw_to_claw 0.339616 0.341005   0.001389 1.929851e-06
# ground_to_ground 0.442740 0.442673   0.000067 4.447662e-09
#
# — Sample 1 — Inputs: design_options.connection_pads.readout.claw_length=0.0909091, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.606061
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.568657 0.569306   0.000649 4.216340e-07
#   claw_to_ground 0.118193 0.118724   0.000531 2.821031e-07
#    cross_to_claw 0.051998 0.052763   0.000765 5.849013e-07
#   cross_to_cross 0.568657 0.569425   0.000768 5.895592e-07
#     claw_to_claw 0.111141 0.111576   0.000435 1.891968e-07
# ground_to_ground 0.415697 0.416836   0.001139 1.297504e-06
#
# — Sample 2 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.272727
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.239722 0.240229   0.000507 2.571633e-07
#   claw_to_ground 0.109517 0.110155   0.000637 4.060891e-07
#    cross_to_claw 0.165374 0.164220   0.001154 1.331287e-06
#   cross_to_cross 0.239722 0.240322   0.000600 3.599721e-07
#     claw_to_claw 0.114911 0.115537   0.000626 3.918410e-07
# ground_to_ground 0.195275 0.195620   0.000345 1.190296e-07
#
# — Sample 3 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.363636
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.345244 0.344342   0.000901 8.119571e-07
#   claw_to_ground 0.192985 0.193260   0.000275 7.565259e-08
#    cross_to_claw 0.205119 0.206826   0.001707 2.913213e-06
#   cross_to_cross 0.345244 0.344457   0.000786 6.181552e-07
#     claw_to_claw 0.196844 0.196967   0.000123 1.514554e-08
# ground_to_ground 0.294791 0.294614   0.000177 3.128316e-08
#
# — Sample 4 — Inputs: design_options.connection_pads.readout.claw_length=0.0606061, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.212121
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.202381 0.202287   0.000094 8.756673e-09
#   claw_to_ground 0.080307 0.080702   0.000395 1.560255e-07
#    cross_to_claw 0.111293 0.112692   0.001400 1.958805e-06
#   cross_to_cross 0.202381 0.202300   0.000081 6.505679e-09
#     claw_to_claw 0.082236 0.082903   0.000667 4.446305e-07
# ground_to_ground 0.158240 0.158195   0.000045 2.038869e-09
#
# — Sample 5 — Inputs: design_options.connection_pads.readout.claw_length=0.0909091, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.484848
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.471814 0.472711   0.000897 8.043020e-07
#   claw_to_ground 0.110928 0.110660   0.000268 7.170959e-08
#    cross_to_claw 0.120708 0.119535   0.001174 1.377365e-06
#   cross_to_cross 0.471814 0.472550   0.000736 5.413680e-07
#     claw_to_claw 0.111184 0.110874   0.000310 9.613665e-08
# ground_to_ground 0.347032 0.347956   0.000923 8.526244e-07
#
# — Sample 6 — Inputs: design_options.connection_pads.readout.claw_length=0.212121, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.424242
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.409661 0.409123   0.000538 2.895676e-07
#   claw_to_ground 0.248461 0.248226   0.000235 5.517975e-08
#    cross_to_claw 0.155454 0.156842   0.001388 1.926871e-06
#   cross_to_cross 0.409661 0.409148   0.000514 2.637415e-07
#     claw_to_claw 0.243760 0.243364   0.000396 1.568423e-07
# ground_to_ground 0.358368 0.358034   0.000334 1.118566e-07
#
# — Sample 7 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.917929 0.896645   0.021284  0.000453
#   claw_to_ground 0.487229 0.472195   0.015035  0.000226
#    cross_to_claw 0.282345 0.276651   0.005694  0.000032
#   cross_to_cross 0.917929 0.896885   0.021044  0.000443
#     claw_to_claw 0.478485 0.463412   0.015073  0.000227
# ground_to_ground 0.781127 0.764706   0.016421  0.000270
#
# — Sample 14 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.151515
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.132011 0.133418   0.001407 1.979763e-06
#   claw_to_ground 0.002703 0.002145   0.000559 3.120298e-07
#    cross_to_claw 0.068873 0.068134   0.000739 5.458989e-07
#   cross_to_cross 0.132011 0.133521   0.001510 2.279177e-06
#     claw_to_claw 0.005543 0.005104   0.000440 1.931645e-07
# ground_to_ground 0.082652 0.083263   0.000611 3.730192e-07
#
# — Sample 15 — Inputs: design_options.connection_pads.readout.claw_length=0.848485, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=1
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.942876 0.943294   0.000418 1.750480e-07
#   claw_to_ground 0.795840 0.796587   0.000747 5.583859e-07
#    cross_to_claw 0.827238 0.827993   0.000756 5.709186e-07
#   cross_to_cross 0.942876 0.942666   0.000209 4.378535e-08
#     claw_to_claw 0.820564 0.821397   0.000833 6.930747e-07
# ground_to_ground 0.916598 0.916475   0.000123 1.524456e-08
#
# — Sample 16 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0
#            param       ref      pred  abs_error     sq_error
#  cross_to_ground -0.009019 -0.013466   0.004447 1.977923e-05
#   claw_to_ground -0.001285 -0.002031   0.000746 5.560057e-07
#    cross_to_claw  0.102722  0.112832   0.010110 1.022037e-04
#   cross_to_cross -0.009019 -0.013481   0.004462 1.991306e-05
#     claw_to_claw  0.005781  0.006181   0.000400 1.598706e-07
# ground_to_ground -0.013951 -0.016138   0.002186 4.779945e-06
#
# — Sample 17 — Inputs: design_options.connection_pads.readout.claw_length=0.030303, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.151515
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.134756 0.135114   0.000358 1.281242e-07
#   claw_to_ground 0.059336 0.059256   0.000080 6.355300e-09
#    cross_to_claw 0.035844 0.035946   0.000102 1.031491e-08
#   cross_to_cross 0.134756 0.135222   0.000466 2.173715e-07
#     claw_to_claw 0.055225 0.055306   0.000081 6.490997e-09
# ground_to_ground 0.106649 0.106255   0.000393 1.547238e-07
#
# — Sample 18 — Inputs: design_options.connection_pads.readout.claw_length=0.636364, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.969697
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.925295 0.926344   0.001050 1.101556e-06
#   claw_to_ground 0.603840 0.604662   0.000822 6.763211e-07
#    cross_to_claw 0.615412 0.615720   0.000307 9.442104e-08
#   cross_to_cross 0.925295 0.926204   0.000909 8.259609e-07
#     claw_to_claw 0.620342 0.620978   0.000637 4.051911e-07
# ground_to_ground 0.831788 0.832746   0.000958 9.174681e-07
#
# — Sample 19 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.515152
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.459715 0.460039   0.000323 1.046433e-07
#   claw_to_ground 0.297220 0.297680   0.000460 2.112409e-07
#    cross_to_claw 0.344106 0.345664   0.001558 2.428875e-06
#   cross_to_cross 0.459715 0.459934   0.000219 4.775202e-08
#     claw_to_claw 0.307416 0.308296   0.000880 7.750136e-07
# ground_to_ground 0.413454 0.412676   0.000778 6.051792e-07
#
# — Sample 20 — Inputs: design_options.connection_pads.readout.claw_length=0.727273, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.939394
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.891126 0.888086   0.003040  0.000009
#   claw_to_ground 0.687122 0.684464   0.002658  0.000007
#    cross_to_claw 0.710181 0.704925   0.005256  0.000028
#   cross_to_cross 0.891126 0.888528   0.002598  0.000007
#     claw_to_claw 0.707411 0.704236   0.003175  0.000010
# ground_to_ground 0.842361 0.839161   0.003201  0.000010
#
# — Sample 21 — Inputs: design_options.connection_pads.readout.claw_length=0.121212, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.212121
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.202373 0.202437   0.000065 4.173055e-09
#   claw_to_ground 0.159411 0.159492   0.000081 6.536500e-09
#    cross_to_claw 0.110617 0.110647   0.000030 8.990429e-10
#   cross_to_cross 0.202373 0.202438   0.000065 4.221324e-09
#     claw_to_claw 0.156303 0.156320   0.000017 2.808641e-10
# ground_to_ground 0.187902 0.188496   0.000594 3.526105e-07
#
# — Sample 22 — Inputs: design_options.connection_pads.readout.claw_length=0.545455, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.727273
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.690080 0.689399   0.000681 4.638122e-07
#   claw_to_ground 0.530881 0.530085   0.000796 6.331913e-07
#    cross_to_claw 0.512295 0.514349   0.002054 4.219358e-06
#   cross_to_cross 0.690080 0.689249   0.000832 6.920525e-07
#     claw_to_claw 0.541992 0.542080   0.000089 7.847745e-09
# ground_to_ground 0.650914 0.649686   0.001228 1.508223e-06
#
# — Sample 23 — Inputs: design_options.connection_pads.readout.claw_length=0.393939, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.787879
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.768000 0.768416   0.000416 1.733720e-07
#   claw_to_ground 0.424016 0.423740   0.000276 7.636178e-08
#    cross_to_claw 0.266492 0.264247   0.002246 5.042599e-06
#   cross_to_cross 0.768000 0.768456   0.000456 2.078426e-07
#     claw_to_claw 0.417928 0.417091   0.000837 7.003453e-07
# ground_to_ground 0.660838 0.660765   0.000073 5.276165e-09
#
# — Sample 24 — Inputs: design_options.connection_pads.readout.claw_length=0.212121, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.272727
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.251434 0.251801   0.000367 1.345966e-07
#   claw_to_ground 0.217736 0.218485   0.000749 5.617460e-07
#    cross_to_claw 0.253574 0.251873   0.001701 2.892323e-06
#   cross_to_cross 0.251434 0.251657   0.000223 4.963085e-08
#     claw_to_claw 0.224982 0.226143   0.001161 1.346793e-06
# ground_to_ground 0.243345 0.243288   0.000057 3.260316e-09
#
# — Sample 25 — Inputs: design_options.connection_pads.readout.claw_length=0.515152, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.909091
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.872704 0.859434   0.013270  0.000176
#   claw_to_ground 0.493030 0.482544   0.010487  0.000110
#    cross_to_claw 0.503275 0.499047   0.004228  0.000018
#   cross_to_cross 0.872704 0.859731   0.012972  0.000168
#     claw_to_claw 0.505818 0.495391   0.010426  0.000109
# ground_to_ground 0.756324 0.744341   0.011983  0.000144
#
# — Sample 26 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.818182
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.753493 0.752235   0.001258  0.000002
#   claw_to_ground 0.382811 0.381248   0.001563  0.000002
#    cross_to_claw 0.405561 0.402942   0.002618  0.000007
#   cross_to_cross 0.753493 0.752182   0.001311  0.000002
#     claw_to_claw 0.393197 0.391522   0.001675  0.000003
# ground_to_ground 0.638737 0.636767   0.001970  0.000004
#
# — Sample 27 — Inputs: design_options.connection_pads.readout.claw_length=0.545455, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.545455
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.651676 0.652795   0.001119 1.251512e-06
#   claw_to_ground 0.278998 0.279063   0.000065 4.270650e-09
#    cross_to_claw 0.165402 0.165335   0.000066 4.412862e-09
#   cross_to_cross 0.651676 0.652798   0.001122 1.258189e-06
#     claw_to_claw 0.272336 0.272382   0.000045 2.041607e-09
# ground_to_ground 0.529156 0.530125   0.000969 9.394091e-07
#
# — Sample 35 — Inputs: design_options.connection_pads.readout.claw_length=0.393939, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.69697
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.634838 0.634510   0.000328 1.076532e-07
#   claw_to_ground 0.353608 0.353296   0.000311 9.700717e-08
#    cross_to_claw 0.383906 0.383174   0.000731 5.348954e-07
#   cross_to_cross 0.634838 0.634473   0.000365 1.332690e-07
#     claw_to_claw 0.364234 0.363641   0.000593 3.515484e-07
# ground_to_ground 0.548552 0.548786   0.000234 5.494600e-08
#
# — Sample 36 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.636364
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.614330 0.611958   0.002372  0.000006
#   claw_to_ground 0.455792 0.451711   0.004080  0.000017
#    cross_to_claw 0.297193 0.298643   0.001450  0.000002
#   cross_to_cross 0.614330 0.611925   0.002405  0.000006
#     claw_to_claw 0.451349 0.447231   0.004119  0.000017
# ground_to_ground 0.571021 0.568864   0.002157  0.000005
#
# — Sample 37 — Inputs: design_options.connection_pads.readout.claw_length=0.151515, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.818182
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.811485 0.810847   0.000638 4.071577e-07
#   claw_to_ground 0.194001 0.193541   0.000460 2.113433e-07
#    cross_to_claw 0.101129 0.101687   0.000558 3.115670e-07
#   cross_to_cross 0.811485 0.810558   0.000927 8.592051e-07
#     claw_to_claw 0.186254 0.185909   0.000345 1.189006e-07
# ground_to_ground 0.601232 0.601039   0.000193 3.733787e-08
#
# — Sample 38 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.575758
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.534790 0.536711   0.001921 3.690449e-06
#   claw_to_ground 0.201489 0.202447   0.000958 9.175673e-07
#    cross_to_claw 0.107891 0.108247   0.000356 1.267130e-07
#   cross_to_cross 0.534790 0.536664   0.001874 3.511973e-06
#     claw_to_claw 0.194643 0.195313   0.000670 4.489898e-07
# ground_to_ground 0.425505 0.426782   0.001277 1.631683e-06
#
# — Sample 39 — Inputs: design_options.connection_pads.readout.claw_length=0.333333, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.818182
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.767509 0.766320   0.001189 1.414115e-06
#   claw_to_ground 0.343787 0.343762   0.000025 6.185827e-10
#    cross_to_claw 0.195615 0.195521   0.000094 8.749921e-09
#   cross_to_cross 0.767509 0.766084   0.001425 2.030346e-06
#     claw_to_claw 0.335825 0.335970   0.000145 2.102636e-08
# ground_to_ground 0.631981 0.631607   0.000374 1.396845e-07
#
# — Sample 40 — Inputs: design_options.connection_pads.readout.claw_length=0.575758, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.848485
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.771335 0.771476   0.000141 1.987807e-08
#   claw_to_ground 0.513315 0.515016   0.001700 2.891340e-06
#    cross_to_claw 0.539221 0.541319   0.002099 4.403779e-06
#   cross_to_cross 0.771335 0.771390   0.000056 3.101974e-09
#     claw_to_claw 0.528965 0.530474   0.001509 2.277269e-06
# ground_to_ground 0.700258 0.700473   0.000215 4.633757e-08
#
# — Sample 41 — Inputs: design_options.connection_pads.readout.claw_length=0.30303, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.30303
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.273747 0.274097   0.000350 1.227829e-07
#   claw_to_ground 0.298716 0.299389   0.000673 4.532159e-07
#    cross_to_claw 0.364832 0.363761   0.001070 1.145381e-06
#   cross_to_cross 0.273747 0.274384   0.000637 4.057094e-07
#     claw_to_claw 0.311758 0.311746   0.000011 1.320820e-10
# ground_to_ground 0.288918 0.288524   0.000394 1.548910e-07
#
# — Sample 42 — Inputs: design_options.connection_pads.readout.claw_length=0.242424, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.636364
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.617744 0.616858   0.000886 7.851245e-07
#   claw_to_ground 0.252306 0.251792   0.000514 2.638478e-07
#    cross_to_claw 0.241833 0.241441   0.000393 1.541636e-07
#   cross_to_cross 0.617744 0.616813   0.000931 8.676759e-07
#     claw_to_claw 0.255228 0.254735   0.000493 2.426427e-07
# ground_to_ground 0.497259 0.496104   0.001155 1.333994e-06
#
# — Sample 43 — Inputs: design_options.connection_pads.readout.claw_length=0, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.454545
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.421622 0.422595   0.000973 9.459373e-07
#   claw_to_ground 0.005276 0.004888   0.000388 1.506680e-07
#    cross_to_claw 0.055988 0.052451   0.003538 1.251552e-05
#   cross_to_cross 0.421622 0.422456   0.000834 6.951292e-07
#     claw_to_claw 0.005749 0.005373   0.000377 1.418061e-07
# ground_to_ground 0.275457 0.276687   0.001229 1.511665e-06
#
# — Sample 44 — Inputs: design_options.connection_pads.readout.claw_length=0.181818, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.545455
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.499898 0.500041   0.000143 2.054234e-08
#   claw_to_ground 0.166051 0.166591   0.000540 2.915999e-07
#    cross_to_claw 0.200627 0.200732   0.000105 1.103427e-08
#   cross_to_cross 0.499898 0.500017   0.000119 1.427645e-08
#     claw_to_claw 0.170539 0.171305   0.000766 5.870838e-07
# ground_to_ground 0.390008 0.389078   0.000930 8.642352e-07
#
# — Sample 45 — Inputs: design_options.connection_pads.readout.claw_length=0.242424, design_options.connection_pads.readout.ground_spacing=0.847458, design_options.cross_length=0.333333
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.315866 0.316729   0.000863 7.454115e-07
#   claw_to_ground 0.274294 0.275705   0.001412 1.992539e-06
#    cross_to_claw 0.190783 0.193510   0.002727 7.435334e-06
#   cross_to_cross 0.315866 0.316768   0.000902 8.138656e-07
#     claw_to_claw 0.271615 0.272741   0.001126 1.268244e-06
# ground_to_ground 0.306559 0.307596   0.001036 1.073748e-06
#
# — Sample 46 — Inputs: design_options.connection_pads.readout.claw_length=0.69697, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.878788
#            param      ref     pred  abs_error  sq_error
#  cross_to_ground 0.793547 0.806058   0.012511  0.000157
#   claw_to_ground 0.620552 0.633239   0.012686  0.000161
#    cross_to_claw 0.658440 0.666271   0.007831  0.000061
#   cross_to_cross 0.793547 0.806300   0.012753  0.000163
#     claw_to_claw 0.640584 0.652946   0.012362  0.000153
# ground_to_ground 0.755254 0.767516   0.012261  0.000150
#
# — Sample 47 — Inputs: design_options.connection_pads.readout.claw_length=0.272727, design_options.connection_pads.readout.ground_spacing=1, design_options.cross_length=0.757576
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.710157 0.709713   0.000443 1.965185e-07
#   claw_to_ground 0.287530 0.287316   0.000214 4.596856e-08
#    cross_to_claw 0.158300 0.159096   0.000797 6.345707e-07
#   cross_to_cross 0.710157 0.709439   0.000718 5.151275e-07
#     claw_to_claw 0.279898 0.279604   0.000294 8.657571e-08
# ground_to_ground 0.573021 0.573001   0.000020 3.955932e-10
#
# — Sample 48 — Inputs: design_options.connection_pads.readout.claw_length=0.424242, design_options.connection_pads.readout.ground_spacing=0.152542, design_options.cross_length=0.424242
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.388436 0.388020   0.000416 1.733943e-07
#   claw_to_ground 0.415531 0.411514   0.004017 1.613674e-05
#    cross_to_claw 0.470388 0.468862   0.001525 2.327064e-06
#   cross_to_cross 0.388436 0.388040   0.000396 1.569748e-07
#     claw_to_claw 0.431202 0.426953   0.004250 1.805948e-05
# ground_to_ground 0.408667 0.406435   0.002231 4.979259e-06
#
# — Sample 49 — Inputs: design_options.connection_pads.readout.claw_length=0.363636, design_options.connection_pads.readout.ground_spacing=0, design_options.cross_length=0.636364
#            param      ref     pred  abs_error     sq_error
#  cross_to_ground 0.576431 0.576976   0.000545 2.968163e-07
#   claw_to_ground 0.324808 0.326104   0.001296 1.679609e-06
#    cross_to_claw 0.360080 0.359674   0.000406 1.644760e-07
#   cross_to_cross 0.576431 0.576910   0.000479 2.293316e-07
#     claw_to_claw 0.335047 0.336036   0.000989 9.779059e-07
# ground_to_ground 0.500103 0.500531   0.000427 1.825642e-07
#
# Global scaled error stats:
#   min abs_error: 5.447734779950864e-07
#   median abs_error: 0.0007449496308921943
#   max abs_error: 0.022561502404896627

# %% [markdown]
# # Unscaled

# %%
# Unscale everything and look at errors in real units that we can actually understand

# Load output capacitance column names
with open('X_names', 'r') as f:
    cap_names = f.read().splitlines()  

qiskit_names = np.load('y_columns.npy', allow_pickle=True).astype(str).tolist()  # our inputs

# Unscale inputs
X_test_unscaled = np.asarray(X_test_cur.copy())
for i in range(X_test_unscaled.shape[0]):
    for j in range(X_test_unscaled.shape[1]):
        param_name = qiskit_names[j] if j < len(qiskit_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_y_linear_{param_name}.save')
        X_test_unscaled[i, j] = scaler.inverse_transform([[X_test_unscaled[i, j]]])[0][0]

# Unscale outputs 
y_test_unscaled = np.asarray(y_test_cur.copy())
for i in range(y_test_unscaled.shape[0]):
    for j in range(y_test_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_test_unscaled[i, j] = scaler.inverse_transform([[y_test_unscaled[i, j]]])[0][0]

# Unscale predictions using same X scalers
y_pred_unscaled = np.asarray(y_pred.copy())
for i in range(y_pred_unscaled.shape[0]):
    for j in range(y_pred_unscaled.shape[1]):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        scaler = joblib.load(f'scalers/scaler_X_linear_{cap_name}.save')
        y_pred_unscaled[i, j] = scaler.inverse_transform([[y_pred_unscaled[i, j]]])[0][0]

n_samples, n_params = y_test_unscaled.shape

# Errrs
sq_errors_unscaled  = (y_test_unscaled - y_pred_unscaled) ** 2
abs_errors_unscaled = np.abs(y_test_unscaled - y_pred_unscaled)

# Build dataframe
rows_unscaled = []
for i in range(N_SAMPLES_TO_SHOW):
    for j in range(n_params):
        cap_name = cap_names[j] if j < len(cap_names) else f'col_{j}'
        rows_unscaled.append({
            'sample_idx': i,
            'param': cap_name,
            'ref_unscaled': y_test_unscaled[i, j],
            'pred_unscaled': y_pred_unscaled[i, j],
            'abs_error_unscaled': abs_errors_unscaled[i, j],
            'sq_error_unscaled': sq_errors_unscaled[i, j],
        })

df_unscaled = pd.DataFrame(rows_unscaled)

# Save
out_csv_unscaled = Path(f'model2_predictions_and_errors_unscaled_{encoding}.csv')
df_unscaled.to_csv(out_csv_unscaled, index=False, float_format='%.6g')
print(f'Saved CSV -> {out_csv_unscaled.resolve()}\n')

# Pretty print per-sample 
for i in range(N_SAMPLES_TO_SHOW):
    sub = df_unscaled[df_unscaled['sample_idx'] == i].copy()
    sub = sub[['param', 'ref_unscaled', 'pred_unscaled', 'abs_error_unscaled', 'sq_error_unscaled']]
    input_str = ', '.join(
        f'{qiskit_names[k] if k < len(qiskit_names) else f"col_{k}"}={X_test_unscaled[i,k]:.6g}'
        for k in range(X_test_unscaled.shape[1])
    )
    print(f'— Sample {i} (Unscaled) — Inputs: {input_str}')
    print(sub.to_string(index=False))
    print()

print('Global unscaled error stats:')
print('  min abs_error:', float(abs_errors_unscaled.min()))
print('  median abs_error:', float(np.median(abs_errors_unscaled)))
print('  max abs_error:', float(abs_errors_unscaled.max()))
# Out:
# Saved CSV -> /home/olivias/ML_qubit_design/model_predict_qubit_TransmonCross_cap_matrix/model2_predictions_and_errors_unscaled_model2_surrogate.csv
#
# — Sample 0 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00018, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00026
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     133.51715     133.686264            0.169114           0.028600
#   claw_to_ground      96.70298      96.886055            0.183075           0.033516
#    cross_to_claw       5.98705       5.935884            0.051166           0.002618
#   cross_to_cross     133.51715     133.664703            0.147553           0.021772
#     claw_to_claw     103.12264     103.308655            0.186015           0.034602
# ground_to_ground     287.80599     287.783875            0.022115           0.000489
#
# — Sample 1 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0001, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00029
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     148.82923     148.950577            0.121347           0.014725
#   claw_to_ground      69.91185      69.978134            0.066284           0.004394
#    cross_to_claw       2.28210       2.292159            0.010059           0.000101
#   cross_to_cross     148.82923     148.972733            0.143503           0.020593
#     claw_to_claw      72.52964      72.587883            0.058243           0.003392
# ground_to_ground     278.84301     279.220551            0.377541           0.142537
#
# — Sample 2 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00011, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00018
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground      87.35435      87.449127            0.094777           0.008983
#   claw_to_ground      68.82915      68.908684            0.079534           0.006326
#    cross_to_claw       3.77328       3.758104            0.015176           0.000230
#   cross_to_cross      87.35435      87.466476            0.112126           0.012572
#     claw_to_claw      73.03445      73.118271            0.083821           0.007026
# ground_to_ground     205.78769     205.902039            0.114349           0.013076
#
# — Sample 3 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00013, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00021
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     107.07535     106.906944            0.168406           0.028360
#   claw_to_ground      79.24633      79.280655            0.034325           0.001178
#    cross_to_claw       4.29602       4.318469            0.022449           0.000504
#   cross_to_cross     107.07535     106.928413            0.146937           0.021590
#     claw_to_claw      84.00537      84.021851            0.016481           0.000272
# ground_to_ground     238.77069     238.712067            0.058623           0.003437
#
# — Sample 4 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=9e-05, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00016
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground
(Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00015, design_options.connection_pads.readout.ground_spacing=9.1e-06, design_options.cross_length=0.0002
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     101.58489     101.746246            0.161356           0.026036
#   claw_to_ground      89.39401      89.570183            0.176173           0.031037
#    cross_to_claw       4.10747       4.143334            0.035864           0.001286
#   cross_to_cross     101.58489     101.753494            0.168604           0.028427
#     claw_to_claw      94.01724      94.168037            0.150797           0.022740
# ground_to_ground     242.67125     243.014694            0.343444           0.117954
#
# — Sample 46 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.0003, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.00038
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     190.85907     193.197220            2.338150           5.466945
#   claw_to_ground     132.60867     134.191986            1.583316           2.506890
#    cross_to_claw      10.25834      10.361334            0.102994           0.010608
#   cross_to_cross     190.85907     193.242569            2.383499           5.681067
#     claw_to_claw     143.42262     145.077957            1.655337           2.740141
# ground_to_ground     391.38400     395.447845            4.063845          16.514840
#
# — Sample 47 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00016, design_options.connection_pads.readout.ground_spacing=1e-05, design_options.cross_length=0.00034
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     175.27419     175.191345            0.082845           0.006863
#   claw_to_ground      91.04597      91.019211            0.026759           0.000716
#    cross_to_claw       3.68023       3.690707            0.010477           0.000110
#   cross_to_cross     175.27419     175.140060            0.134130           0.017991
#     claw_to_claw      95.12638      95.086983            0.039397           0.001552
# ground_to_ground     330.98552     330.978943            0.006577           0.000043
#
# — Sample 48 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00021, design_options.connection_pads.readout.ground_spacing=5e-06, design_options.cross_length=0.00023
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     115.14761     115.069786            0.077824           0.006057
#   claw_to_ground     107.02111     106.519760            0.501350           0.251352
#    cross_to_claw       7.78498       7.764916            0.020064           0.000403
#   cross_to_cross     115.14761     115.073563            0.074047           0.005483
#     claw_to_claw     115.38621     114.817177            0.569033           0.323799
# ground_to_ground     276.51308     275.773499            0.739581           0.546981
#
# — Sample 49 (Unscaled) — Inputs: design_options.connection_pads.readout.claw_length=0.00019, design_options.connection_pads.readout.ground_spacing=4.1e-06, design_options.cross_length=0.0003
#            param  ref_unscaled  pred_unscaled  abs_error_unscaled  sq_error_unscaled
#  cross_to_ground     150.28208     150.383896            0.101816           0.010366
#   claw_to_ground      95.69848      95.860229            0.161749           0.026163
#    cross_to_claw       6.33415       6.328816            0.005334           0.000028
#   cross_to_cross     150.28208     150.371582            0.089502           0.008011
#     claw_to_claw     102.51089     102.643303            0.132413           0.017533
# ground_to_ground     306.81832     306.959930            0.141610           0.020054
#
# Global unscaled error stats:
#   min abs_error: 4.816299438470395e-05
#   median abs_error: 0.08901343383788429
#   max abs_error: 5.736533076171838

# %% [markdown]
# ## Visualize Results

# %% [markdown]
# Lets see how good we actually did

# %%
# find percentage difference like 100 * abs(pred - re) / abs(ref), with tiny epsilon to avoid division by zero
eps = 1e-15
pct_errors_unscaled = 100.0 * np.abs(y_pred_unscaled - y_test_unscaled) / (np.abs(y_test_unscaled) + eps)

short_names = [c.split('.')[-1] if '.' in c else c for c in cap_names[:n_params]]
data_per_col = [pct_errors_unscaled[:, j] for j in range(n_params)]
all_pct = pct_errors_unscaled.ravel()

# %%
# box plot showing % error distribution per capacitance output 
fig, ax = plt.subplots(figsize=(12, 5))
bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,
                flierprops=dict(marker='o', markersize=3, alpha=0.4, markerfacecolor='grey'))
for patch in bp['boxes']:
    patch.set_facecolor('steelblue')
    patch.set_alpha(0.7)
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Percentage Error Distribution per Output')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_boxplot.pdf')
plt.show()
# Out:
# /tmp/ipykernel_2178590/2286795443.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_per_col, labels=short_names, patch_artist=True, showfliers=True,

# %%
# histogram it too
n_cols_grid = 3
n_rows_grid = math.ceil(n_params / n_cols_grid)

fig, axes = plt.subplots(n_rows_grid, n_cols_grid, figsize=(5 * n_cols_grid, 4 * n_rows_grid))
axes = axes.ravel()

for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    ax = axes[j]
    ax.hist(col_pct, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
    ax.axvline(np.median(col_pct), color='red', linestyle='--',
               label=f'Median: {np.median(col_pct):.2f}%')
    ax.axvline(np.mean(col_pct), color='orange', linestyle='--',
               label=f'Mean: {np.mean(col_pct):.2f}%')
    ax.set_title(short_names[j], fontsize=10)
    ax.set_xlabel('% Error')
    ax.set_ylabel('Count')
    ax.legend(fontsize=7)

# hide unused subplots
for k in range(n_params, len(axes)):
    fig.delaxes(axes[k])

fig.suptitle('Model 2: Percentage Error Histograms per Output', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('plots/model2_pct_error_histograms_per_output.pdf')
plt.show()

# %%
#look at the stats nicely
print(f"{'Output':<25s} {'Median %':>10s} {'Mean %':>10s} {'90th %':>10s} {'Max %':>10s}")
print('-' * 70)
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    name = short_names[j]
    print(f"{name:<25s} {np.median(col_pct):10.2f} {np.mean(col_pct):10.2f} "
          f"{np.percentile(col_pct, 90):10.2f} {np.max(col_pct):10.2f}")
print('-' * 70)
print(f"{'All outputs':<25s} {np.median(all_pct):10.2f} {np.mean(all_pct):10.2f} "
      f"{np.percentile(all_pct, 90):10.2f} {np.max(all_pct):10.2f}")
# Out:
# Output                      Median %     Mean %     90th %      Max %
# ----------------------------------------------------------------------
# cross_to_ground                 0.09       0.22       0.42       2.03
# claw_to_ground                  0.09       0.24       0.60       2.99
# cross_to_claw                   0.32       0.52       1.29       4.51
# cross_to_cross                  0.09       0.21       0.41       2.04
# claw_to_claw                    0.09       0.23       0.57       2.94
# ground_to_ground                0.08       0.17       0.40       1.58
# ----------------------------------------------------------------------
# All outputs                     0.10       0.26       0.69       4.51

# %%
# scatter plot with fancy visulaization of points using this grouping thing

fig, ax = plt.subplots(figsize=(12, 6))
for j in range(n_params):
    col_pct = pct_errors_unscaled[:, j]
    x = np.full_like(col_pct, j) + np.random.uniform(-0.2, 0.2, size=len(col_pct))
    ax.scatter(x, col_pct, alpha=0.4, s=12, label=short_names[j])
ax.set_xticks(range(n_params))
ax.set_xticklabels(short_names, rotation=45, ha='right')
ax.set_ylabel('Percentage Error (%)')
ax.set_xlabel('Capacitance Output')
ax.set_title('Model 2: Per-Sample Percentage Error by Capacitance Output')
plt.tight_layout()
plt.savefig('plots/model2_pct_error_scatter.pdf')
plt.show()
